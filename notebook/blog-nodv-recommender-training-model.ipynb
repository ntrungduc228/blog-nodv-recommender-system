# %%
import requests
from time import sleep

from tqdm import tqdm
import pymongo
from pymongo import MongoClient

# %%
import logging
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO

# %%
import sys
sys.path.append('../')
from src.settings import MONGODB_SETTINGS

# %%
client = MongoClient(MONGODB_SETTINGS['host'])
db = client[MONGODB_SETTINGS['db']]
col = db[MONGODB_SETTINGS['collection']]

# %%
posts = col.find()

# %%
for i, post in enumerate(posts):
    print(post['title'])
    if i == 12: break
# Out:
# ĐỒ ÁN THIẾT KẾ WEBSITE BLOG SITE
# setState trong React
# Regular Expression trong Javascript
# Các bài tập java cơ bản
# Những câu hỏi lập trình khi pv (2): bài toán ATM
# Ví dụ sắp xếp nổi bọt với Java
# Chương trình lọc thư rác bằng Java, code ví dụ
# Đọc ghi file Excel trong Java sử dụng Apache POI
# THREAD AND THREAD POOLS IN JAVA
# Sử dụng CountDownLatch trong Java
# Multithreading: Java Synchronized Blocks
# Understand synchronized and improve lock performance in Java
# Front-End Web Developers

# %%
from src.utils import editorJs_data_to_text
import json

# %%
posts = col.find()
test_post = next(posts)

# %%
raw_content = test_post['content']
content = editorJs_data_to_text(json.loads(raw_content))

# %%
print(content)
# Out:
# đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đí ...

# %%
for i, post in tqdm(enumerate(col.find()), total=col.count_documents({})):
    try:
        col.update_one({"_id": post["_id"]}, {"$set": {"idrs": i}})
        pp_content = editorJs_data_to_text(json.loads(post['content']))
        col.update_one({"_id": post["_id"]}, {"$set": {"pp_content": pp_content}})
    except Exception as e:
        print(e)
        continue
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 78/78 [00:20<00:00,  3.81it/s]

# %%
client = MongoClient(MONGODB_SETTINGS['host'])
db = client[MONGODB_SETTINGS['db']]
col = db[MONGODB_SETTINGS['collection']]

posts = col.find()
test_post = next(posts)

# %%
test_post['pp_content']
# Out:
# 'đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đ ...

# %%
def make_sentences():
    for post in col.find():
        yield post['pp_content'] # lấy thuộc tính pp_content của từng document trong post collection

# %%
def make_texts_corpus(sentences):
    for sentence in sentences:
        yield simple_preprocess(sentence, deacc=True) # tách chữ cái của từng pp_content
#         yield [word for word in sentence.split()]

# %%
import itertools

import gensim
from gensim.utils import simple_preprocess

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)
id2word = gensim.corpora.Dictionary(sentences)
# Out:
# INFO : adding document #0 to Dictionary<0 unique tokens: []>
# INFO : built Dictionary<5072 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 78 documents (total 37890 corpus positions)
# INFO : Dictionary lifecycle event {'msg': "built Dictionary<5072 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 78 documents (total 37890 corpus positions)", 'datetime': '2022-12-20T10:15:03.722152', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
id2word.token2id
# Out:
# {'account': 0,
#  'actor': 1,
#  'allocation': 2,
#  'amazon': 3,
#  'an': 4,
#  'analysis': 5,
#  'anh': 6,
#  'anhđuong': 7,
#  'ap_đat': 8,
#  'api': 9,
#  'application': 10,
#  'avatar': 11,
#  'axios': 12,
#  'bai': 13,
#  'bai_bo': 14,
#  'bai_toan': 15,
#  'ban_be': 16,
#  'ban_cai': 17,
#  'ban_chat': 18,
#  'banfacebook': 19,
#  'bang': 20,
#  'bannetflix': 21,
#  'banxoa': 22,
#  'bao_cao': 23,
#  'bao_gom': 24,
#  'bao_mat': 25,
#  'bao_phu': 26,
#  'bao_ve': 27,
#  'baoluu': 28,
#  'bat_kha_thi': 29,
#  'bayes': 30,
#  'bayesian': 31,
#  'bebo': 32,
#  'bia': 33,
#  'bich': 34,
#  'bien': 35,
#  'bien_tap': 36,
#  'bien_đoi': 37,
#  'bieu_dien': 38,
#  'bieu_thi': 39,
#  'bieu_tuong': 40,
#  'big': 41,
#  'binh': 42,
#  'binh_luan': 43,
#  'bio': 44,
#  'biopost': 45,
#  'blog': 46,
#  'blogger': 47,
#  'bo_nho': 48,
#  'bookmark': 49,
#  'boolean': 50,
#  'boot': 51,
#  'bought': 52,
#  'bung_no': 53,
#  'business': 54,
#  'ca_si': 55,
#  'cai_thien': 56,
#  'cai_tien': 57,
#  'can_thiet': 58,
#  'canh': 59,
#  'canh_sat': 60,
#  'cap': 61,
#  'cap_đo': 62,
#  'cascading': 63,
#  'case': 64,
#  'cau': 65,
#  'cau_hinh': 66,
#  'cau_truc': 67,
#  'cauxoa': 68,
#  'cham': 69,
#  'chan': 70,
#  'chat_luong': 71,
#  'chay': 72,
#  'che_đo': 73,
#  'chi_thuc_su': 74,
#  'chi_tiet': 75,
#  'chia': 76,
#  'chien_luoc': 77,
#  'chien_thuat': 78,
#  'chinh_sua': 79,
#  'chinh_xac': 80,
#  'chinhlam': 81,
#  'chong': 82,
#  'chu_bai': 83,
#  'chu_quan': 84,
#  'chu_đe': 85,
#  'chua': 86,
#  'chuan_hoa': 87,
#  'chuc_nang': 88,
#  'chung_khoan': 89,
#  'chung_minh': 90,
#  'chuoi': 91,
#  'chuong': 92,
#  'chuong_trinh': 93,
#  'chuyen_biet': 94,
#  'chuyen_hoa': 95,
#  'chuyen_huong': 96,
#  'chuyen_tiep': 97,
#  'chuyen_đoi': 98,
#  'classification': 99,
#  'click': 100,
#  'client': 101,
#  'clip': 102,
#  'cloud': 103,
#  'co_ban': 104,
#  'co_le': 105,
#  'co_phieu': 106,
#  'co_so': 107,
#  'co_đinh': 108,
#  'code': 109,
#  'codebase': 110,
#  'coi': 111,
#  'collaborative': 112,
#  'collection': 113,
#  'comment': 114,
#  'compass': 115,
#  'component': 116,
#  'con_nguoi': 117,
#  'cong_cu': 118,
#  'cong_khai': 119,
#  'cong_nghe': 120,
#  'cong_ty': 121,
#  'cong_viec': 122,
#  'congthat': 123,
#  'content': 124,
#  'contentbased': 125,
#  'corpora': 126,
#  'corpus': 127,
#  'corpuslevel': 128,
#  'createddate': 129,
#  'csdl': 130,
#  'css': 131,
#  'cung_cap': 132,
#  'cuoc_song': 133,
#  'dan': 134,
#  'dang': 135,
#  'danh_sach': 136,
#  'danvoi': 137,
#  'data': 138,
#  'dataset': 139,
#  'ddd': 140,
#  'de_dang': 141,
#  'debug': 142,
#  'degree': 143,
#  'dependency': 144,
#  'di_đong': 145,
#  'diagram': 146,
#  'dich_vu': 147,
#  'dirichlet': 148,
#  'discriminant': 149,
#  'dm': 150,
#  'doanh': 151,
#  'doanh_nghiep': 152,
#  'doanh_thu': 153,
#  'document': 154,
#  'documentlevel': 155,
#  'doi': 156,
#  'doitim': 157,
#  'doiviet': 158,
#  'du_an': 159,
#  'du_bao': 160,
#  'du_lieu': 161,
#  'du_đoan': 162,
#  'dua': 163,
#  'dung': 164,
#  'duy_tri': 165,
#  'editor': 166,
#  'email': 167,
#  'facebook': 168,
#  'false': 169,
#  'file': 170,
#  'filtering': 171,
#  'follow': 172,
#  'followers': 173,
#  'following': 174,
#  'followings': 175,
#  'follwers': 176,
#  'framework': 177,
#  'frequently': 178,
#  'gan': 179,
#  'gender': 180,
#  'ghi_chu': 181,
#  'gia': 182,
#  'gia_đinh': 183,
#  'giai_phap': 184,
#  'giai_thuong': 185,
#  'giai_đap': 186,
#  'giam_sat': 187,
#  'giao_dien': 188,
#  'giao_luu': 189,
#  'gibbs': 190,
#  'gioi_thieu': 191,
#  'gioi_tinh': 192,
#  'git': 193,
#  'github': 194,
#  'giup': 195,
#  'go': 196,
#  'go_loi': 197,
#  'goi': 198,
#  'goi_y': 199,
#  'google': 200,
#  'gop_y': 201,
#  'groovy': 202,
#  'gui': 203,
#  'hai': 204,
#  'han_che': 205,
#  'hang': 206,
#  'hanh_vi': 207,
#  'hanh_đong': 208,
#  'hat': 209,
#  'he': 210,
#  'he_thong': 211,
#  'hien': 212,
#  'hien_thi': 213,
#  'hien_tuong': 214,
#  'hien_đai': 215,
#  'hierarchical': 216,
#  'hieu_nang': 217,
#  'hieu_qua': 218,
#  'hieu_suat': 219,
#  'highlighting': 220,
#  'hinh': 221,
#  'hinh_anh': 222,
#  'hinh_su': 223,
#  'hinh_thuc': 224,
#  'hoa': 225,
#  'hoan_chinh': 226,
#  'hoan_thanh': 227,
#  'hoan_thien': 228,
#  'hoat_đong': 229,
#  'hoc': 230,
#  'hoc_hoi': 231,
#  'hon_hop': 232,
#  'hontu': 233,
#  'html': 234,
#  'htmlvi': 235,
#  'http': 236,
#  'huan_luyen': 237,
#  'hung': 238,
#  'hung_thu': 239,
#  'huong': 240,
#  'huongxu': 241,
#  'huu_dung': 242,
#  'huu_han': 243,
#  'huu_ich': 244,
#  'huy': 245,
#  'hypertext': 246,
#  'id': 247,
#  'idea': 248,
#  'index': 249,
#  'intellij': 250,
#  'internet': 251,
#  'isactive': 252,
#  'ispublish': 253,
#  'isread': 254,
#  'it': 255,
#  'item': 256,
#  'items': 257,
#  'java': 258,
#  'javascript': 259,
#  'jetbrains': 260,
#  'jetty': 261,
#  'join': 262,
#  'joomla': 263,
#  'js': 264,
#  'json': 265,
#  'kem': 266,
#  'kenh': 267,
#  'ket': 268,
#  'ket_ban': 269,
#  'ket_noi': 270,
#  'ket_qua': 271,
#  'key': 272,
#  'kha_nang': 273,
#  'khach_hang': 274,
#  'khap': 275,
#  'kho': 276,
#  'khoa': 277,
#  'khoanbai': 278,
#  'khoi': 279,
#  'khong_gian': 280,
#  'khuon_kho': 281,
#  'khuyen_nghi': 282,
#  'kich_co': 283,
#  'kiem': 284,
#  'kiem_tra': 285,
#  'kiemcac': 286,
#  'kiemfacebook': 287,
#  'kien_thuc': 288,
#  'kien_truc': 289,
#  'kieu': 290,
#  'kinh': 291,
#  'kinh_doanh': 292,
#  'kinh_lup': 293,
#  'kinh_te': 294,
#  'ky': 295,
#  'ky_thuat': 296,
#  'ky_tu': 297,
#  'lam_viec': 298,
#  'lan': 299,
#  'language': 300,
#  'lap': 301,
#  'lap_debug': 302,
#  'lap_trinh': 303,
#  'lap_trinh_vien': 304,
#  'lapnhung': 305,
#  'latent': 306,
#  'lda': 307,
#  'learning': 308,
#  'len_loi': 309,
#  'level': 310,
#  'lich_su': 311,
#  'lien': 312,
#  'lien_tuc': 313,
#  'lieu': 314,
#  'lieuhinh': 315,
#  'likes': 316,
#  'linear': 317,
#  'linh_hoat': 318,
#  'linh_vuc': 319,
#  'link': 320,
#  'linux': 321,
#  'lo_ngai': 322,
#  'loat': 323,
#  'loi': 324,
#  'loi_ich': 325,
#  'loi_nhuan': 326,
#  'loi_the': 327,
#  'lsa': 328,
#  'lua_chon': 329,
#  'luong': 330,
#  'luot': 331,
#  'luu': 332,
#  'luu_giu': 333,
#  'luu_tru': 334,
#  'ly': 335,
#  'ly_thuyet': 336,
#  'lyket': 337,
#  'ma': 338,
#  'mac_đinh': 339,
#  'mach': 340,
#  'machine': 341,
#  'macos': 342,
#  'mai': 343,
#  'make': 344,
#  'mang': 345,
#  'manh_me': 346,
#  'marketing': 347,
#  'markup': 348,
#  'mat_khau': 349,
#  'matheo': 350,
#  'matkhi': 351,
#  'mau': 352,
#  'maven': 353,
#  'may': 354,
#  'may_tinh': 355,
#  'medium': 356,
#  'menu': 357,
#  'mien': 358,
#  'mieu_ta': 359,
#  'minh_hoa': 360,
#  'ml': 361,
#  'mo_hinh': 362,
#  'mo_hinh_hoa': 363,
#  'mo_rong': 364,
#  'mo_ta': 365,
#  'modal': 366,
#  'model': 367,
#  'modeling': 368,
#  'module': 369,
#  'mon': 370,
#  'mong': 371,
#  'mong_muon': 372,
#  'mongodatabase': 373,
#  'mongodb': 374,
#  'mua': 375,
#  'muc': 376,
#  'muc_tu': 377,
#  'muc_đich': 378,
#  'muc_đo': 379,
#  'muot_ma': 380,
#  'nam': 381,
#  'nam_bat': 382,
#  'nang': 383,
#  'nang_suat': 384,
#  'native': 385,
#  'nen_tang': 386,
#  'neu': 387,
#  'ngan': 388,
#  'ngay_nay': 389,
#  'nghia_la': 390,
#  'nghiem': 391,
#  'nghien_cuu': 392,
#  'nghiep_vu': 393,
#  'nghiepho': 394,
#  'ngoai_tru': 395,
#  'ngon_ngu': 396,
#  'nguoi': 397,
#  'nhan': 398,
#  'nhan_loai': 399,
#  'nhan_tao': 400,
#  'nhanh_chong': 401,
#  'nhap': 402,
#  'nhap_noi_dung': 403,
#  'nhapchinh': 404,
#  'nhat_ky': 405,
#  'nhatđuoc': 406,
#  'nhiem_vu': 407,
#  'nhu': 408,
#  'nhu_cau': 409,
#  'nickname': 410,
#  'nodejs': 411,
#  'nodv': 412,
#  'noi_bat': 413,
#  'noi_dung': 414,
#  'noi_tai': 415,
#  'noi_tieng': 416,
#  'noo': 417,
#  'notat': 418,
#  'nu': 419,
#  'nut': 420,
#  'oauth': 421,
#  'object': 422,
#  'objectid': 423,
#  'observe': 424,
#  'of': 425,
#  'on': 426,
#  'online': 427,
#  'page': 428,
#  'parameter': 429,
#  'password': 430,
#  'pha_tron': 431,
#  'pham_vi': 432,
#  'phan_biet': 433,
#  'phan_bo': 434,
#  'phan_hoi': 435,
#  'phan_loai': 436,
#  'phan_mem': 437,
#  'phan_phoi': 438,
#  'phan_ra': 439,
#  'phan_tich': 440,
#  'phan_xu': 441,
#  'phat_trien': 442,
#  'phep': 443,
#  'phien_ban': 444,
#  'phim': 445,
#  'pho_bien': 446,
#  'phong_cach': 447,
#  'phong_phu': 448,
#  'phuc': 449,
#  'phuc_tap': 450,
#  'phuc_vu': 451,
#  'phuoc': 452,
#  'phuong': 453,
#  'phuong_phap': 454,
#  'plsa': 455,
#  'post': 456,
#  'postid': 457,
#  'preference': 458,
#  'prior': 459,
#  'project': 460,
#  'provider': 461,
#  'providerid': 462,
#  'publish': 463,
#  'python': 464,
#  'qua_khu': 465,
#  'quan_he': 466,
#  'quan_ly': 467,
#  'quang_cao': 468,
#  'quen_thuoc': 469,
#  'quy_mo': 470,
#  'quy_đinh': 471,
#  'quyen': 472,
#  'quyet_đinh': 473,
#  'ra_mat': 474,
#  'ra_đoi': 475,
#  'rangkhong': 476,
#  'react': 477,
#  'reactjs': 478,
#  'receiverid': 479,
#  'recommend': 480,
#  'recommendation': 481,
#  'recommended': 482,
#  'recommender': 483,
#  'refactorings': 484,
#  'replyid': 485,
#  'request': 486,
#  'response': 487,
#  'roi_rac': 488,
#  'role': 489,
#  'rong': 490,
#  'rong_rai': 491,
#  'rongviec': 492,
#  'ruby': 493,
#  'rut': 494,
#  'sach': 495,
#  'sai_lech': 496,
#  'sampling': 497,
#  'san': 498,
#  'san_pham': 499,
#  'san_sang': 500,
#  'sang_tao': 501,
#  'sap_xep': 502,
#  'sau': 503,
#  'scalatu': 504,
#  'schema': 505,
#  'senderid': 506,
#  'server': 507,
#  'setting': 508,
#  'share': 509,
#  'sheets': 510,
#  'sidebar': 511,
#  'similarity': 512,
#  'simple': 513,
#  'single': 514,
#  'sinh': 515,
#  'sinh_thai': 516,
#  'site': 517,
#  'snippets': 518,
#  'so_luong': 519,
#  'so_thich': 520,
#  'so_đo': 521,
#  'soan_thao': 522,
#  'song': 523,
#  'spa': 524,
#  'sparse': 525,
#  'spring': 526,
#  'sql': 527,
#  'starter': 528,
#  'string': 529,
#  'stt': 530,
#  'studio': 531,
#  'style': 532,
#  'sua': 533,
#  'subtitle': 534,
#  'supervised': 535,
#  'suy_dien': 536,
#  'suy_luan': 537,
#  'syntax': 538,
#  'system': 539,
#  'systems': 540,
#  'ta': 541,
#  'tab': 542,
#  'tac': 543,
#  'tac_gia': 544,
#  'tai': 545,
#  'tai_cau_truc': 546,
#  'tai_khoan': 547,
#  'tai_lieu': 548,
#  'tam': 549,
#  'tang_toc': 550,
#  'tang_truong': 551,
#  'tap': 552,
#  'tap_hop': 553,
#  'tapnoi': 554,
#  'tat': 555,
#  'teamcity': 556,
#  'text': 557,
#  'thac_mac': 558,
#  'tham_so': 559,
#  'than_thien': 560,
#  'thanh': 561,
#  'thanh_cong': 562,
#  'thanh_phan': 563,
#  'thao_tac': 564,
#  'that_bai': 565,
#  'thay': 566,
#  'the_gioi': 567,
#  'the_hien': 568,
#  'the_ky': 569,
#  'theo_doi': 570,
#  'theta': 571,
#  'thichkhi': 572,
#  'thiet_bi': 573,
#  'thiet_ke': 574,
#  'thietkhong': 575,
#  'thietsu_dung': 576,
#  'thieu_sot': 577,
#  'thinh': 578,
#  'thoa_man': 579,
#  'thoa_suc': 580,
#  'thoai_mai': 581,
#  'thoi': 582,
#  'thoi_đai': 583,
#  'thong': 584,
#  'thong_bao': 585,
#  'thong_minh': 586,
#  'thong_qua': 587,
#  'thong_thuong': 588,
#  'thong_tin': 589,
#  'threelevel': 590,
#  'thu_thap': 591,
#  'thu_vien': 592,
#  'thua': 593,
#  'thuan_tien': 594,
#  'thuat_toan': 595,
#  'thuat_toan_hoc': 596,
#  'thuc': 597,
#  'thuc_hien_tai': 598,
#  'thuc_the': 599,
#  'thumbnail': 600,
#  'thuong': 601,
#  'thuong_mai': 602,
#  'thuongcho': 603,
#  'thutheo': 604,
#  'tich_hop': 605,
#  'tiem_nang': 606,
#  'tien_ich': 607,
#  'tien_tien': 608,
#  'tien_trinh': 609,
#  'tieng': 610,
#  'tiep_can': 611,
#  'tiep_thi': 612,
#  'tieu_đe': 613,
#  'tieu_đe_bai': 614,
#  'tim_kiem': 615,
#  'timeread': 616,
#  'tin_hieu': 617,
#  'tin_nhiem': 618,
#  'tin_tuc': 619,
#  'tinh_nang': 620,
#  'tinh_toan': 621,
#  'title': 622,
#  'toan': 623,
#  'toan_bo': 624,
#  'toan_cau': 625,
#  'toan_the': 626,
#  'together': 627,
#  'toi_gian': 628,
#  'toi_uu_hoa': 629,
#  'tomcat': 630,
#  'tong_quan': 631,
#  'tong_quat': 632,
#  'tong_thetao': 633,
#  'topic': 634,
#  'topics': 635,
#  'tra_loi': 636,
#  'trai': 637,
#  'trai_đat': 638,
#  'tran': 639,
#  'trang': 640,
#  'trang_chu': 641,
#  'trang_thai': 642,
#  'trang_web': 643,
#  'trao_đoi': 644,
#  'tren': 645,
#  'trenđang': 646,
#  'tri_tue': 647,
#  'trien_khai': 648,
#  'trinh': 649,
#  'trinh_bay': 650,
#  'trinh_duyet': 651,
#  'tro': 652,
#  'tro_nen': 653,
#  'tron': 654,
#  'trong': 655,
#  'truc_tuyen': 656,
#  'true': 657,
#  'trung': 658,
#  'truong': 659,
#  'truy': 660,
#  'truy_cap': 661,
#  'tu_khoa': 662,
#  'tu_vung': 663,
#  'tu_đien': 664,
#  'tu_đong': 665,
#  'tuan': 666,
#  'tuc': 667,
#  'tuc_la': 668,
#  'tuoi_đoi': 669,
#  'tuong_lai': 670,
#  'tuong_quan': 671,
#  'tuong_thich': 672,
#  'tuong_tu': 673,
#  'tuong_ung': 674,
#  'tuong_đong': 675,
#  'tuy': 676,
#  'tv': 677,
#  'type': 678,
#  'ui': 679,
#  'undertow': 680,
#  'ung': 681,
#  'ung_dung': 682,
#  'universal': 683,
#  'unsupervised': 684,
#  'uoc_luong': 685,
#  'use': 686,
#  'usecase': 687,
#  'user': 688,
#  'userid': 689,
#  'useritem': 690,
#  'userlikeids': 691,
#  'username': 692,
#  'users': 693,
#  'userxoa': 694,
#  'uu_điem': 695,
#  'vahoac': 696,
#  'vai_tro': 697,
#  'van': 698,
#  'van_ban': 699,
#  'van_dung': 700,
#  'van_hanh': 701,
#  'variable': 702,
#  'vi_du': 703,
#  'viet': 704,
#  'vietblog': 705,
#  'vietxem': 706,
#  'visual': 707,
#  'vo_cung': 708,
#  'vong': 709,
#  'vs': 710,
#  'vu': 711,
#  'vuong': 712,
#  'vuot_bac': 713,
#  'war': 714,
#  'web': 715,
#  'website': 716,
#  'websocket': 717,
#  'wi': 718,
#  'wide_web': 719,
#  'windows': 720,
#  'word': 721,
#  'wordpress': 722,
#  'world': 723,
#  'xa': 724,
#  'xa_hoi': 725,
#  'xac_nhan': 726,
#  'xac_suat': 727,
#  'xac_thuc': 728,
#  'xac_đinh': 729,
#  'xay_dung': 730,
#  'xem_xet': 731,
#  'xep_hang': 732,
#  'xmlhttprequest': 733,
#  'xoa': 734,
#  'xoa_bai': 735,
#  'xoa_bookmark': 736,
#  'xoa_hien_thi': 737,
#  'xu': 738,
#  'xu_huong': 739,
#  'y_muon': 740,
#  'y_nghia': 741,
#  'y_tuong': 742,
#  'y_đinh': 743,
#  'yahoo': 744,
#  'youtube': 745,
#  'đa_dang': 746,
#  'đac_nhap': 747,
#  'đac_tinh': 748,
#  'đac_trung': 749,
#  'đac_điem': 750,
#  'đai_dien': 751,
#  'đang': 752,
#  'đang_ky': 753,
#  'đang_nhap': 754,
#  'đangchinh': 755,
#  'đanh': 756,
#  'đanh_dau': 757,
#  'đanh_đau': 758,
#  'đau': 759,
#  'đau_ra': 760,
#  'đau_vao': 761,
#  'đaua': 762,
#  'đay_đu': 763,
#  'đe_cap': 764,
#  'đe_tai': 765,
#  'đe_xuat': 766,
#  'đe_y': 767,
#  'đi': 768,
#  'đi_sau': 769,
#  'đien_tu': 770,
#  'đieu_khien': 771,
#  'đinh_dang': 772,
#  'đinh_hinh': 773,
#  'đinh_nghia': 774,
#  'đo': 775,
#  'đo_an': 776,
#  'đoan': 777,
#  'đoc': 778,
#  'đoc_gia': 779,
#  'đoi_khi': 780,
#  'đoi_song': 781,
#  'đoi_tuong': 782,
#  'đoianh': 783,
#  'đon': 784,
#  'đon_gian': 785,
#  'đon_gian_hoa': 786,
#  'đong': 787,
#  'đong_bo': 788,
#  'đong_nghia': 789,
#  'đong_đao': 790,
#  'đođang': 791,
#  'đuocđong': 792,
#  'đuong': 793,
#  'android': 794,
#  'cap_nhat': 795,
#  'cho_du': 796,
#  'components': 797,
#  'componets': 798,
#  'defining': 799,
#  'dom': 800,
#  'engine': 801,
#  'exports': 802,
#  'extend': 803,
#  'hooks': 804,
#  'implementation': 805,
#  'implemented': 806,
#  'import': 807,
#  'ios': 808,
#  'lives': 809,
#  'logic': 810,
#  'lop': 811,
#  'mac': 812,
#  'moi_truong': 813,
#  'mot_the_hien': 814,
#  'mount': 815,
#  'nguoc_lai': 816,
#  'node': 817,
#  'oke': 818,
#  'or': 819,
#  'package': 820,
#  'phan_tach': 821,
#  'platform': 822,
#  'reactart': 823,
#  'reactchildren': 824,
#  'reactcomponent': 825,
#  'reactdom': 826,
#  'reactdomrender': 827,
#  'reactdomserver': 828,
#  'reactnative': 829,
#  'renderer': 830,
#  'renderers': 831,
#  'rerenders': 832,
#  'return': 833,
#  'sai_lam': 834,
#  'setstate': 835,
#  'state': 836,
#  'target': 837,
#  'thac': 838,
#  'thiet_lap': 839,
#  'thu_vi': 840,
#  'tiec': 841,
#  'ty_du': 842,
#  'updater': 843,
#  'utilities': 844,
#  'uy': 845,
#  've': 846,
#  'view': 847,
#  'xay': 848,
#  'đeu': 849,
#  'đoc_lap': 850,
#  'ap_dung': 851,
#  'bao_toan': 852,
#  'bat_buoc': 853,
#  'bi_an': 854,
#  'bieu_thuc': 855,
#  'bo_qua': 856,
#  'bon': 857,
#  'chang_han': 858,
#  'cheo': 859,
#  'chi_đinh': 860,
#  'chinh_quy': 861,
#  'chon_lua': 862,
#  'chu': 863,
#  'chu_so': 864,
#  'chubat': 865,
#  'co_nghia': 866,
#  'co_nghia_la': 867,
#  'cong': 868,
#  'constructor': 869,
#  'cu_phap': 870,
#  'dai': 871,
#  'dau': 872,
#  'dau_cham_hoi': 873,
#  'dau_cham_than': 874,
#  'dau_hoi': 875,
#  'day': 876,
#  'dien_ta': 877,
#  'dong': 878,
#  'duoimot': 879,
#  'duy_nhat': 880,
#  'expression': 881,
#  'gach': 882,
#  'gach_ngang': 883,
#  'gia_su': 884,
#  'gioi_han': 885,
#  'gom': 886,
#  'hoi': 887,
#  'in': 888,
#  'keo': 889,
#  'ket_thuc': 890,
#  'khop': 891,
#  'kia': 892,
#  'ky_hieu': 893,
#  'lan_luot': 894,
#  'luu_y': 895,
#  'mac_du': 896,
#  'mat_khac': 897,
#  'mot_chut': 898,
#  'mot_so_nguyen': 899,
#  'naomot': 900,
#  'ngan_can': 901,
#  'ngoac': 902,
#  'ngoac_vuong': 903,
#  'ngoac_đon': 904,
#  'ngoac_đon_tinh': 905,
#  'nhon': 906,
#  'nhu_nhieu': 907,
#  'pattern': 908,
#  'phan_tu': 909,
#  'phu': 910,
#  'phuong_thuc': 911,
#  'ranh_gioi': 912,
#  'regexp': 913,
#  'regular': 914,
#  'rieng_biet': 915,
#  'somot': 916,
#  'tatnghiabat': 917,
#  'thay_vi': 918,
#  'thong_dung': 919,
#  'thuc_thi': 920,
#  'thuoc_tinh': 921,
#  'toan_tu': 922,
#  'trangbat': 923,
#  'truyen': 924,
#  'tumot': 925,
#  'tuong': 926,
#  'tuy_chon': 927,
#  'unicode': 928,
#  'vv': 929,
#  'đam_bao_mau': 930,
#  'đao_nguoc': 931,
#  'đep_mat': 932,
#  'đung': 933,
#  'đuong_ong': 934,
#  'and': 935,
#  'array': 936,
#  'arrint': 937,
#  'at': 938,
#  'bai_tap': 939,
#  'ban_phim': 940,
#  'bot': 941,
#  'bounds': 942,
#  'bubble': 943,
#  'cacacyahtp': 944,
#  'cach': 945,
#  'chieu': 946,
#  'chon': 947,
#  'cua': 948,
#  'cung': 949,
#  'dao': 950,
#  'duoc': 951,
#  'exception': 952,
#  'for': 953,
#  'goc': 954,
#  'is': 955,
#  'khac': 956,
#  'kich_thuoc': 957,
#  'la': 958,
#  'lathaycacac': 959,
#  'length': 960,
#  'lua': 961,
#  'main': 962,
#  'max': 963,
#  'min': 964,
#  'mot': 965,
#  'nghich': 966,
#  'nghich_đao': 967,
#  'nguoc': 968,
#  'nhapa': 969,
#  'nhieu': 970,
#  'nhung': 971,
#  'noi': 972,
#  'objects': 973,
#  'original': 974,
#  'out': 975,
#  'so_nguyen': 976,
#  'sort': 977,
#  'sorted': 978,
#  'str': 979,
#  'strmot': 980,
#  'tham_chieu': 981,
#  'thaycacac': 982,
#  'this': 983,
#  'thread': 984,
#  'tien': 985,
#  'tri': 986,
#  'tu': 987,
#  'vi': 988,
#  'vua': 989,
#  'vuot': 990,
#  'xuat': 991,
#  'anh_huong': 992,
#  'atm': 993,
#  'atmbai': 994,
#  'bigdecimal': 995,
#  'chu_vi': 996,
#  'chu_y': 997,
#  'class': 998,
#  'co_che': 999,
#  ...}

# %%
id2word.filter_extremes(no_below=3, no_above=0.5)
id2word.compactify()
id2word.save('../models/id2word.dictionary')
# Out:
# INFO : discarding 3402 tokens: [('account', 2), ('actor', 1), ('allocation', 1), ('amazon', 2), ('analysis', 2), ('anhđuong', 1), ('avatar', 1), ('axios', 1), ('bai_bo', 1), ('ban_cai', 2)]...
# INFO : keeping 1670 tokens which were in no less than 3 and no more than 39 (=50.0%) documents
# INFO : resulting dictionary: Dictionary<1670 unique tokens: ['an', 'anh', 'ap_đat', 'api', 'application']...>
# INFO : Dictionary lifecycle event {'fname_or_handle': '../models/id2word.dictionary', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-12-20T10:15:04.038155', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/id2word.dictionary

# %%
len(id2word)
# Out:
# 1670

# %%
id2word.token2id
# Out:
# {'an': 0,
#  'anh': 1,
#  'ap_đat': 2,
#  'api': 3,
#  'application': 4,
#  'bai': 5,
#  'bai_toan': 6,
#  'ban_be': 7,
#  'ban_chat': 8,
#  'bang': 9,
#  'bao_cao': 10,
#  'bao_gom': 11,
#  'bao_mat': 12,
#  'bao_ve': 13,
#  'bien': 14,
#  'bien_đoi': 15,
#  'bieu_dien': 16,
#  'bieu_thi': 17,
#  'bieu_tuong': 18,
#  'binh': 19,
#  'blog': 20,
#  'blogger': 21,
#  'bung_no': 22,
#  'business': 23,
#  'cai_thien': 24,
#  'cai_tien': 25,
#  'can_thiet': 26,
#  'canh': 27,
#  'cap': 28,
#  'cascading': 29,
#  'cau': 30,
#  'cau_truc': 31,
#  'cham': 32,
#  'chan': 33,
#  'chat_luong': 34,
#  'chay': 35,
#  'che_đo': 36,
#  'chi_tiet': 37,
#  'chia': 38,
#  'chien_luoc': 39,
#  'chinh_sua': 40,
#  'chinh_xac': 41,
#  'chong': 42,
#  'chu_quan': 43,
#  'chu_đe': 44,
#  'chua': 45,
#  'chuc_nang': 46,
#  'chung_khoan': 47,
#  'chung_minh': 48,
#  'chuoi': 49,
#  'chuong': 50,
#  'chuong_trinh': 51,
#  'chuyen_hoa': 52,
#  'chuyen_huong': 53,
#  'chuyen_đoi': 54,
#  'client': 55,
#  'co_ban': 56,
#  'co_le': 57,
#  'co_phieu': 58,
#  'co_so': 59,
#  'co_đinh': 60,
#  'code': 61,
#  'coi': 62,
#  'con_nguoi': 63,
#  'cong_cu': 64,
#  'cong_nghe': 65,
#  'cong_ty': 66,
#  'cong_viec': 67,
#  'css': 68,
#  'cung_cap': 69,
#  'cuoc_song': 70,
#  'dan': 71,
#  'dang': 72,
#  'danh_sach': 73,
#  'data': 74,
#  'de_dang': 75,
#  'di_đong': 76,
#  'dich_vu': 77,
#  'doanh_nghiep': 78,
#  'doanh_thu': 79,
#  'document': 80,
#  'doi': 81,
#  'du_an': 82,
#  'du_bao': 83,
#  'du_lieu': 84,
#  'du_đoan': 85,
#  'dua': 86,
#  'dung': 87,
#  'duy_tri': 88,
#  'email': 89,
#  'facebook': 90,
#  'file': 91,
#  'framework': 92,
#  'gan': 93,
#  'gia': 94,
#  'gia_đinh': 95,
#  'giai_phap': 96,
#  'giam_sat': 97,
#  'giao_dien': 98,
#  'giao_luu': 99,
#  'gioi_thieu': 100,
#  'gioi_tinh': 101,
#  'git': 102,
#  'github': 103,
#  'go': 104,
#  'goi': 105,
#  'goi_y': 106,
#  'google': 107,
#  'gui': 108,
#  'han_che': 109,
#  'hanh_vi': 110,
#  'hanh_đong': 111,
#  'hat': 112,
#  'he': 113,
#  'he_thong': 114,
#  'hien': 115,
#  'hien_thi': 116,
#  'hien_tuong': 117,
#  'hien_đai': 118,
#  'hieu_qua': 119,
#  'hieu_suat': 120,
#  'hinh': 121,
#  'hinh_anh': 122,
#  'hinh_thuc': 123,
#  'hoa': 124,
#  'hoan_chinh': 125,
#  'hoan_thanh': 126,
#  'hoan_thien': 127,
#  'hoc': 128,
#  'hoc_hoi': 129,
#  'hon_hop': 130,
#  'html': 131,
#  'huong': 132,
#  'huu_han': 133,
#  'huu_ich': 134,
#  'huy': 135,
#  'internet': 136,
#  'it': 137,
#  'java': 138,
#  'javascript': 139,
#  'join': 140,
#  'js': 141,
#  'json': 142,
#  'kem': 143,
#  'ket': 144,
#  'ket_noi': 145,
#  'ket_qua': 146,
#  'khach_hang': 147,
#  'khap': 148,
#  'kho': 149,
#  'khoa': 150,
#  'khoi': 151,
#  'khong_gian': 152,
#  'khuon_kho': 153,
#  'khuyen_nghi': 154,
#  'kich_co': 155,
#  'kiem': 156,
#  'kiem_tra': 157,
#  'kien_thuc': 158,
#  'kieu': 159,
#  'kinh_doanh': 160,
#  'kinh_te': 161,
#  'ky': 162,
#  'ky_thuat': 163,
#  'ky_tu': 164,
#  'lam_viec': 165,
#  'lan': 166,
#  'lap': 167,
#  'lap_trinh': 168,
#  'lap_trinh_vien': 169,
#  'level': 170,
#  'lich_su': 171,
#  'lien': 172,
#  'lien_tuc': 173,
#  'lieu': 174,
#  'linh_hoat': 175,
#  'linh_vuc': 176,
#  'link': 177,
#  'lo_ngai': 178,
#  'loat': 179,
#  'loi': 180,
#  'loi_ich': 181,
#  'loi_nhuan': 182,
#  'loi_the': 183,
#  'lua_chon': 184,
#  'luong': 185,
#  'luu': 186,
#  'luu_tru': 187,
#  'ly': 188,
#  'ly_thuyet': 189,
#  'ma': 190,
#  'mac_đinh': 191,
#  'mach': 192,
#  'macos': 193,
#  'mai': 194,
#  'mang': 195,
#  'manh_me': 196,
#  'marketing': 197,
#  'mau': 198,
#  'may': 199,
#  'may_tinh': 200,
#  'menu': 201,
#  'mien': 202,
#  'minh_hoa': 203,
#  'mo_hinh': 204,
#  'mo_rong': 205,
#  'mo_ta': 206,
#  'model': 207,
#  'mon': 208,
#  'mong': 209,
#  'mong_muon': 210,
#  'mua': 211,
#  'muc': 212,
#  'muc_đich': 213,
#  'muc_đo': 214,
#  'nam': 215,
#  'nam_bat': 216,
#  'nang': 217,
#  'nang_suat': 218,
#  'nen_tang': 219,
#  'neu': 220,
#  'ngan': 221,
#  'ngay_nay': 222,
#  'nghia_la': 223,
#  'nghiem': 224,
#  'nghien_cuu': 225,
#  'ngoai_tru': 226,
#  'ngon_ngu': 227,
#  'nhan': 228,
#  'nhan_loai': 229,
#  'nhan_tao': 230,
#  'nhanh_chong': 231,
#  'nhap': 232,
#  'nhiem_vu': 233,
#  'nhu_cau': 234,
#  'nodejs': 235,
#  'noi_bat': 236,
#  'noi_dung': 237,
#  'noi_tieng': 238,
#  'nu': 239,
#  'nut': 240,
#  'of': 241,
#  'online': 242,
#  'page': 243,
#  'pha_tron': 244,
#  'pham_vi': 245,
#  'phan_biet': 246,
#  'phan_bo': 247,
#  'phan_hoi': 248,
#  'phan_loai': 249,
#  'phan_mem': 250,
#  'phan_tich': 251,
#  'phep': 252,
#  'phien_ban': 253,
#  'pho_bien': 254,
#  'phong_cach': 255,
#  'phong_phu': 256,
#  'phuc_tap': 257,
#  'phuc_vu': 258,
#  'phuong_phap': 259,
#  'project': 260,
#  'python': 261,
#  'qua_khu': 262,
#  'quan_he': 263,
#  'quan_ly': 264,
#  'quang_cao': 265,
#  'quen_thuoc': 266,
#  'quy_mo': 267,
#  'quy_đinh': 268,
#  'quyen': 269,
#  'quyet_đinh': 270,
#  'ra_mat': 271,
#  'ra_đoi': 272,
#  'react': 273,
#  'request': 274,
#  'response': 275,
#  'role': 276,
#  'rong': 277,
#  'rong_rai': 278,
#  'ruby': 279,
#  'rut': 280,
#  'sach': 281,
#  'san': 282,
#  'san_pham': 283,
#  'san_sang': 284,
#  'sang_tao': 285,
#  'sap_xep': 286,
#  'sau': 287,
#  'server': 288,
#  'share': 289,
#  'sheets': 290,
#  'sinh': 291,
#  'sinh_thai': 292,
#  'so_luong': 293,
#  'so_thich': 294,
#  'song': 295,
#  'style': 296,
#  'sua': 297,
#  'ta': 298,
#  'tab': 299,
#  'tac': 300,
#  'tai': 301,
#  'tai_khoan': 302,
#  'tai_lieu': 303,
#  'tam': 304,
#  'tang_truong': 305,
#  'tap': 306,
#  'tap_hop': 307,
#  'tat': 308,
#  'thac_mac': 309,
#  'tham_so': 310,
#  'than_thien': 311,
#  'thanh': 312,
#  'thanh_cong': 313,
#  'thanh_phan': 314,
#  'thao_tac': 315,
#  'that_bai': 316,
#  'thay': 317,
#  'the_gioi': 318,
#  'the_hien': 319,
#  'the_ky': 320,
#  'theo_doi': 321,
#  'thiet_bi': 322,
#  'thiet_ke': 323,
#  'thoa_man': 324,
#  'thoai_mai': 325,
#  'thoi': 326,
#  'thoi_đai': 327,
#  'thong': 328,
#  'thong_bao': 329,
#  'thong_minh': 330,
#  'thong_qua': 331,
#  'thong_thuong': 332,
#  'thong_tin': 333,
#  'thu_vien': 334,
#  'thua': 335,
#  'thuan_tien': 336,
#  'thuat_toan': 337,
#  'thuc': 338,
#  'thuc_hien_tai': 339,
#  'thuong': 340,
#  'thuong_mai': 341,
#  'tich_hop': 342,
#  'tiem_nang': 343,
#  'tien_ich': 344,
#  'tien_tien': 345,
#  'tien_trinh': 346,
#  'tieng': 347,
#  'tiep_can': 348,
#  'tiep_thi': 349,
#  'tieu_đe': 350,
#  'tim_kiem': 351,
#  'tin_hieu': 352,
#  'tinh_nang': 353,
#  'tinh_toan': 354,
#  'toan': 355,
#  'toan_bo': 356,
#  'toan_cau': 357,
#  'toi_uu_hoa': 358,
#  'tong_quan': 359,
#  'tra_loi': 360,
#  'trai': 361,
#  'tran': 362,
#  'trang': 363,
#  'trang_thai': 364,
#  'trang_web': 365,
#  'trao_đoi': 366,
#  'tri_tue': 367,
#  'trien_khai': 368,
#  'trinh': 369,
#  'trinh_bay': 370,
#  'trinh_duyet': 371,
#  'tro': 372,
#  'tro_nen': 373,
#  'tron': 374,
#  'trong': 375,
#  'truc_tuyen': 376,
#  'trung': 377,
#  'truong': 378,
#  'truy_cap': 379,
#  'tu_đong': 380,
#  'tuan': 381,
#  'tuc': 382,
#  'tuc_la': 383,
#  'tuong_lai': 384,
#  'tuong_thich': 385,
#  'tuong_tu': 386,
#  'tuong_ung': 387,
#  'tuong_đong': 388,
#  'tuy': 389,
#  'tv': 390,
#  'ui': 391,
#  'ung': 392,
#  'ung_dung': 393,
#  'user': 394,
#  'users': 395,
#  'uu_điem': 396,
#  'vai_tro': 397,
#  'van': 398,
#  'van_ban': 399,
#  'van_hanh': 400,
#  'vi_du': 401,
#  'vo_cung': 402,
#  'vong': 403,
#  'vu': 404,
#  'web': 405,
#  'website': 406,
#  'windows': 407,
#  'word': 408,
#  'world': 409,
#  'xa_hoi': 410,
#  'xac_nhan': 411,
#  'xac_thuc': 412,
#  'xac_đinh': 413,
#  'xay_dung': 414,
#  'xem_xet': 415,
#  'xep_hang': 416,
#  'xoa': 417,
#  'xu': 418,
#  'xu_huong': 419,
#  'y_nghia': 420,
#  'y_tuong': 421,
#  'y_đinh': 422,
#  'yahoo': 423,
#  'đa_dang': 424,
#  'đac_tinh': 425,
#  'đac_trung': 426,
#  'đac_điem': 427,
#  'đai_dien': 428,
#  'đang': 429,
#  'đanh': 430,
#  'đanh_dau': 431,
#  'đau': 432,
#  'đau_ra': 433,
#  'đau_vao': 434,
#  'đay_đu': 435,
#  'đe_cap': 436,
#  'đe_xuat': 437,
#  'đe_y': 438,
#  'đien_tu': 439,
#  'đieu_khien': 440,
#  'đinh_dang': 441,
#  'đinh_nghia': 442,
#  'đoan': 443,
#  'đoc': 444,
#  'đoi_khi': 445,
#  'đoi_song': 446,
#  'đoi_tuong': 447,
#  'đon': 448,
#  'đon_gian': 449,
#  'đong': 450,
#  'đong_bo': 451,
#  'đong_nghia': 452,
#  'đuong': 453,
#  'android': 454,
#  'cap_nhat': 455,
#  'cho_du': 456,
#  'ios': 457,
#  'lop': 458,
#  'mac': 459,
#  'moi_truong': 460,
#  'nguoc_lai': 461,
#  'or': 462,
#  'sai_lam': 463,
#  'thiet_lap': 464,
#  'thu_vi': 465,
#  'tiec': 466,
#  've': 467,
#  'view': 468,
#  'xay': 469,
#  'ap_dung': 470,
#  'bat_buoc': 471,
#  'bi_an': 472,
#  'bo_qua': 473,
#  'bon': 474,
#  'chang_han': 475,
#  'chon_lua': 476,
#  'chu': 477,
#  'co_nghia_la': 478,
#  'cong': 479,
#  'cu_phap': 480,
#  'dai': 481,
#  'dau': 482,
#  'day': 483,
#  'dong': 484,
#  'duy_nhat': 485,
#  'gia_su': 486,
#  'gioi_han': 487,
#  'hoi': 488,
#  'in': 489,
#  'keo': 490,
#  'ket_thuc': 491,
#  'khop': 492,
#  'kia': 493,
#  'lan_luot': 494,
#  'luu_y': 495,
#  'mac_du': 496,
#  'mat_khac': 497,
#  'mot_chut': 498,
#  'ngan_can': 499,
#  'nhon': 500,
#  'phan_tu': 501,
#  'phu': 502,
#  'phuong_thuc': 503,
#  'rieng_biet': 504,
#  'thay_vi': 505,
#  'thuc_thi': 506,
#  'thuoc_tinh': 507,
#  'truyen': 508,
#  'tuong': 509,
#  'vv': 510,
#  'đung': 511,
#  'and': 512,
#  'bai_tap': 513,
#  'bot': 514,
#  'chieu': 515,
#  'cua': 516,
#  'cung': 517,
#  'duoc': 518,
#  'for': 519,
#  'goc': 520,
#  'is': 521,
#  'kich_thuoc': 522,
#  'la': 523,
#  'min': 524,
#  'nguoc': 525,
#  'nhung': 526,
#  'noi': 527,
#  'objects': 528,
#  'thread': 529,
#  'tien': 530,
#  'tri': 531,
#  'tu': 532,
#  'vi': 533,
#  'vua': 534,
#  'xuat': 535,
#  'anh_huong': 536,
#  'chu_y': 537,
#  'class': 538,
#  'co_che': 539,
#  'co_gang': 540,
#  'giai_quyet': 541,
#  'hom_nay': 542,
#  'khai_bao': 543,
#  'nguyen': 544,
#  'thang': 545,
#  'thich_hop': 546,
#  'tien_te': 547,
#  'tru': 548,
#  'cho': 549,
#  'hy_vong': 550,
#  'ke': 551,
#  'lap_lai': 552,
#  'nhac': 553,
#  'phong_van': 554,
#  'so_sanh': 555,
#  'tham_khao': 556,
#  'thu': 557,
#  'tiep_xuc': 558,
#  'toc_đo': 559,
#  'xep': 560,
#  'đoi': 561,
#  'ban_đau': 562,
#  'cai_đat': 563,
#  'chuyen_nghiep': 564,
#  'con_so': 565,
#  'ghi': 566,
#  'huan': 567,
#  'huong_dan': 568,
#  'set': 569,
#  'tach': 570,
#  'tich': 571,
#  'tien_hanh': 572,
#  'tui': 573,
#  'xong': 574,
#  'customer': 575,
#  'microsoft': 576,
#  'ban': 577,
#  'co_han': 578,
#  'kich_hoat': 579,
#  'roi': 580,
#  'start': 581,
#  'tiep': 582,
#  'vo': 583,
#  'xet': 584,
#  'đe': 585,
#  'cho_đoi': 586,
#  'khac_biet': 587,
#  'khoan': 588,
#  'test': 589,
#  'truong_hop': 590,
#  'đem': 591,
#  'ao': 592,
#  'method': 593,
#  'so_huu': 594,
#  'tham_gia': 595,
#  'the': 596,
#  'thuat_ngu': 597,
#  'ton_tai': 598,
#  'tranh': 599,
#  'binh_thuong': 600,
#  'buoc': 601,
#  'chi_phi': 602,
#  'co': 603,
#  'developer': 604,
#  'di_chuyen': 605,
#  'docs': 606,
#  'giao_tiep': 607,
#  'lien_ket': 608,
#  'ngam': 609,
#  'ngan_chan': 610,
#  'nguy_co': 611,
#  'ro_rang': 612,
#  'su_kien': 613,
#  'tac_dung': 614,
#  'ton': 615,
#  'tri_hoan': 616,
#  'đa_so': 617,
#  'đinh': 618,
#  'đot_ngot': 619,
#  'backend': 620,
#  'bo': 621,
#  'bo_sung': 622,
#  'cam_hung': 623,
#  'cam_nhan': 624,
#  'can': 625,
#  'chia_khoa': 626,
#  'chuan': 627,
#  'chuc': 628,
#  'cong_nghiep': 629,
#  'cuc_ky': 630,
#  'dich': 631,
#  'dinh': 632,
#  'doc': 633,
#  'frontend': 634,
#  'gan_ket': 635,
#  'giay': 636,
#  'gon': 637,
#  'hang_đau': 638,
#  'hau_nhu': 639,
#  'hieu_biet': 640,
#  'hinh_thanh': 641,
#  'hoan_hao': 642,
#  'huu': 643,
#  'ke_hoach': 644,
#  'keo_dai': 645,
#  'ket_hop': 646,
#  'kham_pha': 647,
#  'khung': 648,
#  'kich_ban': 649,
#  'kiem_soat': 650,
#  'kinh_nghiem': 651,
#  'ky_nang': 652,
#  'lap_tuc': 653,
#  'liet_ke': 654,
#  'like': 655,
#  'lo': 656,
#  'long': 657,
#  'luoi': 658,
#  'man_hinh': 659,
#  'may_chu': 660,
#  'mien_phi': 661,
#  'mobile': 662,
#  'muc_tieu': 663,
#  'nang_đong': 664,
#  'nganh': 665,
#  'nghi': 666,
#  'nguoi_ta': 667,
#  'nguon_luc': 668,
#  'nguyen_tac': 669,
#  'nhe': 670,
#  'pha': 671,
#  'phan_ung': 672,
#  'phat_hanh': 673,
#  'phong': 674,
#  'quy': 675,
#  'social': 676,
#  'suc_manh': 677,
#  'sup_đo': 678,
#  'tai_nguyen': 679,
#  'tang_cuong': 680,
#  'tat_nhien': 681,
#  'tham_quan': 682,
#  'that': 683,
#  'thay_the': 684,
#  'thich_nghi': 685,
#  'thiet_yeu': 686,
#  'thu_cong': 687,
#  'thu_nghiem': 688,
#  'thuc_hanh': 689,
#  'tiet_kiem': 690,
#  'tieu': 691,
#  'tieu_chuan': 692,
#  'tinh': 693,
#  'to_chuc': 694,
#  'toi_thieu': 695,
#  'toi_đa': 696,
#  'top': 697,
#  'tot_đep': 698,
#  'trach_nhiem': 699,
#  'tram': 700,
#  'trang_tri': 701,
#  'trao': 702,
#  'tro_giup': 703,
#  'truc_quan': 704,
#  'trung_tam': 705,
#  'truot': 706,
#  'truyen_thong': 707,
#  'tu_do': 708,
#  'tuong_tac': 709,
#  'tuy_bien': 710,
#  'tuyet': 711,
#  'tuyet_voi': 712,
#  'twitter': 713,
#  'video': 714,
#  'xach': 715,
#  'yeu': 716,
#  'yeu_to': 717,
#  'đa': 718,
#  'đap_ung': 719,
#  'đep': 720,
#  'đien_hinh': 721,
#  'đien_thoai': 722,
#  'đieu_chinh': 723,
#  'đinh_huong': 724,
#  'đoi_hoi': 725,
#  'đong_bang': 726,
#  'đong_goi': 727,
#  'bam': 728,
#  'cong_bo': 729,
#  'design': 730,
#  'dien': 731,
#  'giup_đo': 732,
#  'kim': 733,
#  'mui': 734,
#  'phu_thuoc': 735,
#  'trong_luong': 736,
#  'đam': 737,
#  'đieu_hanh': 738,
#  'chap_nhan': 739,
#  'chuyen_gia': 740,
#  'coi_trong': 741,
#  'development': 742,
#  'hieu': 743,
#  'hop': 744,
#  'khac_phuc': 745,
#  'ma_hoa': 746,
#  'nua': 747,
#  'phat_hien': 748,
#  'php': 749,
#  'quen': 750,
#  'quy_trinh': 751,
#  'sieu': 752,
#  'su_co': 753,
#  'thu_hut': 754,
#  'thuong_xuyen': 755,
#  'tro_choi': 756,
#  'tro_lai': 757,
#  'vung': 758,
#  'an_khong': 759,
#  'cam': 760,
#  'database': 761,
#  'giai_thich': 762,
#  'hop_le': 763,
#  'khai_niem': 764,
#  'ngon': 765,
#  'ngu': 766,
#  'noi_chuyen': 767,
#  'tao': 768,
#  'token': 769,
#  'tom': 770,
#  'tuong_đuong': 771,
#  'ty': 772,
#  'yen': 773,
#  'đay': 774,
#  'cha': 775,
#  'cu': 776,
#  'du': 777,
#  'giai_đoan': 778,
#  'nang_ne': 779,
#  'nhat': 780,
#  'phan': 781,
#  'restful': 782,
#  'version': 783,
#  'xa_la': 784,
#  'build': 785,
#  'cai': 786,
#  'so': 787,
#  'vui': 788,
#  'bao': 789,
#  'bat': 790,
#  'ca': 791,
#  'duong_nhu': 792,
#  'gian': 793,
#  'ket_luan': 794,
#  'moi': 795,
#  'phuong_tien': 796,
#  'sai': 797,
#  'đau_tu': 798,
#  'am': 799,
#  'an_toan': 800,
#  'apple': 801,
#  'bac': 802,
#  'chiem': 803,
#  'khoa_hoc': 804,
#  'sung': 805,
#  'swift': 806,
#  'tien_loi': 807,
#  'trieu': 808,
#  'uoc_tinh': 809,
#  'đao_tao': 810,
#  'an_ninh': 811,
#  'an_tuong': 812,
#  'benh_tat': 813,
#  'bill': 814,
#  'cam_giac': 815,
#  'cam_xuc': 816,
#  'canh_bao': 817,
#  'canh_tranh': 818,
#  'cau_chuyen': 819,
#  'chet': 820,
#  'chien_thang': 821,
#  'chien_tranh': 822,
#  'co_the': 823,
#  'cuoc_đoi': 824,
#  'dam': 825,
#  'ghet': 826,
#  'gia_tang': 827,
#  'giai_tri': 828,
#  'giau_co': 829,
#  'gioi': 830,
#  'good': 831,
#  'hau_qua': 832,
#  'ho': 833,
#  'hoi_nghi': 834,
#  'hong': 835,
#  'khu_vuc': 836,
#  'khuyen': 837,
#  'kien': 838,
#  'lai': 839,
#  'lang_phi': 840,
#  'lanh_đao': 841,
#  'lau_dai': 842,
#  'lo_lang': 843,
#  'loai_bo': 844,
#  'luat_phap': 845,
#  'mat': 846,
#  'may_bay': 847,
#  'moc': 848,
#  'mong_đoi': 849,
#  'muong': 850,
#  'nang_luong': 851,
#  'ngan_han': 852,
#  'ngan_ngua': 853,
#  'nghe_nghiep': 854,
#  'nghiem_tuc': 855,
#  'nguy_hiem': 856,
#  'nhan_manh': 857,
#  'nhan_thuc': 858,
#  'nhiet': 859,
#  'nhuong': 860,
#  'no_luc': 861,
#  'quan_niem': 862,
#  'rui_ro': 863,
#  'san_bay': 864,
#  'steve': 865,
#  'tac_đong': 866,
#  'tai_chinh': 867,
#  'tan_cong': 868,
#  'tan_huong': 869,
#  'te': 870,
#  'thach_thuc': 871,
#  'tham_vong': 872,
#  'than_trong': 873,
#  'thap_ky': 874,
#  'thi_truong': 875,
#  'thong_cam': 876,
#  'thuc_đay': 877,
#  'tiem_an': 878,
#  'tien_đo': 879,
#  'tieu_cuc': 880,
#  'tim': 881,
#  'tinh_huong': 882,
#  'tinh_than': 883,
#  'to': 884,
#  'tom_tat': 885,
#  'ton_hai': 886,
#  'tre_em': 887,
#  'viec_lam': 888,
#  'vo_tinh': 889,
#  'vu_khi': 890,
#  'vu_trang': 891,
#  'vui_choi': 892,
#  'xanh': 893,
#  'xau': 894,
#  'xe': 895,
#  'y_thuc': 896,
#  'đai_ly': 897,
#  'đap': 898,
#  'đinh_nghia_la': 899,
#  'đoi_mat': 900,
#  'đua': 901,
#  'alzheimer': 902,
#  'anh_sang': 903,
#  'ban_đoc': 904,
#  'bat_chap': 905,
#  'bat_on': 906,
#  'bieu_đo': 907,
#  'cap_bach': 908,
#  'chinh_phu': 909,
#  'chinh_tri': 910,
#  'cong_nhan': 911,
#  'cong_đong': 912,
#  'cuc_ki': 913,
#  'cuoc_chien': 914,
#  'cuoi': 915,
#  'du_đinh': 916,
#  'ga': 917,
#  'giau': 918,
#  'hai_huoc': 919,
#  'hap_dan': 920,
#  'khi': 921,
#  'khi_hau': 922,
#  'ki_cang': 923,
#  'lam_ban': 924,
#  'li_do': 925,
#  'man': 926,
#  'mao_hiem': 927,
#  'mat_troi': 928,
#  'me': 929,
#  'my': 930,
#  'nan': 931,
#  'nao': 932,
#  'nga': 933,
#  'ngheo': 934,
#  'ngung': 935,
#  'nguon_goc': 936,
#  'nguyen_lieu': 937,
#  'nhan_luc': 938,
#  'nong': 939,
#  'phi': 940,
#  'quan': 941,
#  'quan_ao': 942,
#  'quan_li': 943,
#  'quoc': 944,
#  'quy_gia': 945,
#  'rieng_le': 946,
#  'sam': 947,
#  'sau_sac': 948,
#  'show': 949,
#  'silicon': 950,
#  'suy_nghi': 951,
#  'tap_chi': 952,
#  'tau': 953,
#  'that_nghiep': 954,
#  'the_chat': 955,
#  'thu_thach': 956,
#  'thuyet_phuc': 957,
#  'ti_phu': 958,
#  'toa': 959,
#  'toi_te': 960,
#  'tong_thong': 961,
#  'trat_tu': 962,
#  'trung_binh': 963,
#  'tu_nhien': 964,
#  'ung_ho': 965,
#  'ung_thu': 966,
#  'vat_chat': 967,
#  'vien_canh': 968,
#  'von': 969,
#  'vui_ve': 970,
#  'xin_loi': 971,
#  'xung_quanh': 972,
#  'xung_đot': 973,
#  'y_kien': 974,
#  'yen_tam': 975,
#  'đai_dich': 976,
#  'đe_nghi': 977,
#  'đoi_xu': 978,
#  'đung_đan': 979,
#  'agile': 980,
#  'ben_vung': 981,
#  'bo_phan': 982,
#  'cam_ket': 983,
#  'chat_che': 984,
#  'daily': 985,
#  'khuyen_khich': 986,
#  'linh': 987,
#  'meeting': 988,
#  'minh_bach': 989,
#  'phan_tram': 990,
#  'phat': 991,
#  'phut': 992,
#  'planning': 993,
#  'quanh': 994,
#  'review': 995,
#  'scrum': 996,
#  'sprint': 997,
#  'startup': 998,
#  'stories': 999,
#  ...}

# %%
class StreamCorpus(object):
    def __init__(self, sentences, dictionary, clip_docs=None):
        """
        Parse the first `clip_docs` documents
        Yield each document in turn, as a list of tokens.
        """
        self.sentences = sentences
        self.dictionary = dictionary
        self.clip_docs = clip_docs

    def __iter__(self):
        for tokens in itertools.islice(make_texts_corpus(self.sentences),
                                       self.clip_docs):
            yield self.dictionary.doc2bow(tokens)

    def __len__(self):
        return self.clip_docs

# %%
sentences = make_sentences()
corpus = StreamCorpus(sentences, id2word)

# %%
for i, c in enumerate(corpus):
    print(c)
    if i == 10: break
# Out:
# [(0, 3), (1, 6), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 2), (8, 1), (9, 2), (10, 1), (11, 5), (12, 1), (13, 1), (14, 2), (15, 1), (16, 6), (17, 2), (18, 7), (19, 1), (20, 29), (21, 2), (22, 2), (23, 1), (24, 3), (25, 2), (26, 2), (27, 1), (28, 2), (29, 1), (30, 1), (31, 6), (32, 1), (33, 1), (34, 1), (35, 4), (36, 2), (37, 4), (38, 2), (39, 1), (40, 16), (41, 1), (42, 1), (43, 1), (44, 19), (45, 4), (46, 16), (47, 1), (48, 1), (49, 1), (50, 6), (51, 3), (52, 1), (53, 2), (54, 1), (55, 3), (56, 2), (57, 1), (58, 1), (59, 11), (60, 1), (61, 10), (62, 2), (63, 5), (64, 2), (65, 5), (66, 1), (67, 2), (68, 4), (69, 5), (70, 4), (71, 1), (72, 5), (73, 4), (74, 2), (75, 4), (76, 1), (77, 2), (78, 4), (79, 1), (80, 12), (81, 2), (82, 1), (83, 1), (84, 38), (85, 5), (86, 13), (87, 2), (88, 1), (89, 2), (90, 4), (91, 1), (92, 2), (93, 5), (94, 1), (95, 2), (96, 1), (97, 8), (98, 15), (99, 1), (100, 5), (101, 1), (102, 2), (103, 2), (104, 1), (105, 2), (106, 15), (107, 3), (108, 4), (109, 2), (110, 1), (111, 1), (112, 4), (113, 3), (114, 36), (115, 2), (116, 12), (117, 1), (118, 1), (119, 3), (120, 1), (121, 5), (122, 1), (123, 2), (124, 1), (125, 1), (126, 3), (127, 1), (128, 15), (129, 2), (130, 1), (131, 5), (132, 4), (133, 1), (134, 2), (135, 2), (136, 5), (137, 1), (138, 2), (139, 2), (140, 1), (141, 3), (142, 2), (143, 1), (144, 1), (145, 1), (146, 5), (147, 3), (148, 1), (149, 2), (150, 2), (151, 1), (152, 1), (153, 1), (154, 1), (155, 1), (156, 1), (157, 2), (158, 2), (159, 3), (160, 4), (161, 1), (162, 1), (163, 1), (164, 1), (165, 2), (166, 1), (167, 1), (168, 3), (169, 2), (170, 4), (171, 1), (172, 1), (173, 1), (174, 1), (175, 2), (176, 4), (177, 5), (178, 1), (179, 1), (180, 1), (181, 3), (182, 1), (183, 1), (184, 3), (185, 1), (186, 13), (187, 2), (188, 1), (189, 2), (190, 11), (191, 1), (192, 1), (193, 1), (194, 1), (195, 8), (196, 2), (197, 1), (198, 3), (199, 7), (200, 1), (201, 1), (202, 1), (203, 1), (204, 14), (205, 1), (206, 12), (207, 1), (208, 3), (209, 2), (210, 1), (211, 2), (212, 1), (213, 7), (214, 3), (215, 3), (216, 3), (217, 3), (218, 1), (219, 2), (220, 1), (221, 1), (222, 3), (223, 1), (224, 1), (225, 5), (226, 2), (227, 8), (228, 11), (229, 1), (230, 1), (231, 3), (232, 5), (233, 1), (234, 9), (235, 4), (236, 2), (237, 6), (238, 2), (239, 1), (240, 5), (241, 1), (242, 1), (243, 2), (244, 2), (245, 2), (246, 2), (247, 4), (248, 4), (249, 1), (250, 3), (251, 4), (252, 12), (253, 1), (254, 2), (255, 1), (256, 2), (257, 2), (258, 2), (259, 7), (260, 1), (261, 1), (262, 1), (263, 3), (264, 2), (265, 2), (266, 1), (267, 1), (268, 1), (269, 4), (270, 1), (271, 1), (272, 2), (273, 2), (274, 5), (275, 2), (276, 3), (277, 1), (278, 1), (279, 1), (280, 1), (281, 2), (282, 3), (283, 8), (284, 1), (285, 1), (286, 1), (287, 1), (288, 2), (289, 2), (290, 1), (291, 8), (292, 1), (293, 4), (294, 1), (295, 1), (296, 1), (297, 3), (298, 1), (299, 1), (300, 1), (301, 2), (302, 2), (303, 10), (304, 1), (305, 2), (306, 9), (307, 2), (308, 2), (309, 1), (310, 6), (311, 1), (312, 5), (313, 3), (314, 1), (315, 4), (316, 2), (317, 1), (318, 2), (319, 2), (320, 1), (321, 21), (322, 1), (323, 11), (324, 1), (325, 1), (326, 1), (327, 1), (328, 4), (329, 22), (330, 5), (331, 3), (332, 1), (333, 16), (334, 2), (335, 2), (336, 1), (337, 14), (338, 2), (339, 2), (340, 1), (341, 1), (342, 4), (343, 1), (344, 1), (345, 1), (346, 2), (347, 1), (348, 1), (349, 3), (350, 2), (351, 12), (352, 1), (353, 4), (354, 1), (355, 2), (356, 1), (357, 1), (358, 1), (359, 1), (360, 1), (361, 1), (362, 1), (363, 3), (364, 2), (365, 2), (366, 2), (367, 1), (368, 1), (369, 3), (370, 2), (371, 4), (372, 1), (373, 2), (374, 2), (375, 4), (376, 2), (377, 1), (378, 3), (379, 2), (380, 7), (381, 1), (382, 2), (383, 2), (384, 3), (385, 1), (386, 5), (387, 1), (388, 1), (389, 1), (390, 1), (391, 1), (392, 3), (393, 11), (394, 19), (395, 9), (396, 1), (397, 2), (398, 5), (399, 11), (400, 1), (401, 5), (402, 1), (403, 1), (404, 1), (405, 2), (406, 22), (407, 1) ...
# [(3, 2), (30, 2), (31, 1), (35, 1), (45, 1), (67, 1), (69, 1), (105, 10), (116, 1), (165, 2), (212, 1), (219, 3), (252, 1), (254, 1), (264, 1), (273, 28), (287, 1), (288, 2), (319, 1), (353, 1), (360, 2), (378, 2), (393, 1), (428, 1), (442, 1), (444, 1), (454, 1), (455, 8), (456, 1), (457, 1), (458, 3), (459, 1), (460, 1), (461, 1), (462, 1), (463, 1), (464, 4), (465, 1), (466, 1), (467, 3), (468, 1), (469, 3)]
# [(11, 2), (17, 2), (27, 2), (41, 2), (45, 6), (49, 27), (64, 2), (69, 1), (72, 1), (84, 2), (105, 2), (116, 1), (119, 1), (124, 2), (134, 1), (139, 2), (143, 1), (144, 1), (146, 1), (157, 5), (159, 2), (162, 3), (164, 37), (167, 2), (168, 1), (174, 2), (184, 2), (190, 3), (195, 3), (198, 14), (206, 1), (215, 2), (223, 1), (226, 2), (227, 2), (246, 1), (252, 3), (257, 1), (298, 3), (299, 1), (306, 1), (307, 3), (308, 1), (312, 1), (313, 1), (319, 1), (333, 1), (351, 1), (356, 3), (361, 1), (363, 1), (375, 1), (377, 19), (386, 2), (398, 1), (399, 2), (401, 5), (402, 1), (413, 1), (414, 1), (420, 3), (426, 1), (428, 2), (429, 1), (431, 1), (432, 2), (433, 1), (434, 2), (443, 1), (447, 5), (449, 3), (455, 1), (461, 1), (469, 1), (470, 3), (471, 2), (472, 1), (473, 1), (474, 2), (475, 1), (476, 1), (477, 5), (478, 2), (479, 1), (480, 2), (481, 1), (482, 31), (483, 4), (484, 2), (485, 2), (486, 2), (487, 2), (488, 1), (489, 1), (490, 1), (491, 3), (492, 37), (493, 1), (494, 1), (495, 1), (496, 1), (497, 1), (498, 1), (499, 1), (500, 1), (501, 9), (502, 2), (503, 4), (504, 1), (505, 1), (506, 1), (507, 1), (508, 1), (509, 1), (510, 1), (511, 2)]
# [(9, 2), (49, 18), (50, 1), (51, 2), (56, 2), (87, 2), (115, 2), (138, 3), (162, 1), (164, 1), (167, 1), (180, 1), (195, 6), (203, 2), (232, 9), (241, 1), (259, 1), (286, 2), (315, 1), (369, 2), (393, 1), (405, 1), (447, 1), (469, 2), (474, 2), (481, 1), (482, 1), (489, 3), (501, 4), (512, 2), (513, 1), (514, 1), (515, 2), (516, 3), (517, 1), (518, 2), (519, 1), (520, 2), (521, 12), (522, 1), (523, 4), (524, 3), (525, 1), (526, 1), (527, 1), (528, 1), (529, 1), (530, 1), (531, 2), (532, 1), (533, 2), (534, 2), (535, 4)]
# [(6, 6), (8, 1), (16, 5), (30, 2), (32, 1), (35, 1), (41, 5), (51, 12), (65, 1), (67, 1), (69, 1), (72, 4), (84, 3), (105, 1), (121, 1), (128, 1), (132, 1), (133, 1), (138, 2), (146, 5), (159, 6), (168, 1), (187, 1), (199, 3), (203, 1), (210, 2), (221, 1), (246, 1), (297, 1), (310, 1), (331, 2), (332, 1), (333, 1), (335, 1), (354, 5), (355, 1), (360, 1), (380, 1), (385, 1), (418, 1), (429, 1), (432, 1), (434, 1), (436, 1), (438, 1), (443, 2), (444, 1), (450, 4), (452, 1), (455, 1), (475, 2), (482, 4), (489, 8), (496, 1), (508, 1), (511, 1), (515, 1), (530, 2), (536, 1), (537, 1), (538, 2), (539, 1), (540, 1), (541, 3), (542, 1), (543, 1), (544, 2), (545, 1), (546, 1), (547, 1), (548, 1)]
# [(6, 2), (8, 1), (26, 1), (28, 1), (30, 1), (35, 1), (61, 2), (71, 2), (84, 4), (125, 1), (132, 1), (138, 3), (158, 1), (159, 1), (167, 3), (168, 1), (172, 5), (189, 1), (195, 4), (210, 1), (286, 12), (298, 1), (337, 3), (386, 6), (401, 3), (403, 10), (429, 1), (435, 1), (449, 2), (455, 1), (467, 1), (469, 1), (486, 1), (501, 28), (514, 7), (515, 1), (527, 7), (549, 4), (550, 1), (551, 5), (552, 1), (553, 1), (554, 1), (555, 9), (556, 1), (557, 1), (558, 2), (559, 1), (560, 3), (561, 4)]
# [(6, 1), (35, 2), (41, 1), (51, 3), (61, 1), (71, 1), (84, 1), (86, 1), (89, 4), (91, 8), (98, 1), (100, 1), (122, 1), (126, 1), (131, 1), (138, 5), (146, 2), (157, 6), (177, 1), (186, 1), (227, 1), (228, 3), (246, 1), (249, 9), (259, 3), (298, 8), (300, 1), (312, 2), (383, 1), (386, 1), (399, 1), (401, 3), (431, 2), (444, 1), (449, 3), (461, 1), (470, 2), (555, 2), (557, 5), (562, 3), (563, 1), (564, 1), (565, 1), (566, 1), (567, 1), (568, 1), (569, 1), (570, 3), (571, 1), (572, 2), (573, 14), (574, 1)]
# [(56, 1), (61, 2), (62, 1), (69, 1), (89, 1), (91, 14), (116, 2), (132, 1), (138, 1), (146, 2), (159, 2), (168, 1), (188, 2), (190, 1), (241, 1), (298, 1), (312, 2), (314, 2), (333, 2), (334, 2), (372, 2), (401, 3), (408, 1), (441, 1), (442, 2), (443, 1), (444, 7), (447, 2), (484, 3), (495, 1), (538, 5), (566, 5), (575, 3), (576, 4)]
# [(35, 2), (96, 1), (104, 1), (105, 1), (117, 2), (138, 4), (140, 5), (146, 2), (151, 1), (167, 1), (168, 1), (212, 1), (227, 1), (252, 1), (298, 11), (303, 1), (370, 2), (386, 1), (401, 5), (403, 1), (429, 1), (438, 1), (451, 3), (455, 1), (458, 6), (469, 3), (478, 1), (484, 1), (489, 13), (491, 2), (493, 1), (495, 1), (506, 5), (512, 1), (529, 75), (556, 1), (561, 6), (566, 1), (574, 2), (577, 3), (578, 1), (579, 2), (580, 1), (581, 1), (582, 1), (583, 1), (584, 3), (585, 1)]
# [(35, 1), (51, 11), (105, 3), (126, 8), (138, 1), (140, 2), (146, 3), (151, 1), (185, 1), (190, 1), (215, 1), (233, 1), (252, 1), (293, 2), (298, 2), (300, 1), (310, 1), (317, 1), (329, 2), (344, 1), (383, 2), (393, 2), (401, 3), (404, 1), (429, 1), (447, 2), (455, 1), (458, 4), (495, 1), (503, 6), (506, 4), (525, 1), (529, 9), (543, 1), (549, 6), (579, 1), (581, 4), (586, 2), (587, 1), (588, 1), (589, 1), (590, 1), (591, 1)]
# [(33, 1), (35, 1), (61, 1), (105, 3), (138, 11), (150, 3), (151, 9), (159, 1), (190, 1), (199, 1), (298, 1), (319, 2), (356, 1), (386, 2), (389, 1), (401, 7), (415, 1), (429, 1), (431, 1), (443, 1), (444, 1), (447, 2), (451, 15), (455, 1), (469, 1), (506, 4), (509, 1), (529, 10), (538, 6), (539, 1), (540, 1), (543, 1), (561, 1), (592, 1), (593, 15), (594, 2), (595, 1), (596, 1), (597, 1), (598, 3), (599, 1)]

# %%
# save corpus
gensim.corpora.MmCorpus.serialize('../models/corpus.mm', corpus)
# Out:
# INFO : storing corpus in Matrix Market format to ../models/corpus.mm
# INFO : saving sparse matrix to ../models/corpus.mm
# INFO : PROGRESS: saving document #0
# INFO : saved 67x1670 matrix, density=10.458% (11701/111890)
# INFO : saving MmCorpus index to ../models/corpus.mm.index

# %%
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 67 documents, 1670 features, 11701 non-zero entries

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus, id2word=id2word, num_topics=30, passes=4,
            chunksize=20, random_state=42, alpha=1e-2, eta=0.5e-2,
            minimum_probability=0.0, per_word_topics=False)
# Out:
# INFO : using serial LDA version on this node
# INFO : running online (multi-pass) LDA training, 30 topics, 4 passes over the supplied corpus of 67 documents, updating model once every 20 documents, evaluating perplexity every 67 documents, iterating 50x with a convergence threshold of 0.001000
# INFO : PROGRESS: pass 0, at document #20/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #22 (0.010): 0.039*"du_lich" + 0.033*"ve" + 0.024*"vui_choi" + 0.023*"lua_chon" + 0.019*"chuyen" + 0.019*"hanh_ly" + 0.017*"lich_trinh" + 0.015*"kinh_nghiem" + 0.013*"phuong_tien" + 0.013*"di_chuyen"
# INFO : topic #16 (0.010): 0.037*"thong_minh" + 0.020*"con_nguoi" + 0.019*"muc_tieu" + 0.018*"nghien_cuu" + 0.014*"he_thong" + 0.013*"kiem_soat" + 0.013*"may" + 0.011*"tri_tue" + 0.010*"ta" + 0.008*"tri"
# INFO : topic #23 (0.010): 0.023*"trang_web" + 0.020*"thiet_ke" + 0.020*"sprint" + 0.018*"web" + 0.017*"marketing" + 0.011*"mua" + 0.011*"team" + 0.010*"javascript" + 0.010*"du_an" + 0.010*"html"
# INFO : topic #14 (0.010): 0.040*"design" + 0.026*"thiet_ke" + 0.020*"google" + 0.018*"user" + 0.017*"framework" + 0.014*"cung_cap" + 0.014*"web" + 0.014*"thanh_phan" + 0.013*"bao_gom" + 0.012*"css"
# INFO : topic #2 (0.010): 0.019*"du_lich" + 0.015*"trang_web" + 0.014*"thiet_ke" + 0.014*"thong_minh" + 0.010*"web" + 0.008*"bui" + 0.008*"html" + 0.007*"chuyen" + 0.007*"xay_dung" + 0.007*"cung_cap"
# INFO : topic diff=108.774582, rho=1.000000
# INFO : PROGRESS: pass 0, at document #40/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #16 (0.010): 0.135*"co_the" + 0.064*"nang_luong" + 0.022*"sinh_thai" + 0.021*"nghien_cuu" + 0.012*"chet" + 0.012*"chuyen_gia" + 0.010*"nhiet" + 0.010*"quy" + 0.010*"thanh" + 0.009*"nguy_co"
# INFO : topic #12 (0.010): 0.031*"thong_minh" + 0.018*"backend" + 0.015*"frontend" + 0.011*"may" + 0.010*"ta" + 0.009*"muc_tieu" + 0.009*"marketing" + 0.009*"sprint" + 0.009*"tri_tue" + 0.008*"con_nguoi"
# INFO : topic #6 (0.010): 0.096*"tieu_thu" + 0.031*"đoi" + 0.026*"hieu_qua" + 0.020*"chung_minh" + 0.019*"agile" + 0.013*"vong" + 0.013*"muc_tieu" + 0.011*"đam" + 0.011*"nhu_cau" + 0.010*"du_an"
# INFO : topic #8 (0.010): 0.043*"sprint" + 0.023*"marketing" + 0.022*"mua" + 0.018*"user" + 0.017*"backend" + 0.015*"team" + 0.014*"frontend" + 0.014*"meeting" + 0.011*"scrum" + 0.010*"vai_tro"
# INFO : topic #14 (0.010): 0.051*"đieu_hanh" + 0.046*"google" + 0.044*"huong" + 0.032*"trong_luong" + 0.029*"he" + 0.028*"giup_đo" + 0.024*"android" + 0.022*"vv" + 0.020*"design" + 0.017*"san_pham"
# INFO : topic diff=6.011281, rho=0.707107
# INFO : PROGRESS: pass 0, at document #60/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #9 (0.010): 0.015*"design" + 0.014*"du_lich" + 0.013*"thiet_ke" + 0.012*"cung_cap" + 0.011*"chuyen" + 0.010*"web" + 0.009*"css" + 0.009*"mua" + 0.009*"xay_dung" + 0.008*"the"
# INFO : topic #6 (0.010): 0.103*"tieu_thu" + 0.061*"keo_dai" + 0.053*"chu_ky" + 0.041*"đam" + 0.034*"tich_cuc" + 0.028*"hieu_qua" + 0.022*"tham_gia" + 0.018*"gia_tang" + 0.017*"chung_minh" + 0.017*"đoi"
# INFO : topic #16 (0.010): 0.090*"co_the" + 0.054*"nang_luong" + 0.037*"nguy_co" + 0.032*"loi" + 0.024*"nghien_cuu" + 0.020*"kinh_te" + 0.020*"tim" + 0.017*"the_ky" + 0.016*"tai_chinh" + 0.014*"thi_truong"
# INFO : topic #19 (0.010): 0.088*"an_uong" + 0.075*"benh" + 0.070*"song" + 0.045*"thoi_quen" + 0.038*"mac" + 0.025*"cuoc_song" + 0.024*"mon" + 0.023*"chua" + 0.019*"lua_chon" + 0.019*"bua"
# INFO : topic #2 (0.010): 0.017*"du_lich" + 0.014*"trang_web" + 0.013*"thiet_ke" + 0.012*"thong_minh" + 0.009*"web" + 0.008*"bui" + 0.007*"html" + 0.007*"chuyen" + 0.007*"xay_dung" + 0.007*"cung_cap"
# INFO : topic diff=6.854795, rho=0.577350
# INFO : -72.706 per-word bound, 7703972543503103164416.0 perplexity estimate based on a held-out corpus of 7 documents with 2106 words
# INFO : PROGRESS: pass 0, at document #67/67
# INFO : merging changes from 7 documents into a model of 67 documents
# INFO : topic #18 (0.010): 0.029*"backend" + 0.016*"frontend" + 0.013*"trang_web" + 0.013*"ngon_ngu" + 0.012*"thiet_ke" + 0.011*"html" + 0.011*"web" + 0.010*"ung_dung" + 0.010*"tinh_nang" + 0.009*"css"
# INFO : topic #27 (0.010): 0.077*"ca" + 0.030*"ta" + 0.024*"api" + 0.021*"cai" + 0.013*"chua" + 0.012*"request" + 0.010*"can" + 0.009*"agile" + 0.008*"sua" + 0.008*"can_thiet"
# INFO : topic #26 (0.010): 0.184*"uong" + 0.102*"chau" + 0.055*"ngu" + 0.030*"kem" + 0.030*"đuong" + 0.029*"chuyen_nghiep" + 0.026*"chi" + 0.024*"soi_đong" + 0.022*"mo" + 0.019*"mat"
# INFO : topic #10 (0.010): 0.040*"agile" + 0.019*"đoi" + 0.016*"du_an" + 0.012*"muc_tieu" + 0.010*"vong" + 0.010*"san_pham" + 0.009*"team" + 0.009*"marketing" + 0.009*"phan_mem" + 0.009*"he_thong"
# INFO : topic #21 (0.010): 0.045*"tin_dung" + 0.043*"tien" + 0.043*"doanh_nghiep" + 0.038*"thi_truong" + 0.035*"dau" + 0.029*"đao" + 0.022*"gia" + 0.016*"ngan_hang" + 0.014*"đat" + 0.014*"dong"
# INFO : topic diff=7.492953, rho=0.500000
# INFO : PROGRESS: pass 1, at document #20/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #16 (0.010): 0.045*"nang_luong" + 0.045*"co_the" + 0.029*"nguy_co" + 0.025*"nghien_cuu" + 0.022*"thong_minh" + 0.021*"con_nguoi" + 0.018*"bao" + 0.017*"loi" + 0.015*"xanh" + 0.015*"muc_tieu"
# INFO : topic #20 (0.010): 0.061*"chuan" + 0.045*"kem" + 0.040*"san_pham" + 0.017*"agile" + 0.014*"can" + 0.012*"dang" + 0.012*"mat" + 0.012*"api" + 0.010*"trang" + 0.008*"đon_gian"
# INFO : topic #22 (0.010): 0.090*"skincare" + 0.041*"vui_choi" + 0.039*"ve" + 0.037*"du_lich" + 0.034*"tay" + 0.032*"lua_chon" + 0.024*"di_chuyen" + 0.024*"hanh_ly" + 0.021*"lich_trinh" + 0.021*"ky"
# INFO : topic #17 (0.010): 0.100*"phan" + 0.097*"api" + 0.052*"du_lieu" + 0.048*"đinh_dang" + 0.042*"restful" + 0.041*"chuan" + 0.039*"request" + 0.038*"quan_he" + 0.031*"cha" + 0.021*"san_pham"
# INFO : topic #7 (0.010): 0.013*"du_lich" + 0.011*"bui" + 0.006*"kinh_nghiem" + 0.005*"mua" + 0.005*"chuyen" + 0.004*"tour" + 0.003*"nuoc_ngoai" + 0.003*"khoi_hanh" + 0.003*"kiem_tra" + 0.003*"san_pham"
# INFO : topic diff=7.572158, rho=0.432338
# INFO : PROGRESS: pass 1, at document #40/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #23 (0.010): 0.012*"trang_web" + 0.011*"thiet_ke" + 0.011*"sprint" + 0.010*"web" + 0.009*"marketing" + 0.006*"mua" + 0.006*"team" + 0.006*"javascript" + 0.005*"du_an" + 0.005*"html"
# INFO : topic #15 (0.010): 0.065*"che_đo" + 0.057*"đau_tu" + 0.031*"san_pham" + 0.028*"can" + 0.026*"sua" + 0.021*"mat" + 0.017*"thi_truong" + 0.016*"duy_tri" + 0.015*"thuc" + 0.012*"cung_cap"
# INFO : topic #29 (0.010): 0.129*"kinh_doanh" + 0.047*"nang" + 0.035*"quy_trinh" + 0.027*"cong_ty" + 0.021*"marketing" + 0.016*"sinh_thai" + 0.016*"sau" + 0.015*"chuong_trinh" + 0.014*"that_bai" + 0.013*"mua"
# INFO : topic #24 (0.010): 0.130*"can" + 0.024*"khach_hang" + 0.024*"san_pham" + 0.024*"tang_truong" + 0.022*"du_an" + 0.020*"quan_ly" + 0.017*"lam_viec" + 0.017*"chay" + 0.016*"kinh_doanh" + 0.015*"đieu_chinh"
# INFO : topic #13 (0.010): 0.073*"lan" + 0.041*"kem" + 0.020*"đoc" + 0.020*"thanh_phan" + 0.019*"lop" + 0.015*"ban" + 0.014*"dang" + 0.013*"java" + 0.012*"goi" + 0.012*"san_pham"
# INFO : topic diff=7.982375, rho=0.432338
# INFO : PROGRESS: pass 1, at document #60/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #21 (0.010): 0.065*"tien" + 0.028*"dau" + 0.024*"doanh_nghiep" + 0.020*"gia" + 0.020*"mat" + 0.018*"thi_truong" + 0.018*"đong" + 0.016*"ngan_hang" + 0.016*"day" + 0.015*"san"
# INFO : topic #29 (0.010): 0.102*"kinh_doanh" + 0.056*"nang" + 0.029*"cong_ty" + 0.027*"quy_trinh" + 0.023*"tinh_than" + 0.019*"sau" + 0.018*"chuong_trinh" + 0.017*"thuong_xuyen" + 0.016*"marketing" + 0.013*"tich_cuc"
# INFO : topic #10 (0.010): 0.017*"agile" + 0.008*"đoi" + 0.007*"du_an" + 0.006*"muc_tieu" + 0.005*"vong" + 0.005*"san_pham" + 0.004*"team" + 0.004*"marketing" + 0.004*"phan_mem" + 0.004*"he_thong"
# INFO : topic #26 (0.010): 0.118*"uong" + 0.115*"chau" + 0.102*"ngu" + 0.050*"kem" + 0.038*"mat" + 0.033*"long" + 0.032*"ha" + 0.019*"the_thao" + 0.019*"tham_khao" + 0.018*"du_lich"
# INFO : topic #16 (0.010): 0.094*"co_the" + 0.059*"nang_luong" + 0.044*"loi" + 0.042*"nguy_co" + 0.028*"nghien_cuu" + 0.018*"tim" + 0.016*"the_ky" + 0.016*"ngan_ngua" + 0.014*"bao" + 0.014*"loi_ich"
# INFO : topic diff=8.057790, rho=0.432338
# INFO : -71.517 per-word bound, 3377839813849330483200.0 perplexity estimate based on a held-out corpus of 7 documents with 2106 words
# INFO : PROGRESS: pass 1, at document #67/67
# INFO : merging changes from 7 documents into a model of 67 documents
# INFO : topic #24 (0.010): 0.082*"tang_truong" + 0.081*"can" + 0.042*"đieu_chinh" + 0.031*"du_an" + 0.029*"truong_thanh" + 0.027*"quan_ly" + 0.027*"chieu" + 0.019*"phuong_an" + 0.019*"khach_hang" + 0.018*"yeu_to"
# INFO : topic #1 (0.010): 0.005*"thiet_ke" + 0.005*"trang_web" + 0.004*"thread" + 0.004*"web" + 0.004*"method" + 0.004*"xay_dung" + 0.003*"cung_cap" + 0.003*"đoi_tuong" + 0.003*"css" + 0.003*"agile"
# INFO : topic #12 (0.010): 0.008*"thong_minh" + 0.005*"backend" + 0.004*"frontend" + 0.003*"may" + 0.003*"ta" + 0.003*"muc_tieu" + 0.003*"marketing" + 0.003*"sprint" + 0.003*"tri_tue" + 0.002*"con_nguoi"
# INFO : topic #23 (0.010): 0.006*"trang_web" + 0.006*"thiet_ke" + 0.006*"sprint" + 0.005*"web" + 0.005*"marketing" + 0.003*"mua" + 0.003*"team" + 0.003*"javascript" + 0.003*"du_an" + 0.003*"html"
# INFO : topic #7 (0.010): 0.003*"du_lich" + 0.003*"bui" + 0.002*"kinh_nghiem" + 0.002*"mua" + 0.001*"chuyen" + 0.001*"tour" + 0.001*"nuoc_ngoai" + 0.001*"khoi_hanh" + 0.001*"kiem_tra" + 0.001*"san_pham"
# INFO : topic diff=7.657884, rho=0.432338
# INFO : PROGRESS: pass 2, at document #20/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #14 (0.010): 0.132*"design" + 0.072*"thiet_ke" + 0.065*"google" + 0.048*"la" + 0.044*"san" + 0.044*"web" + 0.037*"bao_gom" + 0.034*"framework" + 0.029*"nen_tang" + 0.029*"bieu_tuong"
# INFO : topic #20 (0.010): 0.117*"chuan" + 0.101*"kem" + 0.047*"san_pham" + 0.007*"mat" + 0.006*"can" + 0.005*"dang" + 0.004*"agile" + 0.003*"trang" + 0.003*"api" + 0.002*"đon_gian"
# INFO : topic #24 (0.010): 0.050*"can" + 0.048*"tang_truong" + 0.038*"du_an" + 0.028*"đieu_chinh" + 0.025*"quan_ly" + 0.025*"khach_hang" + 0.018*"san_pham" + 0.018*"truong_thanh" + 0.017*"chieu" + 0.016*"mua"
# INFO : topic #7 (0.010): 0.002*"du_lich" + 0.002*"bui" + 0.001*"kinh_nghiem" + 0.001*"mua" + 0.001*"chuyen" + 0.001*"tour" + 0.001*"nuoc_ngoai" + 0.001*"khoi_hanh" + 0.001*"kiem_tra" + 0.001*"san_pham"
# INFO : topic #25 (0.010): 0.077*"ngon_ngu" + 0.073*"ung_dung" + 0.032*"am" + 0.031*"thiet_ke" + 0.031*"swift" + 0.027*"lap_trinh" + 0.027*"tinh_nang" + 0.027*"mo_hinh" + 0.025*"tuyet_voi" + 0.021*"cong_cu"
# INFO : topic diff=6.518918, rho=0.396838
# INFO : PROGRESS: pass 2, at document #40/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #10 (0.010): 0.005*"agile" + 0.003*"đoi" + 0.002*"du_an" + 0.002*"muc_tieu" + 0.002*"vong" + 0.002*"san_pham" + 0.002*"team" + 0.002*"marketing" + 0.002*"phan_mem" + 0.002*"he_thong"
# INFO : topic #7 (0.010): 0.002*"du_lich" + 0.001*"bui" + 0.001*"kinh_nghiem" + 0.001*"mua" + 0.001*"chuyen" + 0.001*"tour" + 0.001*"nuoc_ngoai" + 0.001*"khoi_hanh" + 0.001*"kiem_tra" + 0.001*"san_pham"
# INFO : topic #29 (0.010): 0.137*"kinh_doanh" + 0.049*"nang" + 0.029*"cong_ty" + 0.028*"quy_trinh" + 0.020*"sinh_thai" + 0.017*"marketing" + 0.017*"sau" + 0.016*"mo_hinh" + 0.016*"chuong_trinh" + 0.015*"that_bai"
# INFO : topic #17 (0.010): 0.157*"phan" + 0.080*"api" + 0.070*"du_lieu" + 0.066*"chuan" + 0.061*"đinh_dang" + 0.057*"cha" + 0.055*"restful" + 0.052*"quan_he" + 0.029*"nang_ne" + 0.024*"san_pham"
# INFO : topic #20 (0.010): 0.353*"kem" + 0.284*"chuan" + 0.079*"san_pham" + 0.002*"mat" + 0.001*"can" + 0.001*"dang" + 0.001*"agile" + 0.001*"trang" + 0.001*"api" + 0.001*"đon_gian"
# INFO : topic diff=5.379651, rho=0.396838
# INFO : PROGRESS: pass 2, at document #60/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #0 (0.010): 0.231*"mat" + 0.224*"agile" + 0.144*"san_pham" + 0.128*"quy_trinh" + 0.035*"mong_muon" + 0.032*"vong" + 0.027*"test" + 0.026*"stories" + 0.025*"development" + 0.017*"user"
# INFO : topic #6 (0.010): 0.131*"tieu_thu" + 0.052*"hieu_qua" + 0.047*"keo_dai" + 0.042*"đam" + 0.041*"chu_ky" + 0.036*"đoi" + 0.027*"tham_gia" + 0.026*"he_thong" + 0.025*"chung_minh" + 0.022*"tich_cuc"
# INFO : topic #2 (0.010): 0.002*"du_lich" + 0.002*"trang_web" + 0.002*"thiet_ke" + 0.002*"thong_minh" + 0.001*"web" + 0.001*"bui" + 0.001*"html" + 0.001*"chuyen" + 0.001*"xay_dung" + 0.001*"cung_cap"
# INFO : topic #13 (0.010): 0.082*"lan" + 0.034*"kem" + 0.020*"nhanh_chong" + 0.018*"lop" + 0.018*"thanh_phan" + 0.016*"đoc" + 0.015*"ban" + 0.013*"toan_cau" + 0.013*"bao_ve" + 0.013*"goi"
# INFO : topic #17 (0.010): 0.172*"quan_he" + 0.103*"phan" + 0.098*"nang_ne" + 0.067*"nhat" + 0.064*"du_lieu" + 0.053*"api" + 0.043*"chuan" + 0.040*"đinh_dang" + 0.038*"cha" + 0.036*"restful"
# INFO : topic diff=4.373259, rho=0.396838
# INFO : -71.214 per-word bound, 2739302178561203372032.0 perplexity estimate based on a held-out corpus of 7 documents with 2106 words
# INFO : PROGRESS: pass 2, at document #67/67
# INFO : merging changes from 7 documents into a model of 67 documents
# INFO : topic #13 (0.010): 0.076*"lan" + 0.033*"kem" + 0.019*"thanh_phan" + 0.019*"nhanh_chong" + 0.018*"ban" + 0.017*"lop" + 0.015*"đoc" + 0.012*"toan_cau" + 0.012*"goi" + 0.012*"bao_ve"
# INFO : topic #22 (0.010): 0.250*"skincare" + 0.090*"tay" + 0.045*"ky" + 0.035*"cum" + 0.030*"lua_chon" + 0.029*"quy_đinh" + 0.026*"đep" + 0.023*"lo" + 0.023*"niem" + 0.022*"luu_y"
# INFO : topic #12 (0.010): 0.002*"thong_minh" + 0.001*"backend" + 0.001*"frontend" + 0.001*"may" + 0.001*"ta" + 0.001*"muc_tieu" + 0.001*"marketing" + 0.001*"sprint" + 0.001*"tri_tue" + 0.001*"con_nguoi"
# INFO : topic #3 (0.010): 0.170*"backend" + 0.122*"frontend" + 0.063*"du_lieu" + 0.050*"tao" + 0.047*"phuong_thuc" + 0.040*"client" + 0.035*"thong_bao" + 0.029*"token" + 0.027*"minh_hoa" + 0.024*"hien_thi"
# INFO : topic #5 (0.010): 0.063*"kinh_te" + 0.056*"thi_truong" + 0.037*"von" + 0.023*"tai_chinh" + 0.021*"nam" + 0.018*"the_gioi" + 0.016*"quy" + 0.015*"rui_ro" + 0.015*"quoc" + 0.013*"xa_hoi"
# INFO : topic diff=3.507858, rho=0.396838
# INFO : PROGRESS: pass 3, at document #20/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #1 (0.010): 0.001*"thiet_ke" + 0.001*"trang_web" + 0.001*"thread" + 0.001*"web" + 0.001*"method" + 0.001*"xay_dung" + 0.001*"cung_cap" + 0.001*"đoi_tuong" + 0.001*"css" + 0.001*"agile"
# INFO : topic #2 (0.010): 0.001*"du_lich" + 0.001*"trang_web" + 0.001*"thiet_ke" + 0.001*"thong_minh" + 0.001*"web" + 0.001*"bui" + 0.001*"html" + 0.001*"chuyen" + 0.001*"xay_dung" + 0.001*"cung_cap"
# INFO : topic #11 (0.010): 0.072*"trang_web" + 0.063*"web" + 0.051*"thiet_ke" + 0.045*"javascript" + 0.041*"html" + 0.040*"ngon_ngu" + 0.035*"lap_trinh" + 0.031*"css" + 0.026*"ma" + 0.024*"doanh_nghiep"
# INFO : topic #16 (0.010): 0.055*"co_the" + 0.050*"nang_luong" + 0.034*"nguy_co" + 0.028*"loi" + 0.027*"thong_minh" + 0.027*"nghien_cuu" + 0.022*"con_nguoi" + 0.022*"xanh" + 0.017*"loi_ich" + 0.016*"co"
# INFO : topic #29 (0.010): 0.072*"kinh_doanh" + 0.028*"nang" + 0.025*"marketing" + 0.021*"cong_ty" + 0.018*"tich_cuc" + 0.018*"mo_hinh" + 0.016*"quy_trinh" + 0.016*"sau" + 0.016*"tinh_than" + 0.014*"ap_dung"
# INFO : topic diff=2.861294, rho=0.368856
# INFO : PROGRESS: pass 3, at document #40/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #13 (0.010): 0.090*"lan" + 0.032*"kem" + 0.023*"lop" + 0.022*"thanh_phan" + 0.019*"ban" + 0.016*"nhanh_chong" + 0.015*"goi" + 0.015*"đoc" + 0.014*"bao_ve" + 0.013*"trang"
# INFO : topic #4 (0.010): 0.047*"xay_dung" + 0.038*"cung_cap" + 0.034*"đoc" + 0.032*"dang" + 0.031*"hoc" + 0.022*"thua" + 0.020*"đon_gian" + 0.019*"kieu" + 0.019*"cai" + 0.019*"loi"
# INFO : topic #3 (0.010): 0.213*"backend" + 0.149*"frontend" + 0.087*"du_lieu" + 0.062*"tao" + 0.061*"phuong_thuc" + 0.043*"client" + 0.031*"xay" + 0.030*"gui" + 0.029*"hien_thi" + 0.026*"goi"
# INFO : topic #12 (0.010): 0.001*"thong_minh" + 0.001*"backend" + 0.001*"frontend" + 0.001*"may" + 0.001*"ta" + 0.001*"muc_tieu" + 0.001*"marketing" + 0.001*"sprint" + 0.001*"tri_tue" + 0.001*"con_nguoi"
# INFO : topic #28 (0.010): 0.248*"user" + 0.222*"stories" + 0.145*"marketing" + 0.075*"ghi" + 0.052*"noi_dung" + 0.040*"tiep_thi" + 0.037*"tinh_nang" + 0.036*"khach_hang" + 0.014*"thiet_ke" + 0.008*"role"
# INFO : topic diff=2.104554, rho=0.368856
# INFO : PROGRESS: pass 3, at document #60/67
# INFO : merging changes from 20 documents into a model of 67 documents
# INFO : topic #0 (0.010): 0.247*"mat" + 0.200*"san_pham" + 0.198*"agile" + 0.161*"quy_trinh" + 0.036*"vong" + 0.027*"mong_muon" + 0.026*"test" + 0.024*"development" + 0.010*"stories" + 0.008*"đem"
# INFO : topic #24 (0.010): 0.088*"can" + 0.079*"tang_truong" + 0.023*"đieu_chinh" + 0.021*"khach_hang" + 0.021*"thuong_xuyen" + 0.021*"lam_viec" + 0.020*"quan_ly" + 0.019*"du_an" + 0.019*"cong_viec" + 0.015*"yeu_to"
# INFO : topic #6 (0.010): 0.127*"tieu_thu" + 0.055*"hieu_qua" + 0.044*"keo_dai" + 0.040*"đam" + 0.039*"chu_ky" + 0.037*"đoi" + 0.028*"he_thong" + 0.026*"tham_gia" + 0.024*"chung_minh" + 0.022*"dung"
# INFO : topic #18 (0.010): 0.001*"backend" + 0.001*"frontend" + 0.001*"trang_web" + 0.001*"ngon_ngu" + 0.001*"thiet_ke" + 0.001*"html" + 0.001*"web" + 0.001*"ung_dung" + 0.001*"tinh_nang" + 0.001*"css"
# INFO : topic #13 (0.010): 0.090*"lan" + 0.028*"kem" + 0.021*"nhanh_chong" + 0.020*"lop" + 0.018*"thanh_phan" + 0.017*"ban" + 0.016*"bao_ve" + 0.014*"đoc" + 0.014*"goi" + 0.013*"sup_đo"
# INFO : topic diff=1.574997, rho=0.368856
# INFO : -71.109 per-word bound, 2546761345202904367104.0 perplexity estimate based on a held-out corpus of 7 documents with 2106 words
# INFO : PROGRESS: pass 3, at document #67/67
# INFO : merging changes from 7 documents into a model of 67 documents
# INFO : topic #16 (0.010): 0.087*"co_the" + 0.077*"nang_luong" + 0.047*"nguy_co" + 0.044*"loi" + 0.034*"xanh" + 0.023*"nghien_cuu" + 0.022*"loi_ich" + 0.019*"tim" + 0.019*"chang_han" + 0.017*"đuong"
# INFO : topic #10 (0.010): 0.001*"agile" + 0.001*"đoi" + 0.001*"du_an" + 0.001*"muc_tieu" + 0.001*"vong" + 0.001*"san_pham" + 0.001*"team" + 0.001*"marketing" + 0.001*"phan_mem" + 0.001*"he_thong"
# INFO : topic #12 (0.010): 0.001*"thong_minh" + 0.001*"backend" + 0.001*"frontend" + 0.001*"may" + 0.001*"ta" + 0.001*"muc_tieu" + 0.001*"marketing" + 0.001*"sprint" + 0.001*"tri_tue" + 0.001*"con_nguoi"
# INFO : topic #7 (0.010): 0.001*"du_lich" + 0.001*"bui" + 0.001*"kinh_nghiem" + 0.001*"mua" + 0.001*"chuyen" + 0.001*"tour" + 0.001*"nuoc_ngoai" + 0.001*"khoi_hanh" + 0.001*"kiem_tra" + 0.001*"san_pham"
# INFO : topic #23 (0.010): 0.001*"trang_web" + 0.001*"thiet_ke" + 0.001*"sprint" + 0.001*"web" + 0.001*"marketing" + 0.001*"mua" + 0.001*"team" + 0.001*"javascript" + 0.001*"du_an" + 0.001*"html"
# INFO : topic diff=1.253532, rho=0.368856
# INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=1670, num_topics=30, decay=0.5, chunksize=20> in 5.09s', 'datetime': '2022-12-20T10:15:12.861195', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
lda_model.save('../models/LDA.model')
lda_model.print_topics()
# Out:
# INFO : LdaState lifecycle event {'fname_or_handle': '../models/LDA.model.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-12-20T10:15:12.920197', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/LDA.model.state
# INFO : LdaModel lifecycle event {'fname_or_handle': '../models/LDA.model', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['dispatcher', 'state', 'id2word'], 'datetime': '2022-12-20T10:15:12.954190', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : storing np array 'expElogbeta' to ../models/LDA.model.expElogbeta.npy
# INFO : not storing attribute dispatcher
# INFO : not storing attribute state
# INFO : not storing attribute id2word
# INFO : saved ../models/LDA.model
# INFO : topic #16 (0.010): 0.087*"co_the" + 0.077*"nang_luong" + 0.047*"nguy_co" + 0.044*"loi" + 0.034*"xanh" + 0.023*"nghien_cuu" + 0.022*"loi_ich" + 0.019*"tim" + 0.019*"chang_han" + 0.017*"đuong"
# INFO : topic #17 (0.010): 0.254*"phan" + 0.118*"quan_he" + 0.108*"du_lieu" + 0.067*"nang_ne" + 0.059*"nhat" + 0.030*"đinh_dang" + 0.028*"chuan" + 0.027*"cha" + 0.027*"restful" + 0.024*"api"
# INFO : topic #15 (0.010): 0.115*"che_đo" + 0.090*"đau_tu" + 0.034*"can" + 0.030*"sua" + 0.026*"san_pham" + 0.021*"thuc" + 0.021*"dang" + 0.020*"giau" + 0.018*"cung_cap" + 0.018*"bao"
# INFO : topic #2 (0.010): 0.001*"du_lich" + 0.001*"trang_web" + 0.001*"thiet_ke" + 0.001*"thong_minh" + 0.001*"web" + 0.001*"bui" + 0.001*"html" + 0.001*"chuyen" + 0.001*"xay_dung" + 0.001*"cung_cap"
# INFO : topic #4 (0.010): 0.052*"xay_dung" + 0.038*"thua" + 0.037*"cung_cap" + 0.035*"dang" + 0.029*"loi" + 0.027*"hoc" + 0.026*"đoc" + 0.026*"ngon" + 0.025*"cai" + 0.023*"san"
# INFO : topic #6 (0.010): 0.146*"tieu_thu" + 0.054*"trien_khai" + 0.052*"hieu_qua" + 0.040*"he_thong" + 0.039*"du_an" + 0.033*"đoi" + 0.030*"chu_ky" + 0.030*"san_xuat" + 0.028*"chung_minh" + 0.026*"keo_dai"
# INFO : topic #27 (0.010): 0.171*"ta" + 0.138*"api" + 0.087*"request" + 0.047*"code" + 0.040*"user" + 0.037*"file" + 0.034*"project" + 0.033*"server" + 0.030*"ket_noi" + 0.026*"response"
# INFO : topic #19 (0.010): 0.087*"an_uong" + 0.068*"song" + 0.053*"benh" + 0.051*"đuong" + 0.051*"uong" + 0.036*"bua" + 0.036*"dau" + 0.035*"chua" + 0.032*"mac" + 0.028*"tre"
# INFO : topic #11 (0.010): 0.059*"ngon_ngu" + 0.059*"lap_trinh" + 0.046*"web" + 0.045*"javascript" + 0.036*"trang_web" + 0.036*"java" + 0.031*"php" + 0.029*"thiet_ke" + 0.028*"ma" + 0.022*"doanh_nghiep"
# INFO : topic #0 (0.010): 0.241*"mat" + 0.195*"san_pham" + 0.194*"agile" + 0.157*"quy_trinh" + 0.035*"vong" + 0.026*"mong_muon" + 0.025*"test" + 0.024*"development" + 0.010*"stories" + 0.008*"đem"
# INFO : topic #21 (0.010): 0.099*"doanh_nghiep" + 0.063*"tien" + 0.046*"tin_dung" + 0.043*"thi_truong" + 0.026*"mua" + 0.025*"gia" + 0.024*"đao" + 0.018*"dong" + 0.017*"luat" + 0.017*"đong"
# INFO : topic #29 (0.010): 0.129*"kinh_doanh" + 0.050*"nang" + 0.032*"tich_cuc" + 0.027*"cong_ty" + 0.023*"tinh_than" + 0.020*"sau" + 0.016*"chuong_trinh" + 0.016*"thuong_xuyen" + 0.014*"sinh_thai" + 0.014*"mo_hinh"
# INFO : topic #9 (0.010): 0.001*"design" + 0.001*"du_lich" + 0.001*"thiet_ke" + 0.001*"cung_cap" + 0.001*"chuyen" + 0.001*"web" + 0.001*"css" + 0.001*"mua" + 0.001*"xay_dung" + 0.001*"the"
# INFO : topic #1 (0.010): 0.001*"thiet_ke" + 0.001*"trang_web" + 0.001*"thread" + 0.001*"web" + 0.001*"method" + 0.001*"xay_dung" + 0.001*"cung_cap" + 0.001*"đoi_tuong" + 0.001*"css" + 0.001*"agile"
# INFO : topic #7 (0.010): 0.001*"du_lich" + 0.001*"bui" + 0.001*"kinh_nghiem" + 0.001*"mua" + 0.001*"chuyen" + 0.001*"tour" + 0.001*"nuoc_ngoai" + 0.001*"khoi_hanh" + 0.001*"kiem_tra" + 0.001*"san_pham"
# INFO : topic #3 (0.010): 0.183*"backend" + 0.128*"frontend" + 0.075*"du_lieu" + 0.054*"tao" + 0.053*"phuong_thuc" + 0.037*"client" + 0.034*"thong_bao" + 0.029*"token" + 0.028*"xay" + 0.027*"minh_hoa"
# INFO : topic #5 (0.010): 0.064*"kinh_te" + 0.056*"thi_truong" + 0.037*"von" + 0.024*"tai_chinh" + 0.021*"nam" + 0.019*"the_gioi" + 0.017*"quy" + 0.016*"rui_ro" + 0.015*"quoc" + 0.013*"xa_hoi"
# INFO : topic #8 (0.010): 0.166*"giao_dich" + 0.121*"thong_tin" + 0.105*"sprint" + 0.097*"marketing" + 0.086*"thanh_vien" + 0.054*"team" + 0.051*"scrum" + 0.050*"tai_lieu" + 0.048*"meeting" + 0.043*"tham_gia"
# INFO : topic #10 (0.010): 0.001*"agile" + 0.001*"đoi" + 0.001*"du_an" + 0.001*"muc_tieu" + 0.001*"vong" + 0.001*"san_pham" + 0.001*"team" + 0.001*"marketing" + 0.001*"phan_mem" + 0.001*"he_thong"
# INFO : topic #14 (0.010): 0.142*"la" + 0.060*"san" + 0.056*"google" + 0.053*"design" + 0.052*"he" + 0.043*"thiet_ke" + 0.041*"web" + 0.037*"trong_luong" + 0.035*"hinh_thuc" + 0.031*"nen_tang"
# [(16,
#   '0.087*"co_the" + 0.077*"nang_luong" + 0.047*"nguy_co" + 0.044*"loi" + 0.034*"xanh" + 0.023*"nghien_cuu" + 0.022*"loi_ich" + 0.019*"tim" + 0.019*"chang_han" + 0.017*"đuong"'),
#  (17,
#   '0.254*"phan" + 0.118*"quan_he" + 0.108*"du_lieu" + 0.067*"nang_ne" + 0.059*"nhat" + 0.030*"đinh_dang" + 0.028*"chuan" + 0.027*"cha" + 0.027*"restful" + 0.024*"api"'),
#  (15,
#   '0.115*"che_đo" + 0.090*"đau_tu" + 0.034*"can" + 0.030*"sua" + 0.026*"san_pham" + 0.021*"thuc" + 0.021*"dang" + 0.020*"giau" + 0.018*"cung_cap" + 0.018*"bao"'),
#  (2,
#   '0.001*"du_lich" + 0.001*"trang_web" + 0.001*"thiet_ke" + 0.001*"thong_minh" + 0.001*"web" + 0.001*"bui" + 0.001*"html" + 0.001*"chuyen" + 0.001*"xay_dung" + 0.001*"cung_cap"'),
#  (4,
#   '0.052*"xay_dung" + 0.038*"thua" + 0.037*"cung_cap" + 0.035*"dang" + 0.029*"loi" + 0.027*"hoc" + 0.026*"đoc" + 0.026*"ngon" + 0.025*"cai" + 0.023*"san"'),
#  (6,
#   '0.146*"tieu_thu" + 0.054*"trien_khai" + 0.052*"hieu_qua" + 0.040*"he_thong" + 0.039*"du_an" + 0.033*"đoi" + 0.030*"chu_ky" + 0.030*"san_xuat" + 0.028*"chung_minh" + 0.026*"keo_dai"'),
#  (27,
#   '0.171*"ta" + 0.138*"api" + 0.087*"request" + 0.047*"code" + 0.040*"user" + 0.037*"file" + 0.034*"project" + 0.033*"server" + 0.030*"ket_noi" + 0.026*"response"'),
#  (19,
#   '0.087*"an_uong" + 0.068*"song" + 0.053*"benh" + 0.051*"đuong" + 0.051*"uong" + 0.036*"bua" + 0.036*"dau" + 0.035*"chua" + 0.032*"mac" + 0.028*"tre"'),
#  (11,
#   '0.059*"ngon_ngu" + 0.059*"lap_trinh" + 0.046*"web" + 0.045*"javascript" + 0.036*"trang_web" + 0.036*"java" + 0.031*"php" + 0.029*"thiet_ke" + 0.028*"ma" + 0.022*"doanh_nghiep"'),
#  (0,
#   '0.241*"mat" + 0.195*"san_pham" + 0.194*"agile" + 0.157*"quy_trinh" + 0.035*"vong" + 0.026*"mong_muon" + 0.025*"test" + 0.024*"development" + 0.010*"stories" + 0.008*"đem"'),
#  (21,
#   '0.099*"doanh_nghiep" + 0.063*"tien" + 0.046*"tin_dung" + 0.043*"thi_truong" + 0.026*"mua" + 0.025*"gia" + 0.024*"đao" + 0.018*"dong" + 0.017*"luat" + 0.017*"đong"'),
#  (29,
#   '0.129*"kinh_doanh" + 0.050*"nang" + 0.032*"tich_cuc" + 0.027*"cong_ty" + 0.023*"tinh_than" + 0.020*"sau" + 0.016*"chuong_trinh" + 0.016*"thuong_xuyen" + 0.014*"sinh_thai" + 0.014*"mo_hinh"'),
#  (9,
#   '0.001*"design" + 0.001*"du_lich" + 0.001*"thiet_ke" + 0.001*"cung_cap" + 0.001*"chuyen" + 0.001*"web" + 0.001*"css" + 0.001*"mua" + 0.001*"xay_dung" + 0.001*"the"'),
#  (1,
#   '0.001*"thiet_ke" + 0.001*"trang_web" + 0.001*"thread" + 0.001*"web" + 0.001*"method" + 0.001*"xay_dung" + 0.001*"cung_cap" + 0.001*"đoi_tuong" + 0.001*"css" + 0.001*"agile"'),
#  (7,
#   '0.001*"du_lich" + 0.001*"bui" + 0.001*"kinh_nghiem" + 0.001*"mua" + 0.001*"chuyen" + 0.001*"tour" + 0.001*"nuoc_ngoai" + 0.001*"khoi_hanh" + 0.001*"kiem_tra" + 0.001*"san_pham"'),
#  (3,
#   '0.183*"backend" + 0.128*"frontend" + 0.075*"du_lieu" + 0.054*"tao" + 0.053*"phuong_thuc" + 0.037*"client" + 0.034*"thong_bao" + 0.029*"token" + 0.028*"xay" + 0.027*"minh_hoa"'),
#  (5,
#   '0.064*"kinh_te" + 0.056*"thi_truong" + 0.037*"von" + 0.024*"tai_chinh" + 0.021*"nam" + 0.019*"the_gioi" + 0.017*"quy" + 0.016*"rui_ro" + 0.015*"quoc" + 0.013*"xa_hoi"'),
#  (8,
#   '0.166*"giao_dich" + 0.121*"thong_tin" + 0.105*"sprint" + 0.097*"marketing" + 0.086*"thanh_vien" + 0.054*"team" + 0.051*"scrum" + 0.050*"tai_lieu" + 0.048*"meeting" + 0.043*"tham_gia"'),
#  (10,
#   '0.001*"agile" + 0.001*"đoi" + 0.001*"du_an" + 0.001*"muc_tieu" + 0.001*"vong" + 0.001*"san_pham" + 0.001*"team" + 0.001*"marketing" + 0.001*"phan_mem" + 0.001*"he_thong"'),
#  (14,
#   '0.142*"la" + 0.060*"san" + 0.056*"google" + 0.053*"design" + 0.052*"he" + 0.043*"thiet_ke" + 0.041*"web" + 0.037*"trong_luong" + 0.035*"hinh_thuc" + 0.031*"nen_tang"')]

# %%
import numpy as np
doc_topic_dist = np.array(
    [[tup[1] for tup in lst] for lst in lda_model[corpus]]
)

# %%
doc_topic_dist
# Out:
# array([[3.6597070e-05, 3.6597070e-05, 3.6597070e-05, ..., 1.4697355e-02,
#         3.6597070e-05, 3.6597070e-05],
#        [1.1588337e-05, 1.1588337e-05, 1.1588337e-05, ..., 5.9360261e-03,
#         1.1588337e-05, 7.0366994e-03],
#        [5.1211060e-05, 5.1211060e-05, 5.1211060e-05, ..., 5.2127051e-03,
#         5.1211060e-05, 5.1211060e-05],
#        ...,
#        [3.0650644e-05, 3.0650644e-05, 3.0650644e-05, ..., 3.0650644e-05,
#         3.0650644e-05, 3.3435758e-02],
#        [7.8560610e-05, 7.8560610e-05, 7.8560610e-05, ..., 7.8560610e-05,
#         7.8560610e-05, 7.8560610e-05],
#        [5.6729281e-05, 5.6729281e-05, 5.6729281e-05, ..., 5.6729281e-05,
#         5.6729281e-05, 3.5609804e-02]], dtype=float32)

# %%
import joblib

# %%
joblib.dump(doc_topic_dist, '../models/doc_topic_dist.dat')
# Out:
# ['../models/doc_topic_dist.dat']
