# %%
import requests
from time import sleep

from tqdm import tqdm
import pymongo
from pymongo import MongoClient

import gensim
from gensim.utils import simple_preprocess

# %%
import logging
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO

# %%
import sys
sys.path.append('../')
from src import settings

from src.utils import editorJs_data_to_text
import json

# %%
client = MongoClient(settings.MONGODB_SETTINGS['host'])
db = client[settings.MONGODB_SETTINGS['db']]
col = db[settings.MONGODB_SETTINGS['collection']]

# %%
posts = col.find()

# %%
for i, post in enumerate(posts):
    print(post['title'])
    if i == 12: break
# Out:
# ĐỒ ÁN THIẾT KẾ WEBSITE BLOG SITE
# setState trong React
# Regular Expression trong Javascript
# Các bài tập java cơ bản
# Những câu hỏi lập trình khi pv (2): bài toán ATM
# Ví dụ sắp xếp nổi bọt với Java
# Chương trình lọc thư rác bằng Java, code ví dụ
# Đọc ghi file Excel trong Java sử dụng Apache POI
# THREAD AND THREAD POOLS IN JAVA
# Sử dụng CountDownLatch trong Java
# Multithreading: Java Synchronized Blocks
# Understand synchronized and improve lock performance in Java
# Front-End Web Developers

# %%
posts = col.find()
test_post = next(posts)

# %%
raw_content = test_post['content']
content = editorJs_data_to_text(json.loads(raw_content))

# %%
print(content)
# Out:
# đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đí ...

# %%
for i, post in tqdm(enumerate(col.find()), total=col.count_documents({})):
    try:
        col.update_one({"_id": post["_id"]}, {"$set": {"idrs": i}})
        pp_content = editorJs_data_to_text(json.loads(post['content']))
        col.update_one({"_id": post["_id"]}, {"$set": {"pp_content": pp_content}})
    except Exception as e:
        print(e)
        continue
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 177/177 [00:41<00:00,  4.23it/s]

# %%
client = MongoClient(settings.MONGODB_SETTINGS['host'])
db = client[settings.MONGODB_SETTINGS['db']]
col = db[settings.MONGODB_SETTINGS['collection']]

posts = col.find()
test_post = next(posts)

# %%
test_post['pp_content']
# Out:
# 'đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đ ...

# %%
def make_sentences():
    for post in col.find():
        yield post['pp_content'] # lấy thuộc tính pp_content của từng document trong post collection

# %%
def make_texts_corpus(sentences):
    for sentence in sentences:
        yield simple_preprocess(sentence, deacc=True) # tách chữ cái của từng pp_content
#         yield [word for word in sentence.split()]

# %%
import itertools

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)
id2word = gensim.corpora.Dictionary(sentences)
# Out:
# INFO : adding document #0 to Dictionary<0 unique tokens: []>
# INFO : built Dictionary<8863 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 177 documents (total 91832 corpus positions)
# INFO : Dictionary lifecycle event {'msg': "built Dictionary<8863 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 177 documents (total 91832 corpus positions)", 'datetime': '2022-12-29T04:01:18.341353', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
id2word.token2id
# Out:
# {'account': 0,
#  'actor': 1,
#  'allocation': 2,
#  'amazon': 3,
#  'an': 4,
#  'analysis': 5,
#  'anh': 6,
#  'anhđuong': 7,
#  'ap_đat': 8,
#  'api': 9,
#  'application': 10,
#  'avatar': 11,
#  'axios': 12,
#  'bai': 13,
#  'bai_bo': 14,
#  'bai_toan': 15,
#  'ban_be': 16,
#  'ban_cai': 17,
#  'ban_chat': 18,
#  'banfacebook': 19,
#  'bang': 20,
#  'bannetflix': 21,
#  'banxoa': 22,
#  'bao_cao': 23,
#  'bao_gom': 24,
#  'bao_mat': 25,
#  'bao_phu': 26,
#  'bao_ve': 27,
#  'baoluu': 28,
#  'bat_kha_thi': 29,
#  'bayes': 30,
#  'bayesian': 31,
#  'bebo': 32,
#  'bia': 33,
#  'bich': 34,
#  'bien': 35,
#  'bien_tap': 36,
#  'bien_đoi': 37,
#  'bieu_dien': 38,
#  'bieu_thi': 39,
#  'bieu_tuong': 40,
#  'big': 41,
#  'binh': 42,
#  'binh_luan': 43,
#  'bio': 44,
#  'biopost': 45,
#  'blog': 46,
#  'blogger': 47,
#  'bo_nho': 48,
#  'bookmark': 49,
#  'boolean': 50,
#  'boot': 51,
#  'bought': 52,
#  'bung_no': 53,
#  'business': 54,
#  'ca_si': 55,
#  'cai_thien': 56,
#  'cai_tien': 57,
#  'can_thiet': 58,
#  'canh': 59,
#  'canh_sat': 60,
#  'cap': 61,
#  'cap_đo': 62,
#  'cascading': 63,
#  'case': 64,
#  'cau': 65,
#  'cau_hinh': 66,
#  'cau_truc': 67,
#  'cauxoa': 68,
#  'cham': 69,
#  'chan': 70,
#  'chat_luong': 71,
#  'chay': 72,
#  'che_đo': 73,
#  'chi_thuc_su': 74,
#  'chi_tiet': 75,
#  'chia': 76,
#  'chien_luoc': 77,
#  'chien_thuat': 78,
#  'chinh_sua': 79,
#  'chinh_xac': 80,
#  'chinhlam': 81,
#  'chong': 82,
#  'chu_bai': 83,
#  'chu_quan': 84,
#  'chu_đe': 85,
#  'chua': 86,
#  'chuan_hoa': 87,
#  'chuc_nang': 88,
#  'chung_khoan': 89,
#  'chung_minh': 90,
#  'chuoi': 91,
#  'chuong': 92,
#  'chuong_trinh': 93,
#  'chuyen_biet': 94,
#  'chuyen_hoa': 95,
#  'chuyen_huong': 96,
#  'chuyen_tiep': 97,
#  'chuyen_đoi': 98,
#  'classification': 99,
#  'click': 100,
#  'client': 101,
#  'clip': 102,
#  'cloud': 103,
#  'co_ban': 104,
#  'co_le': 105,
#  'co_phieu': 106,
#  'co_so': 107,
#  'co_đinh': 108,
#  'code': 109,
#  'codebase': 110,
#  'coi': 111,
#  'collaborative': 112,
#  'collection': 113,
#  'comment': 114,
#  'compass': 115,
#  'component': 116,
#  'con_nguoi': 117,
#  'cong_cu': 118,
#  'cong_khai': 119,
#  'cong_nghe': 120,
#  'cong_ty': 121,
#  'cong_viec': 122,
#  'congthat': 123,
#  'content': 124,
#  'contentbased': 125,
#  'corpora': 126,
#  'corpus': 127,
#  'corpuslevel': 128,
#  'createddate': 129,
#  'csdl': 130,
#  'css': 131,
#  'cung_cap': 132,
#  'cuoc_song': 133,
#  'dan': 134,
#  'dang': 135,
#  'danh_sach': 136,
#  'danvoi': 137,
#  'data': 138,
#  'dataset': 139,
#  'ddd': 140,
#  'de_dang': 141,
#  'debug': 142,
#  'degree': 143,
#  'dependency': 144,
#  'di_đong': 145,
#  'diagram': 146,
#  'dich_vu': 147,
#  'dirichlet': 148,
#  'discriminant': 149,
#  'dm': 150,
#  'doanh': 151,
#  'doanh_nghiep': 152,
#  'doanh_thu': 153,
#  'document': 154,
#  'documentlevel': 155,
#  'doi': 156,
#  'doitim': 157,
#  'doiviet': 158,
#  'du_an': 159,
#  'du_bao': 160,
#  'du_lieu': 161,
#  'du_đoan': 162,
#  'dua': 163,
#  'dung': 164,
#  'duy_tri': 165,
#  'editor': 166,
#  'email': 167,
#  'facebook': 168,
#  'false': 169,
#  'file': 170,
#  'filtering': 171,
#  'follow': 172,
#  'followers': 173,
#  'following': 174,
#  'followings': 175,
#  'follwers': 176,
#  'framework': 177,
#  'frequently': 178,
#  'gan': 179,
#  'gender': 180,
#  'ghi_chu': 181,
#  'gia': 182,
#  'gia_đinh': 183,
#  'giai_phap': 184,
#  'giai_thuong': 185,
#  'giai_đap': 186,
#  'giam_sat': 187,
#  'giao_dien': 188,
#  'giao_luu': 189,
#  'gibbs': 190,
#  'gioi_thieu': 191,
#  'gioi_tinh': 192,
#  'git': 193,
#  'github': 194,
#  'giup': 195,
#  'go': 196,
#  'go_loi': 197,
#  'goi': 198,
#  'goi_y': 199,
#  'google': 200,
#  'gop_y': 201,
#  'groovy': 202,
#  'gui': 203,
#  'hai': 204,
#  'han_che': 205,
#  'hang': 206,
#  'hanh_vi': 207,
#  'hanh_đong': 208,
#  'hat': 209,
#  'he': 210,
#  'he_thong': 211,
#  'hien': 212,
#  'hien_thi': 213,
#  'hien_tuong': 214,
#  'hien_đai': 215,
#  'hierarchical': 216,
#  'hieu_nang': 217,
#  'hieu_qua': 218,
#  'hieu_suat': 219,
#  'highlighting': 220,
#  'hinh': 221,
#  'hinh_anh': 222,
#  'hinh_su': 223,
#  'hinh_thuc': 224,
#  'hoa': 225,
#  'hoan_chinh': 226,
#  'hoan_thanh': 227,
#  'hoan_thien': 228,
#  'hoat_đong': 229,
#  'hoc': 230,
#  'hoc_hoi': 231,
#  'hon_hop': 232,
#  'hontu': 233,
#  'html': 234,
#  'htmlvi': 235,
#  'http': 236,
#  'huan_luyen': 237,
#  'hung': 238,
#  'hung_thu': 239,
#  'huong': 240,
#  'huongxu': 241,
#  'huu_dung': 242,
#  'huu_han': 243,
#  'huu_ich': 244,
#  'huy': 245,
#  'hypertext': 246,
#  'id': 247,
#  'idea': 248,
#  'index': 249,
#  'intellij': 250,
#  'internet': 251,
#  'isactive': 252,
#  'ispublish': 253,
#  'isread': 254,
#  'it': 255,
#  'item': 256,
#  'items': 257,
#  'java': 258,
#  'javascript': 259,
#  'jetbrains': 260,
#  'jetty': 261,
#  'join': 262,
#  'joomla': 263,
#  'js': 264,
#  'json': 265,
#  'kem': 266,
#  'kenh': 267,
#  'ket': 268,
#  'ket_ban': 269,
#  'ket_noi': 270,
#  'ket_qua': 271,
#  'key': 272,
#  'kha_nang': 273,
#  'khach_hang': 274,
#  'khap': 275,
#  'kho': 276,
#  'khoa': 277,
#  'khoanbai': 278,
#  'khoi': 279,
#  'khong_gian': 280,
#  'khuon_kho': 281,
#  'khuyen_nghi': 282,
#  'kich_co': 283,
#  'kiem': 284,
#  'kiem_tra': 285,
#  'kiemcac': 286,
#  'kiemfacebook': 287,
#  'kien_thuc': 288,
#  'kien_truc': 289,
#  'kieu': 290,
#  'kinh': 291,
#  'kinh_doanh': 292,
#  'kinh_lup': 293,
#  'kinh_te': 294,
#  'ky': 295,
#  'ky_thuat': 296,
#  'ky_tu': 297,
#  'lam_viec': 298,
#  'lan': 299,
#  'language': 300,
#  'lap': 301,
#  'lap_debug': 302,
#  'lap_trinh': 303,
#  'lap_trinh_vien': 304,
#  'lapnhung': 305,
#  'latent': 306,
#  'lda': 307,
#  'learning': 308,
#  'len_loi': 309,
#  'level': 310,
#  'lich_su': 311,
#  'lien': 312,
#  'lien_tuc': 313,
#  'lieu': 314,
#  'lieuhinh': 315,
#  'likes': 316,
#  'linear': 317,
#  'linh_hoat': 318,
#  'linh_vuc': 319,
#  'link': 320,
#  'linux': 321,
#  'lo_ngai': 322,
#  'loat': 323,
#  'loi': 324,
#  'loi_ich': 325,
#  'loi_nhuan': 326,
#  'loi_the': 327,
#  'lsa': 328,
#  'lua_chon': 329,
#  'luong': 330,
#  'luot': 331,
#  'luu': 332,
#  'luu_giu': 333,
#  'luu_tru': 334,
#  'ly': 335,
#  'ly_thuyet': 336,
#  'lyket': 337,
#  'ma': 338,
#  'mac_đinh': 339,
#  'mach': 340,
#  'machine': 341,
#  'macos': 342,
#  'mai': 343,
#  'make': 344,
#  'mang': 345,
#  'manh_me': 346,
#  'marketing': 347,
#  'markup': 348,
#  'mat_khau': 349,
#  'matheo': 350,
#  'matkhi': 351,
#  'mau': 352,
#  'maven': 353,
#  'may': 354,
#  'may_tinh': 355,
#  'medium': 356,
#  'menu': 357,
#  'mien': 358,
#  'mieu_ta': 359,
#  'minh_hoa': 360,
#  'ml': 361,
#  'mo_hinh': 362,
#  'mo_hinh_hoa': 363,
#  'mo_rong': 364,
#  'mo_ta': 365,
#  'modal': 366,
#  'model': 367,
#  'modeling': 368,
#  'module': 369,
#  'mon': 370,
#  'mong': 371,
#  'mong_muon': 372,
#  'mongodatabase': 373,
#  'mongodb': 374,
#  'mua': 375,
#  'muc': 376,
#  'muc_tu': 377,
#  'muc_đich': 378,
#  'muc_đo': 379,
#  'muot_ma': 380,
#  'nam': 381,
#  'nam_bat': 382,
#  'nang': 383,
#  'nang_suat': 384,
#  'native': 385,
#  'nen_tang': 386,
#  'neu': 387,
#  'ngan': 388,
#  'ngay_nay': 389,
#  'nghia_la': 390,
#  'nghiem': 391,
#  'nghien_cuu': 392,
#  'nghiep_vu': 393,
#  'nghiepho': 394,
#  'ngoai_tru': 395,
#  'ngon_ngu': 396,
#  'nguoi': 397,
#  'nhan': 398,
#  'nhan_loai': 399,
#  'nhan_tao': 400,
#  'nhanh_chong': 401,
#  'nhap': 402,
#  'nhap_noi_dung': 403,
#  'nhapchinh': 404,
#  'nhat_ky': 405,
#  'nhatđuoc': 406,
#  'nhiem_vu': 407,
#  'nhu': 408,
#  'nhu_cau': 409,
#  'nickname': 410,
#  'nodejs': 411,
#  'nodv': 412,
#  'noi_bat': 413,
#  'noi_dung': 414,
#  'noi_tai': 415,
#  'noi_tieng': 416,
#  'noo': 417,
#  'notat': 418,
#  'nu': 419,
#  'nut': 420,
#  'oauth': 421,
#  'object': 422,
#  'objectid': 423,
#  'observe': 424,
#  'of': 425,
#  'on': 426,
#  'online': 427,
#  'page': 428,
#  'parameter': 429,
#  'password': 430,
#  'pha_tron': 431,
#  'pham_vi': 432,
#  'phan_biet': 433,
#  'phan_bo': 434,
#  'phan_hoi': 435,
#  'phan_loai': 436,
#  'phan_mem': 437,
#  'phan_phoi': 438,
#  'phan_ra': 439,
#  'phan_tich': 440,
#  'phan_xu': 441,
#  'phat_trien': 442,
#  'phep': 443,
#  'phien_ban': 444,
#  'phim': 445,
#  'pho_bien': 446,
#  'phong_cach': 447,
#  'phong_phu': 448,
#  'phuc': 449,
#  'phuc_tap': 450,
#  'phuc_vu': 451,
#  'phuoc': 452,
#  'phuong': 453,
#  'phuong_phap': 454,
#  'plsa': 455,
#  'post': 456,
#  'postid': 457,
#  'preference': 458,
#  'prior': 459,
#  'project': 460,
#  'provider': 461,
#  'providerid': 462,
#  'publish': 463,
#  'python': 464,
#  'qua_khu': 465,
#  'quan_he': 466,
#  'quan_ly': 467,
#  'quang_cao': 468,
#  'quen_thuoc': 469,
#  'quy_mo': 470,
#  'quy_đinh': 471,
#  'quyen': 472,
#  'quyet_đinh': 473,
#  'ra_mat': 474,
#  'ra_đoi': 475,
#  'rangkhong': 476,
#  'react': 477,
#  'reactjs': 478,
#  'receiverid': 479,
#  'recommend': 480,
#  'recommendation': 481,
#  'recommended': 482,
#  'recommender': 483,
#  'refactorings': 484,
#  'replyid': 485,
#  'request': 486,
#  'response': 487,
#  'roi_rac': 488,
#  'role': 489,
#  'rong': 490,
#  'rong_rai': 491,
#  'rongviec': 492,
#  'ruby': 493,
#  'rut': 494,
#  'sach': 495,
#  'sai_lech': 496,
#  'sampling': 497,
#  'san': 498,
#  'san_pham': 499,
#  'san_sang': 500,
#  'sang_tao': 501,
#  'sap_xep': 502,
#  'sau': 503,
#  'scalatu': 504,
#  'schema': 505,
#  'senderid': 506,
#  'server': 507,
#  'setting': 508,
#  'share': 509,
#  'sheets': 510,
#  'sidebar': 511,
#  'similarity': 512,
#  'simple': 513,
#  'single': 514,
#  'sinh': 515,
#  'sinh_thai': 516,
#  'site': 517,
#  'snippets': 518,
#  'so_luong': 519,
#  'so_thich': 520,
#  'so_đo': 521,
#  'soan_thao': 522,
#  'song': 523,
#  'spa': 524,
#  'sparse': 525,
#  'spring': 526,
#  'sql': 527,
#  'starter': 528,
#  'string': 529,
#  'stt': 530,
#  'studio': 531,
#  'style': 532,
#  'sua': 533,
#  'subtitle': 534,
#  'supervised': 535,
#  'suy_dien': 536,
#  'suy_luan': 537,
#  'syntax': 538,
#  'system': 539,
#  'systems': 540,
#  'ta': 541,
#  'tab': 542,
#  'tac': 543,
#  'tac_gia': 544,
#  'tai': 545,
#  'tai_cau_truc': 546,
#  'tai_khoan': 547,
#  'tai_lieu': 548,
#  'tam': 549,
#  'tang_toc': 550,
#  'tang_truong': 551,
#  'tap': 552,
#  'tap_hop': 553,
#  'tapnoi': 554,
#  'tat': 555,
#  'teamcity': 556,
#  'text': 557,
#  'thac_mac': 558,
#  'tham_so': 559,
#  'than_thien': 560,
#  'thanh': 561,
#  'thanh_cong': 562,
#  'thanh_phan': 563,
#  'thao_tac': 564,
#  'that_bai': 565,
#  'thay': 566,
#  'the_gioi': 567,
#  'the_hien': 568,
#  'the_ky': 569,
#  'theo_doi': 570,
#  'theta': 571,
#  'thichkhi': 572,
#  'thiet_bi': 573,
#  'thiet_ke': 574,
#  'thietkhong': 575,
#  'thietsu_dung': 576,
#  'thieu_sot': 577,
#  'thinh': 578,
#  'thoa_man': 579,
#  'thoa_suc': 580,
#  'thoai_mai': 581,
#  'thoi': 582,
#  'thoi_đai': 583,
#  'thong': 584,
#  'thong_bao': 585,
#  'thong_minh': 586,
#  'thong_qua': 587,
#  'thong_thuong': 588,
#  'thong_tin': 589,
#  'threelevel': 590,
#  'thu_thap': 591,
#  'thu_vien': 592,
#  'thua': 593,
#  'thuan_tien': 594,
#  'thuat_toan': 595,
#  'thuat_toan_hoc': 596,
#  'thuc': 597,
#  'thuc_hien_tai': 598,
#  'thuc_the': 599,
#  'thumbnail': 600,
#  'thuong': 601,
#  'thuong_mai': 602,
#  'thuongcho': 603,
#  'thutheo': 604,
#  'tich_hop': 605,
#  'tiem_nang': 606,
#  'tien_ich': 607,
#  'tien_tien': 608,
#  'tien_trinh': 609,
#  'tieng': 610,
#  'tiep_can': 611,
#  'tiep_thi': 612,
#  'tieu_đe': 613,
#  'tieu_đe_bai': 614,
#  'tim_kiem': 615,
#  'timeread': 616,
#  'tin_hieu': 617,
#  'tin_nhiem': 618,
#  'tin_tuc': 619,
#  'tinh_nang': 620,
#  'tinh_toan': 621,
#  'title': 622,
#  'toan': 623,
#  'toan_bo': 624,
#  'toan_cau': 625,
#  'toan_the': 626,
#  'together': 627,
#  'toi_gian': 628,
#  'toi_uu_hoa': 629,
#  'tomcat': 630,
#  'tong_quan': 631,
#  'tong_quat': 632,
#  'tong_thetao': 633,
#  'topic': 634,
#  'topics': 635,
#  'tra_loi': 636,
#  'trai': 637,
#  'trai_đat': 638,
#  'tran': 639,
#  'trang': 640,
#  'trang_chu': 641,
#  'trang_thai': 642,
#  'trang_web': 643,
#  'trao_đoi': 644,
#  'tren': 645,
#  'trenđang': 646,
#  'tri_tue': 647,
#  'trien_khai': 648,
#  'trinh': 649,
#  'trinh_bay': 650,
#  'trinh_duyet': 651,
#  'tro': 652,
#  'tro_nen': 653,
#  'tron': 654,
#  'trong': 655,
#  'truc_tuyen': 656,
#  'true': 657,
#  'trung': 658,
#  'truong': 659,
#  'truy': 660,
#  'truy_cap': 661,
#  'tu_khoa': 662,
#  'tu_vung': 663,
#  'tu_đien': 664,
#  'tu_đong': 665,
#  'tuan': 666,
#  'tuc': 667,
#  'tuc_la': 668,
#  'tuoi_đoi': 669,
#  'tuong_lai': 670,
#  'tuong_quan': 671,
#  'tuong_thich': 672,
#  'tuong_tu': 673,
#  'tuong_ung': 674,
#  'tuong_đong': 675,
#  'tuy': 676,
#  'tv': 677,
#  'type': 678,
#  'ui': 679,
#  'undertow': 680,
#  'ung': 681,
#  'ung_dung': 682,
#  'universal': 683,
#  'unsupervised': 684,
#  'uoc_luong': 685,
#  'use': 686,
#  'usecase': 687,
#  'user': 688,
#  'userid': 689,
#  'useritem': 690,
#  'userlikeids': 691,
#  'username': 692,
#  'users': 693,
#  'userxoa': 694,
#  'uu_điem': 695,
#  'vahoac': 696,
#  'vai_tro': 697,
#  'van': 698,
#  'van_ban': 699,
#  'van_dung': 700,
#  'van_hanh': 701,
#  'variable': 702,
#  'vi_du': 703,
#  'viet': 704,
#  'vietblog': 705,
#  'vietxem': 706,
#  'visual': 707,
#  'vo_cung': 708,
#  'vong': 709,
#  'vs': 710,
#  'vu': 711,
#  'vuong': 712,
#  'vuot_bac': 713,
#  'war': 714,
#  'web': 715,
#  'website': 716,
#  'websocket': 717,
#  'wi': 718,
#  'wide_web': 719,
#  'windows': 720,
#  'word': 721,
#  'wordpress': 722,
#  'world': 723,
#  'xa': 724,
#  'xa_hoi': 725,
#  'xac_nhan': 726,
#  'xac_suat': 727,
#  'xac_thuc': 728,
#  'xac_đinh': 729,
#  'xay_dung': 730,
#  'xem_xet': 731,
#  'xep_hang': 732,
#  'xmlhttprequest': 733,
#  'xoa': 734,
#  'xoa_bai': 735,
#  'xoa_bookmark': 736,
#  'xoa_hien_thi': 737,
#  'xu': 738,
#  'xu_huong': 739,
#  'y_muon': 740,
#  'y_nghia': 741,
#  'y_tuong': 742,
#  'y_đinh': 743,
#  'yahoo': 744,
#  'youtube': 745,
#  'đa_dang': 746,
#  'đac_nhap': 747,
#  'đac_tinh': 748,
#  'đac_trung': 749,
#  'đac_điem': 750,
#  'đai_dien': 751,
#  'đang': 752,
#  'đang_ky': 753,
#  'đang_nhap': 754,
#  'đangchinh': 755,
#  'đanh': 756,
#  'đanh_dau': 757,
#  'đanh_đau': 758,
#  'đau': 759,
#  'đau_ra': 760,
#  'đau_vao': 761,
#  'đaua': 762,
#  'đay_đu': 763,
#  'đe_cap': 764,
#  'đe_tai': 765,
#  'đe_xuat': 766,
#  'đe_y': 767,
#  'đi': 768,
#  'đi_sau': 769,
#  'đien_tu': 770,
#  'đieu_khien': 771,
#  'đinh_dang': 772,
#  'đinh_hinh': 773,
#  'đinh_nghia': 774,
#  'đo': 775,
#  'đo_an': 776,
#  'đoan': 777,
#  'đoc': 778,
#  'đoc_gia': 779,
#  'đoi_khi': 780,
#  'đoi_song': 781,
#  'đoi_tuong': 782,
#  'đoianh': 783,
#  'đon': 784,
#  'đon_gian': 785,
#  'đon_gian_hoa': 786,
#  'đong': 787,
#  'đong_bo': 788,
#  'đong_nghia': 789,
#  'đong_đao': 790,
#  'đođang': 791,
#  'đuocđong': 792,
#  'đuong': 793,
#  'android': 794,
#  'cap_nhat': 795,
#  'cho_du': 796,
#  'components': 797,
#  'componets': 798,
#  'defining': 799,
#  'dom': 800,
#  'engine': 801,
#  'exports': 802,
#  'extend': 803,
#  'hooks': 804,
#  'implementation': 805,
#  'implemented': 806,
#  'import': 807,
#  'ios': 808,
#  'lives': 809,
#  'logic': 810,
#  'lop': 811,
#  'mac': 812,
#  'moi_truong': 813,
#  'mot_the_hien': 814,
#  'mount': 815,
#  'nguoc_lai': 816,
#  'node': 817,
#  'oke': 818,
#  'or': 819,
#  'package': 820,
#  'phan_tach': 821,
#  'platform': 822,
#  'reactart': 823,
#  'reactchildren': 824,
#  'reactcomponent': 825,
#  'reactdom': 826,
#  'reactdomrender': 827,
#  'reactdomserver': 828,
#  'reactnative': 829,
#  'renderer': 830,
#  'renderers': 831,
#  'rerenders': 832,
#  'return': 833,
#  'sai_lam': 834,
#  'setstate': 835,
#  'state': 836,
#  'target': 837,
#  'thac': 838,
#  'thiet_lap': 839,
#  'thu_vi': 840,
#  'tiec': 841,
#  'ty_du': 842,
#  'updater': 843,
#  'utilities': 844,
#  'uy': 845,
#  've': 846,
#  'view': 847,
#  'xay': 848,
#  'đeu': 849,
#  'đoc_lap': 850,
#  'ap_dung': 851,
#  'bao_toan': 852,
#  'bat_buoc': 853,
#  'bi_an': 854,
#  'bieu_thuc': 855,
#  'bo_qua': 856,
#  'bon': 857,
#  'chang_han': 858,
#  'cheo': 859,
#  'chi_đinh': 860,
#  'chinh_quy': 861,
#  'chon_lua': 862,
#  'chu': 863,
#  'chu_so': 864,
#  'chubat': 865,
#  'co_nghia': 866,
#  'co_nghia_la': 867,
#  'cong': 868,
#  'constructor': 869,
#  'cu_phap': 870,
#  'dai': 871,
#  'dau': 872,
#  'dau_cham_hoi': 873,
#  'dau_cham_than': 874,
#  'dau_hoi': 875,
#  'day': 876,
#  'dien_ta': 877,
#  'dong': 878,
#  'duoimot': 879,
#  'duy_nhat': 880,
#  'expression': 881,
#  'gach': 882,
#  'gach_ngang': 883,
#  'gia_su': 884,
#  'gioi_han': 885,
#  'gom': 886,
#  'hoi': 887,
#  'in': 888,
#  'keo': 889,
#  'ket_thuc': 890,
#  'khop': 891,
#  'kia': 892,
#  'ky_hieu': 893,
#  'lan_luot': 894,
#  'luu_y': 895,
#  'mac_du': 896,
#  'mat_khac': 897,
#  'mot_chut': 898,
#  'mot_so_nguyen': 899,
#  'naomot': 900,
#  'ngan_can': 901,
#  'ngoac': 902,
#  'ngoac_vuong': 903,
#  'ngoac_đon': 904,
#  'ngoac_đon_tinh': 905,
#  'nhon': 906,
#  'nhu_nhieu': 907,
#  'pattern': 908,
#  'phan_tu': 909,
#  'phu': 910,
#  'phuong_thuc': 911,
#  'ranh_gioi': 912,
#  'regexp': 913,
#  'regular': 914,
#  'rieng_biet': 915,
#  'somot': 916,
#  'tatnghiabat': 917,
#  'thay_vi': 918,
#  'thong_dung': 919,
#  'thuc_thi': 920,
#  'thuoc_tinh': 921,
#  'toan_tu': 922,
#  'trangbat': 923,
#  'truyen': 924,
#  'tumot': 925,
#  'tuong': 926,
#  'tuy_chon': 927,
#  'unicode': 928,
#  'vv': 929,
#  'đam_bao_mau': 930,
#  'đao_nguoc': 931,
#  'đep_mat': 932,
#  'đung': 933,
#  'đuong_ong': 934,
#  'and': 935,
#  'array': 936,
#  'arrint': 937,
#  'at': 938,
#  'bai_tap': 939,
#  'ban_phim': 940,
#  'bot': 941,
#  'bounds': 942,
#  'bubble': 943,
#  'cacacyahtp': 944,
#  'cach': 945,
#  'chieu': 946,
#  'chon': 947,
#  'cua': 948,
#  'cung': 949,
#  'dao': 950,
#  'duoc': 951,
#  'exception': 952,
#  'for': 953,
#  'goc': 954,
#  'is': 955,
#  'khac': 956,
#  'kich_thuoc': 957,
#  'la': 958,
#  'lathaycacac': 959,
#  'length': 960,
#  'lua': 961,
#  'main': 962,
#  'max': 963,
#  'min': 964,
#  'mot': 965,
#  'nghich': 966,
#  'nghich_đao': 967,
#  'nguoc': 968,
#  'nhapa': 969,
#  'nhieu': 970,
#  'nhung': 971,
#  'noi': 972,
#  'objects': 973,
#  'original': 974,
#  'out': 975,
#  'so_nguyen': 976,
#  'sort': 977,
#  'sorted': 978,
#  'str': 979,
#  'strmot': 980,
#  'tham_chieu': 981,
#  'thaycacac': 982,
#  'this': 983,
#  'thread': 984,
#  'tien': 985,
#  'tri': 986,
#  'tu': 987,
#  'vi': 988,
#  'vua': 989,
#  'vuot': 990,
#  'xuat': 991,
#  'anh_huong': 992,
#  'atm': 993,
#  'atmbai': 994,
#  'bigdecimal': 995,
#  'chu_vi': 996,
#  'chu_y': 997,
#  'class': 998,
#  'co_che': 999,
#  ...}

# %%
len(id2word)
# Out:
# 8863

# %%
id2word.filter_extremes(no_below=2, no_above=0.5)
id2word.compactify()
id2word.save('../models/id2word.dictionary')
# Out:
# INFO : discarding 4776 tokens: [('actor', 1), ('allocation', 1), ('anhđuong', 1), ('axios', 1), ('bai_bo', 1), ('banfacebook', 1), ('bannetflix', 1), ('banxoa', 1), ('baoluu', 1), ('bayesian', 1)]...
# INFO : keeping 4087 tokens which were in no less than 2 and no more than 88 (=50.0%) documents
# INFO : resulting dictionary: Dictionary<4087 unique tokens: ['account', 'amazon', 'an', 'analysis', 'anh']...>
# INFO : Dictionary lifecycle event {'fname_or_handle': '../models/id2word.dictionary', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-12-29T04:01:18.527495', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/id2word.dictionary

# %%
len(id2word)
# Out:
# 4087

# %%
id2word.token2id
# Out:
# {'account': 0,
#  'amazon': 1,
#  'an': 2,
#  'analysis': 3,
#  'anh': 4,
#  'ap_đat': 5,
#  'api': 6,
#  'application': 7,
#  'avatar': 8,
#  'bai': 9,
#  'bai_toan': 10,
#  'ban_be': 11,
#  'ban_cai': 12,
#  'ban_chat': 13,
#  'bang': 14,
#  'bao_cao': 15,
#  'bao_gom': 16,
#  'bao_mat': 17,
#  'bao_phu': 18,
#  'bao_ve': 19,
#  'bat_kha_thi': 20,
#  'bayes': 21,
#  'bia': 22,
#  'bich': 23,
#  'bien': 24,
#  'bien_đoi': 25,
#  'bieu_dien': 26,
#  'bieu_thi': 27,
#  'bieu_tuong': 28,
#  'big': 29,
#  'binh': 30,
#  'binh_luan': 31,
#  'blog': 32,
#  'blogger': 33,
#  'bo_nho': 34,
#  'bookmark': 35,
#  'boolean': 36,
#  'boot': 37,
#  'bung_no': 38,
#  'business': 39,
#  'ca_si': 40,
#  'cai_thien': 41,
#  'cai_tien': 42,
#  'can_thiet': 43,
#  'canh': 44,
#  'canh_sat': 45,
#  'cap': 46,
#  'cap_đo': 47,
#  'cascading': 48,
#  'case': 49,
#  'cau': 50,
#  'cau_hinh': 51,
#  'cau_truc': 52,
#  'cham': 53,
#  'chan': 54,
#  'chat_luong': 55,
#  'chay': 56,
#  'che_đo': 57,
#  'chi_tiet': 58,
#  'chia': 59,
#  'chien_luoc': 60,
#  'chinh_sua': 61,
#  'chinh_xac': 62,
#  'chong': 63,
#  'chu_quan': 64,
#  'chu_đe': 65,
#  'chua': 66,
#  'chuan_hoa': 67,
#  'chuc_nang': 68,
#  'chung_khoan': 69,
#  'chung_minh': 70,
#  'chuoi': 71,
#  'chuong': 72,
#  'chuong_trinh': 73,
#  'chuyen_hoa': 74,
#  'chuyen_huong': 75,
#  'chuyen_tiep': 76,
#  'chuyen_đoi': 77,
#  'click': 78,
#  'client': 79,
#  'clip': 80,
#  'cloud': 81,
#  'co_ban': 82,
#  'co_le': 83,
#  'co_phieu': 84,
#  'co_so': 85,
#  'co_đinh': 86,
#  'code': 87,
#  'coi': 88,
#  'collection': 89,
#  'comment': 90,
#  'compass': 91,
#  'component': 92,
#  'con_nguoi': 93,
#  'cong_cu': 94,
#  'cong_khai': 95,
#  'cong_nghe': 96,
#  'cong_ty': 97,
#  'cong_viec': 98,
#  'csdl': 99,
#  'css': 100,
#  'cung_cap': 101,
#  'cuoc_song': 102,
#  'dan': 103,
#  'dang': 104,
#  'danh_sach': 105,
#  'data': 106,
#  'de_dang': 107,
#  'debug': 108,
#  'di_đong': 109,
#  'dich_vu': 110,
#  'doanh': 111,
#  'doanh_nghiep': 112,
#  'doanh_thu': 113,
#  'document': 114,
#  'doi': 115,
#  'du_an': 116,
#  'du_bao': 117,
#  'du_lieu': 118,
#  'du_đoan': 119,
#  'dua': 120,
#  'dung': 121,
#  'duy_tri': 122,
#  'editor': 123,
#  'email': 124,
#  'facebook': 125,
#  'file': 126,
#  'framework': 127,
#  'gan': 128,
#  'ghi_chu': 129,
#  'gia': 130,
#  'gia_đinh': 131,
#  'giai_phap': 132,
#  'giai_thuong': 133,
#  'giai_đap': 134,
#  'giam_sat': 135,
#  'giao_dien': 136,
#  'giao_luu': 137,
#  'gioi_thieu': 138,
#  'gioi_tinh': 139,
#  'git': 140,
#  'github': 141,
#  'go': 142,
#  'go_loi': 143,
#  'goi': 144,
#  'goi_y': 145,
#  'google': 146,
#  'gop_y': 147,
#  'gui': 148,
#  'hai': 149,
#  'han_che': 150,
#  'hanh_vi': 151,
#  'hanh_đong': 152,
#  'hat': 153,
#  'he': 154,
#  'he_thong': 155,
#  'hien': 156,
#  'hien_thi': 157,
#  'hien_tuong': 158,
#  'hien_đai': 159,
#  'hieu_nang': 160,
#  'hieu_suat': 161,
#  'hinh': 162,
#  'hinh_anh': 163,
#  'hinh_su': 164,
#  'hinh_thuc': 165,
#  'hoa': 166,
#  'hoan_chinh': 167,
#  'hoan_thanh': 168,
#  'hoan_thien': 169,
#  'hoc': 170,
#  'hoc_hoi': 171,
#  'hon_hop': 172,
#  'html': 173,
#  'http': 174,
#  'huan_luyen': 175,
#  'hung': 176,
#  'hung_thu': 177,
#  'huong': 178,
#  'huu_dung': 179,
#  'huu_han': 180,
#  'huu_ich': 181,
#  'huy': 182,
#  'hypertext': 183,
#  'id': 184,
#  'index': 185,
#  'internet': 186,
#  'it': 187,
#  'java': 188,
#  'javascript': 189,
#  'jetbrains': 190,
#  'join': 191,
#  'js': 192,
#  'json': 193,
#  'kem': 194,
#  'kenh': 195,
#  'ket': 196,
#  'ket_ban': 197,
#  'ket_noi': 198,
#  'ket_qua': 199,
#  'kha_nang': 200,
#  'khach_hang': 201,
#  'khap': 202,
#  'kho': 203,
#  'khoa': 204,
#  'khoi': 205,
#  'khong_gian': 206,
#  'khuon_kho': 207,
#  'khuyen_nghi': 208,
#  'kich_co': 209,
#  'kiem': 210,
#  'kiem_tra': 211,
#  'kiemcac': 212,
#  'kien_thuc': 213,
#  'kien_truc': 214,
#  'kieu': 215,
#  'kinh': 216,
#  'kinh_doanh': 217,
#  'kinh_te': 218,
#  'ky': 219,
#  'ky_thuat': 220,
#  'ky_tu': 221,
#  'lam_viec': 222,
#  'lan': 223,
#  'lap': 224,
#  'lap_trinh': 225,
#  'lap_trinh_vien': 226,
#  'learning': 227,
#  'len_loi': 228,
#  'level': 229,
#  'lich_su': 230,
#  'lien': 231,
#  'lien_tuc': 232,
#  'lieu': 233,
#  'linh_hoat': 234,
#  'linh_vuc': 235,
#  'link': 236,
#  'linux': 237,
#  'lo_ngai': 238,
#  'loat': 239,
#  'loi': 240,
#  'loi_ich': 241,
#  'loi_nhuan': 242,
#  'loi_the': 243,
#  'lua_chon': 244,
#  'luong': 245,
#  'luot': 246,
#  'luu': 247,
#  'luu_giu': 248,
#  'luu_tru': 249,
#  'ly': 250,
#  'ly_thuyet': 251,
#  'ma': 252,
#  'mac_đinh': 253,
#  'mach': 254,
#  'machine': 255,
#  'macos': 256,
#  'mai': 257,
#  'mang': 258,
#  'manh_me': 259,
#  'marketing': 260,
#  'markup': 261,
#  'mat_khau': 262,
#  'mau': 263,
#  'may': 264,
#  'may_tinh': 265,
#  'menu': 266,
#  'mien': 267,
#  'mieu_ta': 268,
#  'minh_hoa': 269,
#  'ml': 270,
#  'mo_hinh': 271,
#  'mo_rong': 272,
#  'mo_ta': 273,
#  'modal': 274,
#  'model': 275,
#  'module': 276,
#  'mon': 277,
#  'mong': 278,
#  'mong_muon': 279,
#  'mongodb': 280,
#  'mua': 281,
#  'muc': 282,
#  'muc_đich': 283,
#  'muc_đo': 284,
#  'muot_ma': 285,
#  'nam': 286,
#  'nam_bat': 287,
#  'nang': 288,
#  'nang_suat': 289,
#  'native': 290,
#  'nen_tang': 291,
#  'neu': 292,
#  'ngan': 293,
#  'ngay_nay': 294,
#  'nghia_la': 295,
#  'nghiem': 296,
#  'nghien_cuu': 297,
#  'nghiep_vu': 298,
#  'ngoai_tru': 299,
#  'ngon_ngu': 300,
#  'nguoi': 301,
#  'nhan': 302,
#  'nhan_loai': 303,
#  'nhan_tao': 304,
#  'nhanh_chong': 305,
#  'nhap': 306,
#  'nhat_ky': 307,
#  'nhiem_vu': 308,
#  'nhu': 309,
#  'nhu_cau': 310,
#  'nodejs': 311,
#  'noi_bat': 312,
#  'noi_dung': 313,
#  'noi_tai': 314,
#  'noi_tieng': 315,
#  'nu': 316,
#  'nut': 317,
#  'object': 318,
#  'of': 319,
#  'on': 320,
#  'online': 321,
#  'page': 322,
#  'password': 323,
#  'pha_tron': 324,
#  'pham_vi': 325,
#  'phan_biet': 326,
#  'phan_bo': 327,
#  'phan_hoi': 328,
#  'phan_loai': 329,
#  'phan_mem': 330,
#  'phan_phoi': 331,
#  'phan_tich': 332,
#  'phep': 333,
#  'phien_ban': 334,
#  'phim': 335,
#  'pho_bien': 336,
#  'phong_cach': 337,
#  'phong_phu': 338,
#  'phuc': 339,
#  'phuc_tap': 340,
#  'phuc_vu': 341,
#  'phuong': 342,
#  'phuong_phap': 343,
#  'post': 344,
#  'project': 345,
#  'python': 346,
#  'qua_khu': 347,
#  'quan_he': 348,
#  'quan_ly': 349,
#  'quang_cao': 350,
#  'quen_thuoc': 351,
#  'quy_mo': 352,
#  'quy_đinh': 353,
#  'quyen': 354,
#  'quyet_đinh': 355,
#  'ra_mat': 356,
#  'ra_đoi': 357,
#  'react': 358,
#  'reactjs': 359,
#  'request': 360,
#  'response': 361,
#  'role': 362,
#  'rong': 363,
#  'rong_rai': 364,
#  'ruby': 365,
#  'rut': 366,
#  'sach': 367,
#  'sai_lech': 368,
#  'san': 369,
#  'san_pham': 370,
#  'san_sang': 371,
#  'sang_tao': 372,
#  'sap_xep': 373,
#  'sau': 374,
#  'schema': 375,
#  'server': 376,
#  'setting': 377,
#  'share': 378,
#  'sheets': 379,
#  'single': 380,
#  'sinh': 381,
#  'sinh_thai': 382,
#  'so_luong': 383,
#  'so_thich': 384,
#  'soan_thao': 385,
#  'song': 386,
#  'spa': 387,
#  'spring': 388,
#  'sql': 389,
#  'string': 390,
#  'studio': 391,
#  'style': 392,
#  'sua': 393,
#  'suy_luan': 394,
#  'syntax': 395,
#  'system': 396,
#  'systems': 397,
#  'ta': 398,
#  'tab': 399,
#  'tac': 400,
#  'tac_gia': 401,
#  'tai': 402,
#  'tai_cau_truc': 403,
#  'tai_khoan': 404,
#  'tai_lieu': 405,
#  'tam': 406,
#  'tang_toc': 407,
#  'tang_truong': 408,
#  'tap': 409,
#  'tap_hop': 410,
#  'tat': 411,
#  'text': 412,
#  'thac_mac': 413,
#  'tham_so': 414,
#  'than_thien': 415,
#  'thanh': 416,
#  'thanh_cong': 417,
#  'thanh_phan': 418,
#  'thao_tac': 419,
#  'that_bai': 420,
#  'thay': 421,
#  'the_gioi': 422,
#  'the_hien': 423,
#  'the_ky': 424,
#  'theo_doi': 425,
#  'thiet_bi': 426,
#  'thiet_ke': 427,
#  'thinh': 428,
#  'thoa_man': 429,
#  'thoa_suc': 430,
#  'thoai_mai': 431,
#  'thoi': 432,
#  'thoi_đai': 433,
#  'thong': 434,
#  'thong_bao': 435,
#  'thong_minh': 436,
#  'thong_qua': 437,
#  'thong_thuong': 438,
#  'thong_tin': 439,
#  'thu_thap': 440,
#  'thu_vien': 441,
#  'thua': 442,
#  'thuan_tien': 443,
#  'thuat_toan': 444,
#  'thuc': 445,
#  'thuc_hien_tai': 446,
#  'thuc_the': 447,
#  'thuong': 448,
#  'thuong_mai': 449,
#  'tich_hop': 450,
#  'tiem_nang': 451,
#  'tien_ich': 452,
#  'tien_tien': 453,
#  'tien_trinh': 454,
#  'tieng': 455,
#  'tiep_can': 456,
#  'tiep_thi': 457,
#  'tieu_đe': 458,
#  'tim_kiem': 459,
#  'tin_hieu': 460,
#  'tin_tuc': 461,
#  'tinh_nang': 462,
#  'tinh_toan': 463,
#  'toan': 464,
#  'toan_bo': 465,
#  'toan_cau': 466,
#  'toan_the': 467,
#  'toi_gian': 468,
#  'toi_uu_hoa': 469,
#  'tong_quan': 470,
#  'tong_quat': 471,
#  'topic': 472,
#  'tra_loi': 473,
#  'trai': 474,
#  'trai_đat': 475,
#  'tran': 476,
#  'trang': 477,
#  'trang_chu': 478,
#  'trang_thai': 479,
#  'trang_web': 480,
#  'trao_đoi': 481,
#  'tri_tue': 482,
#  'trien_khai': 483,
#  'trinh': 484,
#  'trinh_bay': 485,
#  'trinh_duyet': 486,
#  'tro': 487,
#  'tro_nen': 488,
#  'tron': 489,
#  'trong': 490,
#  'truc_tuyen': 491,
#  'true': 492,
#  'trung': 493,
#  'truong': 494,
#  'truy': 495,
#  'truy_cap': 496,
#  'tu_khoa': 497,
#  'tu_vung': 498,
#  'tu_đien': 499,
#  'tu_đong': 500,
#  'tuan': 501,
#  'tuc': 502,
#  'tuc_la': 503,
#  'tuong_lai': 504,
#  'tuong_quan': 505,
#  'tuong_thich': 506,
#  'tuong_tu': 507,
#  'tuong_ung': 508,
#  'tuong_đong': 509,
#  'tuy': 510,
#  'tv': 511,
#  'type': 512,
#  'ui': 513,
#  'ung': 514,
#  'ung_dung': 515,
#  'universal': 516,
#  'uoc_luong': 517,
#  'use': 518,
#  'user': 519,
#  'userid': 520,
#  'users': 521,
#  'uu_điem': 522,
#  'vahoac': 523,
#  'vai_tro': 524,
#  'van': 525,
#  'van_ban': 526,
#  'van_dung': 527,
#  'van_hanh': 528,
#  'vi_du': 529,
#  'vo_cung': 530,
#  'vong': 531,
#  'vs': 532,
#  'vu': 533,
#  'vuong': 534,
#  'vuot_bac': 535,
#  'web': 536,
#  'website': 537,
#  'windows': 538,
#  'word': 539,
#  'wordpress': 540,
#  'world': 541,
#  'xa': 542,
#  'xa_hoi': 543,
#  'xac_nhan': 544,
#  'xac_thuc': 545,
#  'xac_đinh': 546,
#  'xay_dung': 547,
#  'xem_xet': 548,
#  'xep_hang': 549,
#  'xoa': 550,
#  'xu': 551,
#  'xu_huong': 552,
#  'y_nghia': 553,
#  'y_tuong': 554,
#  'y_đinh': 555,
#  'yahoo': 556,
#  'youtube': 557,
#  'đa_dang': 558,
#  'đac_tinh': 559,
#  'đac_trung': 560,
#  'đac_điem': 561,
#  'đai_dien': 562,
#  'đang': 563,
#  'đang_ky': 564,
#  'đang_nhap': 565,
#  'đanh': 566,
#  'đanh_dau': 567,
#  'đau': 568,
#  'đau_ra': 569,
#  'đau_vao': 570,
#  'đay_đu': 571,
#  'đe_cap': 572,
#  'đe_tai': 573,
#  'đe_xuat': 574,
#  'đe_y': 575,
#  'đi_sau': 576,
#  'đien_tu': 577,
#  'đieu_khien': 578,
#  'đinh_dang': 579,
#  'đinh_hinh': 580,
#  'đinh_nghia': 581,
#  'đoan': 582,
#  'đoc': 583,
#  'đoi_khi': 584,
#  'đoi_song': 585,
#  'đoi_tuong': 586,
#  'đon': 587,
#  'đon_gian': 588,
#  'đon_gian_hoa': 589,
#  'đong': 590,
#  'đong_bo': 591,
#  'đong_nghia': 592,
#  'đong_đao': 593,
#  'đuong': 594,
#  'android': 595,
#  'cap_nhat': 596,
#  'cho_du': 597,
#  'components': 598,
#  'dom': 599,
#  'engine': 600,
#  'import': 601,
#  'ios': 602,
#  'logic': 603,
#  'lop': 604,
#  'mac': 605,
#  'moi_truong': 606,
#  'mount': 607,
#  'nguoc_lai': 608,
#  'node': 609,
#  'oke': 610,
#  'or': 611,
#  'package': 612,
#  'phan_tach': 613,
#  'return': 614,
#  'sai_lam': 615,
#  'state': 616,
#  'target': 617,
#  'thac': 618,
#  'thiet_lap': 619,
#  'thu_vi': 620,
#  'tiec': 621,
#  'updater': 622,
#  'utilities': 623,
#  'uy': 624,
#  've': 625,
#  'view': 626,
#  'xay': 627,
#  'đoc_lap': 628,
#  'ap_dung': 629,
#  'bat_buoc': 630,
#  'bi_an': 631,
#  'bo_qua': 632,
#  'bon': 633,
#  'chang_han': 634,
#  'cheo': 635,
#  'chi_đinh': 636,
#  'chon_lua': 637,
#  'chu': 638,
#  'chu_so': 639,
#  'co_nghia': 640,
#  'co_nghia_la': 641,
#  'cong': 642,
#  'constructor': 643,
#  'cu_phap': 644,
#  'dai': 645,
#  'dau': 646,
#  'day': 647,
#  'dong': 648,
#  'duy_nhat': 649,
#  'gach': 650,
#  'gia_su': 651,
#  'gioi_han': 652,
#  'hoi': 653,
#  'in': 654,
#  'keo': 655,
#  'ket_thuc': 656,
#  'khop': 657,
#  'kia': 658,
#  'lan_luot': 659,
#  'luu_y': 660,
#  'mac_du': 661,
#  'mat_khac': 662,
#  'mot_chut': 663,
#  'ngan_can': 664,
#  'nhon': 665,
#  'phan_tu': 666,
#  'phu': 667,
#  'phuong_thuc': 668,
#  'ranh_gioi': 669,
#  'rieng_biet': 670,
#  'thay_vi': 671,
#  'thong_dung': 672,
#  'thuc_thi': 673,
#  'thuoc_tinh': 674,
#  'truyen': 675,
#  'tuong': 676,
#  'tuy_chon': 677,
#  'vv': 678,
#  'đao_nguoc': 679,
#  'đep_mat': 680,
#  'đung': 681,
#  'đuong_ong': 682,
#  'and': 683,
#  'bai_tap': 684,
#  'bot': 685,
#  'chieu': 686,
#  'chon': 687,
#  'cua': 688,
#  'cung': 689,
#  'dao': 690,
#  'duoc': 691,
#  'exception': 692,
#  'for': 693,
#  'goc': 694,
#  'is': 695,
#  'khac': 696,
#  'kich_thuoc': 697,
#  'la': 698,
#  'lua': 699,
#  'main': 700,
#  'max': 701,
#  'min': 702,
#  'mot': 703,
#  'nghich': 704,
#  'nguoc': 705,
#  'nhieu': 706,
#  'nhung': 707,
#  'noi': 708,
#  'objects': 709,
#  'so_nguyen': 710,
#  'tham_chieu': 711,
#  'this': 712,
#  'thread': 713,
#  'tien': 714,
#  'tri': 715,
#  'tu': 716,
#  'vi': 717,
#  'vua': 718,
#  'xuat': 719,
#  'anh_huong': 720,
#  'atm': 721,
#  'chu_y': 722,
#  'class': 723,
#  'co_che': 724,
#  'co_gang': 725,
#  'dien_tich': 726,
#  'double': 727,
#  'format': 728,
#  'giai_quyet': 729,
#  'hom_nay': 730,
#  'khai_bao': 731,
#  'khia_canh': 732,
#  'nguyen': 733,
#  'thang': 734,
#  'thang_may': 735,
#  'thich_hop': 736,
#  'tien_le': 737,
#  'tien_te': 738,
#  'toan_hoc': 739,
#  'tru': 740,
#  'break': 741,
#  'cho': 742,
#  'hoan_đoi': 743,
#  'hy_vong': 744,
#  'ke': 745,
#  'lap_lai': 746,
#  'nhac': 747,
#  'performance': 748,
#  'phong_van': 749,
#  'rac_roi': 750,
#  'so_sanh': 751,
#  'tham_khao': 752,
#  'thu': 753,
#  'tiep_xuc': 754,
#  'toc_đo': 755,
#  'tuyen_dung': 756,
#  'xep': 757,
#  'đoi': 758,
#  'ban_đau': 759,
#  'by': 760,
#  'cai_đat': 761,
#  'chuyen_nghiep': 762,
#  'con_so': 763,
#  'duyet': 764,
#  'ghi': 765,
#  'huan': 766,
#  'huong_dan': 767,
#  'list': 768,
#  'loc': 769,
#  'luyen': 770,
#  'rac': 771,
#  'set': 772,
#  'tach': 773,
#  'tap_huan_luyen': 774,
#  'ti_le': 775,
#  'tich': 776,
#  'tien_hanh': 777,
#  'tui': 778,
#  'xong': 779,
#  'cell': 780,
#  'customer': 781,
#  'download': 782,
#  'excel': 783,
#  'microsoft': 784,
#  'su': 785,
#  'ban': 786,
#  'bang_chung': 787,
#  'co_han': 788,
#  'counter': 789,
#  'ham': 790,
#  'hien_hanh': 791,
#  'implement': 792,
#  'ke_thua': 793,
#  'kich_hoat': 794,
#  'lock': 795,
#  'ngat': 796,
#  'resource': 797,
#  'roi': 798,
#  'sleep': 799,
#  'start': 800,
#  'synchronization': 801,
#  'thead': 802,
#  'thoi_han': 803,
#  'tiep': 804,
#  'vo': 805,
#  'vo_han': 806,
#  'with': 807,
#  'xet': 808,
#  'xu_dung': 809,
#  'đe': 810,
#  'cho_đoi': 811,
#  'giam_gia_tri': 812,
#  'khac_biet': 813,
#  'khoan': 814,
#  'phien_phuc': 815,
#  'test': 816,
#  'truong_hop': 817,
#  'unit': 818,
#  'đem': 819,
#  'add': 820,
#  'ao': 821,
#  'block': 822,
#  'create': 823,
#  'keyword': 824,
#  'method': 825,
#  'methods': 826,
#  'monitor': 827,
#  'reference': 828,
#  'so_huu': 829,
#  'synchronize': 830,
#  'synchronized': 831,
#  'tham_gia': 832,
#  'the': 833,
#  'thuat_ngu': 834,
#  'ton_tai': 835,
#  'tranh': 836,
#  'binh_thuong': 837,
#  'body': 838,
#  'buoc': 839,
#  'cau_lenh': 840,
#  'chi_phi': 841,
#  'chon_loc': 842,
#  'co': 843,
#  'coding': 844,
#  'developer': 845,
#  'di_chuyen': 846,
#  'docs': 847,
#  'giai_phong': 848,
#  'giao_tiep': 849,
#  'hien_nhien': 850,
#  'hoan_tat': 851,
#  'lien_ket': 852,
#  'limit': 853,
#  'links': 854,
#  'loai_tru': 855,
#  'ngam': 856,
#  'ngan_chan': 857,
#  'nguy_co': 858,
#  'nhien': 859,
#  'not': 860,
#  'other': 861,
#  'player': 862,
#  'related': 863,
#  'ro_rang': 864,
#  'su_kien': 865,
#  'table': 866,
#  'tables': 867,
#  'tac_dung': 868,
#  'tips': 869,
#  'ton': 870,
#  'tranh_chap': 871,
#  'tri_hoan': 872,
#  'tu_lieu': 873,
#  'your': 874,
#  'đa_so': 875,
#  'đat_cuoc': 876,
#  'đinh': 877,
#  'đot_ngot': 878,
#  'apps': 879,
#  'backend': 880,
#  'bang_bieu': 881,
#  'bo': 882,
#  'bo_cuc': 883,
#  'bo_sung': 884,
#  'bo_tri': 885,
#  'bootstrap': 886,
#  'buttons': 887,
#  'cam_hung': 888,
#  'cam_nhan': 889,
#  'cam_ung': 890,
#  'can': 891,
#  'chat_lieu': 892,
#  'che_tao': 893,
#  'chia_khoa': 894,
#  'chuan': 895,
#  'chuc': 896,
#  'chung_ban': 897,
#  'cong_nghiep': 898,
#  'cot': 899,
#  'cu_xu': 900,
#  'cua_so': 901,
#  'cuc_ky': 902,
#  'cycle': 903,
#  'developers': 904,
#  'dich': 905,
#  'dinh': 906,
#  'doc': 907,
#  'elements': 908,
#  'frameworks': 909,
#  'frontend': 910,
#  'gan_ket': 911,
#  'ghi_nho': 912,
#  'gia_nhap': 913,
#  'giay': 914,
#  'gon': 915,
#  'ham_mo': 916,
#  'hang_đau': 917,
#  'hau_nhu': 918,
#  'hien_đai_đe': 919,
#  'hieu_biet': 920,
#  'hinh_thanh': 921,
#  'hoan_hao': 922,
#  'huu': 923,
#  'icon': 924,
#  'jquery': 925,
#  'ke_hoach': 926,
#  'keo_dai': 927,
#  'ket_hop': 928,
#  'kham_pha': 929,
#  'khien': 930,
#  'kho_tang': 931,
#  'khung': 932,
#  'kich_ban': 933,
#  'kiem_soat': 934,
#  'kinh_nghiem': 935,
#  'kit': 936,
#  'ky_nang': 937,
#  'lap_tuc': 938,
#  'liet_ke': 939,
#  'like': 940,
#  'lo': 941,
#  'long': 942,
#  'lop_hoc': 943,
#  'luoi': 944,
#  'luoi_đien': 945,
#  'man_hinh': 946,
#  'mat_tich': 947,
#  'mau_sac': 948,
#  'may_chu': 949,
#  'media': 950,
#  'metro': 951,
#  'mien_phi': 952,
#  'mixins': 953,
#  'mobile': 954,
#  'muc_tieu': 955,
#  'nang_đong': 956,
#  'navigation': 957,
#  'nganh': 958,
#  'nghi': 959,
#  'nghien': 960,
#  'nguoi_ta': 961,
#  'nguon_luc': 962,
#  'nguyen_mau': 963,
#  'nguyen_tac': 964,
#  'nham_chan': 965,
#  'nhe': 966,
#  'noi_that': 967,
#  'pha': 968,
#  'phan_ung': 969,
#  'phang': 970,
#  'phat_hanh': 971,
#  'phong': 972,
#  'pin': 973,
#  'plugin': 974,
#  'quat': 975,
#  'quy': 976,
#  'radio': 977,
#  'sass': 978,
#  'scale': 979,
#  'sieng_nang': 980,
#  'social': 981,
#  'suc_manh': 982,
#  'sup_đo': 983,
#  'suu_tap': 984,
#  'tai_nguyen': 985,
#  'tam_tri': 986,
#  'tang_cuong': 987,
#  'tap_tin': 988,
#  'tat_nhien': 989,
#  'template': 990,
#  'tha': 991,
#  'tham_quan': 992,
#  'that': 993,
#  'thay_the': 994,
#  'theme': 995,
#  'thich_nghi': 996,
#  'thiet_yeu': 997,
#  'thong_so': 998,
#  'thu_cong': 999,
#  ...}

# %%
class StreamCorpus(object):
    def __init__(self, sentences, dictionary, clip_docs=None):
        """
        Parse the first `clip_docs` documents
        Yield each document in turn, as a list of tokens.
        """
        self.sentences = sentences
        self.dictionary = dictionary
        self.clip_docs = clip_docs

    def __iter__(self):
        for tokens in itertools.islice(make_texts_corpus(self.sentences),
                                       self.clip_docs):
            yield self.dictionary.doc2bow(tokens)

    def __len__(self):
        return self.clip_docs

# %%
sentences = make_sentences()
corpus = StreamCorpus(sentences, id2word)

# %%
#for i, c in enumerate(corpus):
#   print(c)
#    if i == 10: break

# %%
# save corpus
gensim.corpora.MmCorpus.serialize('../models/corpus.mm', corpus)
# Out:
# INFO : storing corpus in Matrix Market format to ../models/corpus.mm
# INFO : saving sparse matrix to ../models/corpus.mm
# INFO : PROGRESS: saving document #0
# INFO : saved 177x4087 matrix, density=5.002% (36185/723399)
# INFO : saving MmCorpus index to ../models/corpus.mm.index

# %%
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 177 documents, 4087 features, 36185 non-zero entries

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus, id2word=id2word, num_topics=57, passes=10,
            chunksize=67, random_state=46, alpha=1e-2, eta=0.5e-2,
            minimum_probability=0.0, per_word_topics=False)
# Out:
# INFO : using serial LDA version on this node
# INFO : running online (multi-pass) LDA training, 57 topics, 10 passes over the supplied corpus of 177 documents, updating model once every 67 documents, evaluating perplexity every 177 documents, iterating 50x with a convergence threshold of 0.001000
# INFO : PROGRESS: pass 0, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #46 (0.010): 0.029*"da" + 0.020*"song" + 0.017*"lanh_manh" + 0.016*"loi" + 0.012*"tien" + 0.008*"san_pham" + 0.007*"lan" + 0.007*"benh" + 0.007*"ta" + 0.007*"nghien_cuu"
# INFO : topic #38 (0.010): 0.081*"calo" + 0.029*"can" + 0.028*"co_the" + 0.015*"thuc_pham" + 0.014*"nang_luong" + 0.013*"nap" + 0.012*"song" + 0.011*"da" + 0.010*"loi" + 0.009*"chay"
# INFO : topic #51 (0.010): 0.019*"khoi_nghiep" + 0.018*"kinh_doanh" + 0.011*"song" + 0.009*"calo" + 0.008*"loi" + 0.007*"lam_viec" + 0.007*"thong_minh" + 0.006*"can" + 0.006*"lanh_manh" + 0.006*"mua"
# INFO : topic #5 (0.010): 0.024*"khoi_nghiep" + 0.022*"kinh_doanh" + 0.018*"marketing" + 0.017*"agile" + 0.016*"user" + 0.012*"san_pham" + 0.010*"khach_hang" + 0.010*"sprint" + 0.009*"du_an" + 0.009*"huong"
# INFO : topic #16 (0.010): 0.024*"marketing" + 0.013*"agile" + 0.012*"synchronized" + 0.012*"du_lich" + 0.008*"ha_long" + 0.007*"khoi_nghiep" + 0.007*"user" + 0.007*"mua" + 0.006*"method" + 0.006*"tien"
# INFO : topic diff=101.124847, rho=1.000000
# INFO : PROGRESS: pass 0, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #27 (0.010): 0.024*"du_lich" + 0.024*"tien" + 0.022*"tiet_kiem" + 0.019*"chuyen" + 0.018*"xe" + 0.016*"mua" + 0.015*"ve" + 0.014*"the" + 0.012*"nhat" + 0.012*"khoan"
# INFO : topic #14 (0.010): 0.022*"excel" + 0.019*"file" + 0.013*"đoc" + 0.009*"da" + 0.008*"ghi" + 0.007*"ta" + 0.007*"khoi_nghiep" + 0.006*"su" + 0.006*"class" + 0.006*"thiet_ke"
# INFO : topic #13 (0.010): 0.027*"đoc" + 0.021*"tien" + 0.020*"tet" + 0.019*"sach" + 0.018*"cong_nghe" + 0.012*"doanh_nghiep" + 0.012*"phap_ly" + 0.009*"kinh_te" + 0.009*"mua" + 0.009*"thi_truong"
# INFO : topic #47 (0.010): 0.052*"thuoc" + 0.021*"du_lich" + 0.017*"phong_tuc" + 0.014*"da" + 0.013*"moi_truong" + 0.012*"mua" + 0.012*"mien" + 0.011*"van_hoa" + 0.009*"ngu" + 0.008*"chua"
# INFO : topic #31 (0.010): 0.011*"đoi" + 0.010*"backend" + 0.010*"du_lieu" + 0.009*"he_thong" + 0.008*"muc_tieu" + 0.007*"da" + 0.007*"goi" + 0.007*"frontend" + 0.005*"vong" + 0.005*"lam_viec"
# INFO : topic diff=10.425775, rho=0.707107
# INFO : -34.772 per-word bound, 29331089915.0 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 0, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #39 (0.010): 0.380*"loc" + 0.024*"xanh" + 0.023*"rac" + 0.021*"trang_bi" + 0.015*"bui" + 0.015*"hut" + 0.014*"san_pham" + 0.014*"phan_loai" + 0.012*"cai_đat" + 0.010*"thu"
# INFO : topic #1 (0.010): 0.144*"toi_uu_hoa" + 0.045*"lien_ket" + 0.041*"giai_phong" + 0.031*"co_nghia_la" + 0.022*"tranh_chap" + 0.016*"player" + 0.016*"truy_cap" + 0.014*"đoi_tuong" + 0.013*"lock" + 0.012*"hien_nhien"
# INFO : topic #49 (0.010): 0.021*"kinh_te" + 0.017*"thi_truong" + 0.012*"khung_hoang" + 0.012*"phan_loai" + 0.011*"tang_truong" + 0.010*"bat_đong_san" + 0.009*"da" + 0.009*"tin_dung" + 0.008*"nam" + 0.007*"đao"
# INFO : topic #32 (0.010): 0.034*"mat_ngu" + 0.030*"o_nhiem" + 0.018*"mui" + 0.015*"tuyen" + 0.013*"ngu" + 0.013*"sach" + 0.012*"moi_truong" + 0.011*"canh_sat" + 0.009*"bao_ve" + 0.009*"am"
# INFO : topic #45 (0.010): 0.052*"ngon_ngu" + 0.030*"lap_trinh" + 0.012*"java" + 0.012*"ung_dung" + 0.011*"agile" + 0.007*"du_an" + 0.007*"chay" + 0.007*"php" + 0.006*"pho_bien" + 0.006*"phan_mem"
# INFO : topic diff=10.475982, rho=0.577350
# INFO : PROGRESS: pass 1, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #7 (0.010): 0.126*"agile" + 0.057*"marketing" + 0.051*"team" + 0.032*"imf" + 0.029*"user" + 0.027*"chuong_trinh" + 0.025*"bieu_dien" + 0.021*"test" + 0.020*"scrum" + 0.019*"constructor"
# INFO : topic #33 (0.010): 0.198*"da" + 0.062*"skincare" + 0.034*"cham_soc" + 0.033*"duong" + 0.030*"kem" + 0.027*"lan" + 0.024*"mat" + 0.021*"mat_na" + 0.019*"rua" + 0.016*"duong_chat"
# INFO : topic #27 (0.010): 0.063*"thue" + 0.054*"phong" + 0.046*"tro" + 0.025*"xe" + 0.021*"tien" + 0.020*"giao_thong" + 0.019*"mua" + 0.016*"đuong" + 0.014*"thong_tin" + 0.012*"tai_nan"
# INFO : topic #43 (0.010): 0.401*"may" + 0.050*"co" + 0.027*"kha_nang" + 0.024*"he_thong" + 0.021*"thong_minh" + 0.019*"phan_ung" + 0.013*"nhan_tao" + 0.012*"con_nguoi" + 0.012*"ta" + 0.011*"lich_su"
# INFO : topic #37 (0.010): 0.087*"giac_ngu" + 0.053*"ngu" + 0.017*"nao" + 0.016*"trua" + 0.015*"tieng" + 0.011*"chat_luong" + 0.010*"co_the" + 0.009*"ue_oai" + 0.009*"suc_khoe" + 0.008*"uong"
# INFO : topic diff=9.173842, rho=0.464149
# INFO : PROGRESS: pass 1, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #36 (0.010): 0.043*"du_lieu" + 0.042*"backend" + 0.038*"frontend" + 0.028*"api" + 0.026*"code" + 0.024*"đoan" + 0.021*"danh_sach" + 0.018*"xang" + 0.018*"phuong_thuc" + 0.017*"request"
# INFO : topic #22 (0.010): 0.040*"da" + 0.028*"sach" + 0.025*"san_pham" + 0.015*"phan_tu" + 0.015*"mat" + 0.012*"lan" + 0.012*"kien_thuc" + 0.012*"huu_co" + 0.010*"khuon_mat" + 0.010*"kien_nhan"
# INFO : topic #33 (0.010): 0.197*"da" + 0.061*"skincare" + 0.034*"cham_soc" + 0.033*"duong" + 0.029*"kem" + 0.027*"lan" + 0.024*"mat" + 0.021*"mat_na" + 0.018*"rua" + 0.015*"duong_chat"
# INFO : topic #26 (0.010): 0.030*"da" + 0.009*"lan" + 0.007*"duong" + 0.006*"mat" + 0.006*"phan_tu" + 0.006*"san_pham" + 0.005*"cham_soc" + 0.004*"am" + 0.004*"dau" + 0.004*"kinh_doanh"
# INFO : topic #56 (0.010): 0.009*"tang_truong" + 0.007*"kinh_doanh" + 0.007*"kinh_te" + 0.006*"khoi_nghiep" + 0.005*"du_bao" + 0.005*"the_gioi" + 0.004*"cong_ty" + 0.004*"kha_nang" + 0.003*"đau_tu" + 0.003*"huong"
# INFO : topic diff=9.672510, rho=0.464149
# INFO : -33.375 per-word bound, 11138329597.4 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 1, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #37 (0.010): 0.250*"giac_ngu" + 0.182*"ngu" + 0.055*"nao" + 0.032*"trua" + 0.029*"met_moi" + 0.029*"tieng" + 0.020*"chat_luong" + 0.015*"ue_oai" + 0.015*"uong" + 0.014*"co_the"
# INFO : topic #4 (0.010): 0.071*"xa_hoi" + 0.053*"moi_truong" + 0.025*"phap_luat" + 0.023*"cong_tac" + 0.022*"nam" + 0.021*"đau_tu" + 0.019*"sinh_thai" + 0.018*"to_chuc" + 0.016*"nha_nuoc" + 0.015*"quan_ly"
# INFO : topic #35 (0.010): 0.007*"da" + 0.004*"khoi_nghiep" + 0.004*"skincare" + 0.004*"he_thong" + 0.004*"thong_minh" + 0.004*"kinh_doanh" + 0.003*"xay_dung" + 0.003*"dau" + 0.003*"kha_nang" + 0.003*"kem"
# INFO : topic #20 (0.010): 0.009*"da" + 0.006*"khoi_nghiep" + 0.006*"calo" + 0.005*"kinh_doanh" + 0.003*"du_an" + 0.003*"san_pham" + 0.003*"huong" + 0.003*"mo_hinh" + 0.003*"xay_dung" + 0.003*"lan"
# INFO : topic #50 (0.010): 0.274*"tet" + 0.063*"gia_đinh" + 0.061*"le" + 0.037*"cu" + 0.033*"chuc" + 0.027*"mam" + 0.021*"tot_đep" + 0.019*"com" + 0.016*"nha_cua" + 0.016*"hoa"
# INFO : topic diff=9.816913, rho=0.464149
# INFO : PROGRESS: pass 2, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #20 (0.010): 0.007*"da" + 0.004*"khoi_nghiep" + 0.004*"calo" + 0.004*"kinh_doanh" + 0.003*"du_an" + 0.003*"san_pham" + 0.002*"huong" + 0.002*"mo_hinh" + 0.002*"xay_dung" + 0.002*"lan"
# INFO : topic #29 (0.010): 0.157*"chet" + 0.143*"da" + 0.120*"tay" + 0.048*"mat" + 0.047*"lan" + 0.036*"duong" + 0.033*"cang" + 0.029*"quy_trinh" + 0.029*"cham_soc" + 0.023*"tay_trang"
# INFO : topic #8 (0.010): 0.045*"song" + 0.033*"ngu" + 0.029*"cuoc_song" + 0.028*"suc_khoe" + 0.024*"thoi_quen" + 0.017*"loi" + 0.016*"lanh_manh" + 0.015*"tinh_than" + 0.013*"cang_thang" + 0.012*"giac_ngu"
# INFO : topic #49 (0.010): 0.089*"tang_truong" + 0.083*"khung_hoang" + 0.083*"kinh_te" + 0.075*"thi_truong" + 0.051*"du_bao" + 0.043*"suy_thoai" + 0.034*"lam_phat" + 0.030*"bat_đong_san" + 0.026*"chu_ky" + 0.026*"ngan_hang"
# INFO : topic #51 (0.010): 0.132*"khoi_nghiep" + 0.107*"kinh_doanh" + 0.037*"y_tuong" + 0.035*"thanh_cong" + 0.032*"ban_tay_trang" + 0.025*"von" + 0.020*"giau" + 0.019*"khach_hang" + 0.017*"cong_viec" + 0.016*"ban_hoa"
# INFO : topic diff=8.337376, rho=0.421009
# INFO : PROGRESS: pass 2, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #28 (0.010): 0.391*"khung_hoang" + 0.191*"kinh_te" + 0.082*"bong_bong" + 0.020*"lam_phat" + 0.013*"kinh_doanh" + 0.013*"thi_truong" + 0.012*"giay_to" + 0.008*"tai_chinh" + 0.006*"mo_rong" + 0.004*"khung"
# INFO : topic #47 (0.010): 0.051*"du_lich" + 0.050*"van_hoa" + 0.031*"thuoc" + 0.022*"đep" + 0.020*"mien" + 0.020*"truyen_thong" + 0.019*"phong_tuc" + 0.019*"may_man" + 0.019*"tay" + 0.018*"bac"
# INFO : topic #0 (0.010): 0.028*"thuc_pham" + 0.028*"che_đo" + 0.022*"chat" + 0.019*"an_uong" + 0.018*"suc_khoe" + 0.017*"co_the" + 0.016*"benh" + 0.016*"lanh_manh" + 0.015*"chua" + 0.015*"uong"
# INFO : topic #2 (0.010): 0.107*"stories" + 0.080*"nhac_nho" + 0.080*"user" + 0.036*"ghi" + 0.036*"liet_ke" + 0.035*"anh" + 0.025*"card" + 0.025*"đau_oc" + 0.024*"đong_vien" + 0.024*"marketer"
# INFO : topic #53 (0.010): 0.851*"ao" + 0.006*"goi" + 0.005*"vay" + 0.002*"nam" + 0.002*"the_ky" + 0.001*"lop" + 0.001*"thi_truong" + 0.001*"au" + 0.001*"tien" + 0.000*"đau_tu"
# INFO : topic diff=7.266392, rho=0.421009
# INFO : -33.386 per-word bound, 11221395979.7 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 2, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #46 (0.010): 0.099*"song" + 0.053*"loi" + 0.047*"hinh_thanh" + 0.038*"lanh_manh" + 0.033*"kien_thuc" + 0.025*"mac" + 0.023*"benh" + 0.023*"tuoi_tho" + 0.022*"keo_dai" + 0.019*"in"
# INFO : topic #27 (0.010): 0.088*"phong" + 0.083*"thue" + 0.071*"tro" + 0.030*"xe" + 0.026*"tien" + 0.026*"giao_thong" + 0.025*"đuong" + 0.020*"gia" + 0.016*"phuong_tien" + 0.016*"mua"
# INFO : topic #14 (0.010): 0.112*"thu_vien" + 0.098*"file" + 0.088*"class" + 0.085*"code" + 0.038*"excel" + 0.038*"model" + 0.028*"topic" + 0.027*"đoc" + 0.024*"tiep" + 0.023*"giao_dien"
# INFO : topic #9 (0.010): 0.002*"khoi_nghiep" + 0.001*"da" + 0.001*"kinh_doanh" + 0.001*"thong_minh" + 0.001*"may" + 0.001*"skincare" + 0.001*"kha_nang" + 0.001*"he_thong" + 0.001*"san_pham" + 0.001*"y_tuong"
# INFO : topic #33 (0.010): 0.204*"da" + 0.048*"skincare" + 0.037*"cham_soc" + 0.036*"lan" + 0.033*"duong" + 0.032*"kem" + 0.028*"mat" + 0.019*"am" + 0.019*"rua" + 0.017*"my_pham"
# INFO : topic diff=6.233665, rho=0.421009
# INFO : PROGRESS: pass 3, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #37 (0.010): 0.271*"ngu" + 0.227*"giac_ngu" + 0.059*"nao" + 0.045*"thuoc" + 0.030*"tieng" + 0.027*"giac" + 0.026*"co_the" + 0.024*"met_moi" + 0.024*"chat_luong" + 0.019*"uong"
# INFO : topic #26 (0.010): 0.006*"da" + 0.002*"lan" + 0.001*"duong" + 0.001*"mat" + 0.001*"phan_tu" + 0.001*"san_pham" + 0.001*"cham_soc" + 0.001*"am" + 0.001*"dau" + 0.001*"kinh_doanh"
# INFO : topic #25 (0.010): 0.012*"phu_nu" + 0.011*"phong" + 0.011*"lua_chon" + 0.009*"hop_đong" + 0.009*"hai" + 0.009*"đien" + 0.008*"chu" + 0.007*"đong" + 0.007*"vat" + 0.007*"ky"
# INFO : topic #1 (0.010): 0.083*"synchronized" + 0.063*"method" + 0.055*"lock" + 0.044*"toi_uu_hoa" + 0.039*"thread" + 0.036*"đoi_tuong" + 0.036*"monitor" + 0.031*"tranh_chap" + 0.030*"java" + 0.028*"thuc_thi"
# INFO : topic #29 (0.010): 0.210*"chet" + 0.166*"tay" + 0.082*"da" + 0.043*"cang" + 0.043*"mat" + 0.038*"lan" + 0.035*"duong" + 0.032*"yen" + 0.021*"quy_trinh" + 0.018*"ban"
# INFO : topic diff=4.805174, rho=0.388023
# INFO : PROGRESS: pass 3, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #10 (0.010): 0.259*"tien" + 0.087*"khoan" + 0.050*"ngan_hang" + 0.031*"tai_khoan" + 0.029*"đau_tu" + 0.027*"chi" + 0.024*"gui" + 0.022*"the" + 0.021*"giao_dich" + 0.020*"chi_phi"
# INFO : topic #7 (0.010): 0.206*"agile" + 0.118*"marketing" + 0.086*"team" + 0.044*"scrum" + 0.038*"imf" + 0.034*"user" + 0.027*"test" + 0.027*"bieu_dien" + 0.023*"tiep_thi" + 0.023*"phan_mem"
# INFO : topic #21 (0.010): 0.026*"ta" + 0.025*"mua" + 0.018*"luat" + 0.015*"the_gioi" + 0.014*"trung" + 0.013*"dien_tich" + 0.013*"chau" + 0.012*"le" + 0.011*"anh" + 0.011*"quoc"
# INFO : topic #45 (0.010): 0.397*"ngon_ngu" + 0.207*"lap_trinh" + 0.092*"java" + 0.052*"swift" + 0.049*"php" + 0.036*"python" + 0.021*"chay" + 0.021*"di_đong" + 0.017*"pho_bien" + 0.016*"javascript"
# INFO : topic #6 (0.010): 0.287*"giai_đoan" + 0.073*"sprint" + 0.049*"hom" + 0.031*"sale" + 0.029*"story" + 0.027*"tra_loi" + 0.027*"california" + 0.027*"lifestyle" + 0.026*"meeting" + 0.025*"huyet_ap"
# INFO : topic diff=3.729187, rho=0.388023
# INFO : -33.444 per-word bound, 11683139053.5 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 3, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #20 (0.010): 0.001*"da" + 0.001*"khoi_nghiep" + 0.001*"calo" + 0.001*"kinh_doanh" + 0.001*"du_an" + 0.001*"san_pham" + 0.001*"huong" + 0.000*"mo_hinh" + 0.000*"xay_dung" + 0.000*"lan"
# INFO : topic #30 (0.010): 0.157*"thread" + 0.103*"ham" + 0.073*"ts" + 0.068*"counter" + 0.032*"ta" + 0.030*"in" + 0.021*"ngat" + 0.020*"ke_thua" + 0.020*"resource" + 0.017*"with"
# INFO : topic #15 (0.010): 0.126*"sach" + 0.088*"đoc" + 0.037*"tieng" + 0.028*"hoc" + 0.021*"kha_nang" + 0.017*"giao_tiep" + 0.017*"tien" + 0.015*"thanh_cong" + 0.014*"thoi_quen" + 0.014*"y_tuong"
# INFO : topic #19 (0.010): 0.001*"marketing" + 0.001*"chuoi" + 0.000*"kinh_doanh" + 0.000*"khoi_nghiep" + 0.000*"mua" + 0.000*"lam_viec" + 0.000*"thanh_cong" + 0.000*"sprint" + 0.000*"agile" + 0.000*"san_pham"
# INFO : topic #28 (0.010): 0.394*"khung_hoang" + 0.258*"kinh_te" + 0.075*"bong_bong" + 0.020*"lam_phat" + 0.010*"kinh_doanh" + 0.009*"giay_to" + 0.009*"thi_truong" + 0.005*"tai_chinh" + 0.005*"mo_rong" + 0.003*"khung"
# INFO : topic diff=2.986313, rho=0.388023
# INFO : PROGRESS: pass 4, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #34 (0.010): 0.046*"web" + 0.039*"thiet_ke" + 0.036*"trang_web" + 0.030*"html" + 0.028*"javascript" + 0.023*"css" + 0.022*"de_dang" + 0.022*"ma" + 0.021*"chuong_trinh" + 0.018*"bootstrap"
# INFO : topic #50 (0.010): 0.242*"tet" + 0.077*"gia_đinh" + 0.054*"le" + 0.039*"cu" + 0.038*"chuc" + 0.029*"tot_đep" + 0.028*"mam" + 0.026*"com" + 0.022*"đon" + 0.021*"goi"
# INFO : topic #2 (0.010): 0.147*"stories" + 0.145*"user" + 0.055*"ghi" + 0.055*"card" + 0.053*"liet_ke" + 0.047*"noi_dung" + 0.040*"nhac_nho" + 0.036*"cot" + 0.033*"developers" + 0.033*"marketer"
# INFO : topic #11 (0.010): 0.045*"user" + 0.044*"website" + 0.041*"du_lieu" + 0.031*"api" + 0.028*"mo_ta" + 0.028*"app" + 0.027*"users" + 0.024*"server" + 0.024*"request" + 0.023*"page"
# INFO : topic #47 (0.010): 0.065*"van_hoa" + 0.062*"du_lich" + 0.034*"bac" + 0.032*"nam" + 0.029*"truyen_thong" + 0.027*"tay" + 0.025*"đep" + 0.025*"trang_phuc" + 0.020*"mac" + 0.019*"phu"
# INFO : topic diff=2.297289, rho=0.361745
# INFO : PROGRESS: pass 4, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #44 (0.010): 0.000*"ngon_ngu" + 0.000*"ung_dung" + 0.000*"web" + 0.000*"lap_trinh" + 0.000*"thiet_ke" + 0.000*"trang_web" + 0.000*"du_lieu" + 0.000*"swift" + 0.000*"mo_hinh" + 0.000*"javascript"
# INFO : topic #3 (0.010): 0.022*"kinh_te" + 0.019*"chi_tieu" + 0.018*"dan" + 0.016*"nam" + 0.013*"the_gioi" + 0.012*"cong_nghiep" + 0.012*"anh_huong" + 0.011*"viet_nam" + 0.010*"san_xuat" + 0.008*"bao_ve"
# INFO : topic #7 (0.010): 0.194*"agile" + 0.135*"marketing" + 0.080*"team" + 0.048*"scrum" + 0.042*"user" + 0.036*"imf" + 0.027*"tiep_thi" + 0.025*"phan_mem" + 0.024*"test" + 0.024*"bieu_dien"
# INFO : topic #23 (0.010): 0.117*"tiet_kiem" + 0.020*"lam_viec" + 0.019*"mua" + 0.019*"ke_hoach" + 0.014*"lang_phi" + 0.014*"mon" + 0.014*"thu_nhap" + 0.010*"cong_viec" + 0.010*"sinh_hoat" + 0.010*"đien"
# INFO : topic #38 (0.010): 0.148*"calo" + 0.072*"can" + 0.044*"co_the" + 0.043*"vien" + 0.027*"khoa_hoc" + 0.026*"nang_luong" + 0.023*"nap" + 0.021*"nghien_cuu" + 0.017*"đot" + 0.017*"kcal"
# INFO : topic diff=1.693800, rho=0.361745
# INFO : -33.414 per-word bound, 11443873341.3 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 4, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #51 (0.010): 0.135*"khoi_nghiep" + 0.103*"kinh_doanh" + 0.034*"thanh_cong" + 0.034*"y_tuong" + 0.026*"khach_hang" + 0.026*"tu_hao" + 0.025*"von" + 0.024*"ban_tay_trang" + 0.021*"cong_viec" + 0.021*"tom_tat"
# INFO : topic #19 (0.010): 0.000*"marketing" + 0.000*"chuoi" + 0.000*"kinh_doanh" + 0.000*"khoi_nghiep" + 0.000*"mua" + 0.000*"lam_viec" + 0.000*"thanh_cong" + 0.000*"sprint" + 0.000*"agile" + 0.000*"san_pham"
# INFO : topic #34 (0.010): 0.047*"web" + 0.034*"html" + 0.033*"trang_web" + 0.033*"thiet_ke" + 0.030*"javascript" + 0.030*"de_dang" + 0.026*"vu" + 0.023*"chuong_trinh" + 0.021*"ui" + 0.020*"ma"
# INFO : topic #27 (0.010): 0.091*"phong" + 0.083*"thue" + 0.072*"tro" + 0.030*"xe" + 0.026*"tien" + 0.025*"đuong" + 0.025*"giao_thong" + 0.023*"gia" + 0.017*"phuong_tien" + 0.014*"khu_vuc"
# INFO : topic #54 (0.010): 0.031*"ung_dung" + 0.026*"cong_nghiep" + 0.025*"vr" + 0.021*"cong_nghe" + 0.018*"thiet_bi" + 0.016*"doanh_nghiep" + 0.011*"du_lieu" + 0.011*"thuc" + 0.011*"khoa_hoc" + 0.011*"he_thong"
# INFO : topic diff=1.376556, rho=0.361745
# INFO : PROGRESS: pass 5, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #54 (0.010): 0.031*"ung_dung" + 0.020*"cong_nghiep" + 0.018*"vr" + 0.018*"cong_nghe" + 0.016*"thiet_bi" + 0.013*"doanh_nghiep" + 0.012*"he_thong" + 0.011*"xay_dung" + 0.010*"du_lieu" + 0.009*"thuc"
# INFO : topic #21 (0.010): 0.025*"ta" + 0.022*"luat" + 0.018*"trung" + 0.017*"the_gioi" + 0.017*"chau" + 0.016*"tho" + 0.016*"dien_tich" + 0.016*"au" + 0.015*"mua" + 0.013*"anh"
# INFO : topic #13 (0.010): 0.044*"sinh_vien" + 0.041*"tien" + 0.034*"doanh_nghiep" + 0.034*"quyet_đinh" + 0.033*"gia" + 0.024*"đai_hoc" + 0.017*"on_đinh" + 0.015*"truong" + 0.015*"giai_quyet" + 0.015*"cong_ty"
# INFO : topic #14 (0.010): 0.126*"file" + 0.079*"class" + 0.067*"excel" + 0.060*"code" + 0.047*"thu_vien" + 0.045*"ta" + 0.040*"đoc" + 0.036*"model" + 0.035*"string" + 0.026*"thanh"
# INFO : topic #39 (0.010): 0.252*"loc" + 0.079*"xanh" + 0.075*"bui" + 0.063*"mua" + 0.033*"san_pham" + 0.031*"sach" + 0.028*"hut" + 0.028*"che_đo" + 0.020*"rac" + 0.019*"tui"
# INFO : topic diff=1.140311, rho=0.340172
# INFO : PROGRESS: pass 5, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #10 (0.010): 0.249*"tien" + 0.091*"khoan" + 0.049*"ngan_hang" + 0.032*"đau_tu" + 0.029*"tai_khoan" + 0.026*"chi" + 0.024*"chi_phi" + 0.024*"gui" + 0.021*"thanh_toan" + 0.021*"giao_dich"
# INFO : topic #2 (0.010): 0.118*"user" + 0.117*"stories" + 0.072*"nhac_nho" + 0.056*"ghi" + 0.045*"card" + 0.043*"liet_ke" + 0.043*"noi_dung" + 0.033*"cot" + 0.031*"anh" + 0.028*"cho_du"
# INFO : topic #14 (0.010): 0.121*"file" + 0.076*"class" + 0.071*"excel" + 0.057*"code" + 0.045*"thu_vien" + 0.044*"ta" + 0.039*"đoc" + 0.035*"model" + 0.034*"string" + 0.026*"thanh"
# INFO : topic #54 (0.010): 0.033*"ung_dung" + 0.019*"cong_nghe" + 0.018*"cong_nghiep" + 0.015*"vr" + 0.014*"thiet_bi" + 0.012*"doanh_nghiep" + 0.011*"du_lieu" + 0.011*"he_thong" + 0.011*"xay_dung" + 0.009*"thuc"
# INFO : topic #3 (0.010): 0.020*"kinh_te" + 0.019*"chi_tieu" + 0.019*"dan" + 0.016*"nam" + 0.013*"the_gioi" + 0.012*"cong_nghiep" + 0.011*"anh_huong" + 0.011*"viet_nam" + 0.008*"đat" + 0.008*"bao_ve"
# INFO : topic diff=0.835883, rho=0.340172
# INFO : -33.373 per-word bound, 11128092523.9 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 5, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #9 (0.010): 0.000*"khoi_nghiep" + 0.000*"da" + 0.000*"kinh_doanh" + 0.000*"thong_minh" + 0.000*"may" + 0.000*"skincare" + 0.000*"kha_nang" + 0.000*"he_thong" + 0.000*"san_pham" + 0.000*"y_tuong"
# INFO : topic #29 (0.010): 0.282*"tay" + 0.243*"chet" + 0.066*"yen" + 0.053*"cang" + 0.040*"ban" + 0.025*"trang" + 0.023*"duong" + 0.022*"khu_vuc" + 0.018*"mat" + 0.017*"vien"
# INFO : topic #20 (0.010): 0.000*"da" + 0.000*"khoi_nghiep" + 0.000*"calo" + 0.000*"kinh_doanh" + 0.000*"du_an" + 0.000*"san_pham" + 0.000*"huong" + 0.000*"mo_hinh" + 0.000*"xay_dung" + 0.000*"lan"
# INFO : topic #27 (0.010): 0.091*"phong" + 0.083*"thue" + 0.072*"tro" + 0.030*"xe" + 0.026*"tien" + 0.025*"đuong" + 0.024*"giao_thong" + 0.024*"gia" + 0.017*"phuong_tien" + 0.014*"khu_vuc"
# INFO : topic #42 (0.010): 0.204*"it" + 0.001*"java" + 0.001*"đong_ho" + 0.001*"ngon_ngu" + 0.000*"lap_trinh" + 0.000*"phan_tu" + 0.000*"php" + 0.000*"python" + 0.000*"javascript" + 0.000*"ung_dung"
# INFO : topic diff=0.728115, rho=0.340172
# INFO : PROGRESS: pass 6, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #21 (0.010): 0.023*"luat" + 0.022*"ta" + 0.018*"trung" + 0.018*"chau" + 0.018*"the_gioi" + 0.018*"tho" + 0.016*"au" + 0.016*"dien_tich" + 0.016*"anh" + 0.013*"vay"
# INFO : topic #36 (0.010): 0.067*"du_lieu" + 0.040*"backend" + 0.039*"api" + 0.037*"code" + 0.031*"đoan" + 0.028*"frontend" + 0.027*"ta" + 0.026*"thong_bao" + 0.022*"request" + 0.021*"loi"
# INFO : topic #12 (0.010): 0.076*"blog" + 0.061*"binh_luan" + 0.060*"theo_doi" + 0.056*"chu_đe" + 0.051*"topic" + 0.051*"use" + 0.050*"case" + 0.048*"tieng" + 0.047*"hoc" + 0.047*"đang_nhap"
# INFO : topic #20 (0.010): 0.000*"da" + 0.000*"khoi_nghiep" + 0.000*"calo" + 0.000*"kinh_doanh" + 0.000*"du_an" + 0.000*"san_pham" + 0.000*"huong" + 0.000*"mo_hinh" + 0.000*"xay_dung" + 0.000*"lan"
# INFO : topic #50 (0.010): 0.236*"tet" + 0.080*"gia_đinh" + 0.046*"le" + 0.039*"chuc" + 0.037*"cu" + 0.030*"tot_đep" + 0.028*"mam" + 0.027*"goi" + 0.027*"com" + 0.024*"mon"
# INFO : topic diff=0.665637, rho=0.322048
# INFO : PROGRESS: pass 6, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #21 (0.010): 0.022*"luat" + 0.020*"anh" + 0.020*"ta" + 0.017*"the_gioi" + 0.017*"trung" + 0.017*"chau" + 0.015*"tho" + 0.015*"dien_tich" + 0.013*"au" + 0.013*"nang_luong"
# INFO : topic #2 (0.010): 0.118*"user" + 0.116*"stories" + 0.070*"nhac_nho" + 0.056*"ghi" + 0.050*"liet_ke" + 0.046*"noi_dung" + 0.045*"card" + 0.040*"cot" + 0.028*"anh" + 0.028*"cho_du"
# INFO : topic #35 (0.010): 0.000*"da" + 0.000*"khoi_nghiep" + 0.000*"skincare" + 0.000*"he_thong" + 0.000*"thong_minh" + 0.000*"kinh_doanh" + 0.000*"xay_dung" + 0.000*"dau" + 0.000*"kha_nang" + 0.000*"kem"
# INFO : topic #26 (0.010): 0.000*"da" + 0.000*"lan" + 0.000*"duong" + 0.000*"mat" + 0.000*"phan_tu" + 0.000*"san_pham" + 0.000*"cham_soc" + 0.000*"am" + 0.000*"dau" + 0.000*"kinh_doanh"
# INFO : topic #5 (0.010): 0.062*"con_so" + 0.061*"chu_đao" + 0.043*"huong" + 0.038*"kinh_doanh" + 0.032*"khoi_nghiep" + 0.029*"quy" + 0.025*"muc_tieu" + 0.016*"hop" + 0.016*"cong_ty" + 0.015*"kha_nang"
# INFO : topic diff=0.503227, rho=0.322048
# INFO : -33.341 per-word bound, 10877796904.5 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 6, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #53 (0.010): 0.939*"ao" + 0.016*"vay" + 0.005*"goi" + 0.000*"nam" + 0.000*"the_ky" + 0.000*"lop" + 0.000*"thi_truong" + 0.000*"au" + 0.000*"tien" + 0.000*"đau_tu"
# INFO : topic #29 (0.010): 0.300*"tay" + 0.236*"chet" + 0.063*"yen" + 0.054*"cang" + 0.043*"ban" + 0.030*"trang" + 0.026*"khu_vuc" + 0.020*"duong" + 0.017*"vien" + 0.017*"san_pham"
# INFO : topic #50 (0.010): 0.262*"tet" + 0.081*"gia_đinh" + 0.046*"le" + 0.038*"cu" + 0.037*"chuc" + 0.031*"tot_đep" + 0.027*"mam" + 0.024*"đau" + 0.024*"goi" + 0.022*"hoa"
# INFO : topic #22 (0.010): 0.040*"mui" + 0.034*"mang" + 0.028*"min" + 0.025*"san_pham" + 0.024*"hinh" + 0.024*"mat" + 0.020*"project" + 0.019*"khoi" + 0.017*"hien_đai" + 0.016*"hien_thi"
# INFO : topic #9 (0.010): 0.000*"khoi_nghiep" + 0.000*"da" + 0.000*"kinh_doanh" + 0.000*"thong_minh" + 0.000*"may" + 0.000*"skincare" + 0.000*"kha_nang" + 0.000*"he_thong" + 0.000*"san_pham" + 0.000*"y_tuong"
# INFO : topic diff=0.473952, rho=0.322048
# INFO : PROGRESS: pass 7, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #19 (0.010): 0.000*"marketing" + 0.000*"chuoi" + 0.000*"kinh_doanh" + 0.000*"khoi_nghiep" + 0.000*"mua" + 0.000*"lam_viec" + 0.000*"thanh_cong" + 0.000*"sprint" + 0.000*"agile" + 0.000*"san_pham"
# INFO : topic #54 (0.010): 0.031*"ung_dung" + 0.021*"cong_nghiep" + 0.019*"vr" + 0.018*"cong_nghe" + 0.017*"thiet_bi" + 0.014*"doanh_nghiep" + 0.012*"he_thong" + 0.011*"xay_dung" + 0.011*"du_lieu" + 0.010*"trai"
# INFO : topic #5 (0.010): 0.050*"kinh_doanh" + 0.043*"khoi_nghiep" + 0.039*"huong" + 0.035*"con_so" + 0.031*"chu_đao" + 0.028*"quy" + 0.023*"muc_tieu" + 0.021*"cong_ty" + 0.018*"so_huu" + 0.016*"mao_hiem"
# INFO : topic #28 (0.010): 0.428*"khung_hoang" + 0.383*"kinh_te" + 0.067*"bong_bong" + 0.023*"lam_phat" + 0.009*"kinh_doanh" + 0.008*"giay_to" + 0.008*"thi_truong" + 0.004*"mo_rong" + 0.002*"tai_chinh" + 0.000*"khung"
# INFO : topic #53 (0.010): 0.929*"ao" + 0.014*"vay" + 0.006*"goi" + 0.000*"nam" + 0.000*"the_ky" + 0.000*"lop" + 0.000*"thi_truong" + 0.000*"au" + 0.000*"tien" + 0.000*"đau_tu"
# INFO : topic diff=0.464303, rho=0.306544
# INFO : PROGRESS: pass 7, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #28 (0.010): 0.416*"khung_hoang" + 0.372*"kinh_te" + 0.065*"bong_bong" + 0.022*"lam_phat" + 0.009*"kinh_doanh" + 0.008*"giay_to" + 0.007*"thi_truong" + 0.004*"mo_rong" + 0.002*"tai_chinh" + 0.000*"khung"
# INFO : topic #13 (0.010): 0.047*"tien" + 0.041*"sinh_vien" + 0.037*"quyet_đinh" + 0.036*"doanh_nghiep" + 0.035*"gia" + 0.023*"đai_hoc" + 0.023*"du_an" + 0.018*"on_đinh" + 0.018*"giai_quyet" + 0.015*"truong"
# INFO : topic #48 (0.010): 0.056*"san_xuat" + 0.025*"tai_nguyen" + 0.016*"đoi" + 0.014*"thong_minh" + 0.012*"quan_ly" + 0.011*"than_kinh" + 0.011*"quy_trinh" + 0.010*"vong" + 0.010*"chat_luong" + 0.009*"trien_khai"
# INFO : topic #1 (0.010): 0.080*"synchronized" + 0.059*"method" + 0.049*"lock" + 0.044*"toi_uu_hoa" + 0.039*"thread" + 0.039*"đong_bo" + 0.033*"đoi_tuong" + 0.032*"monitor" + 0.032*"java" + 0.029*"tranh_chap"
# INFO : topic #20 (0.010): 0.000*"da" + 0.000*"khoi_nghiep" + 0.000*"calo" + 0.000*"kinh_doanh" + 0.000*"du_an" + 0.000*"san_pham" + 0.000*"huong" + 0.000*"mo_hinh" + 0.000*"xay_dung" + 0.000*"lan"
# INFO : topic diff=0.364547, rho=0.306544
# INFO : -33.315 per-word bound, 10688722956.4 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 7, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #1 (0.010): 0.090*"toi_uu_hoa" + 0.064*"synchronized" + 0.054*"method" + 0.040*"lock" + 0.033*"tranh_chap" + 0.032*"thread" + 0.031*"đong_bo" + 0.029*"java" + 0.029*"đoi_tuong" + 0.026*"trang_thai"
# INFO : topic #47 (0.010): 0.071*"van_hoa" + 0.053*"du_lich" + 0.043*"nam" + 0.043*"bac" + 0.031*"truyen_thong" + 0.026*"trang_phuc" + 0.023*"đep" + 0.022*"net" + 0.020*"mac" + 0.020*"viet_nam"
# INFO : topic #38 (0.010): 0.118*"calo" + 0.104*"khoa_hoc" + 0.102*"vien" + 0.059*"can" + 0.039*"nghien_cuu" + 0.033*"co_the" + 0.023*"nang_luong" + 0.018*"nap" + 0.014*"đot" + 0.013*"kcal"
# INFO : topic #14 (0.010): 0.111*"file" + 0.089*"class" + 0.079*"code" + 0.055*"thu_vien" + 0.052*"ta" + 0.048*"excel" + 0.043*"model" + 0.036*"đoc" + 0.032*"tiep_can" + 0.028*"thanh"
# INFO : topic #42 (0.010): 0.207*"it" + 0.000*"java" + 0.000*"đong_ho" + 0.000*"ngon_ngu" + 0.000*"lap_trinh" + 0.000*"phan_tu" + 0.000*"php" + 0.000*"python" + 0.000*"javascript" + 0.000*"ung_dung"
# INFO : topic diff=0.362334, rho=0.306544
# INFO : PROGRESS: pass 8, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #27 (0.010): 0.078*"phong" + 0.073*"thue" + 0.061*"tro" + 0.029*"xe" + 0.024*"tien" + 0.022*"gia" + 0.022*"đuong" + 0.019*"giao_thong" + 0.015*"phuong_tien" + 0.014*"thong_tin"
# INFO : topic #39 (0.010): 0.230*"loc" + 0.091*"mua" + 0.078*"xanh" + 0.077*"bui" + 0.037*"sach" + 0.035*"san_pham" + 0.026*"che_đo" + 0.025*"phong" + 0.025*"hut" + 0.019*"rac"
# INFO : topic #50 (0.010): 0.235*"tet" + 0.080*"gia_đinh" + 0.041*"le" + 0.038*"chuc" + 0.037*"cu" + 0.031*"tot_đep" + 0.030*"goi" + 0.029*"mam" + 0.026*"com" + 0.025*"mon"
# INFO : topic #38 (0.010): 0.153*"calo" + 0.072*"can" + 0.052*"khoa_hoc" + 0.047*"vien" + 0.041*"co_the" + 0.025*"nang_luong" + 0.024*"nghien_cuu" + 0.022*"nap" + 0.017*"kcal" + 0.017*"đot"
# INFO : topic #13 (0.010): 0.050*"tien" + 0.045*"sinh_vien" + 0.039*"quyet_đinh" + 0.033*"gia" + 0.031*"doanh_nghiep" + 0.024*"đai_hoc" + 0.017*"on_đinh" + 0.017*"du_an" + 0.016*"giai_quyet" + 0.016*"truong"
# INFO : topic diff=0.366321, rho=0.293083
# INFO : PROGRESS: pass 8, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #20 (0.010): 0.000*"da" + 0.000*"khoi_nghiep" + 0.000*"calo" + 0.000*"kinh_doanh" + 0.000*"du_an" + 0.000*"san_pham" + 0.000*"huong" + 0.000*"mo_hinh" + 0.000*"xay_dung" + 0.000*"lan"
# INFO : topic #19 (0.010): 0.000*"marketing" + 0.000*"chuoi" + 0.000*"kinh_doanh" + 0.000*"khoi_nghiep" + 0.000*"mua" + 0.000*"lam_viec" + 0.000*"thanh_cong" + 0.000*"sprint" + 0.000*"agile" + 0.000*"san_pham"
# INFO : topic #8 (0.010): 0.044*"cuoc_song" + 0.042*"song" + 0.028*"suc_khoe" + 0.022*"thoi_quen" + 0.018*"cang_thang" + 0.017*"tinh_than" + 0.016*"cong_viec" + 0.013*"loi" + 0.012*"tich_cuc" + 0.012*"y_nghia"
# INFO : topic #31 (0.010): 0.000*"đoi" + 0.000*"backend" + 0.000*"du_lieu" + 0.000*"he_thong" + 0.000*"muc_tieu" + 0.000*"da" + 0.000*"goi" + 0.000*"frontend" + 0.000*"vong" + 0.000*"lam_viec"
# INFO : topic #30 (0.010): 0.196*"thread" + 0.086*"ham" + 0.085*"counter" + 0.038*"ts" + 0.036*"ta" + 0.034*"in" + 0.027*"khoi" + 0.025*"resource" + 0.021*"lop" + 0.021*"thuc_thi"
# INFO : topic diff=0.294164, rho=0.293083
# INFO : -33.297 per-word bound, 10550932433.7 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 8, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #44 (0.010): 0.000*"ngon_ngu" + 0.000*"ung_dung" + 0.000*"web" + 0.000*"lap_trinh" + 0.000*"thiet_ke" + 0.000*"trang_web" + 0.000*"du_lieu" + 0.000*"swift" + 0.000*"mo_hinh" + 0.000*"javascript"
# INFO : topic #4 (0.010): 0.073*"xa_hoi" + 0.043*"nam" + 0.042*"moi_truong" + 0.024*"sinh_thai" + 0.023*"to_chuc" + 0.022*"nha_nuoc" + 0.021*"chinh_phu" + 0.021*"đau_tu" + 0.019*"kinh_te" + 0.018*"đat_nuoc"
# INFO : topic #24 (0.010): 0.000*"da" + 0.000*"he_thong" + 0.000*"du_lieu" + 0.000*"tang_truong" + 0.000*"thong_bao" + 0.000*"du_bao" + 0.000*"website" + 0.000*"blog" + 0.000*"phan_tu" + 0.000*"kinh_te"
# INFO : topic #9 (0.010): 0.000*"khoi_nghiep" + 0.000*"da" + 0.000*"kinh_doanh" + 0.000*"thong_minh" + 0.000*"may" + 0.000*"skincare" + 0.000*"kha_nang" + 0.000*"he_thong" + 0.000*"san_pham" + 0.000*"y_tuong"
# INFO : topic #53 (0.010): 0.936*"ao" + 0.018*"vay" + 0.006*"goi" + 0.000*"nam" + 0.000*"the_ky" + 0.000*"lop" + 0.000*"thi_truong" + 0.000*"au" + 0.000*"tien" + 0.000*"đau_tu"
# INFO : topic diff=0.302394, rho=0.293083
# INFO : PROGRESS: pass 9, at document #67/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #10 (0.010): 0.205*"tien" + 0.063*"khoan" + 0.048*"đau_tu" + 0.041*"ngan_hang" + 0.029*"đong_tien" + 0.026*"giao_dich" + 0.025*"virtual" + 0.024*"tai_khoan" + 0.023*"thanh_toan" + 0.022*"đong"
# INFO : topic #29 (0.010): 0.284*"tay" + 0.238*"chet" + 0.054*"ban" + 0.054*"cang" + 0.050*"yen" + 0.043*"trang" + 0.025*"khu_vuc" + 0.019*"san_pham" + 0.019*"vien" + 0.018*"duong"
# INFO : topic #26 (0.010): 0.000*"da" + 0.000*"lan" + 0.000*"duong" + 0.000*"mat" + 0.000*"phan_tu" + 0.000*"san_pham" + 0.000*"cham_soc" + 0.000*"am" + 0.000*"dau" + 0.000*"kinh_doanh"
# INFO : topic #6 (0.010): 0.193*"giai_đoan" + 0.129*"sprint" + 0.098*"story" + 0.047*"meeting" + 0.037*"tham_du" + 0.037*"tra_loi" + 0.031*"hom" + 0.030*"california" + 0.030*"lifestyle" + 0.026*"sale"
# INFO : topic #40 (0.010): 0.100*"lao_đong" + 0.087*"doanh_nghiep" + 0.085*"cong_nhan" + 0.070*"cong_ty" + 0.060*"đau_tu" + 0.037*"chuoi" + 0.034*"the_ky" + 0.028*"quan_ly" + 0.025*"suy_nghi" + 0.024*"von"
# INFO : topic diff=0.309698, rho=0.281252
# INFO : PROGRESS: pass 9, at document #134/177
# INFO : merging changes from 67 documents into a model of 177 documents
# INFO : topic #29 (0.010): 0.275*"tay" + 0.242*"chet" + 0.053*"ban" + 0.052*"cang" + 0.048*"yen" + 0.041*"trang" + 0.024*"khu_vuc" + 0.018*"vien" + 0.018*"san_pham" + 0.017*"khoa_hoc"
# INFO : topic #52 (0.010): 0.469*"lang" + 0.090*"đong_y" + 0.024*"chong_mat" + 0.001*"tri" + 0.000*"ngu" + 0.000*"giac_ngu" + 0.000*"da" + 0.000*"ngon" + 0.000*"giac" + 0.000*"thai"
# INFO : topic #24 (0.010): 0.000*"da" + 0.000*"he_thong" + 0.000*"du_lieu" + 0.000*"tang_truong" + 0.000*"thong_bao" + 0.000*"du_bao" + 0.000*"website" + 0.000*"blog" + 0.000*"phan_tu" + 0.000*"kinh_te"
# INFO : topic #45 (0.010): 0.378*"ngon_ngu" + 0.190*"lap_trinh" + 0.090*"java" + 0.047*"swift" + 0.044*"pho_bien" + 0.043*"php" + 0.037*"javascript" + 0.032*"python" + 0.028*"ung_dung" + 0.024*"chay"
# INFO : topic #39 (0.010): 0.199*"loc" + 0.100*"xanh" + 0.093*"mua" + 0.066*"bui" + 0.036*"sach" + 0.035*"san_pham" + 0.033*"rac" + 0.024*"phong" + 0.024*"che_đo" + 0.023*"tui"
# INFO : topic diff=0.251686, rho=0.281252
# INFO : -33.282 per-word bound, 10445543612.3 perplexity estimate based on a held-out corpus of 43 documents with 22947 words
# INFO : PROGRESS: pass 9, at document #177/177
# INFO : merging changes from 43 documents into a model of 177 documents
# INFO : topic #48 (0.010): 0.089*"san_xuat" + 0.019*"tai_nguyen" + 0.015*"thong_minh" + 0.015*"đoi" + 0.014*"quan_ly" + 0.014*"quy_trinh" + 0.013*"chat_luong" + 0.013*"trien_khai" + 0.011*"he_thong" + 0.010*"camera"
# INFO : topic #39 (0.010): 0.238*"loc" + 0.101*"mua" + 0.083*"xanh" + 0.076*"bui" + 0.042*"sach" + 0.037*"san_pham" + 0.031*"phong" + 0.027*"che_đo" + 0.026*"hut" + 0.019*"ban"
# INFO : topic #0 (0.010): 0.031*"thuc_pham" + 0.030*"che_đo" + 0.024*"chat" + 0.020*"an_uong" + 0.019*"suc_khoe" + 0.015*"benh" + 0.015*"uong" + 0.015*"chua" + 0.015*"lanh_manh" + 0.014*"thit"
# INFO : topic #4 (0.010): 0.072*"xa_hoi" + 0.044*"nam" + 0.037*"moi_truong" + 0.024*"sinh_thai" + 0.023*"to_chuc" + 0.022*"nha_nuoc" + 0.021*"chinh_phu" + 0.021*"đau_tu" + 0.020*"kinh_te" + 0.018*"đat_nuoc"
# INFO : topic #3 (0.010): 0.024*"dan" + 0.016*"nam" + 0.014*"kinh_te" + 0.013*"chi_tieu" + 0.013*"viet_nam" + 0.012*"vu" + 0.012*"cong_nghiep" + 0.012*"the_gioi" + 0.011*"nang" + 0.011*"chinh_phu"
# INFO : topic diff=0.264180, rho=0.281252
# INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=4087, num_topics=57, decay=0.5, chunksize=67> in 19.26s', 'datetime': '2022-12-29T04:01:39.391866', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)
coherence_model_lda = CoherenceModel(model=lda_model, texts=sentences, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# INFO : using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# INFO : 1 batches submitted to accumulate stats from 64 documents (25259 virtual)
# INFO : 2 batches submitted to accumulate stats from 128 documents (49599 virtual)
# INFO : 3 batches submitted to accumulate stats from 192 documents (72539 virtual)
# INFO : 7 accumulators retrieved from output queue
# INFO : accumulated word occurrence stats for 72592 virtual documents
# Coherence Score:  0.4951063106239485

# %%
import gensim
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
print('\nPerplexity: ', lda_model.log_perplexity(corpus))
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 177 documents, 4087 features, 36185 non-zero entries
# INFO : -22.623 per-word bound, 6457650.2 perplexity estimate based on a held-out corpus of 177 documents with 81947 words
# Perplexity:  -22.62257786771165

# %%
lda_model.save('../models/LDA.model')
lda_model.print_topics()
# Out:
# INFO : LdaState lifecycle event {'fname_or_handle': '../models/LDA.model.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-12-29T04:02:07.024492', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/LDA.model.state
# INFO : LdaModel lifecycle event {'fname_or_handle': '../models/LDA.model', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['state', 'dispatcher', 'id2word'], 'datetime': '2022-12-29T04:02:07.048074', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : storing np array 'expElogbeta' to ../models/LDA.model.expElogbeta.npy
# INFO : not storing attribute state
# INFO : not storing attribute dispatcher
# INFO : not storing attribute id2word
# INFO : saved ../models/LDA.model
# INFO : topic #5 (0.010): 0.064*"con_so" + 0.060*"chu_đao" + 0.044*"huong" + 0.038*"kinh_doanh" + 0.030*"quy" + 0.027*"khoi_nghiep" + 0.026*"muc_tieu" + 0.017*"cong_ty" + 0.016*"hop" + 0.016*"kha_nang"
# INFO : topic #24 (0.010): 0.000*"da" + 0.000*"he_thong" + 0.000*"du_lieu" + 0.000*"tang_truong" + 0.000*"thong_bao" + 0.000*"du_bao" + 0.000*"website" + 0.000*"blog" + 0.000*"phan_tu" + 0.000*"kinh_te"
# INFO : topic #55 (0.010): 0.067*"cong_nghe" + 0.046*"nhan_tao" + 0.044*"con_nguoi" + 0.037*"tri_tue" + 0.034*"tu_đong" + 0.032*"he_thong" + 0.025*"hoa" + 0.024*"thong_minh" + 0.019*"khach_hang" + 0.019*"hoc"
# INFO : topic #29 (0.010): 0.320*"tay" + 0.218*"chet" + 0.057*"yen" + 0.057*"ban" + 0.049*"cang" + 0.036*"trang" + 0.029*"khu_vuc" + 0.024*"chau" + 0.022*"san_pham" + 0.020*"vien"
# INFO : topic #28 (0.010): 0.402*"khung_hoang" + 0.367*"kinh_te" + 0.061*"bong_bong" + 0.021*"lam_phat" + 0.009*"kinh_doanh" + 0.007*"giay_to" + 0.007*"thi_truong" + 0.004*"mo_rong" + 0.001*"tai_chinh" + 0.000*"khung"
# INFO : topic #9 (0.010): 0.000*"khoi_nghiep" + 0.000*"da" + 0.000*"kinh_doanh" + 0.000*"thong_minh" + 0.000*"may" + 0.000*"skincare" + 0.000*"kha_nang" + 0.000*"he_thong" + 0.000*"san_pham" + 0.000*"y_tuong"
# INFO : topic #41 (0.010): 0.198*"react" + 0.146*"component" + 0.106*"dom" + 0.058*"javascript" + 0.051*"components" + 0.042*"state" + 0.039*"view" + 0.034*"cap_nhat" + 0.026*"goi" + 0.026*"html"
# INFO : topic #31 (0.010): 0.000*"đoi" + 0.000*"backend" + 0.000*"du_lieu" + 0.000*"he_thong" + 0.000*"muc_tieu" + 0.000*"da" + 0.000*"goi" + 0.000*"frontend" + 0.000*"vong" + 0.000*"lam_viec"
# INFO : topic #38 (0.010): 0.120*"calo" + 0.107*"khoa_hoc" + 0.095*"vien" + 0.060*"can" + 0.039*"nghien_cuu" + 0.034*"co_the" + 0.024*"nang_luong" + 0.018*"nap" + 0.014*"đot" + 0.013*"kcal"
# INFO : topic #15 (0.010): 0.135*"sach" + 0.098*"đoc" + 0.034*"tieng" + 0.026*"hoc" + 0.025*"kha_nang" + 0.021*"giao_tiep" + 0.016*"tu_duy" + 0.013*"y_tuong" + 0.013*"thanh_cong" + 0.012*"ky_nang"
# INFO : topic #53 (0.010): 0.934*"ao" + 0.018*"vay" + 0.007*"goi" + 0.000*"nam" + 0.000*"the_ky" + 0.000*"lop" + 0.000*"thi_truong" + 0.000*"au" + 0.000*"tien" + 0.000*"đau_tu"
# INFO : topic #51 (0.010): 0.170*"khoi_nghiep" + 0.099*"kinh_doanh" + 0.039*"y_tuong" + 0.035*"thanh_cong" + 0.030*"đam_me" + 0.026*"khach_hang" + 0.021*"đung" + 0.021*"von" + 0.020*"giau" + 0.019*"ban_tay_trang"
# INFO : topic #25 (0.010): 0.021*"than" + 0.016*"phu_nu" + 0.013*"lua_chon" + 0.012*"đien" + 0.012*"hop_đong" + 0.011*"khong_gian" + 0.010*"thu" + 0.010*"hai" + 0.009*"vat" + 0.009*"chat_luong"
# INFO : topic #16 (0.010): 0.120*"khong_khi" + 0.040*"online" + 0.030*"mua" + 0.029*"website" + 0.024*"khu" + 0.015*"ha_noi" + 0.013*"khong_gian" + 0.012*"xe_may" + 0.012*"son" + 0.011*"đo_thi"
# INFO : topic #46 (0.010): 0.165*"song" + 0.069*"loi" + 0.048*"lanh_manh" + 0.044*"hinh_thanh" + 0.031*"mac" + 0.029*"kien_thuc" + 0.025*"benh" + 0.025*"tuoi_tho" + 0.022*"keo_dai" + 0.020*"nghien_cuu"
# INFO : topic #33 (0.010): 0.199*"da" + 0.042*"lan" + 0.039*"skincare" + 0.037*"cham_soc" + 0.033*"duong" + 0.031*"kem" + 0.031*"mat" + 0.023*"san_pham" + 0.022*"am" + 0.016*"rua"
# INFO : topic #34 (0.010): 0.050*"web" + 0.038*"thiet_ke" + 0.034*"trang_web" + 0.034*"html" + 0.028*"de_dang" + 0.026*"javascript" + 0.024*"ma" + 0.024*"chuong_trinh" + 0.020*"thanh_phan" + 0.019*"ui"
# INFO : topic #0 (0.010): 0.031*"thuc_pham" + 0.030*"che_đo" + 0.024*"chat" + 0.020*"an_uong" + 0.019*"suc_khoe" + 0.015*"benh" + 0.015*"uong" + 0.015*"chua" + 0.015*"lanh_manh" + 0.014*"thit"
# INFO : topic #43 (0.010): 0.540*"may" + 0.078*"ta" + 0.078*"thiet_ke" + 0.071*"co" + 0.046*"kha_nang" + 0.025*"cong_nghe" + 0.020*"hai" + 0.015*"he_thong" + 0.013*"ac" + 0.010*"lich_su"
# INFO : topic #40 (0.010): 0.122*"lao_đong" + 0.103*"cong_nhan" + 0.098*"doanh_nghiep" + 0.060*"đau_tu" + 0.060*"cong_ty" + 0.038*"chuoi" + 0.032*"quan_ly" + 0.028*"trang_bi" + 0.026*"suy_nghi" + 0.023*"thach_thuc"
# [(5,
#   '0.064*"con_so" + 0.060*"chu_đao" + 0.044*"huong" + 0.038*"kinh_doanh" + 0.030*"quy" + 0.027*"khoi_nghiep" + 0.026*"muc_tieu" + 0.017*"cong_ty" + 0.016*"hop" + 0.016*"kha_nang"'),
#  (24,
#   '0.000*"da" + 0.000*"he_thong" + 0.000*"du_lieu" + 0.000*"tang_truong" + 0.000*"thong_bao" + 0.000*"du_bao" + 0.000*"website" + 0.000*"blog" + 0.000*"phan_tu" + 0.000*"kinh_te"'),
#  (55,
#   '0.067*"cong_nghe" + 0.046*"nhan_tao" + 0.044*"con_nguoi" + 0.037*"tri_tue" + 0.034*"tu_đong" + 0.032*"he_thong" + 0.025*"hoa" + 0.024*"thong_minh" + 0.019*"khach_hang" + 0.019*"hoc"'),
#  (29,
#   '0.320*"tay" + 0.218*"chet" + 0.057*"yen" + 0.057*"ban" + 0.049*"cang" + 0.036*"trang" + 0.029*"khu_vuc" + 0.024*"chau" + 0.022*"san_pham" + 0.020*"vien"'),
#  (28,
#   '0.402*"khung_hoang" + 0.367*"kinh_te" + 0.061*"bong_bong" + 0.021*"lam_phat" + 0.009*"kinh_doanh" + 0.007*"giay_to" + 0.007*"thi_truong" + 0.004*"mo_rong" + 0.001*"tai_chinh" + 0.000*"khung"'),
#  (9,
#   '0.000*"khoi_nghiep" + 0.000*"da" + 0.000*"kinh_doanh" + 0.000*"thong_minh" + 0.000*"may" + 0.000*"skincare" + 0.000*"kha_nang" + 0.000*"he_thong" + 0.000*"san_pham" + 0.000*"y_tuong"'),
#  (41,
#   '0.198*"react" + 0.146*"component" + 0.106*"dom" + 0.058*"javascript" + 0.051*"components" + 0.042*"state" + 0.039*"view" + 0.034*"cap_nhat" + 0.026*"goi" + 0.026*"html"'),
#  (31,
#   '0.000*"đoi" + 0.000*"backend" + 0.000*"du_lieu" + 0.000*"he_thong" + 0.000*"muc_tieu" + 0.000*"da" + 0.000*"goi" + 0.000*"frontend" + 0.000*"vong" + 0.000*"lam_viec"'),
#  (38,
#   '0.120*"calo" + 0.107*"khoa_hoc" + 0.095*"vien" + 0.060*"can" + 0.039*"nghien_cuu" + 0.034*"co_the" + 0.024*"nang_luong" + 0.018*"nap" + 0.014*"đot" + 0.013*"kcal"'),
#  (15,
#   '0.135*"sach" + 0.098*"đoc" + 0.034*"tieng" + 0.026*"hoc" + 0.025*"kha_nang" + 0.021*"giao_tiep" + 0.016*"tu_duy" + 0.013*"y_tuong" + 0.013*"thanh_cong" + 0.012*"ky_nang"'),
#  (53,
#   '0.934*"ao" + 0.018*"vay" + 0.007*"goi" + 0.000*"nam" + 0.000*"the_ky" + 0.000*"lop" + 0.000*"thi_truong" + 0.000*"au" + 0.000*"tien" + 0.000*"đau_tu"'),
#  (51,
#   '0.170*"khoi_nghiep" + 0.099*"kinh_doanh" + 0.039*"y_tuong" + 0.035*"thanh_cong" + 0.030*"đam_me" + 0.026*"khach_hang" + 0.021*"đung" + 0.021*"von" + 0.020*"giau" + 0.019*"ban_tay_trang"'),
#  (25,
#   '0.021*"than" + 0.016*"phu_nu" + 0.013*"lua_chon" + 0.012*"đien" + 0.012*"hop_đong" + 0.011*"khong_gian" + 0.010*"thu" + 0.010*"hai" + 0.009*"vat" + 0.009*"chat_luong"'),
#  (16,
#   '0.120*"khong_khi" + 0.040*"online" + 0.030*"mua" + 0.029*"website" + 0.024*"khu" + 0.015*"ha_noi" + 0.013*"khong_gian" + 0.012*"xe_may" + 0.012*"son" + 0.011*"đo_thi"'),
#  (46,
#   '0.165*"song" + 0.069*"loi" + 0.048*"lanh_manh" + 0.044*"hinh_thanh" + 0.031*"mac" + 0.029*"kien_thuc" + 0.025*"benh" + 0.025*"tuoi_tho" + 0.022*"keo_dai" + 0.020*"nghien_cuu"'),
#  (33,
#   '0.199*"da" + 0.042*"lan" + 0.039*"skincare" + 0.037*"cham_soc" + 0.033*"duong" + 0.031*"kem" + 0.031*"mat" + 0.023*"san_pham" + 0.022*"am" + 0.016*"rua"'),
#  (34,
#   '0.050*"web" + 0.038*"thiet_ke" + 0.034*"trang_web" + 0.034*"html" + 0.028*"de_dang" + 0.026*"javascript" + 0.024*"ma" + 0.024*"chuong_trinh" + 0.020*"thanh_phan" + 0.019*"ui"'),
#  (0,
#   '0.031*"thuc_pham" + 0.030*"che_đo" + 0.024*"chat" + 0.020*"an_uong" + 0.019*"suc_khoe" + 0.015*"benh" + 0.015*"uong" + 0.015*"chua" + 0.015*"lanh_manh" + 0.014*"thit"'),
#  (43,
#   '0.540*"may" + 0.078*"ta" + 0.078*"thiet_ke" + 0.071*"co" + 0.046*"kha_nang" + 0.025*"cong_nghe" + 0.020*"hai" + 0.015*"he_thong" + 0.013*"ac" + 0.010*"lich_su"'),
#  (40,
#   '0.122*"lao_đong" + 0.103*"cong_nhan" + 0.098*"doanh_nghiep" + 0.060*"đau_tu" + 0.060*"cong_ty" + 0.038*"chuoi" + 0.032*"quan_ly" + 0.028*"trang_bi" + 0.026*"suy_nghi" + 0.023*"thach_thuc"')]

# %%
import numpy as np
from gensim import similarities

doc_topic_dist = np.array(
    [[tup[1] for tup in lst] for lst in lda_model[corpus]]
)
index = similarities.MatrixSimilarity(lda_model[corpus])
# Out:
# WARNING : scanning corpus to determine the number of features (consider setting `num_features` explicitly)
# INFO : creating matrix with 177 documents and 57 features

# %%
doc_topic_dist
# Out:
# array([[5.4669681e-06, 2.3231448e-03, 5.4669681e-06, ..., 2.6625896e-01,
#         5.6694020e-02, 5.4669681e-06],
#        [6.6879831e-05, 6.6879831e-05, 6.8502696e-03, ..., 5.1073506e-02,
#         6.6879831e-05, 6.6879831e-05],
#        [2.4368326e-05, 1.6998908e-02, 2.4368326e-05, ..., 1.8155126e-02,
#         2.4368326e-05, 2.4368326e-05],
#        ...,
#        [3.7388167e-05, 3.7388167e-05, 3.7388167e-05, ..., 4.0998036e-01,
#         1.5377366e-02, 3.7388167e-05],
#        [2.7821146e-05, 7.9700630e-03, 2.7821146e-05, ..., 4.2075753e-01,
#         2.7821146e-05, 2.7821146e-05],
#        [6.6429180e-05, 9.7426763e-03, 6.9764843e-03, ..., 3.6319378e-01,
#         6.6429180e-05, 6.6429180e-05]], dtype=float32)

# %%
index.save('../models/matrixSimilarity.index')
# Out:
# INFO : MatrixSimilarity lifecycle event {'fname_or_handle': '../models/matrixSimilarity.index', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-12-29T04:07:56.182175', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/matrixSimilarity.index

# %%
doc_topic_dist.shape
# Out:
# (177, 57)

# %%
import joblib

# %%
joblib.dump(doc_topic_dist, '../models/doc_topic_dist.dat')
# Out:
# ['../models/doc_topic_dist.dat']

# %%
from gensim.models.coherencemodel import CoherenceModel

# %%
import gensim
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
print('\nPerplexity: ', lda_model.log_perplexity(corpus))
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 177 documents, 4087 features, 36185 non-zero entries
# INFO : -22.622 per-word bound, 6457092.4 perplexity estimate based on a held-out corpus of 177 documents with 81947 words
# Perplexity:  -22.622453245707632

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)

# %%
coherence_model_lda = CoherenceModel(model=lda_model, texts=sentences, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# INFO : using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# INFO : 1 batches submitted to accumulate stats from 64 documents (25259 virtual)
# INFO : 2 batches submitted to accumulate stats from 128 documents (49599 virtual)
# INFO : 3 batches submitted to accumulate stats from 192 documents (72539 virtual)
# INFO : 7 accumulators retrieved from output queue
# INFO : accumulated word occurrence stats for 72592 virtual documents
# Coherence Score:  0.4951063106239485
