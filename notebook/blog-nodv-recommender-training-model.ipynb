# %%
import requests
from time import sleep

from tqdm import tqdm
import pymongo
from pymongo import MongoClient

# %%
import logging
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO

# %%
import sys
sys.path.append('../')
from src.settings import MONGODB_SETTINGS

# %%
client = MongoClient(MONGODB_SETTINGS['host'])
db = client[MONGODB_SETTINGS['db']]
col = db[MONGODB_SETTINGS['collection']]

# %%
posts = col.find()

# %%
for i, post in enumerate(posts):
    print(post['title'])
    if i == 10: break
# Out:
# ĐỒ ÁN THIẾT KẾ WEBSITE BLOG SITE
# setState trong React
# Regular Expression trong Javascript
# Các bài tập java cơ bản
# Những câu hỏi lập trình khi pv (2): bài toán ATM
# Ví dụ sắp xếp nổi bọt với Java
# Chương trình lọc thư rác bằng Java, code ví dụ
# Đọc ghi file Excel trong Java sử dụng Apache POI
# THREAD AND THREAD POOLS IN JAVA
# Sử dụng CountDownLatch trong Java
# Multithreading: Java Synchronized Blocks

# %%
from src.utils import editorJs_data_to_text
import json

# %%
posts = col.find()
test_post = next(posts)

# %%
raw_content = test_post['content']
content = editorJs_data_to_text(json.loads(raw_content))

# %%
print(content)
# Out:
# đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đí ...

# %%
for i, post in tqdm(enumerate(col.find()), total=col.count_documents({})):
    try:
        col.update_one({"_id": post["_id"]}, {"$set": {"idrs": i}})
        pp_content = editorJs_data_to_text(json.loads(post['content']))
        col.update_one({"_id": post["_id"]}, {"$set": {"pp_content": pp_content}})
    except Exception as e:
        print(e)
        continue
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 39/39 [00:09<00:00,  3.93it/s]

# %%
client = MongoClient(MONGODB_SETTINGS['host'])
db = client[MONGODB_SETTINGS['db']]
col = db[MONGODB_SETTINGS['collection']]

posts = col.find()
test_post = next(posts)

# %%
test_post['pp_content']
# Out:
# 'đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đ ...

# %%
def make_sentences():
    for post in col.find():
        yield post['pp_content'] # lấy thuộc tính pp_content của từng document trong post collection

# %%
def make_texts_corpus(sentences):
    for sentence in sentences:
        yield simple_preprocess(sentence, deacc=True) # tách chữ cái của từng pp_content
#         yield [word for word in sentence.split()]

# %%
import itertools

import gensim
from gensim.utils import simple_preprocess

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)
id2word = gensim.corpora.Dictionary(sentences)
# Out:
# INFO : adding document #0 to Dictionary<0 unique tokens: []>
# INFO : built Dictionary<3324 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 39 documents (total 17739 corpus positions)
# INFO : Dictionary lifecycle event {'msg': "built Dictionary<3324 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 39 documents (total 17739 corpus positions)", 'datetime': '2022-12-19T01:57:12.032879', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
id2word.token2id
# Out:
# {'account': 0,
#  'actor': 1,
#  'allocation': 2,
#  'amazon': 3,
#  'an': 4,
#  'analysis': 5,
#  'anh': 6,
#  'anhđuong': 7,
#  'ap_đat': 8,
#  'api': 9,
#  'application': 10,
#  'avatar': 11,
#  'axios': 12,
#  'bai': 13,
#  'bai_bo': 14,
#  'bai_toan': 15,
#  'ban_be': 16,
#  'ban_cai': 17,
#  'ban_chat': 18,
#  'banfacebook': 19,
#  'bang': 20,
#  'bannetflix': 21,
#  'banxoa': 22,
#  'bao_cao': 23,
#  'bao_gom': 24,
#  'bao_mat': 25,
#  'bao_phu': 26,
#  'bao_ve': 27,
#  'baoluu': 28,
#  'bat_kha_thi': 29,
#  'bayes': 30,
#  'bayesian': 31,
#  'bebo': 32,
#  'bia': 33,
#  'bich': 34,
#  'bien': 35,
#  'bien_tap': 36,
#  'bien_đoi': 37,
#  'bieu_dien': 38,
#  'bieu_thi': 39,
#  'bieu_tuong': 40,
#  'big': 41,
#  'binh': 42,
#  'binh_luan': 43,
#  'bio': 44,
#  'biopost': 45,
#  'blog': 46,
#  'blogger': 47,
#  'bo_nho': 48,
#  'bookmark': 49,
#  'boolean': 50,
#  'boot': 51,
#  'bought': 52,
#  'bung_no': 53,
#  'business': 54,
#  'ca_si': 55,
#  'cai_thien': 56,
#  'cai_tien': 57,
#  'can_thiet': 58,
#  'canh': 59,
#  'canh_sat': 60,
#  'cap': 61,
#  'cap_đo': 62,
#  'cascading': 63,
#  'case': 64,
#  'cau': 65,
#  'cau_hinh': 66,
#  'cau_truc': 67,
#  'cauxoa': 68,
#  'cham': 69,
#  'chan': 70,
#  'chat_luong': 71,
#  'chay': 72,
#  'che_đo': 73,
#  'chi_thuc_su': 74,
#  'chi_tiet': 75,
#  'chia': 76,
#  'chien_luoc': 77,
#  'chien_thuat': 78,
#  'chinh_sua': 79,
#  'chinh_xac': 80,
#  'chinhlam': 81,
#  'chong': 82,
#  'chu_bai': 83,
#  'chu_quan': 84,
#  'chu_đe': 85,
#  'chua': 86,
#  'chuan_hoa': 87,
#  'chuc_nang': 88,
#  'chung_khoan': 89,
#  'chung_minh': 90,
#  'chuoi': 91,
#  'chuong': 92,
#  'chuong_trinh': 93,
#  'chuyen_biet': 94,
#  'chuyen_hoa': 95,
#  'chuyen_huong': 96,
#  'chuyen_tiep': 97,
#  'chuyen_đoi': 98,
#  'classification': 99,
#  'click': 100,
#  'client': 101,
#  'clip': 102,
#  'cloud': 103,
#  'co_ban': 104,
#  'co_le': 105,
#  'co_phieu': 106,
#  'co_so': 107,
#  'co_đinh': 108,
#  'code': 109,
#  'codebase': 110,
#  'coi': 111,
#  'collaborative': 112,
#  'collection': 113,
#  'comment': 114,
#  'compass': 115,
#  'component': 116,
#  'con_nguoi': 117,
#  'cong_cu': 118,
#  'cong_khai': 119,
#  'cong_nghe': 120,
#  'cong_ty': 121,
#  'cong_viec': 122,
#  'congthat': 123,
#  'content': 124,
#  'contentbased': 125,
#  'corpora': 126,
#  'corpus': 127,
#  'corpuslevel': 128,
#  'createddate': 129,
#  'csdl': 130,
#  'css': 131,
#  'cung_cap': 132,
#  'cuoc_song': 133,
#  'dan': 134,
#  'dang': 135,
#  'danh_sach': 136,
#  'danvoi': 137,
#  'data': 138,
#  'dataset': 139,
#  'ddd': 140,
#  'de_dang': 141,
#  'debug': 142,
#  'degree': 143,
#  'dependency': 144,
#  'di_đong': 145,
#  'diagram': 146,
#  'dich_vu': 147,
#  'dirichlet': 148,
#  'discriminant': 149,
#  'dm': 150,
#  'doanh': 151,
#  'doanh_nghiep': 152,
#  'doanh_thu': 153,
#  'document': 154,
#  'documentlevel': 155,
#  'doi': 156,
#  'doitim': 157,
#  'doiviet': 158,
#  'du_an': 159,
#  'du_bao': 160,
#  'du_lieu': 161,
#  'du_đoan': 162,
#  'dua': 163,
#  'dung': 164,
#  'duy_tri': 165,
#  'editor': 166,
#  'email': 167,
#  'facebook': 168,
#  'false': 169,
#  'file': 170,
#  'filtering': 171,
#  'follow': 172,
#  'followers': 173,
#  'following': 174,
#  'followings': 175,
#  'follwers': 176,
#  'framework': 177,
#  'frequently': 178,
#  'gan': 179,
#  'gender': 180,
#  'ghi_chu': 181,
#  'gia': 182,
#  'gia_đinh': 183,
#  'giai_phap': 184,
#  'giai_thuong': 185,
#  'giai_đap': 186,
#  'giam_sat': 187,
#  'giao_dien': 188,
#  'giao_luu': 189,
#  'gibbs': 190,
#  'gioi_thieu': 191,
#  'gioi_tinh': 192,
#  'git': 193,
#  'github': 194,
#  'giup': 195,
#  'go': 196,
#  'go_loi': 197,
#  'goi': 198,
#  'goi_y': 199,
#  'google': 200,
#  'gop_y': 201,
#  'groovy': 202,
#  'gui': 203,
#  'hai': 204,
#  'han_che': 205,
#  'hang': 206,
#  'hanh_vi': 207,
#  'hanh_đong': 208,
#  'hat': 209,
#  'he': 210,
#  'he_thong': 211,
#  'hien': 212,
#  'hien_thi': 213,
#  'hien_tuong': 214,
#  'hien_đai': 215,
#  'hierarchical': 216,
#  'hieu_nang': 217,
#  'hieu_qua': 218,
#  'hieu_suat': 219,
#  'highlighting': 220,
#  'hinh': 221,
#  'hinh_anh': 222,
#  'hinh_su': 223,
#  'hinh_thuc': 224,
#  'hoa': 225,
#  'hoan_chinh': 226,
#  'hoan_thanh': 227,
#  'hoan_thien': 228,
#  'hoat_đong': 229,
#  'hoc': 230,
#  'hoc_hoi': 231,
#  'hon_hop': 232,
#  'hontu': 233,
#  'html': 234,
#  'htmlvi': 235,
#  'http': 236,
#  'huan_luyen': 237,
#  'hung': 238,
#  'hung_thu': 239,
#  'huong': 240,
#  'huongxu': 241,
#  'huu_dung': 242,
#  'huu_han': 243,
#  'huu_ich': 244,
#  'huy': 245,
#  'hypertext': 246,
#  'id': 247,
#  'idea': 248,
#  'index': 249,
#  'intellij': 250,
#  'internet': 251,
#  'isactive': 252,
#  'ispublish': 253,
#  'isread': 254,
#  'it': 255,
#  'item': 256,
#  'items': 257,
#  'java': 258,
#  'javascript': 259,
#  'jetbrains': 260,
#  'jetty': 261,
#  'join': 262,
#  'joomla': 263,
#  'js': 264,
#  'json': 265,
#  'kem': 266,
#  'kenh': 267,
#  'ket': 268,
#  'ket_ban': 269,
#  'ket_noi': 270,
#  'ket_qua': 271,
#  'key': 272,
#  'kha_nang': 273,
#  'khach_hang': 274,
#  'khap': 275,
#  'kho': 276,
#  'khoa': 277,
#  'khoanbai': 278,
#  'khoi': 279,
#  'khong_gian': 280,
#  'khuon_kho': 281,
#  'khuyen_nghi': 282,
#  'kich_co': 283,
#  'kiem': 284,
#  'kiem_tra': 285,
#  'kiemcac': 286,
#  'kiemfacebook': 287,
#  'kien_thuc': 288,
#  'kien_truc': 289,
#  'kieu': 290,
#  'kinh': 291,
#  'kinh_doanh': 292,
#  'kinh_lup': 293,
#  'kinh_te': 294,
#  'ky': 295,
#  'ky_thuat': 296,
#  'ky_tu': 297,
#  'lam_viec': 298,
#  'lan': 299,
#  'language': 300,
#  'lap': 301,
#  'lap_debug': 302,
#  'lap_trinh': 303,
#  'lap_trinh_vien': 304,
#  'lapnhung': 305,
#  'latent': 306,
#  'lda': 307,
#  'learning': 308,
#  'len_loi': 309,
#  'level': 310,
#  'lich_su': 311,
#  'lien': 312,
#  'lien_tuc': 313,
#  'lieu': 314,
#  'lieuhinh': 315,
#  'likes': 316,
#  'linear': 317,
#  'linh_hoat': 318,
#  'linh_vuc': 319,
#  'link': 320,
#  'linux': 321,
#  'lo_ngai': 322,
#  'loat': 323,
#  'loi': 324,
#  'loi_ich': 325,
#  'loi_nhuan': 326,
#  'loi_the': 327,
#  'lsa': 328,
#  'lua_chon': 329,
#  'luong': 330,
#  'luot': 331,
#  'luu': 332,
#  'luu_giu': 333,
#  'luu_tru': 334,
#  'ly': 335,
#  'ly_thuyet': 336,
#  'lyket': 337,
#  'ma': 338,
#  'mac_đinh': 339,
#  'mach': 340,
#  'machine': 341,
#  'macos': 342,
#  'mai': 343,
#  'make': 344,
#  'mang': 345,
#  'manh_me': 346,
#  'marketing': 347,
#  'markup': 348,
#  'mat_khau': 349,
#  'matheo': 350,
#  'matkhi': 351,
#  'mau': 352,
#  'maven': 353,
#  'may': 354,
#  'may_tinh': 355,
#  'medium': 356,
#  'menu': 357,
#  'mien': 358,
#  'mieu_ta': 359,
#  'minh_hoa': 360,
#  'ml': 361,
#  'mo_hinh': 362,
#  'mo_hinh_hoa': 363,
#  'mo_rong': 364,
#  'mo_ta': 365,
#  'modal': 366,
#  'model': 367,
#  'modeling': 368,
#  'module': 369,
#  'mon': 370,
#  'mong': 371,
#  'mong_muon': 372,
#  'mongodatabase': 373,
#  'mongodb': 374,
#  'mua': 375,
#  'muc': 376,
#  'muc_tu': 377,
#  'muc_đich': 378,
#  'muc_đo': 379,
#  'muot_ma': 380,
#  'nam': 381,
#  'nam_bat': 382,
#  'nang': 383,
#  'nang_suat': 384,
#  'native': 385,
#  'nen_tang': 386,
#  'neu': 387,
#  'ngan': 388,
#  'ngay_nay': 389,
#  'nghia_la': 390,
#  'nghiem': 391,
#  'nghien_cuu': 392,
#  'nghiep_vu': 393,
#  'nghiepho': 394,
#  'ngoai_tru': 395,
#  'ngon_ngu': 396,
#  'nguoi': 397,
#  'nhan': 398,
#  'nhan_loai': 399,
#  'nhan_tao': 400,
#  'nhanh_chong': 401,
#  'nhap': 402,
#  'nhap_noi_dung': 403,
#  'nhapchinh': 404,
#  'nhat_ky': 405,
#  'nhatđuoc': 406,
#  'nhiem_vu': 407,
#  'nhu': 408,
#  'nhu_cau': 409,
#  'nickname': 410,
#  'nodejs': 411,
#  'nodv': 412,
#  'noi_bat': 413,
#  'noi_dung': 414,
#  'noi_tai': 415,
#  'noi_tieng': 416,
#  'noo': 417,
#  'notat': 418,
#  'nu': 419,
#  'nut': 420,
#  'oauth': 421,
#  'object': 422,
#  'objectid': 423,
#  'observe': 424,
#  'of': 425,
#  'on': 426,
#  'online': 427,
#  'page': 428,
#  'parameter': 429,
#  'password': 430,
#  'pha_tron': 431,
#  'pham_vi': 432,
#  'phan_biet': 433,
#  'phan_bo': 434,
#  'phan_hoi': 435,
#  'phan_loai': 436,
#  'phan_mem': 437,
#  'phan_phoi': 438,
#  'phan_ra': 439,
#  'phan_tich': 440,
#  'phan_xu': 441,
#  'phat_trien': 442,
#  'phep': 443,
#  'phien_ban': 444,
#  'phim': 445,
#  'pho_bien': 446,
#  'phong_cach': 447,
#  'phong_phu': 448,
#  'phuc': 449,
#  'phuc_tap': 450,
#  'phuc_vu': 451,
#  'phuoc': 452,
#  'phuong': 453,
#  'phuong_phap': 454,
#  'plsa': 455,
#  'post': 456,
#  'postid': 457,
#  'preference': 458,
#  'prior': 459,
#  'project': 460,
#  'provider': 461,
#  'providerid': 462,
#  'publish': 463,
#  'python': 464,
#  'qua_khu': 465,
#  'quan_he': 466,
#  'quan_ly': 467,
#  'quang_cao': 468,
#  'quen_thuoc': 469,
#  'quy_mo': 470,
#  'quy_đinh': 471,
#  'quyen': 472,
#  'quyet_đinh': 473,
#  'ra_mat': 474,
#  'ra_đoi': 475,
#  'rangkhong': 476,
#  'react': 477,
#  'reactjs': 478,
#  'receiverid': 479,
#  'recommend': 480,
#  'recommendation': 481,
#  'recommended': 482,
#  'recommender': 483,
#  'refactorings': 484,
#  'replyid': 485,
#  'request': 486,
#  'response': 487,
#  'roi_rac': 488,
#  'role': 489,
#  'rong': 490,
#  'rong_rai': 491,
#  'rongviec': 492,
#  'ruby': 493,
#  'rut': 494,
#  'sach': 495,
#  'sai_lech': 496,
#  'sampling': 497,
#  'san': 498,
#  'san_pham': 499,
#  'san_sang': 500,
#  'sang_tao': 501,
#  'sap_xep': 502,
#  'sau': 503,
#  'scalatu': 504,
#  'schema': 505,
#  'senderid': 506,
#  'server': 507,
#  'setting': 508,
#  'share': 509,
#  'sheets': 510,
#  'sidebar': 511,
#  'similarity': 512,
#  'simple': 513,
#  'single': 514,
#  'sinh': 515,
#  'sinh_thai': 516,
#  'site': 517,
#  'snippets': 518,
#  'so_luong': 519,
#  'so_thich': 520,
#  'so_đo': 521,
#  'soan_thao': 522,
#  'song': 523,
#  'spa': 524,
#  'sparse': 525,
#  'spring': 526,
#  'sql': 527,
#  'starter': 528,
#  'string': 529,
#  'stt': 530,
#  'studio': 531,
#  'style': 532,
#  'sua': 533,
#  'subtitle': 534,
#  'supervised': 535,
#  'suy_dien': 536,
#  'suy_luan': 537,
#  'syntax': 538,
#  'system': 539,
#  'systems': 540,
#  'ta': 541,
#  'tab': 542,
#  'tac': 543,
#  'tac_gia': 544,
#  'tai': 545,
#  'tai_cau_truc': 546,
#  'tai_khoan': 547,
#  'tai_lieu': 548,
#  'tam': 549,
#  'tang_toc': 550,
#  'tang_truong': 551,
#  'tap': 552,
#  'tap_hop': 553,
#  'tapnoi': 554,
#  'tat': 555,
#  'teamcity': 556,
#  'text': 557,
#  'thac_mac': 558,
#  'tham_so': 559,
#  'than_thien': 560,
#  'thanh': 561,
#  'thanh_cong': 562,
#  'thanh_phan': 563,
#  'thao_tac': 564,
#  'that_bai': 565,
#  'thay': 566,
#  'the_gioi': 567,
#  'the_hien': 568,
#  'the_ky': 569,
#  'theo_doi': 570,
#  'theta': 571,
#  'thichkhi': 572,
#  'thiet_bi': 573,
#  'thiet_ke': 574,
#  'thietkhong': 575,
#  'thietsu_dung': 576,
#  'thieu_sot': 577,
#  'thinh': 578,
#  'thoa_man': 579,
#  'thoa_suc': 580,
#  'thoai_mai': 581,
#  'thoi': 582,
#  'thoi_đai': 583,
#  'thong': 584,
#  'thong_bao': 585,
#  'thong_minh': 586,
#  'thong_qua': 587,
#  'thong_thuong': 588,
#  'thong_tin': 589,
#  'threelevel': 590,
#  'thu_thap': 591,
#  'thu_vien': 592,
#  'thua': 593,
#  'thuan_tien': 594,
#  'thuat_toan': 595,
#  'thuat_toan_hoc': 596,
#  'thuc': 597,
#  'thuc_hien_tai': 598,
#  'thuc_the': 599,
#  'thumbnail': 600,
#  'thuong': 601,
#  'thuong_mai': 602,
#  'thuongcho': 603,
#  'thutheo': 604,
#  'tich_hop': 605,
#  'tiem_nang': 606,
#  'tien_ich': 607,
#  'tien_tien': 608,
#  'tien_trinh': 609,
#  'tieng': 610,
#  'tiep_can': 611,
#  'tiep_thi': 612,
#  'tieu_đe': 613,
#  'tieu_đe_bai': 614,
#  'tim_kiem': 615,
#  'timeread': 616,
#  'tin_hieu': 617,
#  'tin_nhiem': 618,
#  'tin_tuc': 619,
#  'tinh_nang': 620,
#  'tinh_toan': 621,
#  'title': 622,
#  'toan': 623,
#  'toan_bo': 624,
#  'toan_cau': 625,
#  'toan_the': 626,
#  'together': 627,
#  'toi_gian': 628,
#  'toi_uu_hoa': 629,
#  'tomcat': 630,
#  'tong_quan': 631,
#  'tong_quat': 632,
#  'tong_thetao': 633,
#  'topic': 634,
#  'topics': 635,
#  'tra_loi': 636,
#  'trai': 637,
#  'trai_đat': 638,
#  'tran': 639,
#  'trang': 640,
#  'trang_chu': 641,
#  'trang_thai': 642,
#  'trang_web': 643,
#  'trao_đoi': 644,
#  'tren': 645,
#  'trenđang': 646,
#  'tri_tue': 647,
#  'trien_khai': 648,
#  'trinh': 649,
#  'trinh_bay': 650,
#  'trinh_duyet': 651,
#  'tro': 652,
#  'tro_nen': 653,
#  'tron': 654,
#  'trong': 655,
#  'truc_tuyen': 656,
#  'true': 657,
#  'trung': 658,
#  'truong': 659,
#  'truy': 660,
#  'truy_cap': 661,
#  'tu_khoa': 662,
#  'tu_vung': 663,
#  'tu_đien': 664,
#  'tu_đong': 665,
#  'tuan': 666,
#  'tuc': 667,
#  'tuc_la': 668,
#  'tuoi_đoi': 669,
#  'tuong_lai': 670,
#  'tuong_quan': 671,
#  'tuong_thich': 672,
#  'tuong_tu': 673,
#  'tuong_ung': 674,
#  'tuong_đong': 675,
#  'tuy': 676,
#  'tv': 677,
#  'type': 678,
#  'ui': 679,
#  'undertow': 680,
#  'ung': 681,
#  'ung_dung': 682,
#  'universal': 683,
#  'unsupervised': 684,
#  'uoc_luong': 685,
#  'use': 686,
#  'usecase': 687,
#  'user': 688,
#  'userid': 689,
#  'useritem': 690,
#  'userlikeids': 691,
#  'username': 692,
#  'users': 693,
#  'userxoa': 694,
#  'uu_điem': 695,
#  'vahoac': 696,
#  'vai_tro': 697,
#  'van': 698,
#  'van_ban': 699,
#  'van_dung': 700,
#  'van_hanh': 701,
#  'variable': 702,
#  'vi_du': 703,
#  'viet': 704,
#  'vietblog': 705,
#  'vietxem': 706,
#  'visual': 707,
#  'vo_cung': 708,
#  'vong': 709,
#  'vs': 710,
#  'vu': 711,
#  'vuong': 712,
#  'vuot_bac': 713,
#  'war': 714,
#  'web': 715,
#  'website': 716,
#  'websocket': 717,
#  'wi': 718,
#  'wide_web': 719,
#  'windows': 720,
#  'word': 721,
#  'wordpress': 722,
#  'world': 723,
#  'xa': 724,
#  'xa_hoi': 725,
#  'xac_nhan': 726,
#  'xac_suat': 727,
#  'xac_thuc': 728,
#  'xac_đinh': 729,
#  'xay_dung': 730,
#  'xem_xet': 731,
#  'xep_hang': 732,
#  'xmlhttprequest': 733,
#  'xoa': 734,
#  'xoa_bai': 735,
#  'xoa_bookmark': 736,
#  'xoa_hien_thi': 737,
#  'xu': 738,
#  'xu_huong': 739,
#  'y_muon': 740,
#  'y_nghia': 741,
#  'y_tuong': 742,
#  'y_đinh': 743,
#  'yahoo': 744,
#  'youtube': 745,
#  'đa_dang': 746,
#  'đac_nhap': 747,
#  'đac_tinh': 748,
#  'đac_trung': 749,
#  'đac_điem': 750,
#  'đai_dien': 751,
#  'đang': 752,
#  'đang_ky': 753,
#  'đang_nhap': 754,
#  'đangchinh': 755,
#  'đanh': 756,
#  'đanh_dau': 757,
#  'đanh_đau': 758,
#  'đau': 759,
#  'đau_ra': 760,
#  'đau_vao': 761,
#  'đaua': 762,
#  'đay_đu': 763,
#  'đe_cap': 764,
#  'đe_tai': 765,
#  'đe_xuat': 766,
#  'đe_y': 767,
#  'đi': 768,
#  'đi_sau': 769,
#  'đien_tu': 770,
#  'đieu_khien': 771,
#  'đinh_dang': 772,
#  'đinh_hinh': 773,
#  'đinh_nghia': 774,
#  'đo': 775,
#  'đo_an': 776,
#  'đoan': 777,
#  'đoc': 778,
#  'đoc_gia': 779,
#  'đoi_khi': 780,
#  'đoi_song': 781,
#  'đoi_tuong': 782,
#  'đoianh': 783,
#  'đon': 784,
#  'đon_gian': 785,
#  'đon_gian_hoa': 786,
#  'đong': 787,
#  'đong_bo': 788,
#  'đong_nghia': 789,
#  'đong_đao': 790,
#  'đođang': 791,
#  'đuocđong': 792,
#  'đuong': 793,
#  'android': 794,
#  'cap_nhat': 795,
#  'cho_du': 796,
#  'components': 797,
#  'componets': 798,
#  'defining': 799,
#  'dom': 800,
#  'engine': 801,
#  'exports': 802,
#  'extend': 803,
#  'hooks': 804,
#  'implementation': 805,
#  'implemented': 806,
#  'import': 807,
#  'ios': 808,
#  'lives': 809,
#  'logic': 810,
#  'lop': 811,
#  'mac': 812,
#  'moi_truong': 813,
#  'mot_the_hien': 814,
#  'mount': 815,
#  'nguoc_lai': 816,
#  'node': 817,
#  'oke': 818,
#  'or': 819,
#  'package': 820,
#  'phan_tach': 821,
#  'platform': 822,
#  'reactart': 823,
#  'reactchildren': 824,
#  'reactcomponent': 825,
#  'reactdom': 826,
#  'reactdomrender': 827,
#  'reactdomserver': 828,
#  'reactnative': 829,
#  'renderer': 830,
#  'renderers': 831,
#  'rerenders': 832,
#  'return': 833,
#  'sai_lam': 834,
#  'setstate': 835,
#  'state': 836,
#  'target': 837,
#  'thac': 838,
#  'thiet_lap': 839,
#  'thu_vi': 840,
#  'tiec': 841,
#  'ty_du': 842,
#  'updater': 843,
#  'utilities': 844,
#  'uy': 845,
#  've': 846,
#  'view': 847,
#  'xay': 848,
#  'đeu': 849,
#  'đoc_lap': 850,
#  'ap_dung': 851,
#  'bao_toan': 852,
#  'bat_buoc': 853,
#  'bi_an': 854,
#  'bieu_thuc': 855,
#  'bo_qua': 856,
#  'bon': 857,
#  'chang_han': 858,
#  'cheo': 859,
#  'chi_đinh': 860,
#  'chinh_quy': 861,
#  'chon_lua': 862,
#  'chu': 863,
#  'chu_so': 864,
#  'chubat': 865,
#  'co_nghia': 866,
#  'co_nghia_la': 867,
#  'cong': 868,
#  'constructor': 869,
#  'cu_phap': 870,
#  'dai': 871,
#  'dau': 872,
#  'dau_cham_hoi': 873,
#  'dau_cham_than': 874,
#  'dau_hoi': 875,
#  'day': 876,
#  'dien_ta': 877,
#  'dong': 878,
#  'duoimot': 879,
#  'duy_nhat': 880,
#  'expression': 881,
#  'gach': 882,
#  'gach_ngang': 883,
#  'gia_su': 884,
#  'gioi_han': 885,
#  'gom': 886,
#  'hoi': 887,
#  'in': 888,
#  'keo': 889,
#  'ket_thuc': 890,
#  'khop': 891,
#  'kia': 892,
#  'ky_hieu': 893,
#  'lan_luot': 894,
#  'luu_y': 895,
#  'mac_du': 896,
#  'mat_khac': 897,
#  'mot_chut': 898,
#  'mot_so_nguyen': 899,
#  'naomot': 900,
#  'ngan_can': 901,
#  'ngoac': 902,
#  'ngoac_vuong': 903,
#  'ngoac_đon': 904,
#  'ngoac_đon_tinh': 905,
#  'nhon': 906,
#  'nhu_nhieu': 907,
#  'pattern': 908,
#  'phan_tu': 909,
#  'phu': 910,
#  'phuong_thuc': 911,
#  'ranh_gioi': 912,
#  'regexp': 913,
#  'regular': 914,
#  'rieng_biet': 915,
#  'somot': 916,
#  'tatnghiabat': 917,
#  'thay_vi': 918,
#  'thong_dung': 919,
#  'thuc_thi': 920,
#  'thuoc_tinh': 921,
#  'toan_tu': 922,
#  'trangbat': 923,
#  'truyen': 924,
#  'tumot': 925,
#  'tuong': 926,
#  'tuy_chon': 927,
#  'unicode': 928,
#  'vv': 929,
#  'đam_bao_mau': 930,
#  'đao_nguoc': 931,
#  'đep_mat': 932,
#  'đung': 933,
#  'đuong_ong': 934,
#  'and': 935,
#  'array': 936,
#  'arrint': 937,
#  'at': 938,
#  'bai_tap': 939,
#  'ban_phim': 940,
#  'bot': 941,
#  'bounds': 942,
#  'bubble': 943,
#  'cacacyahtp': 944,
#  'cach': 945,
#  'chieu': 946,
#  'chon': 947,
#  'cua': 948,
#  'cung': 949,
#  'dao': 950,
#  'duoc': 951,
#  'exception': 952,
#  'for': 953,
#  'goc': 954,
#  'is': 955,
#  'khac': 956,
#  'kich_thuoc': 957,
#  'la': 958,
#  'lathaycacac': 959,
#  'length': 960,
#  'lua': 961,
#  'main': 962,
#  'max': 963,
#  'min': 964,
#  'mot': 965,
#  'nghich': 966,
#  'nghich_đao': 967,
#  'nguoc': 968,
#  'nhapa': 969,
#  'nhieu': 970,
#  'nhung': 971,
#  'noi': 972,
#  'objects': 973,
#  'original': 974,
#  'out': 975,
#  'so_nguyen': 976,
#  'sort': 977,
#  'sorted': 978,
#  'str': 979,
#  'strmot': 980,
#  'tham_chieu': 981,
#  'thaycacac': 982,
#  'this': 983,
#  'thread': 984,
#  'tien': 985,
#  'tri': 986,
#  'tu': 987,
#  'vi': 988,
#  'vua': 989,
#  'vuot': 990,
#  'xuat': 991,
#  'anh_huong': 992,
#  'atm': 993,
#  'atmbai': 994,
#  'bigdecimal': 995,
#  'chu_vi': 996,
#  'chu_y': 997,
#  'class': 998,
#  'co_che': 999,
#  ...}

# %%
id2word.filter_extremes(no_below=3, no_above=0.5)
id2word.compactify()
id2word.save('../models/id2word.dictionary')
# Out:
# INFO : Dictionary lifecycle event {'fname_or_handle': '../models/id2word.dictionary', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-12-19T01:57:12.103880', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/id2word.dictionary

# %%
len(id2word)
# Out:
# 3324

# %%
id2word.token2id
# Out:
# {'account': 0,
#  'actor': 1,
#  'allocation': 2,
#  'amazon': 3,
#  'an': 4,
#  'analysis': 5,
#  'anh': 6,
#  'anhđuong': 7,
#  'ap_đat': 8,
#  'api': 9,
#  'application': 10,
#  'avatar': 11,
#  'axios': 12,
#  'bai': 13,
#  'bai_bo': 14,
#  'bai_toan': 15,
#  'ban_be': 16,
#  'ban_cai': 17,
#  'ban_chat': 18,
#  'banfacebook': 19,
#  'bang': 20,
#  'bannetflix': 21,
#  'banxoa': 22,
#  'bao_cao': 23,
#  'bao_gom': 24,
#  'bao_mat': 25,
#  'bao_phu': 26,
#  'bao_ve': 27,
#  'baoluu': 28,
#  'bat_kha_thi': 29,
#  'bayes': 30,
#  'bayesian': 31,
#  'bebo': 32,
#  'bia': 33,
#  'bich': 34,
#  'bien': 35,
#  'bien_tap': 36,
#  'bien_đoi': 37,
#  'bieu_dien': 38,
#  'bieu_thi': 39,
#  'bieu_tuong': 40,
#  'big': 41,
#  'binh': 42,
#  'binh_luan': 43,
#  'bio': 44,
#  'biopost': 45,
#  'blog': 46,
#  'blogger': 47,
#  'bo_nho': 48,
#  'bookmark': 49,
#  'boolean': 50,
#  'boot': 51,
#  'bought': 52,
#  'bung_no': 53,
#  'business': 54,
#  'ca_si': 55,
#  'cai_thien': 56,
#  'cai_tien': 57,
#  'can_thiet': 58,
#  'canh': 59,
#  'canh_sat': 60,
#  'cap': 61,
#  'cap_đo': 62,
#  'cascading': 63,
#  'case': 64,
#  'cau': 65,
#  'cau_hinh': 66,
#  'cau_truc': 67,
#  'cauxoa': 68,
#  'cham': 69,
#  'chan': 70,
#  'chat_luong': 71,
#  'chay': 72,
#  'che_đo': 73,
#  'chi_thuc_su': 74,
#  'chi_tiet': 75,
#  'chia': 76,
#  'chien_luoc': 77,
#  'chien_thuat': 78,
#  'chinh_sua': 79,
#  'chinh_xac': 80,
#  'chinhlam': 81,
#  'chong': 82,
#  'chu_bai': 83,
#  'chu_quan': 84,
#  'chu_đe': 85,
#  'chua': 86,
#  'chuan_hoa': 87,
#  'chuc_nang': 88,
#  'chung_khoan': 89,
#  'chung_minh': 90,
#  'chuoi': 91,
#  'chuong': 92,
#  'chuong_trinh': 93,
#  'chuyen_biet': 94,
#  'chuyen_hoa': 95,
#  'chuyen_huong': 96,
#  'chuyen_tiep': 97,
#  'chuyen_đoi': 98,
#  'classification': 99,
#  'click': 100,
#  'client': 101,
#  'clip': 102,
#  'cloud': 103,
#  'co_ban': 104,
#  'co_le': 105,
#  'co_phieu': 106,
#  'co_so': 107,
#  'co_đinh': 108,
#  'code': 109,
#  'codebase': 110,
#  'coi': 111,
#  'collaborative': 112,
#  'collection': 113,
#  'comment': 114,
#  'compass': 115,
#  'component': 116,
#  'con_nguoi': 117,
#  'cong_cu': 118,
#  'cong_khai': 119,
#  'cong_nghe': 120,
#  'cong_ty': 121,
#  'cong_viec': 122,
#  'congthat': 123,
#  'content': 124,
#  'contentbased': 125,
#  'corpora': 126,
#  'corpus': 127,
#  'corpuslevel': 128,
#  'createddate': 129,
#  'csdl': 130,
#  'css': 131,
#  'cung_cap': 132,
#  'cuoc_song': 133,
#  'dan': 134,
#  'dang': 135,
#  'danh_sach': 136,
#  'danvoi': 137,
#  'data': 138,
#  'dataset': 139,
#  'ddd': 140,
#  'de_dang': 141,
#  'debug': 142,
#  'degree': 143,
#  'dependency': 144,
#  'di_đong': 145,
#  'diagram': 146,
#  'dich_vu': 147,
#  'dirichlet': 148,
#  'discriminant': 149,
#  'dm': 150,
#  'doanh': 151,
#  'doanh_nghiep': 152,
#  'doanh_thu': 153,
#  'document': 154,
#  'documentlevel': 155,
#  'doi': 156,
#  'doitim': 157,
#  'doiviet': 158,
#  'du_an': 159,
#  'du_bao': 160,
#  'du_lieu': 161,
#  'du_đoan': 162,
#  'dua': 163,
#  'dung': 164,
#  'duy_tri': 165,
#  'editor': 166,
#  'email': 167,
#  'facebook': 168,
#  'false': 169,
#  'file': 170,
#  'filtering': 171,
#  'follow': 172,
#  'followers': 173,
#  'following': 174,
#  'followings': 175,
#  'follwers': 176,
#  'framework': 177,
#  'frequently': 178,
#  'gan': 179,
#  'gender': 180,
#  'ghi_chu': 181,
#  'gia': 182,
#  'gia_đinh': 183,
#  'giai_phap': 184,
#  'giai_thuong': 185,
#  'giai_đap': 186,
#  'giam_sat': 187,
#  'giao_dien': 188,
#  'giao_luu': 189,
#  'gibbs': 190,
#  'gioi_thieu': 191,
#  'gioi_tinh': 192,
#  'git': 193,
#  'github': 194,
#  'giup': 195,
#  'go': 196,
#  'go_loi': 197,
#  'goi': 198,
#  'goi_y': 199,
#  'google': 200,
#  'gop_y': 201,
#  'groovy': 202,
#  'gui': 203,
#  'hai': 204,
#  'han_che': 205,
#  'hang': 206,
#  'hanh_vi': 207,
#  'hanh_đong': 208,
#  'hat': 209,
#  'he': 210,
#  'he_thong': 211,
#  'hien': 212,
#  'hien_thi': 213,
#  'hien_tuong': 214,
#  'hien_đai': 215,
#  'hierarchical': 216,
#  'hieu_nang': 217,
#  'hieu_qua': 218,
#  'hieu_suat': 219,
#  'highlighting': 220,
#  'hinh': 221,
#  'hinh_anh': 222,
#  'hinh_su': 223,
#  'hinh_thuc': 224,
#  'hoa': 225,
#  'hoan_chinh': 226,
#  'hoan_thanh': 227,
#  'hoan_thien': 228,
#  'hoat_đong': 229,
#  'hoc': 230,
#  'hoc_hoi': 231,
#  'hon_hop': 232,
#  'hontu': 233,
#  'html': 234,
#  'htmlvi': 235,
#  'http': 236,
#  'huan_luyen': 237,
#  'hung': 238,
#  'hung_thu': 239,
#  'huong': 240,
#  'huongxu': 241,
#  'huu_dung': 242,
#  'huu_han': 243,
#  'huu_ich': 244,
#  'huy': 245,
#  'hypertext': 246,
#  'id': 247,
#  'idea': 248,
#  'index': 249,
#  'intellij': 250,
#  'internet': 251,
#  'isactive': 252,
#  'ispublish': 253,
#  'isread': 254,
#  'it': 255,
#  'item': 256,
#  'items': 257,
#  'java': 258,
#  'javascript': 259,
#  'jetbrains': 260,
#  'jetty': 261,
#  'join': 262,
#  'joomla': 263,
#  'js': 264,
#  'json': 265,
#  'kem': 266,
#  'kenh': 267,
#  'ket': 268,
#  'ket_ban': 269,
#  'ket_noi': 270,
#  'ket_qua': 271,
#  'key': 272,
#  'kha_nang': 273,
#  'khach_hang': 274,
#  'khap': 275,
#  'kho': 276,
#  'khoa': 277,
#  'khoanbai': 278,
#  'khoi': 279,
#  'khong_gian': 280,
#  'khuon_kho': 281,
#  'khuyen_nghi': 282,
#  'kich_co': 283,
#  'kiem': 284,
#  'kiem_tra': 285,
#  'kiemcac': 286,
#  'kiemfacebook': 287,
#  'kien_thuc': 288,
#  'kien_truc': 289,
#  'kieu': 290,
#  'kinh': 291,
#  'kinh_doanh': 292,
#  'kinh_lup': 293,
#  'kinh_te': 294,
#  'ky': 295,
#  'ky_thuat': 296,
#  'ky_tu': 297,
#  'lam_viec': 298,
#  'lan': 299,
#  'language': 300,
#  'lap': 301,
#  'lap_debug': 302,
#  'lap_trinh': 303,
#  'lap_trinh_vien': 304,
#  'lapnhung': 305,
#  'latent': 306,
#  'lda': 307,
#  'learning': 308,
#  'len_loi': 309,
#  'level': 310,
#  'lich_su': 311,
#  'lien': 312,
#  'lien_tuc': 313,
#  'lieu': 314,
#  'lieuhinh': 315,
#  'likes': 316,
#  'linear': 317,
#  'linh_hoat': 318,
#  'linh_vuc': 319,
#  'link': 320,
#  'linux': 321,
#  'lo_ngai': 322,
#  'loat': 323,
#  'loi': 324,
#  'loi_ich': 325,
#  'loi_nhuan': 326,
#  'loi_the': 327,
#  'lsa': 328,
#  'lua_chon': 329,
#  'luong': 330,
#  'luot': 331,
#  'luu': 332,
#  'luu_giu': 333,
#  'luu_tru': 334,
#  'ly': 335,
#  'ly_thuyet': 336,
#  'lyket': 337,
#  'ma': 338,
#  'mac_đinh': 339,
#  'mach': 340,
#  'machine': 341,
#  'macos': 342,
#  'mai': 343,
#  'make': 344,
#  'mang': 345,
#  'manh_me': 346,
#  'marketing': 347,
#  'markup': 348,
#  'mat_khau': 349,
#  'matheo': 350,
#  'matkhi': 351,
#  'mau': 352,
#  'maven': 353,
#  'may': 354,
#  'may_tinh': 355,
#  'medium': 356,
#  'menu': 357,
#  'mien': 358,
#  'mieu_ta': 359,
#  'minh_hoa': 360,
#  'ml': 361,
#  'mo_hinh': 362,
#  'mo_hinh_hoa': 363,
#  'mo_rong': 364,
#  'mo_ta': 365,
#  'modal': 366,
#  'model': 367,
#  'modeling': 368,
#  'module': 369,
#  'mon': 370,
#  'mong': 371,
#  'mong_muon': 372,
#  'mongodatabase': 373,
#  'mongodb': 374,
#  'mua': 375,
#  'muc': 376,
#  'muc_tu': 377,
#  'muc_đich': 378,
#  'muc_đo': 379,
#  'muot_ma': 380,
#  'nam': 381,
#  'nam_bat': 382,
#  'nang': 383,
#  'nang_suat': 384,
#  'native': 385,
#  'nen_tang': 386,
#  'neu': 387,
#  'ngan': 388,
#  'ngay_nay': 389,
#  'nghia_la': 390,
#  'nghiem': 391,
#  'nghien_cuu': 392,
#  'nghiep_vu': 393,
#  'nghiepho': 394,
#  'ngoai_tru': 395,
#  'ngon_ngu': 396,
#  'nguoi': 397,
#  'nhan': 398,
#  'nhan_loai': 399,
#  'nhan_tao': 400,
#  'nhanh_chong': 401,
#  'nhap': 402,
#  'nhap_noi_dung': 403,
#  'nhapchinh': 404,
#  'nhat_ky': 405,
#  'nhatđuoc': 406,
#  'nhiem_vu': 407,
#  'nhu': 408,
#  'nhu_cau': 409,
#  'nickname': 410,
#  'nodejs': 411,
#  'nodv': 412,
#  'noi_bat': 413,
#  'noi_dung': 414,
#  'noi_tai': 415,
#  'noi_tieng': 416,
#  'noo': 417,
#  'notat': 418,
#  'nu': 419,
#  'nut': 420,
#  'oauth': 421,
#  'object': 422,
#  'objectid': 423,
#  'observe': 424,
#  'of': 425,
#  'on': 426,
#  'online': 427,
#  'page': 428,
#  'parameter': 429,
#  'password': 430,
#  'pha_tron': 431,
#  'pham_vi': 432,
#  'phan_biet': 433,
#  'phan_bo': 434,
#  'phan_hoi': 435,
#  'phan_loai': 436,
#  'phan_mem': 437,
#  'phan_phoi': 438,
#  'phan_ra': 439,
#  'phan_tich': 440,
#  'phan_xu': 441,
#  'phat_trien': 442,
#  'phep': 443,
#  'phien_ban': 444,
#  'phim': 445,
#  'pho_bien': 446,
#  'phong_cach': 447,
#  'phong_phu': 448,
#  'phuc': 449,
#  'phuc_tap': 450,
#  'phuc_vu': 451,
#  'phuoc': 452,
#  'phuong': 453,
#  'phuong_phap': 454,
#  'plsa': 455,
#  'post': 456,
#  'postid': 457,
#  'preference': 458,
#  'prior': 459,
#  'project': 460,
#  'provider': 461,
#  'providerid': 462,
#  'publish': 463,
#  'python': 464,
#  'qua_khu': 465,
#  'quan_he': 466,
#  'quan_ly': 467,
#  'quang_cao': 468,
#  'quen_thuoc': 469,
#  'quy_mo': 470,
#  'quy_đinh': 471,
#  'quyen': 472,
#  'quyet_đinh': 473,
#  'ra_mat': 474,
#  'ra_đoi': 475,
#  'rangkhong': 476,
#  'react': 477,
#  'reactjs': 478,
#  'receiverid': 479,
#  'recommend': 480,
#  'recommendation': 481,
#  'recommended': 482,
#  'recommender': 483,
#  'refactorings': 484,
#  'replyid': 485,
#  'request': 486,
#  'response': 487,
#  'roi_rac': 488,
#  'role': 489,
#  'rong': 490,
#  'rong_rai': 491,
#  'rongviec': 492,
#  'ruby': 493,
#  'rut': 494,
#  'sach': 495,
#  'sai_lech': 496,
#  'sampling': 497,
#  'san': 498,
#  'san_pham': 499,
#  'san_sang': 500,
#  'sang_tao': 501,
#  'sap_xep': 502,
#  'sau': 503,
#  'scalatu': 504,
#  'schema': 505,
#  'senderid': 506,
#  'server': 507,
#  'setting': 508,
#  'share': 509,
#  'sheets': 510,
#  'sidebar': 511,
#  'similarity': 512,
#  'simple': 513,
#  'single': 514,
#  'sinh': 515,
#  'sinh_thai': 516,
#  'site': 517,
#  'snippets': 518,
#  'so_luong': 519,
#  'so_thich': 520,
#  'so_đo': 521,
#  'soan_thao': 522,
#  'song': 523,
#  'spa': 524,
#  'sparse': 525,
#  'spring': 526,
#  'sql': 527,
#  'starter': 528,
#  'string': 529,
#  'stt': 530,
#  'studio': 531,
#  'style': 532,
#  'sua': 533,
#  'subtitle': 534,
#  'supervised': 535,
#  'suy_dien': 536,
#  'suy_luan': 537,
#  'syntax': 538,
#  'system': 539,
#  'systems': 540,
#  'ta': 541,
#  'tab': 542,
#  'tac': 543,
#  'tac_gia': 544,
#  'tai': 545,
#  'tai_cau_truc': 546,
#  'tai_khoan': 547,
#  'tai_lieu': 548,
#  'tam': 549,
#  'tang_toc': 550,
#  'tang_truong': 551,
#  'tap': 552,
#  'tap_hop': 553,
#  'tapnoi': 554,
#  'tat': 555,
#  'teamcity': 556,
#  'text': 557,
#  'thac_mac': 558,
#  'tham_so': 559,
#  'than_thien': 560,
#  'thanh': 561,
#  'thanh_cong': 562,
#  'thanh_phan': 563,
#  'thao_tac': 564,
#  'that_bai': 565,
#  'thay': 566,
#  'the_gioi': 567,
#  'the_hien': 568,
#  'the_ky': 569,
#  'theo_doi': 570,
#  'theta': 571,
#  'thichkhi': 572,
#  'thiet_bi': 573,
#  'thiet_ke': 574,
#  'thietkhong': 575,
#  'thietsu_dung': 576,
#  'thieu_sot': 577,
#  'thinh': 578,
#  'thoa_man': 579,
#  'thoa_suc': 580,
#  'thoai_mai': 581,
#  'thoi': 582,
#  'thoi_đai': 583,
#  'thong': 584,
#  'thong_bao': 585,
#  'thong_minh': 586,
#  'thong_qua': 587,
#  'thong_thuong': 588,
#  'thong_tin': 589,
#  'threelevel': 590,
#  'thu_thap': 591,
#  'thu_vien': 592,
#  'thua': 593,
#  'thuan_tien': 594,
#  'thuat_toan': 595,
#  'thuat_toan_hoc': 596,
#  'thuc': 597,
#  'thuc_hien_tai': 598,
#  'thuc_the': 599,
#  'thumbnail': 600,
#  'thuong': 601,
#  'thuong_mai': 602,
#  'thuongcho': 603,
#  'thutheo': 604,
#  'tich_hop': 605,
#  'tiem_nang': 606,
#  'tien_ich': 607,
#  'tien_tien': 608,
#  'tien_trinh': 609,
#  'tieng': 610,
#  'tiep_can': 611,
#  'tiep_thi': 612,
#  'tieu_đe': 613,
#  'tieu_đe_bai': 614,
#  'tim_kiem': 615,
#  'timeread': 616,
#  'tin_hieu': 617,
#  'tin_nhiem': 618,
#  'tin_tuc': 619,
#  'tinh_nang': 620,
#  'tinh_toan': 621,
#  'title': 622,
#  'toan': 623,
#  'toan_bo': 624,
#  'toan_cau': 625,
#  'toan_the': 626,
#  'together': 627,
#  'toi_gian': 628,
#  'toi_uu_hoa': 629,
#  'tomcat': 630,
#  'tong_quan': 631,
#  'tong_quat': 632,
#  'tong_thetao': 633,
#  'topic': 634,
#  'topics': 635,
#  'tra_loi': 636,
#  'trai': 637,
#  'trai_đat': 638,
#  'tran': 639,
#  'trang': 640,
#  'trang_chu': 641,
#  'trang_thai': 642,
#  'trang_web': 643,
#  'trao_đoi': 644,
#  'tren': 645,
#  'trenđang': 646,
#  'tri_tue': 647,
#  'trien_khai': 648,
#  'trinh': 649,
#  'trinh_bay': 650,
#  'trinh_duyet': 651,
#  'tro': 652,
#  'tro_nen': 653,
#  'tron': 654,
#  'trong': 655,
#  'truc_tuyen': 656,
#  'true': 657,
#  'trung': 658,
#  'truong': 659,
#  'truy': 660,
#  'truy_cap': 661,
#  'tu_khoa': 662,
#  'tu_vung': 663,
#  'tu_đien': 664,
#  'tu_đong': 665,
#  'tuan': 666,
#  'tuc': 667,
#  'tuc_la': 668,
#  'tuoi_đoi': 669,
#  'tuong_lai': 670,
#  'tuong_quan': 671,
#  'tuong_thich': 672,
#  'tuong_tu': 673,
#  'tuong_ung': 674,
#  'tuong_đong': 675,
#  'tuy': 676,
#  'tv': 677,
#  'type': 678,
#  'ui': 679,
#  'undertow': 680,
#  'ung': 681,
#  'ung_dung': 682,
#  'universal': 683,
#  'unsupervised': 684,
#  'uoc_luong': 685,
#  'use': 686,
#  'usecase': 687,
#  'user': 688,
#  'userid': 689,
#  'useritem': 690,
#  'userlikeids': 691,
#  'username': 692,
#  'users': 693,
#  'userxoa': 694,
#  'uu_điem': 695,
#  'vahoac': 696,
#  'vai_tro': 697,
#  'van': 698,
#  'van_ban': 699,
#  'van_dung': 700,
#  'van_hanh': 701,
#  'variable': 702,
#  'vi_du': 703,
#  'viet': 704,
#  'vietblog': 705,
#  'vietxem': 706,
#  'visual': 707,
#  'vo_cung': 708,
#  'vong': 709,
#  'vs': 710,
#  'vu': 711,
#  'vuong': 712,
#  'vuot_bac': 713,
#  'war': 714,
#  'web': 715,
#  'website': 716,
#  'websocket': 717,
#  'wi': 718,
#  'wide_web': 719,
#  'windows': 720,
#  'word': 721,
#  'wordpress': 722,
#  'world': 723,
#  'xa': 724,
#  'xa_hoi': 725,
#  'xac_nhan': 726,
#  'xac_suat': 727,
#  'xac_thuc': 728,
#  'xac_đinh': 729,
#  'xay_dung': 730,
#  'xem_xet': 731,
#  'xep_hang': 732,
#  'xmlhttprequest': 733,
#  'xoa': 734,
#  'xoa_bai': 735,
#  'xoa_bookmark': 736,
#  'xoa_hien_thi': 737,
#  'xu': 738,
#  'xu_huong': 739,
#  'y_muon': 740,
#  'y_nghia': 741,
#  'y_tuong': 742,
#  'y_đinh': 743,
#  'yahoo': 744,
#  'youtube': 745,
#  'đa_dang': 746,
#  'đac_nhap': 747,
#  'đac_tinh': 748,
#  'đac_trung': 749,
#  'đac_điem': 750,
#  'đai_dien': 751,
#  'đang': 752,
#  'đang_ky': 753,
#  'đang_nhap': 754,
#  'đangchinh': 755,
#  'đanh': 756,
#  'đanh_dau': 757,
#  'đanh_đau': 758,
#  'đau': 759,
#  'đau_ra': 760,
#  'đau_vao': 761,
#  'đaua': 762,
#  'đay_đu': 763,
#  'đe_cap': 764,
#  'đe_tai': 765,
#  'đe_xuat': 766,
#  'đe_y': 767,
#  'đi': 768,
#  'đi_sau': 769,
#  'đien_tu': 770,
#  'đieu_khien': 771,
#  'đinh_dang': 772,
#  'đinh_hinh': 773,
#  'đinh_nghia': 774,
#  'đo': 775,
#  'đo_an': 776,
#  'đoan': 777,
#  'đoc': 778,
#  'đoc_gia': 779,
#  'đoi_khi': 780,
#  'đoi_song': 781,
#  'đoi_tuong': 782,
#  'đoianh': 783,
#  'đon': 784,
#  'đon_gian': 785,
#  'đon_gian_hoa': 786,
#  'đong': 787,
#  'đong_bo': 788,
#  'đong_nghia': 789,
#  'đong_đao': 790,
#  'đođang': 791,
#  'đuocđong': 792,
#  'đuong': 793,
#  'android': 794,
#  'cap_nhat': 795,
#  'cho_du': 796,
#  'components': 797,
#  'componets': 798,
#  'defining': 799,
#  'dom': 800,
#  'engine': 801,
#  'exports': 802,
#  'extend': 803,
#  'hooks': 804,
#  'implementation': 805,
#  'implemented': 806,
#  'import': 807,
#  'ios': 808,
#  'lives': 809,
#  'logic': 810,
#  'lop': 811,
#  'mac': 812,
#  'moi_truong': 813,
#  'mot_the_hien': 814,
#  'mount': 815,
#  'nguoc_lai': 816,
#  'node': 817,
#  'oke': 818,
#  'or': 819,
#  'package': 820,
#  'phan_tach': 821,
#  'platform': 822,
#  'reactart': 823,
#  'reactchildren': 824,
#  'reactcomponent': 825,
#  'reactdom': 826,
#  'reactdomrender': 827,
#  'reactdomserver': 828,
#  'reactnative': 829,
#  'renderer': 830,
#  'renderers': 831,
#  'rerenders': 832,
#  'return': 833,
#  'sai_lam': 834,
#  'setstate': 835,
#  'state': 836,
#  'target': 837,
#  'thac': 838,
#  'thiet_lap': 839,
#  'thu_vi': 840,
#  'tiec': 841,
#  'ty_du': 842,
#  'updater': 843,
#  'utilities': 844,
#  'uy': 845,
#  've': 846,
#  'view': 847,
#  'xay': 848,
#  'đeu': 849,
#  'đoc_lap': 850,
#  'ap_dung': 851,
#  'bao_toan': 852,
#  'bat_buoc': 853,
#  'bi_an': 854,
#  'bieu_thuc': 855,
#  'bo_qua': 856,
#  'bon': 857,
#  'chang_han': 858,
#  'cheo': 859,
#  'chi_đinh': 860,
#  'chinh_quy': 861,
#  'chon_lua': 862,
#  'chu': 863,
#  'chu_so': 864,
#  'chubat': 865,
#  'co_nghia': 866,
#  'co_nghia_la': 867,
#  'cong': 868,
#  'constructor': 869,
#  'cu_phap': 870,
#  'dai': 871,
#  'dau': 872,
#  'dau_cham_hoi': 873,
#  'dau_cham_than': 874,
#  'dau_hoi': 875,
#  'day': 876,
#  'dien_ta': 877,
#  'dong': 878,
#  'duoimot': 879,
#  'duy_nhat': 880,
#  'expression': 881,
#  'gach': 882,
#  'gach_ngang': 883,
#  'gia_su': 884,
#  'gioi_han': 885,
#  'gom': 886,
#  'hoi': 887,
#  'in': 888,
#  'keo': 889,
#  'ket_thuc': 890,
#  'khop': 891,
#  'kia': 892,
#  'ky_hieu': 893,
#  'lan_luot': 894,
#  'luu_y': 895,
#  'mac_du': 896,
#  'mat_khac': 897,
#  'mot_chut': 898,
#  'mot_so_nguyen': 899,
#  'naomot': 900,
#  'ngan_can': 901,
#  'ngoac': 902,
#  'ngoac_vuong': 903,
#  'ngoac_đon': 904,
#  'ngoac_đon_tinh': 905,
#  'nhon': 906,
#  'nhu_nhieu': 907,
#  'pattern': 908,
#  'phan_tu': 909,
#  'phu': 910,
#  'phuong_thuc': 911,
#  'ranh_gioi': 912,
#  'regexp': 913,
#  'regular': 914,
#  'rieng_biet': 915,
#  'somot': 916,
#  'tatnghiabat': 917,
#  'thay_vi': 918,
#  'thong_dung': 919,
#  'thuc_thi': 920,
#  'thuoc_tinh': 921,
#  'toan_tu': 922,
#  'trangbat': 923,
#  'truyen': 924,
#  'tumot': 925,
#  'tuong': 926,
#  'tuy_chon': 927,
#  'unicode': 928,
#  'vv': 929,
#  'đam_bao_mau': 930,
#  'đao_nguoc': 931,
#  'đep_mat': 932,
#  'đung': 933,
#  'đuong_ong': 934,
#  'and': 935,
#  'array': 936,
#  'arrint': 937,
#  'at': 938,
#  'bai_tap': 939,
#  'ban_phim': 940,
#  'bot': 941,
#  'bounds': 942,
#  'bubble': 943,
#  'cacacyahtp': 944,
#  'cach': 945,
#  'chieu': 946,
#  'chon': 947,
#  'cua': 948,
#  'cung': 949,
#  'dao': 950,
#  'duoc': 951,
#  'exception': 952,
#  'for': 953,
#  'goc': 954,
#  'is': 955,
#  'khac': 956,
#  'kich_thuoc': 957,
#  'la': 958,
#  'lathaycacac': 959,
#  'length': 960,
#  'lua': 961,
#  'main': 962,
#  'max': 963,
#  'min': 964,
#  'mot': 965,
#  'nghich': 966,
#  'nghich_đao': 967,
#  'nguoc': 968,
#  'nhapa': 969,
#  'nhieu': 970,
#  'nhung': 971,
#  'noi': 972,
#  'objects': 973,
#  'original': 974,
#  'out': 975,
#  'so_nguyen': 976,
#  'sort': 977,
#  'sorted': 978,
#  'str': 979,
#  'strmot': 980,
#  'tham_chieu': 981,
#  'thaycacac': 982,
#  'this': 983,
#  'thread': 984,
#  'tien': 985,
#  'tri': 986,
#  'tu': 987,
#  'vi': 988,
#  'vua': 989,
#  'vuot': 990,
#  'xuat': 991,
#  'anh_huong': 992,
#  'atm': 993,
#  'atmbai': 994,
#  'bigdecimal': 995,
#  'chu_vi': 996,
#  'chu_y': 997,
#  'class': 998,
#  'co_che': 999,
#  ...}

# %%
class StreamCorpus(object):
    def __init__(self, sentences, dictionary, clip_docs=None):
        """
        Parse the first `clip_docs` documents
        Yield each document in turn, as a list of tokens.
        """
        self.sentences = sentences
        self.dictionary = dictionary
        self.clip_docs = clip_docs

    def __iter__(self):
        for tokens in itertools.islice(make_texts_corpus(self.sentences),
                                       self.clip_docs):
            yield self.dictionary.doc2bow(tokens)

    def __len__(self):
        return self.clip_docs

# %%
sentences = make_sentences()
corpus = StreamCorpus(sentences, id2word)

# %%
for i, c in enumerate(corpus):
    print(c)
    if i == 10: break
# Out:
# [(0, 2), (1, 2), (2, 2), (3, 1), (4, 3), (5, 1), (6, 6), (7, 1), (8, 1), (9, 1), (10, 1), (11, 4), (12, 3), (13, 1), (14, 1), (15, 1), (16, 2), (17, 1), (18, 1), (19, 1), (20, 2), (21, 1), (22, 1), (23, 1), (24, 5), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1), (33, 1), (34, 3), (35, 2), (36, 1), (37, 1), (38, 6), (39, 2), (40, 7), (41, 2), (42, 1), (43, 24), (44, 2), (45, 1), (46, 29), (47, 2), (48, 1), (49, 3), (50, 2), (51, 3), (52, 1), (53, 2), (54, 1), (55, 1), (56, 3), (57, 2), (58, 2), (59, 1), (60, 1), (61, 2), (62, 1), (63, 1), (64, 19), (65, 1), (66, 5), (67, 6), (68, 1), (69, 1), (70, 1), (71, 1), (72, 4), (73, 2), (74, 1), (75, 4), (76, 2), (77, 1), (78, 1), (79, 16), (80, 1), (81, 1), (82, 1), (83, 1), (84, 1), (85, 19), (86, 4), (87, 1), (88, 16), (89, 1), (90, 1), (91, 1), (92, 6), (93, 3), (94, 1), (95, 1), (96, 2), (97, 1), (98, 1), (99, 1), (100, 9), (101, 3), (102, 4), (103, 1), (104, 2), (105, 1), (106, 1), (107, 11), (108, 1), (109, 10), (110, 1), (111, 2), (112, 1), (113, 4), (114, 1), (115, 1), (116, 1), (117, 5), (118, 2), (119, 1), (120, 5), (121, 1), (122, 2), (123, 1), (124, 5), (125, 1), (126, 1), (127, 4), (128, 1), (129, 6), (130, 2), (131, 4), (132, 5), (133, 4), (134, 1), (135, 5), (136, 4), (137, 1), (138, 2), (139, 1), (140, 1), (141, 4), (142, 1), (143, 1), (144, 1), (145, 1), (146, 1), (147, 2), (148, 8), (149, 1), (150, 1), (151, 1), (152, 4), (153, 1), (154, 12), (155, 1), (156, 2), (157, 1), (158, 1), (159, 1), (160, 1), (161, 38), (162, 5), (163, 13), (164, 2), (165, 1), (166, 2), (167, 2), (168, 4), (169, 2), (170, 1), (171, 1), (172, 3), (173, 2), (174, 2), (175, 3), (176, 1), (177, 2), (178, 1), (179, 5), (180, 3), (181, 2), (182, 1), (183, 2), (184, 1), (185, 1), (186, 1), (187, 8), (188, 15), (189, 1), (190, 1), (191, 5), (192, 1), (193, 2), (194, 2), (195, 15), (196, 1), (197, 1), (198, 2), (199, 15), (200, 3), (201, 1), (202, 1), (203, 4), (204, 3), (205, 2), (206, 3), (207, 1), (208, 1), (209, 4), (210, 3), (211, 36), (212, 2), (213, 12), (214, 1), (215, 1), (216, 1), (217, 1), (218, 3), (219, 1), (220, 1), (221, 5), (222, 1), (223, 2), (224, 2), (225, 1), (226, 1), (227, 3), (228, 1), (229, 5), (230, 15), (231, 2), (232, 1), (233, 1), (234, 5), (235, 1), (236, 2), (237, 3), (238, 1), (239, 1), (240, 4), (241, 1), (242, 1), (243, 1), (244, 2), (245, 2), (246, 1), (247, 13), (248, 4), (249, 2), (250, 4), (251, 5), (252, 3), (253, 2), (254, 2), (255, 1), (256, 5), (257, 8), (258, 2), (259, 2), (260, 1), (261, 1), (262, 1), (263, 1), (264, 3), (265, 2), (266, 1), (267, 1), (268, 1), (269, 4), (270, 1), (271, 5), (272, 2), (273, 6), (274, 3), (275, 1), (276, 2), (277, 2), (278, 1), (279, 1), (280, 1), (281, 1), (282, 1), (283, 1), (284, 1), (285, 2), (286, 1), (287, 1), (288, 2), (289, 1), (290, 3), (291, 1), (292, 4), (293, 1), (294, 1), (295, 1), (296, 1), (297, 1), (298, 2), (299, 1), (300, 1), (301, 1), (302, 1), (303, 3), (304, 2), (305, 1), (306, 2), (307, 17), (308, 10), (309, 1), (310, 4), (311, 1), (312, 1), (313, 1), (314, 1), (315, 1), (316, 2), (317, 1), (318, 2), (319, 4), (320, 5), (321, 1), (322, 1), (323, 1), (324, 1), (325, 3), (326, 1), (327, 1), (328, 2), (329, 3), (330, 1), (331, 2), (332, 13), (333, 1), (334, 2), (335, 1), (336, 2), (337, 1), (338, 11), (339, 1), (340, 1), (341, 8), (342, 1), (343, 1), (344, 1), (345, 8), (346, 2), (347, 1), (348, 1), (349, 1), (350, 1), (351, 1), (352, 3), (353, 1), (354, 7), (355, 1), (356, 1), (357, 1), (358, 1), (359, 2), (360, 1), (361, 1), (362, 14), (363, 3), (364, 1), (365, 12), (366, 1), (367, 1), (368, 3), (369, 1), (370, 3), (371, 2), (372, 1), (373, 1), (374, 7), (375, 2), (376, 1), (377, 2), (378, 7), (379, 3), (380, 1), (381, 3), (382, 3), (383, 3), (384, 1), (385, 1), (386, 2), (387, 1), (388, 1), (389, 3), (390, 1), (391, 1), (392, 5), (393, 1), (394, 1), (395, 2), (396, 8), (397, 1), (398, 11), (399, 1), (400, 1), (401, 3), (402, 5), (403, 4), (404, 1), (405, 2), (406, 1), (407, 1), (408 ...
# [(9, 2), (65, 2), (67, 1), (72, 1), (86, 1), (116, 2), (122, 1), (132, 1), (198, 10), (213, 1), (298, 2), (376, 1), (385, 5), (386, 3), (443, 1), (446, 1), (467, 1), (477, 28), (503, 1), (507, 2), (568, 1), (620, 1), (636, 2), (659, 2), (682, 1), (751, 1), (774, 1), (778, 1), (794, 1), (795, 8), (796, 1), (797, 4), (798, 1), (799, 1), (800, 17), (801, 1), (802, 1), (803, 1), (804, 1), (805, 1), (806, 1), (807, 1), (808, 1), (809, 1), (810, 1), (811, 3), (812, 1), (813, 1), (814, 1), (815, 1), (816, 1), (817, 1), (818, 1), (819, 1), (820, 1), (821, 1), (822, 1), (823, 1), (824, 1), (825, 5), (826, 2), (827, 1), (828, 1), (829, 2), (830, 4), (831, 3), (832, 2), (833, 2), (834, 1), (835, 3), (836, 3), (837, 1), (838, 1), (839, 4), (840, 1), (841, 1), (842, 4), (843, 1), (844, 1), (845, 1), (846, 3), (847, 1), (848, 3), (849, 1), (850, 1)]
# [(24, 2), (39, 2), (50, 1), (59, 2), (80, 2), (86, 6), (91, 27), (118, 2), (132, 1), (135, 1), (161, 2), (195, 1), (198, 2), (204, 8), (213, 1), (218, 1), (225, 2), (229, 1), (244, 1), (259, 2), (266, 1), (268, 1), (271, 1), (285, 5), (290, 2), (295, 3), (297, 37), (301, 2), (303, 1), (314, 2), (329, 2), (338, 3), (345, 3), (352, 14), (365, 1), (381, 2), (390, 1), (395, 2), (396, 2), (433, 1), (443, 3), (450, 1), (453, 1), (541, 3), (542, 1), (552, 1), (553, 3), (555, 1), (561, 1), (562, 1), (568, 1), (589, 1), (615, 1), (624, 3), (637, 1), (640, 1), (655, 1), (658, 19), (673, 2), (698, 1), (699, 2), (703, 5), (704, 5), (708, 1), (729, 1), (730, 1), (741, 3), (749, 1), (751, 2), (752, 1), (757, 1), (759, 2), (760, 1), (761, 2), (777, 1), (782, 5), (785, 3), (795, 1), (816, 1), (848, 1), (851, 3), (852, 1), (853, 2), (854, 1), (855, 24), (856, 1), (857, 2), (858, 1), (859, 8), (860, 1), (861, 18), (862, 1), (863, 5), (864, 9), (865, 1), (866, 1), (867, 2), (868, 1), (869, 1), (870, 2), (871, 1), (872, 31), (873, 1), (874, 1), (875, 1), (876, 4), (877, 1), (878, 2), (879, 1), (880, 2), (881, 3), (882, 10), (883, 1), (884, 2), (885, 2), (886, 2), (887, 1), (888, 1), (889, 1), (890, 3), (891, 37), (892, 1), (893, 1), (894, 1), (895, 1), (896, 1), (897, 1), (898, 1), (899, 1), (900, 1), (901, 1), (902, 3), (903, 2), (904, 3), (905, 1), (906, 1), (907, 1), (908, 9), (909, 9), (910, 2), (911, 4), (912, 3), (913, 1), (914, 3), (915, 1), (916, 1), (917, 1), (918, 1), (919, 1), (920, 1), (921, 1), (922, 4), (923, 1), (924, 1), (925, 1), (926, 1), (927, 1), (928, 1), (929, 1), (930, 1), (931, 1), (932, 1), (933, 2), (934, 1)]
# [(20, 2), (91, 18), (92, 1), (93, 2), (104, 2), (164, 2), (204, 5), (212, 2), (249, 1), (258, 3), (295, 1), (297, 1), (301, 1), (324, 1), (345, 6), (360, 2), (402, 9), (425, 1), (454, 1), (502, 2), (564, 1), (649, 2), (682, 1), (715, 1), (782, 1), (848, 2), (857, 2), (871, 1), (872, 1), (888, 3), (909, 4), (935, 2), (936, 2), (937, 10), (938, 1), (939, 1), (940, 2), (941, 1), (942, 1), (943, 1), (944, 1), (945, 2), (946, 2), (947, 1), (948, 3), (949, 1), (950, 1), (951, 2), (952, 1), (953, 1), (954, 2), (955, 12), (956, 2), (957, 1), (958, 4), (959, 1), (960, 1), (961, 1), (962, 1), (963, 3), (964, 3), (965, 6), (966, 1), (967, 1), (968, 1), (969, 1), (970, 2), (971, 1), (972, 1), (973, 1), (974, 1), (975, 1), (976, 1), (977, 1), (978, 1), (979, 9), (980, 1), (981, 1), (982, 1), (983, 10), (984, 1), (985, 1), (986, 2), (987, 1), (988, 2), (989, 2), (990, 1), (991, 4)]
# [(15, 6), (18, 1), (38, 5), (65, 2), (69, 1), (72, 1), (80, 5), (93, 12), (120, 1), (122, 1), (132, 1), (135, 4), (161, 3), (198, 1), (204, 1), (206, 3), (221, 1), (230, 1), (240, 1), (243, 1), (258, 2), (271, 5), (290, 6), (303, 1), (334, 1), (354, 3), (360, 1), (372, 2), (388, 1), (433, 1), (527, 1), (533, 1), (559, 1), (587, 2), (588, 1), (589, 1), (593, 1), (621, 5), (623, 1), (636, 1), (665, 1), (672, 1), (678, 1), (738, 1), (752, 1), (759, 1), (761, 1), (764, 1), (767, 1), (768, 2), (777, 2), (778, 1), (787, 4), (789, 1), (795, 1), (858, 2), (869, 2), (872, 4), (888, 8), (896, 1), (924, 1), (933, 1), (946, 1), (985, 2), (992, 1), (993, 1), (994, 1), (995, 4), (996, 1), (997, 1), (998, 2), (999, 1), (1000, 1), (1001, 1), (1002, 1), (1003, 4), (1004, 1), (1005, 1), (1006, 1), (1007, 3), (1008, 1), (1009, 1), (1010, 1), (1011, 1), (1012, 1), (1013, 1), (1014, 1), (1015, 1), (1016, 2), (1017, 2), (1018, 4), (1019, 1), (1020, 1), (1021, 1), (1022, 1), (1023, 1), (1024, 1), (1025, 1), (1026, 2), (1027, 1), (1028, 1), (1029, 1), (1030, 1), (1031, 1), (1032, 1)]
# [(15, 2), (18, 1), (58, 1), (61, 1), (65, 1), (72, 1), (109, 2), (134, 2), (161, 4), (195, 2), (204, 4), (226, 1), (240, 1), (258, 3), (288, 1), (290, 1), (301, 3), (303, 1), (312, 5), (336, 1), (345, 4), (372, 1), (502, 12), (541, 1), (595, 3), (657, 1), (673, 6), (703, 3), (704, 2), (709, 10), (752, 1), (763, 1), (775, 1), (785, 2), (795, 1), (846, 1), (848, 1), (884, 1), (909, 28), (941, 7), (946, 1), (972, 7), (1033, 1), (1034, 4), (1035, 4), (1036, 1), (1037, 1), (1038, 1), (1039, 5), (1040, 1), (1041, 7), (1042, 1), (1043, 1), (1044, 1), (1045, 1), (1046, 1), (1047, 9), (1048, 1), (1049, 1), (1050, 2), (1051, 1), (1052, 1), (1053, 3), (1054, 4)]
# [(15, 1), (30, 7), (72, 2), (80, 1), (93, 3), (109, 1), (114, 1), (134, 1), (161, 1), (163, 1), (167, 4), (170, 8), (188, 1), (191, 1), (222, 1), (227, 1), (234, 1), (258, 5), (271, 2), (273, 2), (285, 6), (320, 1), (332, 1), (396, 1), (398, 3), (433, 1), (436, 9), (454, 3), (541, 8), (543, 1), (557, 3), (561, 2), (668, 1), (673, 1), (699, 1), (703, 3), (757, 2), (768, 1), (778, 1), (785, 3), (816, 1), (851, 2), (1047, 2), (1049, 5), (1055, 2), (1056, 3), (1057, 2), (1058, 1), (1059, 1), (1060, 1), (1061, 3), (1062, 1), (1063, 1), (1064, 1), (1065, 7), (1066, 5), (1067, 1), (1068, 9), (1069, 6), (1070, 4), (1071, 1), (1072, 1), (1073, 15), (1074, 3), (1075, 3), (1076, 4), (1077, 8), (1078, 1), (1079, 2), (1080, 14), (1081, 1), (1082, 1)]
# [(104, 1), (109, 2), (111, 1), (132, 1), (167, 1), (170, 14), (213, 2), (240, 1), (247, 2), (258, 1), (271, 2), (290, 2), (303, 1), (335, 2), (338, 1), (425, 1), (529, 1), (541, 1), (561, 2), (563, 2), (589, 2), (592, 2), (652, 2), (703, 3), (721, 1), (772, 1), (774, 2), (777, 1), (778, 7), (782, 2), (878, 3), (895, 1), (998, 5), (1003, 1), (1062, 5), (1065, 1), (1083, 8), (1084, 1), (1085, 1), (1086, 3), (1087, 1), (1088, 1), (1089, 2), (1090, 20), (1091, 2), (1092, 1), (1093, 1), (1094, 2), (1095, 4), (1096, 3), (1097, 2), (1098, 1), (1099, 1), (1100, 7), (1101, 1), (1102, 1), (1103, 2), (1104, 1), (1105, 2), (1106, 1), (1107, 1), (1108, 2), (1109, 1), (1110, 1)]
# [(72, 2), (184, 1), (196, 1), (198, 1), (204, 3), (214, 2), (258, 4), (262, 5), (271, 2), (279, 1), (301, 1), (303, 1), (376, 1), (396, 1), (443, 1), (541, 11), (548, 1), (634, 1), (650, 2), (673, 1), (703, 5), (709, 1), (752, 1), (767, 1), (788, 3), (795, 1), (811, 6), (848, 3), (867, 1), (878, 1), (888, 13), (890, 2), (892, 1), (895, 1), (920, 5), (935, 1), (952, 2), (962, 1), (984, 75), (1048, 1), (1054, 6), (1062, 1), (1081, 2), (1111, 3), (1112, 2), (1113, 1), (1114, 40), (1115, 6), (1116, 12), (1117, 2), (1118, 8), (1119, 1), (1120, 15), (1121, 1), (1122, 1), (1123, 4), (1124, 3), (1125, 2), (1126, 1), (1127, 2), (1128, 2), (1129, 1), (1130, 1), (1131, 4), (1132, 8), (1133, 3), (1134, 5), (1135, 12), (1136, 1), (1137, 4), (1138, 4), (1139, 2), (1140, 5), (1141, 2), (1142, 1), (1143, 8), (1144, 1), (1145, 1), (1146, 1), (1147, 1), (1148, 1), (1149, 1), (1150, 1), (1151, 1), (1152, 2), (1153, 1), (1154, 2), (1155, 1), (1156, 3), (1157, 1), (1158, 1)]
# [(72, 1), (93, 11), (198, 3), (227, 8), (258, 1), (262, 2), (271, 3), (279, 1), (330, 1), (338, 1), (381, 1), (407, 1), (443, 1), (519, 2), (541, 2), (543, 1), (559, 1), (566, 1), (585, 2), (607, 1), (668, 2), (682, 2), (703, 3), (711, 1), (752, 1), (782, 2), (795, 1), (811, 4), (860, 1), (895, 1), (911, 6), (920, 4), (968, 1), (984, 9), (1011, 1), (1034, 6), (1128, 1), (1142, 4), (1147, 2), (1159, 2), (1160, 4), (1161, 10), (1162, 1), (1163, 1), (1164, 1), (1165, 1), (1166, 1), (1167, 3), (1168, 3), (1169, 2), (1170, 3), (1171, 2), (1172, 1), (1173, 3), (1174, 2), (1175, 1), (1176, 1), (1177, 1), (1178, 1), (1179, 1)]
# [(70, 1), (72, 1), (109, 1), (198, 3), (204, 1), (258, 11), (277, 3), (279, 9), (290, 1), (338, 1), (354, 1), (422, 6), (541, 1), (568, 2), (624, 1), (673, 2), (676, 1), (703, 7), (704, 1), (731, 1), (752, 1), (757, 1), (777, 1), (778, 1), (782, 2), (788, 15), (795, 1), (848, 1), (920, 4), (926, 1), (984, 10), (998, 6), (999, 1), (1000, 1), (1011, 1), (1054, 1), (1114, 1), (1180, 2), (1181, 1), (1182, 2), (1183, 11), (1184, 1), (1185, 1), (1186, 1), (1187, 1), (1188, 17), (1189, 2), (1190, 15), (1191, 12), (1192, 2), (1193, 1), (1194, 1), (1195, 1), (1196, 1), (1197, 1), (1198, 2), (1199, 10), (1200, 1), (1201, 28), (1202, 1), (1203, 1), (1204, 1), (1205, 1), (1206, 3), (1207, 1)]

# %%
# save corpus
gensim.corpora.MmCorpus.serialize('../models/corpus.mm', corpus)
# Out:
# INFO : storing corpus in Matrix Market format to ../models/corpus.mm
# INFO : saving sparse matrix to ../models/corpus.mm
# INFO : PROGRESS: saving document #0
# INFO : saved 28x3324 matrix, density=7.485% (6966/93072)
# INFO : saving MmCorpus index to ../models/corpus.mm.index

# %%
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 28 documents, 3324 features, 6966 non-zero entries

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus, id2word=id2word, num_topics=64, passes=10,
            chunksize=100, random_state=42, alpha=1e-2, eta=0.5e-2,
            minimum_probability=0.0, per_word_topics=False)
# Out:
# INFO : using serial LDA version on this node
# INFO : running online (multi-pass) LDA training, 64 topics, 10 passes over the supplied corpus of 28 documents, updating model once every 28 documents, evaluating perplexity every 28 documents, iterating 50x with a convergence threshold of 0.001000
# INFO : -70.028 per-word bound, 1203976549426039619584.0 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 0, at document #28/28
# INFO : topic #27 (0.010): 0.019*"lock" + 0.014*"thread" + 0.011*"monitor" + 0.010*"synchronized" + 0.009*"thuc_thi" + 0.009*"method" + 0.009*"tranh_chap" + 0.008*"đoi_tuong" + 0.008*"khoa" + 0.007*"hanh_đong"
# INFO : topic #55 (0.010): 0.021*"khoi_nghiep" + 0.018*"kinh_doanh" + 0.015*"agile" + 0.012*"phat_trien" + 0.010*"du_an" + 0.009*"san_pham" + 0.008*"cong_ty" + 0.008*"lam_viec" + 0.007*"đau_tu" + 0.007*"huong"
# INFO : topic #23 (0.010): 0.020*"thong_minh" + 0.012*"agile" + 0.011*"phat_trien" + 0.011*"đi" + 0.009*"du_lich" + 0.008*"may" + 0.007*"đoi" + 0.007*"ha_long" + 0.006*"ta" + 0.006*"co"
# INFO : topic #53 (0.010): 0.029*"khoi_nghiep" + 0.027*"kinh_doanh" + 0.011*"tien" + 0.010*"lam_viec" + 0.010*"y_tuong" + 0.009*"mua" + 0.009*"đi" + 0.008*"thanh_cong" + 0.008*"đung" + 0.008*"thong_minh"
# INFO : topic #18 (0.010): 0.026*"thiet_ke" + 0.015*"xay_dung" + 0.014*"cung_cap" + 0.014*"trang_web" + 0.013*"design" + 0.012*"web" + 0.012*"thanh_phan" + 0.012*"css" + 0.011*"material" + 0.011*"bootstrap"
# INFO : topic diff=121.508232, rho=1.000000
# INFO : -18.588 per-word bound, 394093.2 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 1, at document #28/28
# INFO : topic #53 (0.010): 0.027*"khoi_nghiep" + 0.025*"kinh_doanh" + 0.010*"tien" + 0.009*"lam_viec" + 0.009*"y_tuong" + 0.008*"mua" + 0.008*"đi" + 0.008*"thanh_cong" + 0.007*"đung" + 0.007*"thong_minh"
# INFO : topic #59 (0.010): 0.019*"khoi_nghiep" + 0.011*"kinh_doanh" + 0.008*"phat_trien" + 0.008*"kha_nang" + 0.008*"du_an" + 0.007*"đoi" + 0.006*"thong_minh" + 0.006*"muc_tieu" + 0.005*"đau_tu" + 0.005*"agile"
# INFO : topic #58 (0.010): 0.044*"kinh_doanh" + 0.039*"khoi_nghiep" + 0.022*"lam_viec" + 0.015*"cong_viec" + 0.015*"von" + 0.015*"thanh_cong" + 0.014*"giup" + 0.012*"ban_tay_trang" + 0.012*"quan_ly" + 0.012*"y_tuong"
# INFO : topic #52 (0.010): 0.025*"lock" + 0.016*"thread" + 0.015*"method" + 0.015*"monitor" + 0.012*"tranh_chap" + 0.012*"đoi_tuong" + 0.011*"synchronized" + 0.008*"truy_cap" + 0.008*"marketing" + 0.007*"thuc_thi"
# INFO : topic #47 (0.010): 0.069*"backend" + 0.048*"frontend" + 0.030*"du_lieu" + 0.027*"xang" + 0.022*"api" + 0.021*"phuong_thuc" + 0.020*"tao" + 0.019*"danh_sach" + 0.019*"goi" + 0.019*"ta"
# INFO : topic diff=10.243687, rho=0.577350
# INFO : -14.114 per-word bound, 17734.7 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 2, at document #28/28
# INFO : topic #15 (0.010): 0.094*"ta" + 0.061*"api" + 0.034*"request" + 0.031*"viet" + 0.020*"contact" + 0.020*"napa" + 0.014*"cau_truc" + 0.014*"model" + 0.013*"response" + 0.010*"khai_bao"
# INFO : topic #22 (0.010): 0.013*"khoi_nghiep" + 0.008*"frontend" + 0.007*"backend" + 0.007*"may" + 0.007*"thong_minh" + 0.006*"kinh_doanh" + 0.006*"ta" + 0.006*"tien" + 0.005*"đoc" + 0.005*"đung"
# INFO : topic #25 (0.010): 0.016*"khoi_nghiep" + 0.008*"kinh_doanh" + 0.007*"ung_dung" + 0.007*"ngon_ngu" + 0.007*"hoc" + 0.006*"tien" + 0.006*"swift" + 0.006*"y_tuong" + 0.006*"đung" + 0.005*"giup"
# INFO : topic #34 (0.010): 0.035*"khoi_nghiep" + 0.021*"tien" + 0.013*"kinh_doanh" + 0.010*"y_tuong" + 0.010*"doanh_nhan" + 0.010*"viet" + 0.009*"kha_nang" + 0.009*"đoc" + 0.009*"sach" + 0.009*"doanh_nghiep"
# INFO : topic #55 (0.010): 0.014*"khoi_nghiep" + 0.012*"kinh_doanh" + 0.010*"agile" + 0.008*"phat_trien" + 0.007*"du_an" + 0.006*"san_pham" + 0.005*"cong_ty" + 0.005*"lam_viec" + 0.005*"đau_tu" + 0.005*"huong"
# INFO : topic diff=9.822211, rho=0.500000
# INFO : -11.728 per-word bound, 3391.3 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 3, at document #28/28
# INFO : topic #14 (0.010): 0.014*"thong_minh" + 0.009*"con_nguoi" + 0.007*"muc_tieu" + 0.006*"nghien_cuu" + 0.005*"kha_nang" + 0.004*"kiem_soat" + 0.004*"tri_tue" + 0.004*"an_toan" + 0.004*"may" + 0.004*"robot"
# INFO : topic #49 (0.010): 0.042*"khoi_nghiep" + 0.023*"kinh_doanh" + 0.016*"tien" + 0.012*"y_tuong" + 0.012*"mua" + 0.011*"lap_trinh_vien" + 0.010*"mo_hinh" + 0.010*"huong" + 0.009*"co_ban" + 0.009*"manh_me"
# INFO : topic #27 (0.010): 0.008*"lock" + 0.006*"thread" + 0.005*"monitor" + 0.005*"synchronized" + 0.004*"thuc_thi" + 0.004*"method" + 0.004*"tranh_chap" + 0.004*"đoi_tuong" + 0.003*"khoa" + 0.003*"hanh_đong"
# INFO : topic #12 (0.010): 0.061*"user" + 0.053*"stories" + 0.034*"khach_hang" + 0.031*"agile" + 0.028*"marketing" + 0.027*"san_pham" + 0.022*"ghi" + 0.019*"noi_dung" + 0.019*"personas" + 0.016*"giai_quyet"
# INFO : topic #35 (0.010): 0.007*"thiet_ke" + 0.005*"material" + 0.005*"cung_cap" + 0.005*"design" + 0.004*"xay_dung" + 0.004*"web" + 0.004*"thanh_phan" + 0.004*"trang_web" + 0.004*"thread" + 0.004*"css"
# INFO : topic diff=9.010677, rho=0.447214
# INFO : -10.232 per-word bound, 1202.7 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 4, at document #28/28
# INFO : topic #62 (0.010): 0.045*"ve" + 0.043*"du_lich" + 0.027*"hanh_ly" + 0.026*"lua_chon" + 0.022*"vui_choi" + 0.021*"lich_trinh" + 0.020*"chuyen" + 0.018*"kinh_nghiem" + 0.017*"luu_y" + 0.017*"đi"
# INFO : topic #12 (0.010): 0.062*"user" + 0.054*"stories" + 0.035*"khach_hang" + 0.031*"agile" + 0.028*"marketing" + 0.027*"san_pham" + 0.021*"ghi" + 0.020*"noi_dung" + 0.019*"personas" + 0.016*"giai_quyet"
# INFO : topic #4 (0.010): 0.004*"xay_dung" + 0.004*"thiet_ke" + 0.003*"web" + 0.003*"trang_web" + 0.003*"bootstrap" + 0.003*"cung_cap" + 0.003*"đi" + 0.003*"phat_trien" + 0.003*"kha_nang" + 0.003*"đap_ung"
# INFO : topic #5 (0.010): 0.007*"thong_minh" + 0.003*"ta" + 0.003*"tri" + 0.003*"con_nguoi" + 0.003*"co" + 0.002*"may" + 0.002*"nghien_cuu" + 0.002*"kha_nang" + 0.002*"he_thong" + 0.002*"tri_tue"
# INFO : topic #43 (0.010): 0.055*"du_lich" + 0.053*"đi" + 0.028*"chuyen" + 0.021*"mua" + 0.017*"bui" + 0.016*"kinh_nghiem" + 0.014*"the" + 0.013*"xe" + 0.012*"thong_tin" + 0.010*"thuoc"
# INFO : topic diff=7.933317, rho=0.408248
# INFO : -9.271 per-word bound, 617.8 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 5, at document #28/28
# INFO : topic #63 (0.010): 0.055*"lock" + 0.042*"thread" + 0.034*"monitor" + 0.030*"method" + 0.030*"synchronized" + 0.030*"đoi_tuong" + 0.025*"tranh_chap" + 0.021*"thuc_thi" + 0.019*"truy_cap" + 0.019*"khoa"
# INFO : topic #4 (0.010): 0.003*"xay_dung" + 0.003*"thiet_ke" + 0.003*"web" + 0.003*"trang_web" + 0.003*"bootstrap" + 0.002*"cung_cap" + 0.002*"đi" + 0.002*"phat_trien" + 0.002*"kha_nang" + 0.002*"đap_ung"
# INFO : topic #17 (0.010): 0.046*"ha_long" + 0.038*"du_lich" + 0.032*"đi" + 0.024*"ha" + 0.024*"long" + 0.020*"chuyen" + 0.014*"xe" + 0.012*"bien" + 0.012*"đep" + 0.012*"phuong_tien"
# INFO : topic #56 (0.010): 0.005*"marketing" + 0.005*"sprint" + 0.003*"team" + 0.003*"agile" + 0.003*"meeting" + 0.003*"story" + 0.003*"mua" + 0.003*"đoi" + 0.003*"user" + 0.003*"du_an"
# INFO : topic #21 (0.010): 0.010*"khoi_nghiep" + 0.007*"kinh_doanh" + 0.005*"lock" + 0.004*"tien" + 0.003*"cong_ty" + 0.003*"thread" + 0.003*"thuc_thi" + 0.003*"kha_nang" + 0.003*"monitor" + 0.002*"đoi_tuong"
# INFO : topic diff=6.758897, rho=0.377964
# INFO : -8.651 per-word bound, 402.1 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 6, at document #28/28
# INFO : topic #50 (0.010): 0.007*"khoi_nghiep" + 0.006*"du_lich" + 0.005*"kinh_doanh" + 0.003*"đi" + 0.002*"huong" + 0.002*"bui" + 0.002*"ha_long" + 0.002*"mo_rong" + 0.002*"mua" + 0.002*"đo"
# INFO : topic #51 (0.010): 0.051*"swift" + 0.046*"mo_hinh" + 0.042*"ung_dung" + 0.037*"coreml" + 0.032*"ngon_ngu" + 0.028*"apple" + 0.023*"phat_trien" + 0.023*"may" + 0.019*"đao_tao" + 0.019*"creatml"
# INFO : topic #48 (0.010): 0.032*"trang_web" + 0.027*"thiet_ke" + 0.027*"web" + 0.024*"loi" + 0.021*"ngon_ngu" + 0.021*"kiem_tra" + 0.018*"html" + 0.015*"thu_nghiem" + 0.015*"lap_trinh" + 0.015*"co_ban"
# INFO : topic #32 (0.010): 0.038*"khoi_nghiep" + 0.026*"tien" + 0.017*"y_tuong" + 0.013*"đung" + 0.013*"viet" + 0.013*"đoc" + 0.013*"sach" + 0.012*"kinh_doanh" + 0.012*"hang" + 0.012*"doanh_nghiep"
# INFO : topic #6 (0.010): 0.005*"ta" + 0.004*"material" + 0.004*"api" + 0.003*"design" + 0.002*"thiet_ke" + 0.002*"viet" + 0.002*"khoi_nghiep" + 0.002*"framework" + 0.002*"cung_cap" + 0.002*"request"
# INFO : topic diff=5.603029, rho=0.353553
# INFO : -8.251 per-word bound, 304.6 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 7, at document #28/28
# INFO : topic #21 (0.010): 0.005*"khoi_nghiep" + 0.004*"kinh_doanh" + 0.003*"lock" + 0.002*"tien" + 0.002*"cong_ty" + 0.002*"thread" + 0.002*"thuc_thi" + 0.002*"kha_nang" + 0.001*"monitor" + 0.001*"đoi_tuong"
# INFO : topic #41 (0.010): 0.005*"khoi_nghiep" + 0.003*"kinh_doanh" + 0.002*"thong_minh" + 0.002*"huong" + 0.001*"so_huu" + 0.001*"lam_viec" + 0.001*"cong_ty" + 0.001*"tien" + 0.001*"y_tuong" + 0.001*"quy"
# INFO : topic #59 (0.010): 0.005*"khoi_nghiep" + 0.003*"kinh_doanh" + 0.002*"phat_trien" + 0.002*"kha_nang" + 0.002*"du_an" + 0.002*"đoi" + 0.002*"thong_minh" + 0.002*"muc_tieu" + 0.002*"đau_tu" + 0.002*"agile"
# INFO : topic #61 (0.010): 0.001*"thong_minh" + 0.001*"marketing" + 0.001*"hang" + 0.001*"thiet_ke" + 0.001*"muc_tieu" + 0.001*"con_nguoi" + 0.001*"xay_dung" + 0.001*"kha_nang" + 0.001*"tien" + 0.001*"xay"
# INFO : topic #31 (0.010): 0.004*"đi" + 0.003*"thong_minh" + 0.003*"du_lich" + 0.002*"tien" + 0.002*"khoi_nghiep" + 0.002*"may" + 0.002*"ve" + 0.002*"chuyen" + 0.002*"ta" + 0.002*"lam_viec"
# INFO : topic diff=4.551364, rho=0.333333
# INFO : -7.991 per-word bound, 254.5 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 8, at document #28/28
# INFO : topic #41 (0.010): 0.004*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.002*"thong_minh" + 0.001*"huong" + 0.001*"so_huu" + 0.001*"lam_viec" + 0.001*"cong_ty" + 0.001*"tien" + 0.001*"y_tuong" + 0.001*"quy"
# INFO : topic #5 (0.010): 0.002*"thong_minh" + 0.001*"ta" + 0.001*"tri" + 0.001*"con_nguoi" + 0.001*"co" + 0.001*"may" + 0.001*"nghien_cuu" + 0.001*"kha_nang" + 0.001*"he_thong" + 0.001*"tri_tue"
# INFO : topic #1 (0.010): 0.003*"thiet_ke" + 0.002*"cung_cap" + 0.002*"trang_web" + 0.002*"bootstrap" + 0.002*"xay_dung" + 0.002*"user" + 0.002*"web" + 0.001*"đap_ung" + 0.001*"bao_gom" + 0.001*"khoi_nghiep"
# INFO : topic #20 (0.010): 0.027*"lam_viec" + 0.020*"khoi_nghiep" + 0.017*"thanh_cong" + 0.017*"giau_co" + 0.017*"suy_nghi" + 0.013*"doanh_nghiep" + 0.013*"quan_ly" + 0.013*"đuong" + 0.013*"ban_tay_trang" + 0.013*"startup"
# INFO : topic #57 (0.010): 0.002*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.002*"marketing" + 0.001*"hang" + 0.001*"mua" + 0.001*"tien" + 0.001*"y_tuong" + 0.001*"thanh_cong" + 0.001*"agile" + 0.001*"đung"
# INFO : topic diff=3.640004, rho=0.316228
# INFO : -7.822 per-word bound, 226.4 perplexity estimate based on a held-out corpus of 28 documents with 13053 words
# INFO : PROGRESS: pass 9, at document #28/28
# INFO : topic #2 (0.010): 0.003*"thong_minh" + 0.002*"marketing" + 0.001*"sprint" + 0.001*"user" + 0.001*"ta" + 0.001*"kha_nang" + 0.001*"con_nguoi" + 0.001*"hang" + 0.001*"tri" + 0.001*"may"
# INFO : topic #11 (0.010): 0.001*"xay_dung" + 0.001*"trang_web" + 0.000*"thiet_ke" + 0.000*"bootstrap" + 0.000*"cung_cap" + 0.000*"css" + 0.000*"đap_ung" + 0.000*"web" + 0.000*"phong_cach" + 0.000*"phat_trien"
# INFO : topic #39 (0.010): 0.001*"thiet_ke" + 0.001*"trang_web" + 0.001*"khoi_nghiep" + 0.001*"web" + 0.001*"tien" + 0.001*"xay_dung" + 0.000*"loi" + 0.000*"thong_minh" + 0.000*"viet" + 0.000*"agile"
# INFO : topic #47 (0.010): 0.081*"backend" + 0.058*"frontend" + 0.034*"du_lieu" + 0.031*"xang" + 0.024*"phuong_thuc" + 0.024*"api" + 0.024*"tao" + 0.023*"danh_sach" + 0.021*"goi" + 0.021*"ta"
# INFO : topic #28 (0.010): 0.001*"agile" + 0.001*"marketing" + 0.001*"ha_long" + 0.001*"đi" + 0.001*"du_lich" + 0.001*"đoi" + 0.001*"long" + 0.001*"hang" + 0.001*"ha" + 0.001*"du_an"
# INFO : topic diff=2.880767, rho=0.301511
# INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=3324, num_topics=64, decay=0.5, chunksize=100> in 3.47s', 'datetime': '2022-12-19T01:57:16.231510', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
lda_model.save('../models/LDA.model')
lda_model.print_topics()
# Out:
# INFO : LdaState lifecycle event {'fname_or_handle': '../models/LDA.model.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-12-19T01:57:16.247236', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/LDA.model.state
# INFO : LdaModel lifecycle event {'fname_or_handle': '../models/LDA.model', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['id2word', 'state', 'dispatcher'], 'datetime': '2022-12-19T01:57:16.263510', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : storing np array 'expElogbeta' to ../models/LDA.model.expElogbeta.npy
# INFO : not storing attribute id2word
# INFO : not storing attribute state
# INFO : not storing attribute dispatcher
# INFO : saved ../models/LDA.model
# INFO : topic #38 (0.010): 0.001*"đi" + 0.001*"material" + 0.001*"thiet_ke" + 0.001*"xay_dung" + 0.001*"web" + 0.001*"mua" + 0.001*"chuyen" + 0.001*"du_lich" + 0.001*"design" + 0.001*"trang_web"
# INFO : topic #15 (0.010): 0.105*"ta" + 0.068*"api" + 0.038*"request" + 0.034*"viet" + 0.023*"contact" + 0.023*"napa" + 0.015*"cau_truc" + 0.015*"model" + 0.015*"response" + 0.011*"khai_bao"
# INFO : topic #41 (0.010): 0.003*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.001*"thong_minh" + 0.001*"huong" + 0.001*"so_huu" + 0.001*"lam_viec" + 0.001*"cong_ty" + 0.001*"tien" + 0.001*"y_tuong" + 0.001*"quy"
# INFO : topic #43 (0.010): 0.055*"du_lich" + 0.054*"đi" + 0.028*"chuyen" + 0.022*"mua" + 0.017*"bui" + 0.016*"kinh_nghiem" + 0.015*"the" + 0.013*"xe" + 0.012*"thong_tin" + 0.011*"thuoc"
# INFO : topic #28 (0.010): 0.001*"agile" + 0.001*"marketing" + 0.001*"ha_long" + 0.001*"đi" + 0.001*"du_lich" + 0.001*"đoi" + 0.001*"long" + 0.001*"hang" + 0.001*"ha" + 0.001*"du_an"
# INFO : topic #35 (0.010): 0.001*"thiet_ke" + 0.001*"material" + 0.001*"cung_cap" + 0.001*"design" + 0.001*"xay_dung" + 0.001*"web" + 0.001*"thanh_phan" + 0.001*"trang_web" + 0.001*"thread" + 0.001*"css"
# INFO : topic #5 (0.010): 0.001*"thong_minh" + 0.001*"ta" + 0.001*"tri" + 0.001*"con_nguoi" + 0.001*"co" + 0.001*"may" + 0.001*"nghien_cuu" + 0.001*"kha_nang" + 0.001*"he_thong" + 0.001*"tri_tue"
# INFO : topic #33 (0.010): 0.001*"khoi_nghiep" + 0.001*"kinh_doanh" + 0.001*"ta" + 0.001*"agile" + 0.001*"phat_trien" + 0.001*"du_an" + 0.001*"huong" + 0.001*"api" + 0.001*"đoi" + 0.001*"cong_ty"
# INFO : topic #3 (0.010): 0.002*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.001*"đi" + 0.001*"thanh_cong" + 0.001*"giup" + 0.001*"lam_viec" + 0.001*"mua" + 0.001*"von" + 0.001*"ke_hoach" + 0.001*"cong_viec"
# INFO : topic #45 (0.010): 0.092*"marketing" + 0.045*"agile" + 0.023*"hang" + 0.021*"ap_dung" + 0.020*"sprint" + 0.013*"stories" + 0.013*"user" + 0.012*"scrum" + 0.012*"hoat_đong" + 0.010*"tuan"
# INFO : topic #29 (0.010): 0.001*"ket_noi" + 0.001*"server" + 0.001*"user" + 0.001*"khoi" + 0.001*"code" + 0.001*"express" + 0.001*"cai" + 0.001*"file" + 0.001*"đoan" + 0.001*"thu_muc"
# INFO : topic #55 (0.010): 0.002*"khoi_nghiep" + 0.001*"kinh_doanh" + 0.001*"agile" + 0.001*"phat_trien" + 0.001*"du_an" + 0.001*"san_pham" + 0.001*"cong_ty" + 0.001*"lam_viec" + 0.001*"đau_tu" + 0.001*"huong"
# INFO : topic #12 (0.010): 0.063*"user" + 0.055*"stories" + 0.036*"khach_hang" + 0.032*"agile" + 0.028*"marketing" + 0.028*"san_pham" + 0.020*"ghi" + 0.020*"noi_dung" + 0.020*"personas" + 0.016*"giai_quyet"
# INFO : topic #59 (0.010): 0.003*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.001*"phat_trien" + 0.001*"kha_nang" + 0.001*"du_an" + 0.001*"đoi" + 0.001*"thong_minh" + 0.001*"muc_tieu" + 0.001*"đau_tu" + 0.001*"agile"
# INFO : topic #20 (0.010): 0.027*"lam_viec" + 0.020*"khoi_nghiep" + 0.017*"thanh_cong" + 0.017*"giau_co" + 0.017*"suy_nghi" + 0.013*"doanh_nghiep" + 0.013*"quan_ly" + 0.013*"đuong" + 0.013*"ban_tay_trang" + 0.013*"startup"
# INFO : topic #48 (0.010): 0.032*"trang_web" + 0.027*"web" + 0.027*"thiet_ke" + 0.024*"loi" + 0.021*"ngon_ngu" + 0.021*"kiem_tra" + 0.018*"html" + 0.015*"thu_nghiem" + 0.015*"lap_trinh" + 0.015*"co_ban"
# INFO : topic #10 (0.010): 0.028*"thong_minh" + 0.021*"material" + 0.017*"con_nguoi" + 0.017*"design" + 0.017*"muc_tieu" + 0.014*"nghien_cuu" + 0.011*"kha_nang" + 0.010*"kiem_soat" + 0.010*"he_thong" + 0.010*"thiet_ke"
# INFO : topic #46 (0.010): 0.033*"user" + 0.029*"ket_noi" + 0.024*"khoi" + 0.024*"express" + 0.024*"server" + 0.020*"code" + 0.016*"viet" + 0.016*"api" + 0.016*"file" + 0.016*"đoan"
# INFO : topic #50 (0.010): 0.003*"khoi_nghiep" + 0.003*"du_lich" + 0.002*"kinh_doanh" + 0.002*"đi" + 0.001*"huong" + 0.001*"bui" + 0.001*"ha_long" + 0.001*"mo_rong" + 0.001*"mua" + 0.001*"đo"
# INFO : topic #1 (0.010): 0.002*"thiet_ke" + 0.002*"cung_cap" + 0.002*"trang_web" + 0.002*"bootstrap" + 0.002*"xay_dung" + 0.001*"user" + 0.001*"web" + 0.001*"đap_ung" + 0.001*"bao_gom" + 0.001*"khoi_nghiep"
# [(38,
#   '0.001*"đi" + 0.001*"material" + 0.001*"thiet_ke" + 0.001*"xay_dung" + 0.001*"web" + 0.001*"mua" + 0.001*"chuyen" + 0.001*"du_lich" + 0.001*"design" + 0.001*"trang_web"'),
#  (15,
#   '0.105*"ta" + 0.068*"api" + 0.038*"request" + 0.034*"viet" + 0.023*"contact" + 0.023*"napa" + 0.015*"cau_truc" + 0.015*"model" + 0.015*"response" + 0.011*"khai_bao"'),
#  (41,
#   '0.003*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.001*"thong_minh" + 0.001*"huong" + 0.001*"so_huu" + 0.001*"lam_viec" + 0.001*"cong_ty" + 0.001*"tien" + 0.001*"y_tuong" + 0.001*"quy"'),
#  (43,
#   '0.055*"du_lich" + 0.054*"đi" + 0.028*"chuyen" + 0.022*"mua" + 0.017*"bui" + 0.016*"kinh_nghiem" + 0.015*"the" + 0.013*"xe" + 0.012*"thong_tin" + 0.011*"thuoc"'),
#  (28,
#   '0.001*"agile" + 0.001*"marketing" + 0.001*"ha_long" + 0.001*"đi" + 0.001*"du_lich" + 0.001*"đoi" + 0.001*"long" + 0.001*"hang" + 0.001*"ha" + 0.001*"du_an"'),
#  (35,
#   '0.001*"thiet_ke" + 0.001*"material" + 0.001*"cung_cap" + 0.001*"design" + 0.001*"xay_dung" + 0.001*"web" + 0.001*"thanh_phan" + 0.001*"trang_web" + 0.001*"thread" + 0.001*"css"'),
#  (5,
#   '0.001*"thong_minh" + 0.001*"ta" + 0.001*"tri" + 0.001*"con_nguoi" + 0.001*"co" + 0.001*"may" + 0.001*"nghien_cuu" + 0.001*"kha_nang" + 0.001*"he_thong" + 0.001*"tri_tue"'),
#  (33,
#   '0.001*"khoi_nghiep" + 0.001*"kinh_doanh" + 0.001*"ta" + 0.001*"agile" + 0.001*"phat_trien" + 0.001*"du_an" + 0.001*"huong" + 0.001*"api" + 0.001*"đoi" + 0.001*"cong_ty"'),
#  (3,
#   '0.002*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.001*"đi" + 0.001*"thanh_cong" + 0.001*"giup" + 0.001*"lam_viec" + 0.001*"mua" + 0.001*"von" + 0.001*"ke_hoach" + 0.001*"cong_viec"'),
#  (45,
#   '0.092*"marketing" + 0.045*"agile" + 0.023*"hang" + 0.021*"ap_dung" + 0.020*"sprint" + 0.013*"stories" + 0.013*"user" + 0.012*"scrum" + 0.012*"hoat_đong" + 0.010*"tuan"'),
#  (29,
#   '0.001*"ket_noi" + 0.001*"server" + 0.001*"user" + 0.001*"khoi" + 0.001*"code" + 0.001*"express" + 0.001*"cai" + 0.001*"file" + 0.001*"đoan" + 0.001*"thu_muc"'),
#  (55,
#   '0.002*"khoi_nghiep" + 0.001*"kinh_doanh" + 0.001*"agile" + 0.001*"phat_trien" + 0.001*"du_an" + 0.001*"san_pham" + 0.001*"cong_ty" + 0.001*"lam_viec" + 0.001*"đau_tu" + 0.001*"huong"'),
#  (12,
#   '0.063*"user" + 0.055*"stories" + 0.036*"khach_hang" + 0.032*"agile" + 0.028*"marketing" + 0.028*"san_pham" + 0.020*"ghi" + 0.020*"noi_dung" + 0.020*"personas" + 0.016*"giai_quyet"'),
#  (59,
#   '0.003*"khoi_nghiep" + 0.002*"kinh_doanh" + 0.001*"phat_trien" + 0.001*"kha_nang" + 0.001*"du_an" + 0.001*"đoi" + 0.001*"thong_minh" + 0.001*"muc_tieu" + 0.001*"đau_tu" + 0.001*"agile"'),
#  (20,
#   '0.027*"lam_viec" + 0.020*"khoi_nghiep" + 0.017*"thanh_cong" + 0.017*"giau_co" + 0.017*"suy_nghi" + 0.013*"doanh_nghiep" + 0.013*"quan_ly" + 0.013*"đuong" + 0.013*"ban_tay_trang" + 0.013*"startup"'),
#  (48,
#   '0.032*"trang_web" + 0.027*"web" + 0.027*"thiet_ke" + 0.024*"loi" + 0.021*"ngon_ngu" + 0.021*"kiem_tra" + 0.018*"html" + 0.015*"thu_nghiem" + 0.015*"lap_trinh" + 0.015*"co_ban"'),
#  (10,
#   '0.028*"thong_minh" + 0.021*"material" + 0.017*"con_nguoi" + 0.017*"design" + 0.017*"muc_tieu" + 0.014*"nghien_cuu" + 0.011*"kha_nang" + 0.010*"kiem_soat" + 0.010*"he_thong" + 0.010*"thiet_ke"'),
#  (46,
#   '0.033*"user" + 0.029*"ket_noi" + 0.024*"khoi" + 0.024*"express" + 0.024*"server" + 0.020*"code" + 0.016*"viet" + 0.016*"api" + 0.016*"file" + 0.016*"đoan"'),
#  (50,
#   '0.003*"khoi_nghiep" + 0.003*"du_lich" + 0.002*"kinh_doanh" + 0.002*"đi" + 0.001*"huong" + 0.001*"bui" + 0.001*"ha_long" + 0.001*"mo_rong" + 0.001*"mua" + 0.001*"đo"'),
#  (1,
#   '0.002*"thiet_ke" + 0.002*"cung_cap" + 0.002*"trang_web" + 0.002*"bootstrap" + 0.002*"xay_dung" + 0.001*"user" + 0.001*"web" + 0.001*"đap_ung" + 0.001*"bao_gom" + 0.001*"khoi_nghiep"')]

# %%
import numpy as np
doc_topic_dist = np.array(
    [[tup[1] for tup in lst] for lst in lda_model[corpus]]
)

# %%
doc_topic_dist
# Out:
# array([[2.1948139e-05, 2.1948139e-05, 2.1948139e-05, ..., 2.1948139e-05,
#         2.1948139e-05, 9.9600387e-01],
#        [7.8344319e-06, 7.8344319e-06, 7.8344319e-06, ..., 7.8344319e-06,
#         7.8344319e-06, 7.8344319e-06],
#        [3.5636604e-05, 3.5636604e-05, 3.5636604e-05, ..., 3.5636604e-05,
#         3.5636604e-05, 3.5636604e-05],
#        ...,
#        [3.5507757e-05, 3.5507757e-05, 3.5507757e-05, ..., 3.5507757e-05,
#         3.5507757e-05, 3.5507757e-05],
#        [2.5599826e-05, 2.5599826e-05, 2.5599826e-05, ..., 2.5599826e-05,
#         2.5599826e-05, 2.5599826e-05],
#        [2.5599824e-05, 2.5599824e-05, 2.5599824e-05, ..., 2.5599824e-05,
#         2.5599824e-05, 2.5599824e-05]], dtype=float32)

# %%
import joblib

# %%
joblib.dump(doc_topic_dist, '../models/doc_topic_dist.dat')
# Out:
# ['../models/doc_topic_dist.dat']
