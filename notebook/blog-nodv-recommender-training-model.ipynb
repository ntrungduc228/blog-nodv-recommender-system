# %%
import requests
from time import sleep

from tqdm import tqdm
import pymongo
from pymongo import MongoClient

import gensim
from gensim.utils import simple_preprocess

# %%
import logging
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO

# %%
import sys
sys.path.append('../')
from src import settings

from src.utils import editorJs_data_to_text
import json

# %%
client = MongoClient(settings.MONGODB_SETTINGS['host'])
db = client[settings.MONGODB_SETTINGS['db']]
col = db[settings.MONGODB_SETTINGS['collection']]

# %%
posts = col.find()

# %%
for i, post in enumerate(posts):
    print(post['title'])
    if i == 12: break
# Out:
# ĐỒ ÁN THIẾT KẾ WEBSITE BLOG SITE
# Regular Expression trong Javascript
# Các bài tập java cơ bản
# Những câu hỏi lập trình khi pv (2): bài toán ATM
# Ví dụ sắp xếp nổi bọt với Java
# Chương trình lọc thư rác bằng Java, code ví dụ
# Đọc ghi file Excel trong Java sử dụng Apache POI
# THREAD AND THREAD POOLS IN JAVA
# Sử dụng CountDownLatch trong Java
# Multithreading: Java Synchronized Blocks
# Understand synchronized and improve lock performance in Java
# Front-End Web Developers
# Material Design for Web Design

# %%
posts = col.find()
test_post = next(posts)

# %%
raw_content = test_post['content']
content = editorJs_data_to_text(json.loads(raw_content))

# %%
print(content)
# Out:
# đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đí ...

# %%
for i, post in tqdm(enumerate(col.find()), total=col.count_documents({})):
    try:
        col.update_one({"_id": post["_id"]}, {"$set": {"idrs": i}})
        pp_content = editorJs_data_to_text(json.loads(post['content']))
        col.update_one({"_id": post["_id"]}, {"$set": {"pp_content": pp_content}})
    except Exception as e:
        print(e)
        continue
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 177/177 [00:30<00:00,  5.74it/s]

# %%
client = MongoClient(settings.MONGODB_SETTINGS['host'])
db = client[settings.MONGODB_SETTINGS['db']]
col = db[settings.MONGODB_SETTINGS['collection']]

posts = col.find()
test_post = next(posts)

# %%
test_post['pp_content']
# Out:
# 'đồ_án thiết_kế website blog site đầua toàn nhân_loại sống thời_đại bùng_nổ thông_tin thế_kỷ con_người khắp trái_đất kết_bạn lo_ngại hạn_chế không_gian thông_qua mạng internet toàn_cầu thông_tin con_người trao_đổi internet thông_tin đa_dạng phong_phú con_người bạn_bè mạng xã_hội chuyên_biệt giúp giao_lưu kết_bạn trao_đổi thông_tin nắm_bắt nhu_cầu cung_cấp dịch_vụ web ra_đời hình_thức mạng xã_hội blog bàn_cãi cần_thiết hữu_dụng blog chứng_minh quen_thuộc blog yahoo wordpress … mạng xã_hội nổi_tiếng giúp internet thỏa_mãn nhu_cầu thông_tin kết_bạn nghiên_cứu môn hệ_thống thông_minh ứng_dụng kiến_thức học tác_giả đi_sâu đề_tài blog mục_đích website cung_cấp dịch_vụ blog hữu_ích đông_đảo internet kiến_thức hạn_chế đề_tài thiếu_sót kính mong thầy xem_xét góp_ý giúp hoàn_thiện báo_cáo chương tổng_quan đề_tài đề_tài website blog share blog nodv đăng kết_nối đề_tài blog ngày_nay blog thành_phần website blog website thông_tin nhật_ký trực_tuyến trình_bày viết đầu viết blog thể_hiện chủ_quan chủ_đề viết ngày_nay blog blogger viết blog website kinh_doanh để_ý website tin_tức blog tập_hợp viết chủ_đề sản_phẩm doanh_nghiệp blog viết nằm đầu thông_tin chi_tiết tiêu_đề_bài viết viết viếtblog kinh_doanh kênh tiếp_thị giúp tăng_trưởng kinh_doanh viết blog website kinh_doanh chiến_thuật tiếp_thị blog giúp doanh_nghiệp hiển_thị trực_tuyến nắm_bắt lợi_ích blog quyết_định xây_dựng website blog thoải_mái cuộc_sống chủ_đề coi nhật_ký online giải_đáp thắc_mắc đối_tượng phạm_vi nghiên_cứu đối_tượng nghiên_cứu phát_triển kinh_tế xã_hội cuộc_sống hiện_đại công_nghệ phát_triển len_lỏi lĩnh_vực đời_sống con_người lĩnh_vực blog cuộc_sống chủ_đề cạnh blog đóng vai_trò website lợi_ích doanh_nghiệp nắm_bắt website blog nodv ra_đời phục_vụ độc_giả blogger phạm_vi nghiên_cứu website hướng nhu_cầu blog cuộc_sống chủ_đề doanh_nghiệp blog mục_đích tiếp_thị phương_pháp nghiên_cứu học_hỏi lý_thuyết công_nghệ spring boot mongodatabase compass nodejs react websocket thông_qua tài_liệu mạng khóa học internettham_khảo nghiệp_vụ làm_việc website medium wordpress joomla … chương cơ_sở lý_thuyết giới_thiệu công_cụ ngôn_ngữ xây_dựng website công_cụ intellij idea phần_mềm intellij idea sản_phẩm nổi_tiếng jetbrains giải_thưởng phần_mềm thiết_kế cải_tiến năng_suất phát_triển intellij idea cung_cấp trình soạn_thảo thông_minh trình phân_tích mã tập_hợp mạnh_mẽ refactorings loạt ngôn_ngữ lập_trình khuôn_khổ công_nghệ sẵn_sàng lợi_ích phần_mềm intellij idea phép phát_triển phát_triển quản_lý tác vụ thông thườngcho phép viết gỡ_lỗi tái_cấu_trúc kiểm_tra mã ảnh hưởngxử lý liền mạch cơ_sở mã hỗn_hợp java ruby groovy python scalatự động duy_trì chất_lượng mãtheo dõi sửa lỗi cấp_độ – câu kiến_trúc tổng_thểtạo mã “ sạch ” nhanh_chóng mã ngắn nhấtđược thiết_kế làm_việc quy_mô – doanh nghiệphỗ trợ ngôn_ngữ công_nghệ framework chínhlàm hệ_thống điều_khiển phiên_bản phổ_biến teamcity server tích_hợp liên_tục visual code visual studio code ứng_dụng phép biên_tập soạn_thảo đoạn code xây_dựng thiết_kế website nhanh_chóng visual studio code viết tắt vs code trình soạn_thảo vận_hành mượt_mà nền_tảng windows macos linux vs code khả_năng tương_thích thiết_bị cấu_hình tầm trung dễ_dàng visual studio code đa_dạng chức_năng debug đi kèm git syntax highlighting hoàn_thành mã thông_minh snippets khả_năng cải_tiến mã ưu_điểm nổi_bật visual code đa_dạng ngôn_ngữ lập_trình giúp thỏa_sức sáng_tạo html css javascript c … ngôn_ngữ giao_diện tối_giản thân_thiện giúp lập_trình_viên dễ_dàng định_hình nội_dung tiện_ích mở_rộng đa_dạng phong_phú tích_hợp tính_năng tính_năng bảo_mật git khả_năng tăng_tốc vòng lặp_debug … đơn_giản_hóa quản_lý code hệ_thống html css html hypertext markup language ngôn_ngữ đánh_dấu thiết_kế trang_web nghĩa_là mẩu thông_tin trình_bày world wide_web css cascading style sheets định_nghĩa hiển_thị tài_liệu html css hữu_ích thiết_kế web giúp thiết_kế dễ_dàng áp_đặt phong_cách thiết_kế page website nhanh_chóng đồng_bộ react js reactjs thư_viện javascript mã phát_triển facebook ra_mắt mục_đ ...

# %%
def make_sentences():
    for post in col.find():
        yield post['pp_content'] # lấy thuộc tính pp_content của từng document trong post collection

# %%
def make_texts_corpus(sentences):
    for sentence in sentences:
        yield simple_preprocess(sentence, deacc=True) # tách chữ cái của từng pp_content
#         yield [word for word in sentence.split()]

# %%
import itertools

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)
id2word = gensim.corpora.Dictionary(sentences)
# Out:
# INFO : adding document #0 to Dictionary<0 unique tokens: []>
# INFO : built Dictionary<8854 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 177 documents (total 92213 corpus positions)
# INFO : Dictionary lifecycle event {'msg': "built Dictionary<8854 unique tokens: ['account', 'actor', 'allocation', 'amazon', 'an']...> from 177 documents (total 92213 corpus positions)", 'datetime': '2023-01-01T08:28:06.207090', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
id2word.token2id
# Out:
# {'account': 0,
#  'actor': 1,
#  'allocation': 2,
#  'amazon': 3,
#  'an': 4,
#  'analysis': 5,
#  'anh': 6,
#  'anhđuong': 7,
#  'ap_đat': 8,
#  'api': 9,
#  'application': 10,
#  'avatar': 11,
#  'axios': 12,
#  'bai': 13,
#  'bai_bo': 14,
#  'bai_toan': 15,
#  'ban_be': 16,
#  'ban_cai': 17,
#  'ban_chat': 18,
#  'banfacebook': 19,
#  'bang': 20,
#  'bannetflix': 21,
#  'banxoa': 22,
#  'bao_cao': 23,
#  'bao_gom': 24,
#  'bao_mat': 25,
#  'bao_phu': 26,
#  'bao_ve': 27,
#  'baoluu': 28,
#  'bat_kha_thi': 29,
#  'bayes': 30,
#  'bayesian': 31,
#  'bebo': 32,
#  'bia': 33,
#  'bich': 34,
#  'bien': 35,
#  'bien_tap': 36,
#  'bien_đoi': 37,
#  'bieu_dien': 38,
#  'bieu_thi': 39,
#  'bieu_tuong': 40,
#  'big': 41,
#  'binh': 42,
#  'binh_luan': 43,
#  'bio': 44,
#  'biopost': 45,
#  'blog': 46,
#  'blogger': 47,
#  'bo_nho': 48,
#  'bookmark': 49,
#  'boolean': 50,
#  'boot': 51,
#  'bought': 52,
#  'bung_no': 53,
#  'business': 54,
#  'ca_si': 55,
#  'cai_thien': 56,
#  'cai_tien': 57,
#  'can_thiet': 58,
#  'canh': 59,
#  'canh_sat': 60,
#  'cap': 61,
#  'cap_đo': 62,
#  'cascading': 63,
#  'case': 64,
#  'cau': 65,
#  'cau_hinh': 66,
#  'cau_truc': 67,
#  'cauxoa': 68,
#  'cham': 69,
#  'chan': 70,
#  'chat_luong': 71,
#  'chay': 72,
#  'che_đo': 73,
#  'chi_thuc_su': 74,
#  'chi_tiet': 75,
#  'chia': 76,
#  'chien_luoc': 77,
#  'chien_thuat': 78,
#  'chinh_sua': 79,
#  'chinh_xac': 80,
#  'chinhlam': 81,
#  'chong': 82,
#  'chu_bai': 83,
#  'chu_quan': 84,
#  'chu_đe': 85,
#  'chua': 86,
#  'chuan_hoa': 87,
#  'chuc_nang': 88,
#  'chung_khoan': 89,
#  'chung_minh': 90,
#  'chuoi': 91,
#  'chuong': 92,
#  'chuong_trinh': 93,
#  'chuyen_biet': 94,
#  'chuyen_hoa': 95,
#  'chuyen_huong': 96,
#  'chuyen_tiep': 97,
#  'chuyen_đoi': 98,
#  'classification': 99,
#  'click': 100,
#  'client': 101,
#  'clip': 102,
#  'cloud': 103,
#  'co_ban': 104,
#  'co_le': 105,
#  'co_phieu': 106,
#  'co_so': 107,
#  'co_đinh': 108,
#  'code': 109,
#  'codebase': 110,
#  'coi': 111,
#  'collaborative': 112,
#  'collection': 113,
#  'comment': 114,
#  'compass': 115,
#  'component': 116,
#  'con_nguoi': 117,
#  'cong_cu': 118,
#  'cong_khai': 119,
#  'cong_nghe': 120,
#  'cong_ty': 121,
#  'cong_viec': 122,
#  'congthat': 123,
#  'content': 124,
#  'contentbased': 125,
#  'corpora': 126,
#  'corpus': 127,
#  'corpuslevel': 128,
#  'createddate': 129,
#  'csdl': 130,
#  'css': 131,
#  'cung_cap': 132,
#  'cuoc_song': 133,
#  'dan': 134,
#  'dang': 135,
#  'danh_sach': 136,
#  'danvoi': 137,
#  'data': 138,
#  'dataset': 139,
#  'ddd': 140,
#  'de_dang': 141,
#  'debug': 142,
#  'degree': 143,
#  'dependency': 144,
#  'di_đong': 145,
#  'diagram': 146,
#  'dich_vu': 147,
#  'dirichlet': 148,
#  'discriminant': 149,
#  'dm': 150,
#  'doanh': 151,
#  'doanh_nghiep': 152,
#  'doanh_thu': 153,
#  'document': 154,
#  'documentlevel': 155,
#  'doi': 156,
#  'doitim': 157,
#  'doiviet': 158,
#  'du_an': 159,
#  'du_bao': 160,
#  'du_lieu': 161,
#  'du_đoan': 162,
#  'dua': 163,
#  'dung': 164,
#  'duy_tri': 165,
#  'editor': 166,
#  'email': 167,
#  'facebook': 168,
#  'false': 169,
#  'file': 170,
#  'filtering': 171,
#  'follow': 172,
#  'followers': 173,
#  'following': 174,
#  'followings': 175,
#  'follwers': 176,
#  'framework': 177,
#  'frequently': 178,
#  'gan': 179,
#  'gender': 180,
#  'ghi_chu': 181,
#  'gia': 182,
#  'gia_đinh': 183,
#  'giai_phap': 184,
#  'giai_thuong': 185,
#  'giai_đap': 186,
#  'giam_sat': 187,
#  'giao_dien': 188,
#  'giao_luu': 189,
#  'gibbs': 190,
#  'gioi_thieu': 191,
#  'gioi_tinh': 192,
#  'git': 193,
#  'github': 194,
#  'giup': 195,
#  'go': 196,
#  'go_loi': 197,
#  'goi': 198,
#  'goi_y': 199,
#  'google': 200,
#  'gop_y': 201,
#  'groovy': 202,
#  'gui': 203,
#  'hai': 204,
#  'han_che': 205,
#  'hang': 206,
#  'hanh_vi': 207,
#  'hanh_đong': 208,
#  'hat': 209,
#  'he': 210,
#  'he_thong': 211,
#  'hien': 212,
#  'hien_thi': 213,
#  'hien_tuong': 214,
#  'hien_đai': 215,
#  'hierarchical': 216,
#  'hieu_nang': 217,
#  'hieu_qua': 218,
#  'hieu_suat': 219,
#  'highlighting': 220,
#  'hinh': 221,
#  'hinh_anh': 222,
#  'hinh_su': 223,
#  'hinh_thuc': 224,
#  'hoa': 225,
#  'hoan_chinh': 226,
#  'hoan_thanh': 227,
#  'hoan_thien': 228,
#  'hoat_đong': 229,
#  'hoc': 230,
#  'hoc_hoi': 231,
#  'hon_hop': 232,
#  'hontu': 233,
#  'html': 234,
#  'htmlvi': 235,
#  'http': 236,
#  'huan_luyen': 237,
#  'hung': 238,
#  'hung_thu': 239,
#  'huong': 240,
#  'huongxu': 241,
#  'huu_dung': 242,
#  'huu_han': 243,
#  'huu_ich': 244,
#  'huy': 245,
#  'hypertext': 246,
#  'id': 247,
#  'idea': 248,
#  'index': 249,
#  'intellij': 250,
#  'internet': 251,
#  'isactive': 252,
#  'ispublish': 253,
#  'isread': 254,
#  'it': 255,
#  'item': 256,
#  'items': 257,
#  'java': 258,
#  'javascript': 259,
#  'jetbrains': 260,
#  'jetty': 261,
#  'join': 262,
#  'joomla': 263,
#  'js': 264,
#  'json': 265,
#  'kem': 266,
#  'kenh': 267,
#  'ket': 268,
#  'ket_ban': 269,
#  'ket_noi': 270,
#  'ket_qua': 271,
#  'key': 272,
#  'kha_nang': 273,
#  'khach_hang': 274,
#  'khap': 275,
#  'kho': 276,
#  'khoa': 277,
#  'khoanbai': 278,
#  'khoi': 279,
#  'khong_gian': 280,
#  'khuon_kho': 281,
#  'khuyen_nghi': 282,
#  'kich_co': 283,
#  'kiem': 284,
#  'kiem_tra': 285,
#  'kiemcac': 286,
#  'kiemfacebook': 287,
#  'kien_thuc': 288,
#  'kien_truc': 289,
#  'kieu': 290,
#  'kinh': 291,
#  'kinh_doanh': 292,
#  'kinh_lup': 293,
#  'kinh_te': 294,
#  'ky': 295,
#  'ky_thuat': 296,
#  'ky_tu': 297,
#  'lam_viec': 298,
#  'lan': 299,
#  'language': 300,
#  'lap': 301,
#  'lap_debug': 302,
#  'lap_trinh': 303,
#  'lap_trinh_vien': 304,
#  'lapnhung': 305,
#  'latent': 306,
#  'lda': 307,
#  'learning': 308,
#  'len_loi': 309,
#  'level': 310,
#  'lich_su': 311,
#  'lien': 312,
#  'lien_tuc': 313,
#  'lieu': 314,
#  'lieuhinh': 315,
#  'likes': 316,
#  'linear': 317,
#  'linh_hoat': 318,
#  'linh_vuc': 319,
#  'link': 320,
#  'linux': 321,
#  'lo_ngai': 322,
#  'loat': 323,
#  'loi': 324,
#  'loi_ich': 325,
#  'loi_nhuan': 326,
#  'loi_the': 327,
#  'lsa': 328,
#  'lua_chon': 329,
#  'luong': 330,
#  'luot': 331,
#  'luu': 332,
#  'luu_giu': 333,
#  'luu_tru': 334,
#  'ly': 335,
#  'ly_thuyet': 336,
#  'lyket': 337,
#  'ma': 338,
#  'mac_đinh': 339,
#  'mach': 340,
#  'machine': 341,
#  'macos': 342,
#  'mai': 343,
#  'make': 344,
#  'mang': 345,
#  'manh_me': 346,
#  'marketing': 347,
#  'markup': 348,
#  'mat_khau': 349,
#  'matheo': 350,
#  'matkhi': 351,
#  'mau': 352,
#  'maven': 353,
#  'may': 354,
#  'may_tinh': 355,
#  'medium': 356,
#  'menu': 357,
#  'mien': 358,
#  'mieu_ta': 359,
#  'minh_hoa': 360,
#  'ml': 361,
#  'mo_hinh': 362,
#  'mo_hinh_hoa': 363,
#  'mo_rong': 364,
#  'mo_ta': 365,
#  'modal': 366,
#  'model': 367,
#  'modeling': 368,
#  'module': 369,
#  'mon': 370,
#  'mong': 371,
#  'mong_muon': 372,
#  'mongodatabase': 373,
#  'mongodb': 374,
#  'mua': 375,
#  'muc': 376,
#  'muc_tu': 377,
#  'muc_đich': 378,
#  'muc_đo': 379,
#  'muot_ma': 380,
#  'nam': 381,
#  'nam_bat': 382,
#  'nang': 383,
#  'nang_suat': 384,
#  'native': 385,
#  'nen_tang': 386,
#  'neu': 387,
#  'ngan': 388,
#  'ngay_nay': 389,
#  'nghia_la': 390,
#  'nghiem': 391,
#  'nghien_cuu': 392,
#  'nghiep_vu': 393,
#  'nghiepho': 394,
#  'ngoai_tru': 395,
#  'ngon_ngu': 396,
#  'nguoi': 397,
#  'nhan': 398,
#  'nhan_loai': 399,
#  'nhan_tao': 400,
#  'nhanh_chong': 401,
#  'nhap': 402,
#  'nhap_noi_dung': 403,
#  'nhapchinh': 404,
#  'nhat_ky': 405,
#  'nhatđuoc': 406,
#  'nhiem_vu': 407,
#  'nhu': 408,
#  'nhu_cau': 409,
#  'nickname': 410,
#  'nodejs': 411,
#  'nodv': 412,
#  'noi_bat': 413,
#  'noi_dung': 414,
#  'noi_tai': 415,
#  'noi_tieng': 416,
#  'noo': 417,
#  'notat': 418,
#  'nu': 419,
#  'nut': 420,
#  'oauth': 421,
#  'object': 422,
#  'objectid': 423,
#  'observe': 424,
#  'of': 425,
#  'on': 426,
#  'online': 427,
#  'page': 428,
#  'parameter': 429,
#  'password': 430,
#  'pha_tron': 431,
#  'pham_vi': 432,
#  'phan_biet': 433,
#  'phan_bo': 434,
#  'phan_hoi': 435,
#  'phan_loai': 436,
#  'phan_mem': 437,
#  'phan_phoi': 438,
#  'phan_ra': 439,
#  'phan_tich': 440,
#  'phan_xu': 441,
#  'phat_trien': 442,
#  'phep': 443,
#  'phien_ban': 444,
#  'phim': 445,
#  'pho_bien': 446,
#  'phong_cach': 447,
#  'phong_phu': 448,
#  'phuc': 449,
#  'phuc_tap': 450,
#  'phuc_vu': 451,
#  'phuoc': 452,
#  'phuong': 453,
#  'phuong_phap': 454,
#  'plsa': 455,
#  'post': 456,
#  'postid': 457,
#  'preference': 458,
#  'prior': 459,
#  'project': 460,
#  'provider': 461,
#  'providerid': 462,
#  'publish': 463,
#  'python': 464,
#  'qua_khu': 465,
#  'quan_he': 466,
#  'quan_ly': 467,
#  'quang_cao': 468,
#  'quen_thuoc': 469,
#  'quy_mo': 470,
#  'quy_đinh': 471,
#  'quyen': 472,
#  'quyet_đinh': 473,
#  'ra_mat': 474,
#  'ra_đoi': 475,
#  'rangkhong': 476,
#  'react': 477,
#  'reactjs': 478,
#  'receiverid': 479,
#  'recommend': 480,
#  'recommendation': 481,
#  'recommended': 482,
#  'recommender': 483,
#  'refactorings': 484,
#  'replyid': 485,
#  'request': 486,
#  'response': 487,
#  'roi_rac': 488,
#  'role': 489,
#  'rong': 490,
#  'rong_rai': 491,
#  'rongviec': 492,
#  'ruby': 493,
#  'rut': 494,
#  'sach': 495,
#  'sai_lech': 496,
#  'sampling': 497,
#  'san': 498,
#  'san_pham': 499,
#  'san_sang': 500,
#  'sang_tao': 501,
#  'sap_xep': 502,
#  'sau': 503,
#  'scalatu': 504,
#  'schema': 505,
#  'senderid': 506,
#  'server': 507,
#  'setting': 508,
#  'share': 509,
#  'sheets': 510,
#  'sidebar': 511,
#  'similarity': 512,
#  'simple': 513,
#  'single': 514,
#  'sinh': 515,
#  'sinh_thai': 516,
#  'site': 517,
#  'snippets': 518,
#  'so_luong': 519,
#  'so_thich': 520,
#  'so_đo': 521,
#  'soan_thao': 522,
#  'song': 523,
#  'spa': 524,
#  'sparse': 525,
#  'spring': 526,
#  'sql': 527,
#  'starter': 528,
#  'string': 529,
#  'stt': 530,
#  'studio': 531,
#  'style': 532,
#  'sua': 533,
#  'subtitle': 534,
#  'supervised': 535,
#  'suy_dien': 536,
#  'suy_luan': 537,
#  'syntax': 538,
#  'system': 539,
#  'systems': 540,
#  'ta': 541,
#  'tab': 542,
#  'tac': 543,
#  'tac_gia': 544,
#  'tai': 545,
#  'tai_cau_truc': 546,
#  'tai_khoan': 547,
#  'tai_lieu': 548,
#  'tam': 549,
#  'tang_toc': 550,
#  'tang_truong': 551,
#  'tap': 552,
#  'tap_hop': 553,
#  'tapnoi': 554,
#  'tat': 555,
#  'teamcity': 556,
#  'text': 557,
#  'thac_mac': 558,
#  'tham_so': 559,
#  'than_thien': 560,
#  'thanh': 561,
#  'thanh_cong': 562,
#  'thanh_phan': 563,
#  'thao_tac': 564,
#  'that_bai': 565,
#  'thay': 566,
#  'the_gioi': 567,
#  'the_hien': 568,
#  'the_ky': 569,
#  'theo_doi': 570,
#  'theta': 571,
#  'thichkhi': 572,
#  'thiet_bi': 573,
#  'thiet_ke': 574,
#  'thietkhong': 575,
#  'thietsu_dung': 576,
#  'thieu_sot': 577,
#  'thinh': 578,
#  'thoa_man': 579,
#  'thoa_suc': 580,
#  'thoai_mai': 581,
#  'thoi': 582,
#  'thoi_đai': 583,
#  'thong': 584,
#  'thong_bao': 585,
#  'thong_minh': 586,
#  'thong_qua': 587,
#  'thong_thuong': 588,
#  'thong_tin': 589,
#  'threelevel': 590,
#  'thu_thap': 591,
#  'thu_vien': 592,
#  'thua': 593,
#  'thuan_tien': 594,
#  'thuat_toan': 595,
#  'thuat_toan_hoc': 596,
#  'thuc': 597,
#  'thuc_hien_tai': 598,
#  'thuc_the': 599,
#  'thumbnail': 600,
#  'thuong': 601,
#  'thuong_mai': 602,
#  'thuongcho': 603,
#  'thutheo': 604,
#  'tich_hop': 605,
#  'tiem_nang': 606,
#  'tien_ich': 607,
#  'tien_tien': 608,
#  'tien_trinh': 609,
#  'tieng': 610,
#  'tiep_can': 611,
#  'tiep_thi': 612,
#  'tieu_đe': 613,
#  'tieu_đe_bai': 614,
#  'tim_kiem': 615,
#  'timeread': 616,
#  'tin_hieu': 617,
#  'tin_nhiem': 618,
#  'tin_tuc': 619,
#  'tinh_nang': 620,
#  'tinh_toan': 621,
#  'title': 622,
#  'toan': 623,
#  'toan_bo': 624,
#  'toan_cau': 625,
#  'toan_the': 626,
#  'together': 627,
#  'toi_gian': 628,
#  'toi_uu_hoa': 629,
#  'tomcat': 630,
#  'tong_quan': 631,
#  'tong_quat': 632,
#  'tong_thetao': 633,
#  'topic': 634,
#  'topics': 635,
#  'tra_loi': 636,
#  'trai': 637,
#  'trai_đat': 638,
#  'tran': 639,
#  'trang': 640,
#  'trang_chu': 641,
#  'trang_thai': 642,
#  'trang_web': 643,
#  'trao_đoi': 644,
#  'tren': 645,
#  'trenđang': 646,
#  'tri_tue': 647,
#  'trien_khai': 648,
#  'trinh': 649,
#  'trinh_bay': 650,
#  'trinh_duyet': 651,
#  'tro': 652,
#  'tro_nen': 653,
#  'tron': 654,
#  'trong': 655,
#  'truc_tuyen': 656,
#  'true': 657,
#  'trung': 658,
#  'truong': 659,
#  'truy': 660,
#  'truy_cap': 661,
#  'tu_khoa': 662,
#  'tu_vung': 663,
#  'tu_đien': 664,
#  'tu_đong': 665,
#  'tuan': 666,
#  'tuc': 667,
#  'tuc_la': 668,
#  'tuoi_đoi': 669,
#  'tuong_lai': 670,
#  'tuong_quan': 671,
#  'tuong_thich': 672,
#  'tuong_tu': 673,
#  'tuong_ung': 674,
#  'tuong_đong': 675,
#  'tuy': 676,
#  'tv': 677,
#  'type': 678,
#  'ui': 679,
#  'undertow': 680,
#  'ung': 681,
#  'ung_dung': 682,
#  'universal': 683,
#  'unsupervised': 684,
#  'uoc_luong': 685,
#  'use': 686,
#  'usecase': 687,
#  'user': 688,
#  'userid': 689,
#  'useritem': 690,
#  'userlikeids': 691,
#  'username': 692,
#  'users': 693,
#  'userxoa': 694,
#  'uu_điem': 695,
#  'vahoac': 696,
#  'vai_tro': 697,
#  'van': 698,
#  'van_ban': 699,
#  'van_dung': 700,
#  'van_hanh': 701,
#  'variable': 702,
#  'vi_du': 703,
#  'viet': 704,
#  'vietblog': 705,
#  'vietxem': 706,
#  'visual': 707,
#  'vo_cung': 708,
#  'vong': 709,
#  'vs': 710,
#  'vu': 711,
#  'vuong': 712,
#  'vuot_bac': 713,
#  'war': 714,
#  'web': 715,
#  'website': 716,
#  'websocket': 717,
#  'wi': 718,
#  'wide_web': 719,
#  'windows': 720,
#  'word': 721,
#  'wordpress': 722,
#  'world': 723,
#  'xa': 724,
#  'xa_hoi': 725,
#  'xac_nhan': 726,
#  'xac_suat': 727,
#  'xac_thuc': 728,
#  'xac_đinh': 729,
#  'xay_dung': 730,
#  'xem_xet': 731,
#  'xep_hang': 732,
#  'xmlhttprequest': 733,
#  'xoa': 734,
#  'xoa_bai': 735,
#  'xoa_bookmark': 736,
#  'xoa_hien_thi': 737,
#  'xu': 738,
#  'xu_huong': 739,
#  'y_muon': 740,
#  'y_nghia': 741,
#  'y_tuong': 742,
#  'y_đinh': 743,
#  'yahoo': 744,
#  'youtube': 745,
#  'đa_dang': 746,
#  'đac_nhap': 747,
#  'đac_tinh': 748,
#  'đac_trung': 749,
#  'đac_điem': 750,
#  'đai_dien': 751,
#  'đang': 752,
#  'đang_ky': 753,
#  'đang_nhap': 754,
#  'đangchinh': 755,
#  'đanh': 756,
#  'đanh_dau': 757,
#  'đanh_đau': 758,
#  'đau': 759,
#  'đau_ra': 760,
#  'đau_vao': 761,
#  'đaua': 762,
#  'đay_đu': 763,
#  'đe_cap': 764,
#  'đe_tai': 765,
#  'đe_xuat': 766,
#  'đe_y': 767,
#  'đi': 768,
#  'đi_sau': 769,
#  'đien_tu': 770,
#  'đieu_khien': 771,
#  'đinh_dang': 772,
#  'đinh_hinh': 773,
#  'đinh_nghia': 774,
#  'đo': 775,
#  'đo_an': 776,
#  'đoan': 777,
#  'đoc': 778,
#  'đoc_gia': 779,
#  'đoi_khi': 780,
#  'đoi_song': 781,
#  'đoi_tuong': 782,
#  'đoianh': 783,
#  'đon': 784,
#  'đon_gian': 785,
#  'đon_gian_hoa': 786,
#  'đong': 787,
#  'đong_bo': 788,
#  'đong_nghia': 789,
#  'đong_đao': 790,
#  'đođang': 791,
#  'đuocđong': 792,
#  'đuong': 793,
#  'ap_dung': 794,
#  'bao_toan': 795,
#  'bat_buoc': 796,
#  'bi_an': 797,
#  'bieu_thuc': 798,
#  'bo_qua': 799,
#  'bon': 800,
#  'cap_nhat': 801,
#  'chang_han': 802,
#  'cheo': 803,
#  'chi_đinh': 804,
#  'chinh_quy': 805,
#  'chon_lua': 806,
#  'chu': 807,
#  'chu_so': 808,
#  'chubat': 809,
#  'co_nghia': 810,
#  'co_nghia_la': 811,
#  'cong': 812,
#  'constructor': 813,
#  'cu_phap': 814,
#  'dai': 815,
#  'dau': 816,
#  'dau_cham_hoi': 817,
#  'dau_cham_than': 818,
#  'dau_hoi': 819,
#  'day': 820,
#  'dien_ta': 821,
#  'dong': 822,
#  'duoimot': 823,
#  'duy_nhat': 824,
#  'expression': 825,
#  'gach': 826,
#  'gach_ngang': 827,
#  'gia_su': 828,
#  'gioi_han': 829,
#  'gom': 830,
#  'hoi': 831,
#  'in': 832,
#  'keo': 833,
#  'ket_thuc': 834,
#  'khop': 835,
#  'kia': 836,
#  'ky_hieu': 837,
#  'lan_luot': 838,
#  'luu_y': 839,
#  'mac_du': 840,
#  'mat_khac': 841,
#  'mot_chut': 842,
#  'mot_so_nguyen': 843,
#  'naomot': 844,
#  'ngan_can': 845,
#  'ngoac': 846,
#  'ngoac_vuong': 847,
#  'ngoac_đon': 848,
#  'ngoac_đon_tinh': 849,
#  'nguoc_lai': 850,
#  'nhon': 851,
#  'nhu_nhieu': 852,
#  'pattern': 853,
#  'phan_tu': 854,
#  'phu': 855,
#  'phuong_thuc': 856,
#  'ranh_gioi': 857,
#  'regexp': 858,
#  'regular': 859,
#  'rieng_biet': 860,
#  'somot': 861,
#  'tatnghiabat': 862,
#  'thay_vi': 863,
#  'thong_dung': 864,
#  'thuc_thi': 865,
#  'thuoc_tinh': 866,
#  'toan_tu': 867,
#  'trangbat': 868,
#  'truyen': 869,
#  'tumot': 870,
#  'tuong': 871,
#  'tuy_chon': 872,
#  'unicode': 873,
#  'vv': 874,
#  'xay': 875,
#  'đam_bao_mau': 876,
#  'đao_nguoc': 877,
#  'đep_mat': 878,
#  'đung': 879,
#  'đuong_ong': 880,
#  'and': 881,
#  'array': 882,
#  'arrint': 883,
#  'at': 884,
#  'bai_tap': 885,
#  'ban_phim': 886,
#  'bot': 887,
#  'bounds': 888,
#  'bubble': 889,
#  'cacacyahtp': 890,
#  'cach': 891,
#  'chieu': 892,
#  'chon': 893,
#  'cua': 894,
#  'cung': 895,
#  'dao': 896,
#  'duoc': 897,
#  'exception': 898,
#  'for': 899,
#  'goc': 900,
#  'is': 901,
#  'khac': 902,
#  'kich_thuoc': 903,
#  'la': 904,
#  'lathaycacac': 905,
#  'length': 906,
#  'lua': 907,
#  'main': 908,
#  'max': 909,
#  'min': 910,
#  'mot': 911,
#  'nghich': 912,
#  'nghich_đao': 913,
#  'nguoc': 914,
#  'nhapa': 915,
#  'nhieu': 916,
#  'nhung': 917,
#  'noi': 918,
#  'objects': 919,
#  'original': 920,
#  'out': 921,
#  'so_nguyen': 922,
#  'sort': 923,
#  'sorted': 924,
#  'str': 925,
#  'strmot': 926,
#  'tham_chieu': 927,
#  'thaycacac': 928,
#  'this': 929,
#  'thread': 930,
#  'tien': 931,
#  'tri': 932,
#  'tu': 933,
#  'vi': 934,
#  'vua': 935,
#  'vuot': 936,
#  'xuat': 937,
#  'anh_huong': 938,
#  'atm': 939,
#  'atmbai': 940,
#  'bigdecimal': 941,
#  'chu_vi': 942,
#  'chu_y': 943,
#  'class': 944,
#  'co_che': 945,
#  'co_gang': 946,
#  'decimal': 947,
#  'dien_tich': 948,
#  'double': 949,
#  'floatingpoint': 950,
#  'floatingpoints': 951,
#  'format': 952,
#  'giai_quyet': 953,
#  'hom_nay': 954,
#  'javadocs': 955,
#  'jdbc': 956,
#  'khai_bao': 957,
#  'khia_canh': 958,
#  'khong_the_hien': 959,
#  'lam_tron': 960,
#  'maytra': 961,
#  'nguyen': 962,
#  'nhi_phan': 963,
#  'phay': 964,
#  'phep_tinh': 965,
#  'phep_toan': 966,
#  'primitive': 967,
#  'primitivetype': 968,
#  'pv': 969,
#  'thang': 970,
#  'thang_may': 971,
#  'thap_phan': 972,
#  'thich_hop': 973,
#  'tien_le': 974,
#  'tien_te': 975,
#  'toan_hoc': 976,
#  'tru': 977,
#  'xu_ly_tinh_toan': 978,
#  'break': 979,
#  'cho': 980,
#  'hoan_đoi': 981,
#  'hy_vong': 982,
#  'int': 983,
#  'issorted': 984,
#  'ke': 985,
#  'lap_lai': 986,
#  'lap_so': 987,
#  'nhac': 988,
#  'performance': 989,
#  'phong_van': 990,
#  'rac_roi': 991,
#  'sample': 992,
#  'so_sanh': 993,
#  'tham_khao': 994,
#  'thu': 995,
#  'tiep_xuc': 996,
#  'toc_đo': 997,
#  'tuyen_dung': 998,
#  've': 999,
#  ...}

# %%
len(id2word)
# Out:
# 8854

# %%
id2word.filter_extremes(no_below=2, no_above=0.5)
id2word.compactify()
id2word.save('../models/id2word.dictionary')
# Out:
# INFO : discarding 4716 tokens: [('actor', 1), ('allocation', 1), ('anhđuong', 1), ('axios', 1), ('bai_bo', 1), ('banfacebook', 1), ('bannetflix', 1), ('banxoa', 1), ('baoluu', 1), ('bayesian', 1)]...
# INFO : keeping 4138 tokens which were in no less than 2 and no more than 88 (=50.0%) documents
# INFO : resulting dictionary: Dictionary<4138 unique tokens: ['account', 'amazon', 'an', 'analysis', 'anh']...>
# INFO : Dictionary lifecycle event {'fname_or_handle': '../models/id2word.dictionary', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-01-01T08:28:06.339091', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/id2word.dictionary

# %%
len(id2word)
# Out:
# 4138

# %%
id2word.token2id
# Out:
# {'account': 0,
#  'amazon': 1,
#  'an': 2,
#  'analysis': 3,
#  'anh': 4,
#  'ap_đat': 5,
#  'api': 6,
#  'application': 7,
#  'avatar': 8,
#  'bai': 9,
#  'bai_toan': 10,
#  'ban_be': 11,
#  'ban_cai': 12,
#  'ban_chat': 13,
#  'bang': 14,
#  'bao_cao': 15,
#  'bao_gom': 16,
#  'bao_mat': 17,
#  'bao_phu': 18,
#  'bao_ve': 19,
#  'bat_kha_thi': 20,
#  'bayes': 21,
#  'bia': 22,
#  'bich': 23,
#  'bien': 24,
#  'bien_đoi': 25,
#  'bieu_dien': 26,
#  'bieu_thi': 27,
#  'bieu_tuong': 28,
#  'big': 29,
#  'binh': 30,
#  'binh_luan': 31,
#  'blog': 32,
#  'blogger': 33,
#  'bo_nho': 34,
#  'bookmark': 35,
#  'boolean': 36,
#  'boot': 37,
#  'bung_no': 38,
#  'business': 39,
#  'ca_si': 40,
#  'cai_thien': 41,
#  'cai_tien': 42,
#  'can_thiet': 43,
#  'canh': 44,
#  'canh_sat': 45,
#  'cap': 46,
#  'cap_đo': 47,
#  'cascading': 48,
#  'case': 49,
#  'cau': 50,
#  'cau_hinh': 51,
#  'cau_truc': 52,
#  'cham': 53,
#  'chan': 54,
#  'chat_luong': 55,
#  'chay': 56,
#  'che_đo': 57,
#  'chi_tiet': 58,
#  'chia': 59,
#  'chien_luoc': 60,
#  'chinh_sua': 61,
#  'chinh_xac': 62,
#  'chong': 63,
#  'chu_quan': 64,
#  'chu_đe': 65,
#  'chua': 66,
#  'chuan_hoa': 67,
#  'chuc_nang': 68,
#  'chung_khoan': 69,
#  'chung_minh': 70,
#  'chuoi': 71,
#  'chuong': 72,
#  'chuong_trinh': 73,
#  'chuyen_hoa': 74,
#  'chuyen_huong': 75,
#  'chuyen_tiep': 76,
#  'chuyen_đoi': 77,
#  'click': 78,
#  'client': 79,
#  'clip': 80,
#  'cloud': 81,
#  'co_ban': 82,
#  'co_le': 83,
#  'co_phieu': 84,
#  'co_so': 85,
#  'co_đinh': 86,
#  'code': 87,
#  'coi': 88,
#  'collection': 89,
#  'comment': 90,
#  'compass': 91,
#  'component': 92,
#  'con_nguoi': 93,
#  'cong_cu': 94,
#  'cong_khai': 95,
#  'cong_nghe': 96,
#  'cong_ty': 97,
#  'cong_viec': 98,
#  'csdl': 99,
#  'css': 100,
#  'cung_cap': 101,
#  'cuoc_song': 102,
#  'dan': 103,
#  'dang': 104,
#  'danh_sach': 105,
#  'data': 106,
#  'de_dang': 107,
#  'debug': 108,
#  'di_đong': 109,
#  'dich_vu': 110,
#  'doanh': 111,
#  'doanh_nghiep': 112,
#  'doanh_thu': 113,
#  'document': 114,
#  'doi': 115,
#  'du_an': 116,
#  'du_bao': 117,
#  'du_lieu': 118,
#  'du_đoan': 119,
#  'dua': 120,
#  'dung': 121,
#  'duy_tri': 122,
#  'editor': 123,
#  'email': 124,
#  'facebook': 125,
#  'file': 126,
#  'framework': 127,
#  'gan': 128,
#  'ghi_chu': 129,
#  'gia': 130,
#  'gia_đinh': 131,
#  'giai_phap': 132,
#  'giai_thuong': 133,
#  'giai_đap': 134,
#  'giam_sat': 135,
#  'giao_dien': 136,
#  'giao_luu': 137,
#  'gioi_thieu': 138,
#  'gioi_tinh': 139,
#  'git': 140,
#  'github': 141,
#  'go': 142,
#  'go_loi': 143,
#  'goi': 144,
#  'goi_y': 145,
#  'google': 146,
#  'gop_y': 147,
#  'gui': 148,
#  'hai': 149,
#  'han_che': 150,
#  'hanh_vi': 151,
#  'hanh_đong': 152,
#  'hat': 153,
#  'he': 154,
#  'he_thong': 155,
#  'hien': 156,
#  'hien_thi': 157,
#  'hien_tuong': 158,
#  'hien_đai': 159,
#  'hieu_nang': 160,
#  'hieu_suat': 161,
#  'hinh': 162,
#  'hinh_anh': 163,
#  'hinh_su': 164,
#  'hinh_thuc': 165,
#  'hoa': 166,
#  'hoan_chinh': 167,
#  'hoan_thanh': 168,
#  'hoan_thien': 169,
#  'hoc': 170,
#  'hoc_hoi': 171,
#  'hon_hop': 172,
#  'html': 173,
#  'http': 174,
#  'huan_luyen': 175,
#  'hung': 176,
#  'hung_thu': 177,
#  'huong': 178,
#  'huu_dung': 179,
#  'huu_han': 180,
#  'huu_ich': 181,
#  'huy': 182,
#  'hypertext': 183,
#  'id': 184,
#  'index': 185,
#  'internet': 186,
#  'it': 187,
#  'java': 188,
#  'javascript': 189,
#  'jetbrains': 190,
#  'join': 191,
#  'js': 192,
#  'json': 193,
#  'kem': 194,
#  'kenh': 195,
#  'ket': 196,
#  'ket_ban': 197,
#  'ket_noi': 198,
#  'ket_qua': 199,
#  'kha_nang': 200,
#  'khach_hang': 201,
#  'khap': 202,
#  'kho': 203,
#  'khoa': 204,
#  'khoi': 205,
#  'khong_gian': 206,
#  'khuon_kho': 207,
#  'khuyen_nghi': 208,
#  'kich_co': 209,
#  'kiem': 210,
#  'kiem_tra': 211,
#  'kiemcac': 212,
#  'kien_thuc': 213,
#  'kien_truc': 214,
#  'kieu': 215,
#  'kinh': 216,
#  'kinh_doanh': 217,
#  'kinh_te': 218,
#  'ky': 219,
#  'ky_thuat': 220,
#  'ky_tu': 221,
#  'lam_viec': 222,
#  'lan': 223,
#  'lap': 224,
#  'lap_trinh': 225,
#  'lap_trinh_vien': 226,
#  'learning': 227,
#  'len_loi': 228,
#  'level': 229,
#  'lich_su': 230,
#  'lien': 231,
#  'lien_tuc': 232,
#  'lieu': 233,
#  'linh_hoat': 234,
#  'linh_vuc': 235,
#  'link': 236,
#  'linux': 237,
#  'lo_ngai': 238,
#  'loat': 239,
#  'loi': 240,
#  'loi_ich': 241,
#  'loi_nhuan': 242,
#  'loi_the': 243,
#  'lua_chon': 244,
#  'luong': 245,
#  'luot': 246,
#  'luu': 247,
#  'luu_giu': 248,
#  'luu_tru': 249,
#  'ly': 250,
#  'ly_thuyet': 251,
#  'ma': 252,
#  'mac_đinh': 253,
#  'mach': 254,
#  'machine': 255,
#  'macos': 256,
#  'mai': 257,
#  'mang': 258,
#  'manh_me': 259,
#  'marketing': 260,
#  'markup': 261,
#  'mat_khau': 262,
#  'mau': 263,
#  'may': 264,
#  'may_tinh': 265,
#  'menu': 266,
#  'mien': 267,
#  'mieu_ta': 268,
#  'minh_hoa': 269,
#  'ml': 270,
#  'mo_hinh': 271,
#  'mo_rong': 272,
#  'mo_ta': 273,
#  'modal': 274,
#  'model': 275,
#  'module': 276,
#  'mon': 277,
#  'mong': 278,
#  'mong_muon': 279,
#  'mongodb': 280,
#  'mua': 281,
#  'muc': 282,
#  'muc_đich': 283,
#  'muc_đo': 284,
#  'muot_ma': 285,
#  'nam': 286,
#  'nam_bat': 287,
#  'nang': 288,
#  'nang_suat': 289,
#  'native': 290,
#  'nen_tang': 291,
#  'neu': 292,
#  'ngan': 293,
#  'ngay_nay': 294,
#  'nghia_la': 295,
#  'nghiem': 296,
#  'nghien_cuu': 297,
#  'nghiep_vu': 298,
#  'ngoai_tru': 299,
#  'ngon_ngu': 300,
#  'nguoi': 301,
#  'nhan': 302,
#  'nhan_loai': 303,
#  'nhan_tao': 304,
#  'nhanh_chong': 305,
#  'nhap': 306,
#  'nhat_ky': 307,
#  'nhiem_vu': 308,
#  'nhu': 309,
#  'nhu_cau': 310,
#  'nodejs': 311,
#  'noi_bat': 312,
#  'noi_dung': 313,
#  'noi_tai': 314,
#  'noi_tieng': 315,
#  'nu': 316,
#  'nut': 317,
#  'object': 318,
#  'of': 319,
#  'on': 320,
#  'online': 321,
#  'page': 322,
#  'password': 323,
#  'pha_tron': 324,
#  'pham_vi': 325,
#  'phan_biet': 326,
#  'phan_bo': 327,
#  'phan_hoi': 328,
#  'phan_loai': 329,
#  'phan_mem': 330,
#  'phan_phoi': 331,
#  'phan_tich': 332,
#  'phep': 333,
#  'phien_ban': 334,
#  'phim': 335,
#  'pho_bien': 336,
#  'phong_cach': 337,
#  'phong_phu': 338,
#  'phuc': 339,
#  'phuc_tap': 340,
#  'phuc_vu': 341,
#  'phuong': 342,
#  'phuong_phap': 343,
#  'post': 344,
#  'project': 345,
#  'python': 346,
#  'qua_khu': 347,
#  'quan_he': 348,
#  'quan_ly': 349,
#  'quang_cao': 350,
#  'quen_thuoc': 351,
#  'quy_mo': 352,
#  'quy_đinh': 353,
#  'quyen': 354,
#  'quyet_đinh': 355,
#  'ra_mat': 356,
#  'ra_đoi': 357,
#  'react': 358,
#  'reactjs': 359,
#  'request': 360,
#  'response': 361,
#  'role': 362,
#  'rong': 363,
#  'rong_rai': 364,
#  'ruby': 365,
#  'rut': 366,
#  'sach': 367,
#  'sai_lech': 368,
#  'san': 369,
#  'san_pham': 370,
#  'san_sang': 371,
#  'sang_tao': 372,
#  'sap_xep': 373,
#  'sau': 374,
#  'schema': 375,
#  'server': 376,
#  'setting': 377,
#  'share': 378,
#  'sheets': 379,
#  'single': 380,
#  'sinh': 381,
#  'sinh_thai': 382,
#  'so_luong': 383,
#  'so_thich': 384,
#  'soan_thao': 385,
#  'song': 386,
#  'spa': 387,
#  'spring': 388,
#  'sql': 389,
#  'string': 390,
#  'studio': 391,
#  'style': 392,
#  'sua': 393,
#  'suy_luan': 394,
#  'syntax': 395,
#  'system': 396,
#  'systems': 397,
#  'ta': 398,
#  'tab': 399,
#  'tac': 400,
#  'tac_gia': 401,
#  'tai': 402,
#  'tai_cau_truc': 403,
#  'tai_khoan': 404,
#  'tai_lieu': 405,
#  'tam': 406,
#  'tang_toc': 407,
#  'tang_truong': 408,
#  'tap': 409,
#  'tap_hop': 410,
#  'tat': 411,
#  'text': 412,
#  'thac_mac': 413,
#  'tham_so': 414,
#  'than_thien': 415,
#  'thanh': 416,
#  'thanh_cong': 417,
#  'thanh_phan': 418,
#  'thao_tac': 419,
#  'that_bai': 420,
#  'thay': 421,
#  'the_gioi': 422,
#  'the_hien': 423,
#  'the_ky': 424,
#  'theo_doi': 425,
#  'thiet_bi': 426,
#  'thiet_ke': 427,
#  'thinh': 428,
#  'thoa_man': 429,
#  'thoa_suc': 430,
#  'thoai_mai': 431,
#  'thoi': 432,
#  'thoi_đai': 433,
#  'thong': 434,
#  'thong_bao': 435,
#  'thong_minh': 436,
#  'thong_qua': 437,
#  'thong_thuong': 438,
#  'thong_tin': 439,
#  'thu_thap': 440,
#  'thu_vien': 441,
#  'thua': 442,
#  'thuan_tien': 443,
#  'thuat_toan': 444,
#  'thuc': 445,
#  'thuc_hien_tai': 446,
#  'thuc_the': 447,
#  'thuong': 448,
#  'thuong_mai': 449,
#  'tich_hop': 450,
#  'tiem_nang': 451,
#  'tien_ich': 452,
#  'tien_tien': 453,
#  'tien_trinh': 454,
#  'tieng': 455,
#  'tiep_can': 456,
#  'tiep_thi': 457,
#  'tieu_đe': 458,
#  'tim_kiem': 459,
#  'tin_hieu': 460,
#  'tin_tuc': 461,
#  'tinh_nang': 462,
#  'tinh_toan': 463,
#  'toan': 464,
#  'toan_bo': 465,
#  'toan_cau': 466,
#  'toan_the': 467,
#  'toi_gian': 468,
#  'toi_uu_hoa': 469,
#  'tong_quan': 470,
#  'tong_quat': 471,
#  'topic': 472,
#  'tra_loi': 473,
#  'trai': 474,
#  'trai_đat': 475,
#  'tran': 476,
#  'trang': 477,
#  'trang_chu': 478,
#  'trang_thai': 479,
#  'trang_web': 480,
#  'trao_đoi': 481,
#  'tri_tue': 482,
#  'trien_khai': 483,
#  'trinh': 484,
#  'trinh_bay': 485,
#  'trinh_duyet': 486,
#  'tro': 487,
#  'tro_nen': 488,
#  'tron': 489,
#  'trong': 490,
#  'truc_tuyen': 491,
#  'true': 492,
#  'trung': 493,
#  'truong': 494,
#  'truy': 495,
#  'truy_cap': 496,
#  'tu_khoa': 497,
#  'tu_vung': 498,
#  'tu_đien': 499,
#  'tu_đong': 500,
#  'tuan': 501,
#  'tuc': 502,
#  'tuc_la': 503,
#  'tuong_lai': 504,
#  'tuong_quan': 505,
#  'tuong_thich': 506,
#  'tuong_tu': 507,
#  'tuong_ung': 508,
#  'tuong_đong': 509,
#  'tuy': 510,
#  'tv': 511,
#  'type': 512,
#  'ui': 513,
#  'ung': 514,
#  'ung_dung': 515,
#  'universal': 516,
#  'uoc_luong': 517,
#  'use': 518,
#  'user': 519,
#  'userid': 520,
#  'users': 521,
#  'uu_điem': 522,
#  'vahoac': 523,
#  'vai_tro': 524,
#  'van': 525,
#  'van_ban': 526,
#  'van_dung': 527,
#  'van_hanh': 528,
#  'vi_du': 529,
#  'vo_cung': 530,
#  'vong': 531,
#  'vs': 532,
#  'vu': 533,
#  'vuong': 534,
#  'vuot_bac': 535,
#  'web': 536,
#  'website': 537,
#  'windows': 538,
#  'word': 539,
#  'wordpress': 540,
#  'world': 541,
#  'xa': 542,
#  'xa_hoi': 543,
#  'xac_nhan': 544,
#  'xac_thuc': 545,
#  'xac_đinh': 546,
#  'xay_dung': 547,
#  'xem_xet': 548,
#  'xep_hang': 549,
#  'xoa': 550,
#  'xu': 551,
#  'xu_huong': 552,
#  'y_nghia': 553,
#  'y_tuong': 554,
#  'y_đinh': 555,
#  'yahoo': 556,
#  'youtube': 557,
#  'đa_dang': 558,
#  'đac_tinh': 559,
#  'đac_trung': 560,
#  'đac_điem': 561,
#  'đai_dien': 562,
#  'đang': 563,
#  'đang_ky': 564,
#  'đang_nhap': 565,
#  'đanh': 566,
#  'đanh_dau': 567,
#  'đau': 568,
#  'đau_ra': 569,
#  'đau_vao': 570,
#  'đay_đu': 571,
#  'đe_cap': 572,
#  'đe_tai': 573,
#  'đe_xuat': 574,
#  'đe_y': 575,
#  'đi_sau': 576,
#  'đien_tu': 577,
#  'đieu_khien': 578,
#  'đinh_dang': 579,
#  'đinh_hinh': 580,
#  'đinh_nghia': 581,
#  'đoan': 582,
#  'đoc': 583,
#  'đoi_khi': 584,
#  'đoi_song': 585,
#  'đoi_tuong': 586,
#  'đon': 587,
#  'đon_gian': 588,
#  'đon_gian_hoa': 589,
#  'đong': 590,
#  'đong_bo': 591,
#  'đong_nghia': 592,
#  'đong_đao': 593,
#  'đuong': 594,
#  'ap_dung': 595,
#  'bat_buoc': 596,
#  'bi_an': 597,
#  'bo_qua': 598,
#  'bon': 599,
#  'cap_nhat': 600,
#  'chang_han': 601,
#  'cheo': 602,
#  'chi_đinh': 603,
#  'chon_lua': 604,
#  'chu': 605,
#  'chu_so': 606,
#  'co_nghia': 607,
#  'co_nghia_la': 608,
#  'cong': 609,
#  'constructor': 610,
#  'cu_phap': 611,
#  'dai': 612,
#  'dau': 613,
#  'day': 614,
#  'dong': 615,
#  'duy_nhat': 616,
#  'gach': 617,
#  'gia_su': 618,
#  'gioi_han': 619,
#  'hoi': 620,
#  'in': 621,
#  'keo': 622,
#  'ket_thuc': 623,
#  'khop': 624,
#  'kia': 625,
#  'lan_luot': 626,
#  'luu_y': 627,
#  'mac_du': 628,
#  'mat_khac': 629,
#  'mot_chut': 630,
#  'ngan_can': 631,
#  'nguoc_lai': 632,
#  'nhon': 633,
#  'phan_tu': 634,
#  'phu': 635,
#  'phuong_thuc': 636,
#  'ranh_gioi': 637,
#  'rieng_biet': 638,
#  'thay_vi': 639,
#  'thong_dung': 640,
#  'thuc_thi': 641,
#  'thuoc_tinh': 642,
#  'truyen': 643,
#  'tuong': 644,
#  'tuy_chon': 645,
#  'vv': 646,
#  'xay': 647,
#  'đao_nguoc': 648,
#  'đep_mat': 649,
#  'đung': 650,
#  'đuong_ong': 651,
#  'and': 652,
#  'bai_tap': 653,
#  'bot': 654,
#  'chieu': 655,
#  'chon': 656,
#  'cua': 657,
#  'cung': 658,
#  'dao': 659,
#  'duoc': 660,
#  'exception': 661,
#  'for': 662,
#  'goc': 663,
#  'is': 664,
#  'khac': 665,
#  'kich_thuoc': 666,
#  'la': 667,
#  'lua': 668,
#  'main': 669,
#  'max': 670,
#  'min': 671,
#  'mot': 672,
#  'nghich': 673,
#  'nguoc': 674,
#  'nhieu': 675,
#  'nhung': 676,
#  'noi': 677,
#  'objects': 678,
#  'so_nguyen': 679,
#  'tham_chieu': 680,
#  'this': 681,
#  'thread': 682,
#  'tien': 683,
#  'tri': 684,
#  'tu': 685,
#  'vi': 686,
#  'vua': 687,
#  'xuat': 688,
#  'anh_huong': 689,
#  'atm': 690,
#  'chu_y': 691,
#  'class': 692,
#  'co_che': 693,
#  'co_gang': 694,
#  'dien_tich': 695,
#  'double': 696,
#  'format': 697,
#  'giai_quyet': 698,
#  'hom_nay': 699,
#  'khai_bao': 700,
#  'khia_canh': 701,
#  'nguyen': 702,
#  'thang': 703,
#  'thang_may': 704,
#  'thich_hop': 705,
#  'tien_le': 706,
#  'tien_te': 707,
#  'toan_hoc': 708,
#  'tru': 709,
#  'break': 710,
#  'cho': 711,
#  'hoan_đoi': 712,
#  'hy_vong': 713,
#  'ke': 714,
#  'lap_lai': 715,
#  'nhac': 716,
#  'performance': 717,
#  'phong_van': 718,
#  'rac_roi': 719,
#  'so_sanh': 720,
#  'tham_khao': 721,
#  'thu': 722,
#  'tiep_xuc': 723,
#  'toc_đo': 724,
#  'tuyen_dung': 725,
#  've': 726,
#  'xep': 727,
#  'đoi': 728,
#  'ban_đau': 729,
#  'by': 730,
#  'cai_đat': 731,
#  'chuyen_nghiep': 732,
#  'con_so': 733,
#  'duyet': 734,
#  'ghi': 735,
#  'huan': 736,
#  'huong_dan': 737,
#  'list': 738,
#  'loc': 739,
#  'luyen': 740,
#  'rac': 741,
#  'set': 742,
#  'tach': 743,
#  'tap_huan_luyen': 744,
#  'ti_le': 745,
#  'tich': 746,
#  'tien_hanh': 747,
#  'tui': 748,
#  'xong': 749,
#  'cell': 750,
#  'customer': 751,
#  'download': 752,
#  'excel': 753,
#  'microsoft': 754,
#  'su': 755,
#  'ban': 756,
#  'bang_chung': 757,
#  'co_han': 758,
#  'counter': 759,
#  'ham': 760,
#  'hien_hanh': 761,
#  'implement': 762,
#  'ke_thua': 763,
#  'kich_hoat': 764,
#  'lock': 765,
#  'lop': 766,
#  'ngat': 767,
#  'resource': 768,
#  'roi': 769,
#  'sleep': 770,
#  'start': 771,
#  'synchronization': 772,
#  'thead': 773,
#  'thoi_han': 774,
#  'tiep': 775,
#  'vo': 776,
#  'vo_han': 777,
#  'with': 778,
#  'xet': 779,
#  'xu_dung': 780,
#  'đe': 781,
#  'cho_đoi': 782,
#  'giam_gia_tri': 783,
#  'khac_biet': 784,
#  'khoan': 785,
#  'phien_phuc': 786,
#  'test': 787,
#  'truong_hop': 788,
#  'unit': 789,
#  'đem': 790,
#  'add': 791,
#  'ao': 792,
#  'block': 793,
#  'create': 794,
#  'example': 795,
#  'keyword': 796,
#  'method': 797,
#  'methods': 798,
#  'monitor': 799,
#  'reference': 800,
#  'so_huu': 801,
#  'synchronize': 802,
#  'synchronized': 803,
#  'tham_gia': 804,
#  'the': 805,
#  'thuat_ngu': 806,
#  'ton_tai': 807,
#  'tranh': 808,
#  'binh_thuong': 809,
#  'body': 810,
#  'buoc': 811,
#  'cau_lenh': 812,
#  'chi_phi': 813,
#  'chon_loc': 814,
#  'co': 815,
#  'coding': 816,
#  'developer': 817,
#  'di_chuyen': 818,
#  'docs': 819,
#  'giai_phong': 820,
#  'giao_tiep': 821,
#  'hien_nhien': 822,
#  'hoan_tat': 823,
#  'lien_ket': 824,
#  'limit': 825,
#  'links': 826,
#  'loai_tru': 827,
#  'ngam': 828,
#  'ngan_chan': 829,
#  'nguy_co': 830,
#  'nhien': 831,
#  'not': 832,
#  'or': 833,
#  'other': 834,
#  'package': 835,
#  'player': 836,
#  'related': 837,
#  'ro_rang': 838,
#  'su_kien': 839,
#  'table': 840,
#  'tables': 841,
#  'tac_dung': 842,
#  'tips': 843,
#  'ton': 844,
#  'tranh_chap': 845,
#  'tri_hoan': 846,
#  'tu_lieu': 847,
#  'your': 848,
#  'đa_so': 849,
#  'đat_cuoc': 850,
#  'đinh': 851,
#  'đot_ngot': 852,
#  'apps': 853,
#  'backend': 854,
#  'bang_bieu': 855,
#  'bo': 856,
#  'bo_cuc': 857,
#  'bo_sung': 858,
#  'bo_tri': 859,
#  'bootstrap': 860,
#  'buttons': 861,
#  'cam_hung': 862,
#  'cam_nhan': 863,
#  'cam_ung': 864,
#  'can': 865,
#  'chat_lieu': 866,
#  'che_tao': 867,
#  'chia_khoa': 868,
#  'chuan': 869,
#  'chuc': 870,
#  'chung_ban': 871,
#  'cong_nghiep': 872,
#  'cot': 873,
#  'cu_xu': 874,
#  'cua_so': 875,
#  'cuc_ky': 876,
#  'cycle': 877,
#  'developers': 878,
#  'dich': 879,
#  'dinh': 880,
#  'doc': 881,
#  'elements': 882,
#  'frameworks': 883,
#  'frontend': 884,
#  'gan_ket': 885,
#  'ghi_nho': 886,
#  'gia_nhap': 887,
#  'giay': 888,
#  'gon': 889,
#  'ham_mo': 890,
#  'hang_đau': 891,
#  'hau_nhu': 892,
#  'hien_đai_đe': 893,
#  'hieu_biet': 894,
#  'hinh_thanh': 895,
#  'hoan_hao': 896,
#  'huu': 897,
#  'icon': 898,
#  'jquery': 899,
#  'ke_hoach': 900,
#  'keo_dai': 901,
#  'ket_hop': 902,
#  'kham_pha': 903,
#  'khien': 904,
#  'kho_tang': 905,
#  'khung': 906,
#  'kich_ban': 907,
#  'kiem_soat': 908,
#  'kinh_nghiem': 909,
#  'kit': 910,
#  'ky_nang': 911,
#  'lap_tuc': 912,
#  'liet_ke': 913,
#  'like': 914,
#  'lo': 915,
#  'long': 916,
#  'lop_hoc': 917,
#  'luoi': 918,
#  'luoi_đien': 919,
#  'man_hinh': 920,
#  'mat_tich': 921,
#  'mau_sac': 922,
#  'may_chu': 923,
#  'media': 924,
#  'metro': 925,
#  'mien_phi': 926,
#  'mixins': 927,
#  'mobile': 928,
#  'moi_truong': 929,
#  'muc_tieu': 930,
#  'nang_đong': 931,
#  'navigation': 932,
#  'nganh': 933,
#  'nghi': 934,
#  'nghien': 935,
#  'nguoi_ta': 936,
#  'nguon_luc': 937,
#  'nguyen_mau': 938,
#  'nguyen_tac': 939,
#  'nham_chan': 940,
#  'nhe': 941,
#  'noi_that': 942,
#  'pha': 943,
#  'phan_ung': 944,
#  'phang': 945,
#  'phat_hanh': 946,
#  'phong': 947,
#  'pin': 948,
#  'plugin': 949,
#  'quat': 950,
#  'quy': 951,
#  'radio': 952,
#  'sass': 953,
#  'scale': 954,
#  'sieng_nang': 955,
#  'social': 956,
#  'suc_manh': 957,
#  'sup_đo': 958,
#  'suu_tap': 959,
#  'tai_nguyen': 960,
#  'tam_tri': 961,
#  'tang_cuong': 962,
#  'tap_tin': 963,
#  'tat_nhien': 964,
#  'template': 965,
#  'tha': 966,
#  'tham_quan': 967,
#  'that': 968,
#  'thay_the': 969,
#  'theme': 970,
#  'thich_nghi': 971,
#  'thiet_yeu': 972,
#  'thong_so': 973,
#  'thu_cong': 974,
#  'thu_nghiem': 975,
#  'thu_vi': 976,
#  'thuc_hanh': 977,
#  'tiet_kiem': 978,
#  'tieu': 979,
#  'tieu_chuan': 980,
#  'tinh': 981,
#  'to_chuc': 982,
#  'toi_thieu': 983,
#  'toi_đa': 984,
#  'toi_đa_hoa': 985,
#  'top': 986,
#  'tot_đep': 987,
#  'trach_nhiem': 988,
#  'tram': 989,
#  'trang_tri': 990,
#  'transitions': 991,
#  'trao': 992,
#  'tro_giup': 993,
#  'trong_tam': 994,
#  'truc_quan': 995,
#  'trung_tam': 996,
#  'truot': 997,
#  'truyen_thong': 998,
#  'tu_do': 999,
#  ...}

# %%
class StreamCorpus(object):
    def __init__(self, sentences, dictionary, clip_docs=None):
        """
        Parse the first `clip_docs` documents
        Yield each document in turn, as a list of tokens.
        """
        self.sentences = sentences
        self.dictionary = dictionary
        self.clip_docs = clip_docs

    def __iter__(self):
        for tokens in itertools.islice(make_texts_corpus(self.sentences),
                                       self.clip_docs):
            yield self.dictionary.doc2bow(tokens)

    def __len__(self):
        return self.clip_docs

# %%
sentences = make_sentences()
corpus = StreamCorpus(sentences, id2word)

# %%
for i, c in enumerate(corpus):
    print(i, c)
    print('\n')
    if i == 10: break
# Out:
# 0 [(0, 2), (1, 1), (2, 3), (3, 1), (4, 6), (5, 1), (6, 1), (7, 1), (8, 4), (9, 1), (10, 1), (11, 2), (12, 1), (13, 1), (14, 2), (15, 1), (16, 5), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 3), (24, 2), (25, 1), (26, 6), (27, 2), (28, 7), (29, 2), (30, 1), (31, 24), (32, 29), (33, 2), (34, 1), (35, 3), (36, 2), (37, 3), (38, 2), (39, 1), (40, 1), (41, 3), (42, 2), (43, 2), (44, 1), (45, 1), (46, 2), (47, 1), (48, 1), (49, 19), (50, 1), (51, 5), (52, 6), (53, 1), (54, 1), (55, 1), (56, 4), (57, 2), (58, 4), (59, 2), (60, 1), (61, 16), (62, 1), (63, 1), (64, 1), (65, 19), (66, 4), (67, 1), (68, 16), (69, 1), (70, 1), (71, 1), (72, 6), (73, 3), (74, 1), (75, 2), (76, 1), (77, 1), (78, 9), (79, 3), (80, 4), (81, 1), (82, 2), (83, 1), (84, 1), (85, 11), (86, 1), (87, 10), (88, 2), (89, 4), (90, 1), (91, 1), (92, 1), (93, 5), (94, 2), (95, 1), (96, 5), (97, 1), (98, 2), (99, 2), (100, 4), (101, 5), (102, 4), (103, 1), (104, 5), (105, 4), (106, 2), (107, 4), (108, 1), (109, 1), (110, 2), (111, 1), (112, 4), (113, 1), (114, 12), (115, 2), (116, 1), (117, 1), (118, 38), (119, 5), (120, 13), (121, 2), (122, 1), (123, 2), (124, 2), (125, 4), (126, 1), (127, 2), (128, 5), (129, 2), (130, 1), (131, 2), (132, 1), (133, 1), (134, 1), (135, 8), (136, 15), (137, 1), (138, 5), (139, 1), (140, 2), (141, 2), (142, 1), (143, 1), (144, 2), (145, 15), (146, 3), (147, 1), (148, 4), (149, 3), (150, 2), (151, 1), (152, 1), (153, 4), (154, 3), (155, 36), (156, 2), (157, 12), (158, 1), (159, 1), (160, 1), (161, 1), (162, 5), (163, 1), (164, 2), (165, 2), (166, 1), (167, 1), (168, 3), (169, 1), (170, 15), (171, 2), (172, 1), (173, 5), (174, 2), (175, 3), (176, 1), (177, 1), (178, 4), (179, 1), (180, 1), (181, 2), (182, 2), (183, 1), (184, 13), (185, 2), (186, 5), (187, 1), (188, 2), (189, 2), (190, 1), (191, 1), (192, 3), (193, 2), (194, 1), (195, 1), (196, 1), (197, 4), (198, 1), (199, 5), (200, 6), (201, 3), (202, 1), (203, 2), (204, 2), (205, 1), (206, 1), (207, 1), (208, 1), (209, 1), (210, 1), (211, 2), (212, 1), (213, 2), (214, 1), (215, 3), (216, 1), (217, 4), (218, 1), (219, 1), (220, 1), (221, 1), (222, 2), (223, 1), (224, 1), (225, 3), (226, 2), (227, 10), (228, 1), (229, 4), (230, 1), (231, 1), (232, 1), (233, 1), (234, 2), (235, 4), (236, 5), (237, 1), (238, 1), (239, 1), (240, 1), (241, 3), (242, 1), (243, 1), (244, 3), (245, 1), (246, 2), (247, 13), (248, 1), (249, 2), (250, 1), (251, 2), (252, 11), (253, 1), (254, 1), (255, 8), (256, 1), (257, 1), (258, 8), (259, 2), (260, 1), (261, 1), (262, 1), (263, 3), (264, 7), (265, 1), (266, 1), (267, 1), (268, 2), (269, 1), (270, 1), (271, 14), (272, 1), (273, 12), (274, 1), (275, 1), (276, 1), (277, 3), (278, 2), (279, 1), (280, 7), (281, 2), (282, 1), (283, 7), (284, 3), (285, 1), (286, 3), (287, 3), (288, 3), (289, 1), (290, 1), (291, 2), (292, 1), (293, 1), (294, 3), (295, 1), (296, 1), (297, 5), (298, 1), (299, 2), (300, 8), (301, 1), (302, 11), (303, 1), (304, 1), (305, 3), (306, 5), (307, 2), (308, 1), (309, 1), (310, 9), (311, 4), (312, 2), (313, 6), (314, 1), (315, 2), (316, 1), (317, 5), (318, 2), (319, 1), (320, 2), (321, 1), (322, 2), (323, 3), (324, 2), (325, 2), (326, 2), (327, 4), (328, 4), (329, 1), (330, 3), (331, 7), (332, 4), (333, 12), (334, 1), (335, 5), (336, 2), (337, 1), (338, 2), (339, 1), (340, 2), (341, 2), (342, 3), (343, 7), (344, 1), (345, 1), (346, 1), (347, 1), (348, 3), (349, 2), (350, 2), (351, 1), (352, 1), (353, 1), (354, 4), (355, 1), (356, 1), (357, 2), (358, 2), (359, 1), (360, 5), (361, 2), (362, 3), (363, 1), (364, 1), (365, 1), (366, 1), (367, 2), (368, 1), (369, 3), (370, 8), (371, 1), (372, 1), (373, 1), (374, 1), (375, 1), (376, 2), (377, 1), (378, 2), (379, 1), (380, 1), (381, 8), (382, 1), (383, 4), (384, 1), (385, 3), (386, 1), (387, 1), (388, 7), (389, 1), (390, 10), (391, 3), (392, 1), (393, 3), (394, 4), (395, 1), (396, 3), (397, 9), (398, 1), (399, 1), (400, 1), (401, 2), (402, 2), (403, 1), (404, 2), (405, 10), (406, 1), (407, 1), ( ...
#
#
# 1 [(16, 2), (27, 2), (36, 1), (44, 2), (62, 2), (66, 6), (71, 27), (94, 2), (101, 1), (104, 1), (118, 2), (144, 2), (149, 8), (157, 1), (166, 2), (181, 1), (189, 2), (194, 1), (196, 1), (199, 1), (211, 5), (215, 2), (219, 3), (221, 37), (224, 2), (225, 1), (233, 2), (244, 2), (252, 3), (258, 3), (263, 14), (273, 1), (286, 2), (295, 1), (299, 2), (300, 2), (326, 1), (333, 3), (340, 1), (342, 1), (398, 3), (399, 1), (409, 1), (410, 3), (411, 1), (416, 1), (417, 1), (423, 1), (439, 1), (459, 1), (465, 3), (474, 1), (477, 1), (490, 1), (493, 19), (507, 2), (525, 1), (526, 2), (529, 5), (530, 1), (546, 1), (547, 1), (553, 3), (560, 1), (562, 2), (563, 1), (567, 1), (568, 2), (569, 1), (570, 2), (582, 1), (586, 5), (588, 3), (595, 3), (596, 2), (597, 1), (598, 1), (599, 2), (600, 1), (601, 1), (602, 8), (603, 1), (604, 1), (605, 5), (606, 9), (607, 1), (608, 2), (609, 1), (610, 1), (611, 2), (612, 1), (613, 31), (614, 4), (615, 2), (616, 2), (617, 10), (618, 2), (619, 2), (620, 1), (621, 1), (622, 1), (623, 3), (624, 37), (625, 1), (626, 1), (627, 1), (628, 1), (629, 1), (630, 1), (631, 1), (632, 1), (633, 1), (634, 9), (635, 2), (636, 4), (637, 3), (638, 1), (639, 1), (640, 1), (641, 1), (642, 1), (643, 1), (644, 1), (645, 1), (646, 1), (647, 1), (648, 1), (649, 1), (650, 2), (651, 1)]
#
#
# 2 [(14, 2), (71, 18), (72, 1), (73, 2), (82, 2), (121, 2), (149, 5), (156, 2), (185, 1), (188, 3), (219, 1), (221, 1), (224, 1), (240, 1), (258, 6), (269, 2), (306, 9), (319, 1), (343, 1), (373, 2), (419, 1), (484, 2), (515, 1), (536, 1), (586, 1), (599, 2), (612, 1), (613, 1), (621, 3), (634, 4), (647, 2), (652, 2), (653, 1), (654, 1), (655, 2), (656, 1), (657, 3), (658, 1), (659, 1), (660, 2), (661, 1), (662, 1), (663, 2), (664, 12), (665, 2), (666, 1), (667, 4), (668, 1), (669, 1), (670, 3), (671, 3), (672, 6), (673, 1), (674, 1), (675, 2), (676, 1), (677, 1), (678, 1), (679, 1), (680, 1), (681, 10), (682, 1), (683, 1), (684, 2), (685, 1), (686, 2), (687, 2), (688, 4)]
#
#
# 3 [(10, 6), (13, 1), (26, 5), (50, 2), (53, 1), (56, 1), (62, 5), (73, 12), (96, 1), (98, 1), (101, 1), (104, 4), (118, 3), (144, 1), (149, 1), (162, 1), (170, 1), (178, 1), (180, 1), (188, 2), (199, 5), (215, 6), (225, 1), (249, 1), (264, 3), (269, 1), (279, 2), (293, 1), (326, 1), (389, 1), (393, 1), (414, 1), (437, 2), (438, 1), (439, 1), (442, 1), (463, 5), (464, 1), (473, 1), (500, 1), (506, 1), (512, 1), (551, 1), (563, 1), (568, 1), (570, 1), (572, 1), (575, 1), (582, 2), (583, 1), (590, 4), (592, 1), (600, 1), (601, 2), (610, 2), (613, 4), (621, 8), (628, 1), (643, 1), (650, 1), (655, 1), (683, 2), (689, 1), (690, 1), (691, 1), (692, 2), (693, 1), (694, 1), (695, 1), (696, 4), (697, 1), (698, 3), (699, 1), (700, 1), (701, 1), (702, 2), (703, 1), (704, 1), (705, 1), (706, 1), (707, 1), (708, 1), (709, 1)]
#
#
# 4 [(10, 2), (13, 1), (43, 1), (46, 1), (50, 1), (56, 1), (87, 2), (103, 2), (118, 4), (149, 4), (167, 1), (178, 1), (188, 3), (213, 1), (215, 1), (224, 3), (225, 1), (231, 5), (251, 1), (258, 4), (279, 1), (373, 12), (398, 1), (444, 3), (492, 1), (507, 6), (529, 3), (531, 10), (563, 1), (571, 1), (588, 2), (600, 1), (618, 1), (634, 28), (647, 1), (654, 7), (655, 1), (677, 7), (710, 1), (711, 4), (712, 4), (713, 1), (714, 5), (715, 1), (716, 1), (717, 1), (718, 1), (719, 1), (720, 9), (721, 1), (722, 1), (723, 2), (724, 1), (725, 1), (726, 1), (727, 3), (728, 4)]
#
#
# 5 [(10, 1), (21, 7), (56, 2), (62, 1), (73, 3), (87, 1), (90, 1), (103, 1), (118, 1), (120, 1), (124, 4), (126, 8), (136, 1), (138, 1), (163, 1), (168, 1), (173, 1), (188, 5), (199, 2), (200, 2), (211, 6), (236, 1), (247, 1), (300, 1), (302, 3), (326, 1), (329, 9), (343, 3), (398, 8), (400, 1), (412, 3), (416, 2), (503, 1), (507, 1), (526, 1), (529, 3), (567, 2), (583, 1), (588, 3), (595, 2), (632, 1), (720, 2), (722, 5), (729, 3), (730, 2), (731, 1), (732, 1), (733, 1), (734, 3), (735, 1), (736, 1), (737, 1), (738, 7), (739, 5), (740, 1), (741, 4), (742, 1), (743, 3), (744, 4), (745, 8), (746, 1), (747, 2), (748, 14), (749, 1)]
#
#
# 6 [(82, 1), (87, 2), (88, 1), (101, 1), (124, 1), (126, 14), (157, 2), (178, 1), (184, 2), (188, 1), (199, 2), (215, 2), (225, 1), (250, 2), (252, 1), (319, 1), (390, 1), (398, 1), (416, 2), (418, 2), (439, 2), (441, 2), (487, 2), (529, 3), (539, 1), (579, 1), (581, 2), (582, 1), (583, 7), (586, 2), (615, 3), (627, 1), (692, 5), (696, 1), (735, 5), (738, 1), (750, 1), (751, 3), (752, 2), (753, 20), (754, 4), (755, 2)]
#
#
# 7 [(56, 2), (132, 1), (142, 1), (144, 1), (149, 3), (158, 2), (188, 4), (191, 5), (199, 2), (205, 1), (224, 1), (225, 1), (282, 1), (300, 1), (333, 1), (398, 11), (405, 1), (472, 1), (485, 2), (507, 1), (529, 5), (531, 1), (563, 1), (575, 1), (591, 3), (600, 1), (608, 1), (615, 1), (621, 13), (623, 2), (625, 1), (627, 1), (641, 5), (647, 3), (652, 1), (661, 2), (669, 1), (682, 75), (721, 1), (728, 6), (735, 1), (749, 2), (756, 3), (757, 2), (758, 1), (759, 40), (760, 15), (761, 1), (762, 1), (763, 2), (764, 2), (765, 1), (766, 6), (767, 4), (768, 12), (769, 1), (770, 5), (771, 1), (772, 1), (773, 1), (774, 1), (775, 1), (776, 1), (777, 2), (778, 1), (779, 3), (780, 1), (781, 1)]
#
#
# 8 [(56, 1), (73, 11), (144, 3), (168, 8), (188, 1), (191, 2), (199, 3), (205, 1), (245, 1), (252, 1), (286, 1), (308, 1), (333, 1), (383, 2), (398, 2), (400, 1), (414, 1), (421, 1), (435, 2), (452, 1), (503, 2), (515, 2), (529, 3), (533, 1), (563, 1), (586, 2), (600, 1), (603, 1), (627, 1), (636, 6), (641, 4), (674, 1), (682, 9), (700, 1), (711, 6), (764, 1), (766, 4), (771, 4), (773, 2), (782, 2), (783, 1), (784, 1), (785, 1), (786, 1), (787, 1), (788, 1), (789, 1), (790, 1)]
#
#
# 9 [(54, 1), (56, 1), (87, 1), (144, 3), (149, 1), (188, 11), (204, 3), (205, 9), (215, 1), (252, 1), (264, 1), (318, 6), (398, 1), (423, 2), (465, 1), (507, 2), (510, 1), (529, 7), (548, 1), (563, 1), (567, 1), (582, 1), (583, 1), (586, 2), (591, 15), (600, 1), (641, 4), (644, 1), (647, 1), (682, 10), (692, 6), (693, 1), (694, 1), (700, 1), (728, 1), (759, 1), (791, 2), (792, 1), (793, 2), (794, 1), (795, 1), (796, 2), (797, 15), (798, 12), (799, 1), (800, 1), (801, 2), (802, 1), (803, 28), (804, 1), (805, 1), (806, 1), (807, 3), (808, 1)]
#
#
# 10 [(0, 1), (19, 3), (24, 1), (32, 1), (43, 1), (52, 4), (54, 1), (58, 1), (60, 1), (65, 1), (66, 1), (82, 1), (87, 2), (101, 1), (106, 2), (118, 1), (120, 1), (132, 3), (144, 3), (150, 1), (151, 1), (152, 7), (155, 1), (168, 2), (178, 1), (182, 1), (188, 6), (191, 1), (200, 4), (204, 9), (211, 2), (222, 1), (223, 1), (232, 1), (284, 1), (286, 3), (293, 2), (305, 1), (325, 1), (333, 1), (343, 1), (354, 1), (369, 1), (383, 2), (398, 1), (404, 2), (414, 1), (417, 2), (419, 2), (421, 1), (438, 2), (463, 1), (465, 1), (469, 1), (479, 1), (485, 1), (488, 1), (496, 9), (500, 3), (502, 1), (510, 1), (515, 1), (518, 1), (529, 5), (548, 1), (554, 1), (562, 1), (563, 1), (581, 1), (586, 14), (588, 3), (591, 5), (592, 1), (600, 1), (608, 2), (609, 1), (616, 1), (619, 1), (621, 1), (627, 3), (631, 1), (632, 1), (636, 2), (638, 3), (639, 1), (641, 10), (644, 1), (647, 1), (648, 1), (652, 5), (680, 1), (682, 20), (689, 1), (693, 1), (694, 3), (698, 1), (700, 1), (711, 1), (713, 1), (717, 2), (728, 2), (747, 2), (749, 1), (756, 5), (764, 1), (765, 26), (766, 4), (769, 1), (772, 1), (782, 1), (788, 1), (793, 2), (796, 1), (797, 14), (799, 16), (800, 1), (802, 2), (803, 14), (804, 1), (805, 2), (809, 4), (810, 1), (811, 1), (812, 1), (813, 1), (814, 1), (815, 2), (816, 1), (817, 1), (818, 1), (819, 1), (820, 1), (821, 1), (822, 1), (823, 2), (824, 7), (825, 1), (826, 1), (827, 1), (828, 1), (829, 1), (830, 1), (831, 1), (832, 1), (833, 1), (834, 1), (835, 1), (836, 4), (837, 1), (838, 3), (839, 2), (840, 6), (841, 1), (842, 1), (843, 1), (844, 2), (845, 12), (846, 1), (847, 1), (848, 1), (849, 1), (850, 1), (851, 1), (852, 2)]

# %%
# save corpus
gensim.corpora.MmCorpus.serialize('../models/corpus.mm', corpus)
# Out:
# INFO : storing corpus in Matrix Market format to ../models/corpus.mm
# INFO : saving sparse matrix to ../models/corpus.mm
# INFO : PROGRESS: saving document #0
# INFO : saved 166x4138 matrix, density=5.107% (35081/686908)
# INFO : saving MmCorpus index to ../models/corpus.mm.index

# %%
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 166 documents, 4138 features, 35081 non-zero entries

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus, id2word=id2word, num_topics=57, passes=10,
            chunksize=67, random_state=46, alpha=1e-2, eta=0.5e-2,
            minimum_probability=0.0, per_word_topics=False)
# Out:
# INFO : using serial LDA version on this node
# INFO : running online (multi-pass) LDA training, 57 topics, 10 passes over the supplied corpus of 166 documents, updating model once every 67 documents, evaluating perplexity every 166 documents, iterating 50x with a convergence threshold of 0.001000
# INFO : PROGRESS: pass 0, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #27 (0.010): 0.025*"agile" + 0.020*"marketing" + 0.010*"stories" + 0.010*"calo" + 0.009*"user" + 0.009*"san_pham" + 0.009*"da" + 0.009*"khach_hang" + 0.008*"sprint" + 0.007*"can"
# INFO : topic #11 (0.010): 0.014*"agile" + 0.012*"ta" + 0.012*"moi_truong" + 0.010*"du_an" + 0.010*"thong_minh" + 0.007*"khach_hang" + 0.006*"quan_ly" + 0.006*"da" + 0.006*"he_thong" + 0.006*"bao_ve"
# INFO : topic #15 (0.010): 0.019*"khoi_nghiep" + 0.019*"kinh_doanh" + 0.018*"da" + 0.011*"kinh_te" + 0.009*"đau_tu" + 0.008*"the_gioi" + 0.008*"huong" + 0.007*"cong_ty" + 0.006*"lan" + 0.006*"thi_truong"
# INFO : topic #43 (0.010): 0.037*"da" + 0.010*"cham_soc" + 0.009*"mat" + 0.009*"du_an" + 0.008*"agile" + 0.008*"muc_tieu" + 0.007*"sach" + 0.007*"san_pham" + 0.007*"khoi_nghiep" + 0.007*"lan"
# INFO : topic #18 (0.010): 0.015*"lanh_manh" + 0.013*"ao" + 0.013*"tien" + 0.013*"an_uong" + 0.012*"đau_tu" + 0.008*"benh" + 0.008*"khoi_nghiep" + 0.007*"đong_tien" + 0.007*"thi_truong" + 0.007*"kinh_te"
# INFO : topic diff=101.207718, rho=1.000000
# INFO : PROGRESS: pass 0, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #24 (0.010): 0.038*"cong_nghe" + 0.012*"tien" + 0.012*"cong_ty" + 0.011*"đau_tu" + 0.011*"kinh_doanh" + 0.011*"sang_loc" + 0.010*"khong_lo" + 0.009*"khoi_nghiep" + 0.009*"gia" + 0.009*"san_pham"
# INFO : topic #38 (0.010): 0.030*"con_so" + 0.023*"song" + 0.012*"calo" + 0.012*"loi" + 0.011*"đoc" + 0.010*"chu_đao" + 0.009*"nang_luong" + 0.008*"co_the" + 0.007*"lanh_manh" + 0.007*"moi_truong"
# INFO : topic #41 (0.010): 0.182*"loc" + 0.046*"khong_khi" + 0.021*"may" + 0.017*"kinh_te" + 0.014*"moi_truong" + 0.011*"khung_hoang" + 0.009*"nam" + 0.006*"o_nhiem" + 0.006*"kha_nang" + 0.006*"gia"
# INFO : topic #32 (0.010): 0.046*"may" + 0.044*"tu_đong" + 0.020*"ket_noi" + 0.018*"hoc" + 0.018*"du_lieu" + 0.015*"ung_dung" + 0.015*"đao_tao" + 0.014*"online" + 0.012*"san_pham" + 0.010*"thuong_hieu"
# INFO : topic #33 (0.010): 0.099*"mat_ngu" + 0.022*"ngu" + 0.018*"am" + 0.017*"chua" + 0.014*"che_đo" + 0.013*"da" + 0.013*"tra" + 0.010*"sach" + 0.009*"hoa" + 0.009*"benh"
# INFO : topic diff=10.524149, rho=0.707107
# INFO : -39.446 per-word bound, 748709643918.8 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 0, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #9 (0.010): 0.088*"da" + 0.019*"skincare" + 0.016*"mat" + 0.014*"lan" + 0.014*"cham_soc" + 0.013*"kem" + 0.013*"duong" + 0.012*"san_pham" + 0.010*"am" + 0.009*"rua"
# INFO : topic #24 (0.010): 0.069*"pho_chu_tich" + 0.067*"lao" + 0.033*"nop" + 0.028*"cong_nghe" + 0.027*"usd" + 0.020*"vay" + 0.016*"phanh" + 0.013*"von" + 0.011*"đau_tu" + 0.010*"doc"
# INFO : topic #53 (0.010): 0.134*"ta" + 0.078*"project" + 0.060*"view" + 0.056*"ham" + 0.045*"class" + 0.027*"tuong_thich" + 0.021*"framework" + 0.017*"api" + 0.016*"file" + 0.016*"cu_phap"
# INFO : topic #8 (0.010): 0.050*"len_an" + 0.032*"tet" + 0.026*"le" + 0.021*"đoc" + 0.014*"sach" + 0.013*"tieng" + 0.013*"khoi_nghiep" + 0.011*"tien" + 0.010*"kinh_doanh" + 0.010*"ban_đoc"
# INFO : topic #23 (0.010): 0.110*"ngu" + 0.085*"giac_ngu" + 0.033*"co_the" + 0.016*"trang_thai" + 0.015*"ngon" + 0.015*"suc_khoe" + 0.014*"giac" + 0.013*"đieu_tri" + 0.013*"chua" + 0.013*"nao"
# INFO : topic diff=10.646398, rho=0.577350
# INFO : PROGRESS: pass 1, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #3 (0.010): 0.226*"material" + 0.118*"design" + 0.025*"css" + 0.020*"google" + 0.013*"thanh_phan" + 0.012*"cung_cap" + 0.011*"thiet_ke" + 0.011*"calo" + 0.011*"bootstrap" + 0.010*"github"
# INFO : topic #19 (0.010): 0.031*"tang_truong" + 0.029*"kinh_te" + 0.026*"suy_thoai" + 0.023*"du_bao" + 0.020*"the_gioi" + 0.020*"oto" + 0.018*"cham" + 0.015*"kinh" + 0.011*"lam_phat" + 0.011*"chat"
# INFO : topic #14 (0.010): 0.076*"ve" + 0.057*"du_lich" + 0.046*"cao_điem" + 0.045*"lua_chon" + 0.039*"vui_choi" + 0.038*"tham_quan" + 0.032*"so" + 0.032*"nghiem" + 0.029*"momo" + 0.027*"di_chuyen"
# INFO : topic #22 (0.010): 0.033*"da" + 0.008*"lan" + 0.007*"skincare" + 0.007*"cham_soc" + 0.006*"duong" + 0.005*"mat" + 0.004*"nang" + 0.004*"am" + 0.004*"kem" + 0.004*"san_pham"
# INFO : topic #51 (0.010): 0.187*"ts" + 0.097*"chu_ky" + 0.023*"kinh_te" + 0.021*"khung_hoang" + 0.017*"cuoc_chien" + 0.014*"nguyen" + 0.014*"kien" + 0.014*"nhan_đinh" + 0.013*"nam" + 0.010*"đau_tu"
# INFO : topic diff=9.577005, rho=0.472582
# INFO : PROGRESS: pass 1, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #37 (0.010): 0.017*"song" + 0.016*"cuoc_song" + 0.009*"thuc_pham" + 0.009*"suc_khoe" + 0.008*"uong" + 0.008*"đoi" + 0.008*"giai_đoan" + 0.007*"lanh_manh" + 0.006*"ngu" + 0.006*"cam_ket"
# INFO : topic #7 (0.010): 0.029*"tiet_kiem" + 0.028*"phong" + 0.025*"mua" + 0.022*"tien" + 0.020*"thue" + 0.017*"tro" + 0.015*"du_lich" + 0.013*"gia" + 0.011*"may" + 0.011*"xe"
# INFO : topic #2 (0.010): 0.027*"than" + 0.027*"tieng" + 0.024*"lam_viec" + 0.023*"tiet_kiem" + 0.022*"cong_nhan" + 0.015*"ke_hoach" + 0.015*"nhan" + 0.013*"tu_duy" + 0.012*"thoi_quen" + 0.011*"ky_nang"
# INFO : topic #28 (0.010): 0.021*"xa_hoi" + 0.018*"nam" + 0.015*"cong_nghe" + 0.012*"khoa_hoc" + 0.012*"cong_nghiep" + 0.011*"nha_nuoc" + 0.010*"dan" + 0.010*"viet_nam" + 0.010*"kinh_te" + 0.010*"lao_đong"
# INFO : topic #27 (0.010): 0.023*"khach_hang" + 0.019*"du_lieu" + 0.015*"quyet_đinh" + 0.015*"san_xuat" + 0.014*"cong_nghe" + 0.013*"quan_ly" + 0.012*"thong_qua" + 0.011*"dich_vu" + 0.011*"cung_cap" + 0.011*"san_pham"
# INFO : topic diff=10.121558, rho=0.472582
# INFO : -37.348 per-word bound, 174983038069.0 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 1, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #51 (0.010): 0.402*"ts" + 0.115*"chu_ky" + 0.025*"nguyen" + 0.013*"nam" + 0.013*"nhan_đinh" + 0.012*"vien_truong" + 0.011*"kien" + 0.009*"kinh_te" + 0.008*"khung_hoang" + 0.007*"cuoc_chien"
# INFO : topic #22 (0.010): 0.013*"da" + 0.003*"lan" + 0.003*"skincare" + 0.003*"cham_soc" + 0.003*"duong" + 0.002*"mat" + 0.002*"nang" + 0.002*"am" + 0.002*"kem" + 0.002*"san_pham"
# INFO : topic #7 (0.010): 0.031*"phong" + 0.029*"thue" + 0.027*"tro" + 0.021*"tien" + 0.019*"van_hoa" + 0.016*"mua" + 0.016*"xe" + 0.014*"gia" + 0.014*"tiet_kiem" + 0.013*"đuong"
# INFO : topic #6 (0.010): 0.175*"trat_tu" + 0.045*"du_bao" + 0.032*"trung_uong" + 0.026*"imf" + 0.022*"fed" + 0.018*"lai_suat" + 0.017*"suy_thoai" + 0.016*"đay" + 0.013*"phong_chong" + 0.012*"the_gioi"
# INFO : topic #40 (0.010): 0.555*"tay" + 0.231*"mu" + 0.009*"da" + 0.004*"du_lich" + 0.002*"duong" + 0.002*"mat" + 0.002*"chet" + 0.002*"lan" + 0.001*"kem" + 0.001*"san_pham"
# INFO : topic diff=10.055383, rho=0.472582
# INFO : PROGRESS: pass 2, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #12 (0.010): 0.027*"thuc_pham" + 0.023*"calo" + 0.022*"chat" + 0.020*"can" + 0.018*"che_đo" + 0.017*"an_uong" + 0.016*"co_the" + 0.016*"đuong" + 0.015*"lanh_manh" + 0.014*"chat_beo"
# INFO : topic #26 (0.010): 0.006*"kinh_te" + 0.004*"khung_hoang" + 0.003*"thong_minh" + 0.003*"du_lich" + 0.002*"ve" + 0.002*"calo" + 0.002*"thuc_pham" + 0.002*"the_gioi" + 0.002*"lua_chon" + 0.002*"suy_thoai"
# INFO : topic #49 (0.010): 0.224*"marketing" + 0.134*"sprint" + 0.080*"user" + 0.073*"agile" + 0.062*"meeting" + 0.058*"scrum" + 0.054*"story" + 0.053*"mua" + 0.027*"planning" + 0.025*"master"
# INFO : topic #47 (0.010): 0.006*"moi_truong" + 0.003*"o_nhiem" + 0.002*"bao_ve" + 0.002*"kinh_te" + 0.002*"he_thong" + 0.002*"khu" + 0.001*"thong_minh" + 0.001*"khung_hoang" + 0.001*"con_nguoi" + 0.001*"y_thuc"
# INFO : topic #17 (0.010): 0.195*"da" + 0.057*"san_pham" + 0.048*"lan" + 0.038*"duong" + 0.032*"cham_soc" + 0.030*"dau" + 0.022*"sach" + 0.022*"am" + 0.018*"mat" + 0.017*"kho"
# INFO : topic diff=8.324760, rho=0.427272
# INFO : PROGRESS: pass 2, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #2 (0.010): 0.036*"tiet_kiem" + 0.035*"than" + 0.035*"tieng" + 0.025*"lam_viec" + 0.022*"cong_nhan" + 0.019*"nhan" + 0.017*"ke_hoach" + 0.016*"thoi_quen" + 0.015*"tu_duy" + 0.014*"ky_nang"
# INFO : topic #55 (0.010): 0.095*"ngon_ngu" + 0.068*"ung_dung" + 0.059*"lap_trinh" + 0.031*"pho_bien" + 0.021*"hoc" + 0.020*"javascript" + 0.018*"java" + 0.018*"toc_đo" + 0.016*"chuong_trinh" + 0.016*"lap_trinh_vien"
# INFO : topic #36 (0.010): 0.041*"cuoc_song" + 0.035*"song" + 0.018*"cong_viec" + 0.013*"cang_thang" + 0.012*"y_nghia" + 0.012*"thuong_xuyen" + 0.012*"thoi_quen" + 0.010*"loi_ich" + 0.010*"lanh_manh" + 0.010*"suc_khoe"
# INFO : topic #18 (0.010): 0.002*"lanh_manh" + 0.002*"ao" + 0.002*"tien" + 0.002*"an_uong" + 0.002*"đau_tu" + 0.001*"benh" + 0.001*"khoi_nghiep" + 0.001*"đong_tien" + 0.001*"thi_truong" + 0.001*"kinh_te"
# INFO : topic #30 (0.010): 0.079*"khoi_nghiep" + 0.072*"kinh_doanh" + 0.026*"huong" + 0.022*"cong_ty" + 0.021*"đau_tu" + 0.020*"mao_hiem" + 0.018*"du_an" + 0.017*"sinh_thai" + 0.017*"quy" + 0.017*"so_huu"
# INFO : topic diff=7.221243, rho=0.427272
# INFO : -36.950 per-word bound, 132782382448.2 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 2, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #30 (0.010): 0.079*"tu_than" + 0.071*"khoi_nghiep" + 0.064*"kinh_doanh" + 0.024*"huong" + 0.022*"mao_hiem" + 0.020*"cong_ty" + 0.019*"đau_tu" + 0.016*"du_an" + 0.016*"so_huu" + 0.016*"sinh_thai"
# INFO : topic #18 (0.010): 0.002*"lanh_manh" + 0.001*"ao" + 0.001*"tien" + 0.001*"an_uong" + 0.001*"đau_tu" + 0.001*"benh" + 0.001*"khoi_nghiep" + 0.001*"đong_tien" + 0.001*"thi_truong" + 0.001*"kinh_te"
# INFO : topic #21 (0.010): 0.116*"chu_tich" + 0.079*"thu_tuong" + 0.049*"neu" + 0.041*"nam" + 0.039*"kinh_te" + 0.039*"ban" + 0.036*"chau" + 0.033*"chi_đao" + 0.026*"co_ban" + 0.024*"the_gioi"
# INFO : topic #28 (0.010): 0.031*"nam" + 0.030*"khoa_hoc" + 0.028*"xa_hoi" + 0.028*"vien" + 0.018*"giao_thong" + 0.018*"chinh_phu" + 0.017*"luat" + 0.016*"dan" + 0.014*"viet_nam" + 0.013*"nghien_cuu"
# INFO : topic #14 (0.010): 0.256*"du_lich" + 0.071*"trai" + 0.067*"ve" + 0.066*"nghiem" + 0.045*"chuyen" + 0.036*"cao_điem" + 0.036*"di_chuyen" + 0.028*"tham_quan" + 0.027*"lua_chon" + 0.023*"bay"
# INFO : topic diff=6.050123, rho=0.427272
# INFO : PROGRESS: pass 3, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #0 (0.010): 0.237*"user" + 0.195*"stories" + 0.054*"nhac_nho" + 0.046*"marketer" + 0.039*"liet_ke" + 0.031*"good" + 0.026*"cot" + 0.017*"me" + 0.014*"đang" + 0.013*"vv"
# INFO : topic #20 (0.010): 0.029*"thiet_ke" + 0.014*"trai" + 0.013*"thiet_bi" + 0.013*"tinh" + 0.012*"phep" + 0.012*"de_dang" + 0.012*"kieu" + 0.012*"khung" + 0.012*"hinh_anh" + 0.011*"gioi_thieu"
# INFO : topic #41 (0.010): 0.362*"loc" + 0.244*"khong_khi" + 0.238*"may" + 0.022*"trong_lanh" + 0.011*"o_nhiem" + 0.010*"xuat" + 0.010*"kha_nang" + 0.006*"moi_truong" + 0.005*"my" + 0.005*"khu"
# INFO : topic #21 (0.010): 0.080*"chu_tich" + 0.053*"thu_tuong" + 0.044*"kinh_te" + 0.032*"nam" + 0.032*"neu" + 0.029*"ban" + 0.028*"the_gioi" + 0.025*"chau" + 0.024*"chien_tranh" + 0.023*"trung"
# INFO : topic #45 (0.010): 0.004*"calo" + 0.004*"can" + 0.003*"kinh_te" + 0.002*"moi_truong" + 0.002*"co_the" + 0.002*"thuc_pham" + 0.001*"khung_hoang" + 0.001*"da" + 0.001*"sprint" + 0.001*"uong"
# INFO : topic diff=4.551502, rho=0.392910
# INFO : PROGRESS: pass 3, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #49 (0.010): 0.213*"marketing" + 0.119*"sprint" + 0.093*"agile" + 0.076*"user" + 0.055*"meeting" + 0.054*"mua" + 0.052*"scrum" + 0.048*"story" + 0.026*"tiep_thi" + 0.025*"planning"
# INFO : topic #22 (0.010): 0.001*"da" + 0.000*"lan" + 0.000*"skincare" + 0.000*"cham_soc" + 0.000*"duong" + 0.000*"mat" + 0.000*"nang" + 0.000*"am" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #16 (0.010): 0.240*"ao" + 0.122*"vr" + 0.041*"thiet_bi" + 0.033*"san_xuat" + 0.024*"tich_hop" + 0.024*"thuc" + 0.024*"nen_tang" + 0.021*"he_thong" + 0.020*"the_gioi" + 0.020*"doanh_nghiep"
# INFO : topic #46 (0.010): 0.054*"cong_nghe" + 0.039*"nhan_tao" + 0.034*"con_nguoi" + 0.031*"thong_minh" + 0.031*"tri_tue" + 0.023*"he_thong" + 0.021*"kha_nang" + 0.017*"may" + 0.014*"nghien_cuu" + 0.013*"may_tinh"
# INFO : topic #47 (0.010): 0.001*"moi_truong" + 0.001*"o_nhiem" + 0.001*"bao_ve" + 0.000*"kinh_te" + 0.000*"he_thong" + 0.000*"khu" + 0.000*"thong_minh" + 0.000*"khung_hoang" + 0.000*"con_nguoi" + 0.000*"y_thuc"
# INFO : topic diff=3.562716, rho=0.392910
# INFO : -36.873 per-word bound, 125837645229.1 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 3, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #26 (0.010): 0.001*"kinh_te" + 0.001*"khung_hoang" + 0.001*"thong_minh" + 0.000*"du_lich" + 0.000*"ve" + 0.000*"calo" + 0.000*"thuc_pham" + 0.000*"the_gioi" + 0.000*"lua_chon" + 0.000*"suy_thoai"
# INFO : topic #38 (0.010): 0.105*"react" + 0.053*"con_so" + 0.033*"chu_đao" + 0.030*"loi" + 0.018*"luu_y" + 0.017*"lien_tuc" + 0.017*"song" + 0.016*"code" + 0.015*"goi" + 0.015*"du_lieu"
# INFO : topic #32 (0.010): 0.038*"tu_đong" + 0.031*"ung_dung" + 0.031*"du_lieu" + 0.028*"ket_noi" + 0.023*"smartphone" + 0.019*"khoi" + 0.018*"tuong_tac" + 0.017*"hoc" + 0.017*"đoan" + 0.015*"san_pham"
# INFO : topic #47 (0.010): 0.001*"moi_truong" + 0.000*"o_nhiem" + 0.000*"bao_ve" + 0.000*"kinh_te" + 0.000*"he_thong" + 0.000*"khu" + 0.000*"thong_minh" + 0.000*"khung_hoang" + 0.000*"con_nguoi" + 0.000*"y_thuc"
# INFO : topic #23 (0.010): 0.121*"ngu" + 0.072*"giac_ngu" + 0.037*"co_the" + 0.033*"thuoc" + 0.023*"suc_khoe" + 0.022*"đieu_tri" + 0.020*"ngon" + 0.019*"nao" + 0.018*"benh" + 0.016*"chua"
# INFO : topic diff=2.792742, rho=0.392910
# INFO : PROGRESS: pass 4, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #23 (0.010): 0.102*"ngu" + 0.058*"giac_ngu" + 0.041*"co_the" + 0.033*"suc_khoe" + 0.026*"thuoc" + 0.020*"benh" + 0.020*"ngon" + 0.018*"đieu_tri" + 0.018*"nao" + 0.016*"chat_luong"
# INFO : topic #51 (0.010): 0.293*"ts" + 0.183*"chu_ky" + 0.148*"nguyen" + 0.059*"kien" + 0.049*"nhan_đinh" + 0.034*"cuoc_chien" + 0.028*"nong" + 0.020*"vien_truong" + 0.015*"nam" + 0.003*"tai_co_cau"
# INFO : topic #24 (0.010): 0.062*"đau_tu" + 0.038*"đong_tien" + 0.034*"vay" + 0.033*"lao" + 0.032*"usd" + 0.032*"tien" + 0.028*"pho_chu_tich" + 0.028*"gia" + 0.025*"cong_ty" + 0.022*"san"
# INFO : topic #5 (0.010): 0.039*"song" + 0.024*"xanh" + 0.019*"loi" + 0.017*"the_hien" + 0.014*"than" + 0.014*"suc_khoe" + 0.013*"hien_đai" + 0.013*"cuoc_song" + 0.012*"hut" + 0.011*"muoi"
# INFO : topic #3 (0.010): 0.301*"material" + 0.291*"design" + 0.091*"google" + 0.046*"css" + 0.027*"github" + 0.001*"bootstrap" + 0.001*"thanh_phan" + 0.000*"cung_cap" + 0.000*"thiet_ke" + 0.000*"web"
# INFO : topic diff=2.097487, rho=0.365695
# INFO : PROGRESS: pass 4, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #32 (0.010): 0.054*"tu_đong" + 0.032*"ung_dung" + 0.030*"ket_noi" + 0.029*"du_lieu" + 0.023*"hoc" + 0.021*"hoa" + 0.019*"mang" + 0.016*"khoi" + 0.015*"đoan" + 0.014*"cap_nhat"
# INFO : topic #9 (0.010): 0.264*"da" + 0.069*"skincare" + 0.053*"cham_soc" + 0.052*"mat" + 0.048*"lan" + 0.045*"kem" + 0.034*"duong" + 0.027*"rua" + 0.026*"quy_trinh" + 0.025*"nang"
# INFO : topic #31 (0.010): 0.001*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic #38 (0.010): 0.074*"con_so" + 0.061*"chu_đao" + 0.043*"react" + 0.030*"loi" + 0.027*"song" + 0.019*"backend" + 0.014*"yeu_to" + 0.014*"goi" + 0.014*"frontend" + 0.013*"lanh_manh"
# INFO : topic #0 (0.010): 0.201*"user" + 0.165*"stories" + 0.115*"nhac_nho" + 0.044*"marketer" + 0.037*"liet_ke" + 0.028*"good" + 0.027*"me" + 0.020*"cot" + 0.016*"chim" + 0.012*"role"
# INFO : topic diff=1.595915, rho=0.365695
# INFO : -36.811 per-word bound, 120547374331.9 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 4, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #11 (0.010): 0.000*"agile" + 0.000*"ta" + 0.000*"moi_truong" + 0.000*"du_an" + 0.000*"thong_minh" + 0.000*"khach_hang" + 0.000*"quan_ly" + 0.000*"da" + 0.000*"he_thong" + 0.000*"bao_ve"
# INFO : topic #26 (0.010): 0.000*"kinh_te" + 0.000*"khung_hoang" + 0.000*"thong_minh" + 0.000*"du_lich" + 0.000*"ve" + 0.000*"calo" + 0.000*"thuc_pham" + 0.000*"the_gioi" + 0.000*"lua_chon" + 0.000*"suy_thoai"
# INFO : topic #7 (0.010): 0.037*"phong" + 0.032*"thue" + 0.031*"tro" + 0.021*"van_hoa" + 0.018*"xe" + 0.017*"gia" + 0.015*"bac" + 0.013*"đuong" + 0.012*"mua" + 0.012*"tien"
# INFO : topic #31 (0.010): 0.001*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic #17 (0.010): 0.115*"da" + 0.082*"san_pham" + 0.038*"sach" + 0.037*"am" + 0.029*"lan" + 0.028*"duong" + 0.022*"dau" + 0.021*"bui" + 0.019*"so_huu" + 0.018*"lua_chon"
# INFO : topic diff=1.259103, rho=0.365695
# INFO : PROGRESS: pass 5, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #55 (0.010): 0.109*"ngon_ngu" + 0.071*"ung_dung" + 0.070*"lap_trinh" + 0.028*"pho_bien" + 0.023*"java" + 0.021*"lap_trinh_vien" + 0.016*"chuong_trinh" + 0.016*"phan_mem" + 0.015*"javascript" + 0.015*"php"
# INFO : topic #29 (0.010): 0.117*"ta" + 0.112*"phu_nu" + 0.107*"co" + 0.077*"mac" + 0.059*"mau" + 0.058*"vat" + 0.028*"ngu" + 0.023*"vua" + 0.020*"cham" + 0.019*"nghien_cuu"
# INFO : topic #5 (0.010): 0.038*"song" + 0.022*"xanh" + 0.018*"loi" + 0.018*"the_hien" + 0.015*"than" + 0.014*"hien_đai" + 0.013*"suc_khoe" + 0.013*"bui" + 0.013*"cuoc_song" + 0.012*"hut"
# INFO : topic #41 (0.010): 0.317*"may" + 0.307*"loc" + 0.224*"khong_khi" + 0.024*"trong_lanh" + 0.018*"kha_nang" + 0.013*"o_nhiem" + 0.011*"xuat" + 0.010*"khu" + 0.006*"moi_truong" + 0.006*"my"
# INFO : topic #3 (0.010): 0.297*"material" + 0.289*"design" + 0.097*"google" + 0.049*"css" + 0.027*"github" + 0.000*"bootstrap" + 0.000*"thanh_phan" + 0.000*"cung_cap" + 0.000*"thiet_ke" + 0.000*"web"
# INFO : topic diff=1.015543, rho=0.343450
# INFO : PROGRESS: pass 5, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #39 (0.010): 0.086*"kinh_te" + 0.039*"khung_hoang" + 0.022*"thi_truong" + 0.020*"suy_thoai" + 0.018*"tai_chinh" + 0.017*"the_gioi" + 0.016*"ngan_hang" + 0.014*"my" + 0.012*"giai_đoan" + 0.012*"toan_cau"
# INFO : topic #11 (0.010): 0.000*"agile" + 0.000*"ta" + 0.000*"moi_truong" + 0.000*"du_an" + 0.000*"thong_minh" + 0.000*"khach_hang" + 0.000*"quan_ly" + 0.000*"da" + 0.000*"he_thong" + 0.000*"bao_ve"
# INFO : topic #40 (0.010): 0.652*"tay" + 0.177*"mu" + 0.000*"da" + 0.000*"du_lich" + 0.000*"duong" + 0.000*"mat" + 0.000*"chet" + 0.000*"lan" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #19 (0.010): 0.047*"tang_truong" + 0.036*"kinh" + 0.035*"the_gioi" + 0.022*"oto" + 0.022*"cham" + 0.020*"du_bao" + 0.020*"đay" + 0.020*"trang_thai" + 0.019*"anh_huong" + 0.017*"nguy_co"
# INFO : topic #0 (0.010): 0.208*"user" + 0.175*"stories" + 0.109*"nhac_nho" + 0.047*"marketer" + 0.038*"liet_ke" + 0.029*"good" + 0.026*"me" + 0.019*"cot" + 0.017*"role" + 0.015*"chim"
# INFO : topic diff=0.791544, rho=0.343450
# INFO : -36.759 per-word bound, 116276895951.0 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 5, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #35 (0.010): 0.109*"tien" + 0.085*"đien" + 0.074*"chi_tieu" + 0.041*"thu_nhap" + 0.033*"ve_sinh" + 0.028*"an_ninh" + 0.025*"app" + 0.025*"hop_ly" + 0.023*"gia_ca" + 0.022*"tuan"
# INFO : topic #30 (0.010): 0.066*"khoi_nghiep" + 0.062*"kinh_doanh" + 0.061*"tu_than" + 0.026*"huong" + 0.024*"đau_tu" + 0.023*"mao_hiem" + 0.021*"cong_ty" + 0.019*"so_huu" + 0.018*"quy" + 0.017*"mo_rong"
# INFO : topic #4 (0.010): 0.187*"mua" + 0.092*"online" + 0.082*"vu" + 0.057*"xanh" + 0.037*"mui" + 0.027*"thuong_hieu" + 0.024*"sach" + 0.024*"san_pham" + 0.022*"pm" + 0.021*"che_đo"
# INFO : topic #19 (0.010): 0.066*"kinh" + 0.047*"oto" + 0.036*"trang_thai" + 0.036*"the_gioi" + 0.033*"tang_truong" + 0.028*"đo_hoa" + 0.026*"sat" + 0.022*"anh_huong" + 0.020*"cham" + 0.017*"đau"
# INFO : topic #53 (0.010): 0.081*"project" + 0.079*"code" + 0.069*"ta" + 0.048*"ham" + 0.045*"view" + 0.043*"bat" + 0.041*"api" + 0.035*"class" + 0.030*"framework" + 0.029*"file"
# INFO : topic diff=0.657589, rho=0.343450
# INFO : PROGRESS: pass 6, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #16 (0.010): 0.278*"ao" + 0.154*"vr" + 0.046*"thiet_bi" + 0.030*"trai" + 0.025*"nen_tang" + 0.024*"the_gioi" + 0.018*"tich_hop" + 0.015*"mat" + 0.014*"thuc" + 0.013*"nam"
# INFO : topic #40 (0.010): 0.716*"tay" + 0.167*"mu" + 0.000*"da" + 0.000*"du_lich" + 0.000*"duong" + 0.000*"mat" + 0.000*"chet" + 0.000*"lan" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #23 (0.010): 0.101*"ngu" + 0.061*"giac_ngu" + 0.041*"co_the" + 0.031*"suc_khoe" + 0.027*"thuoc" + 0.021*"ngon" + 0.020*"benh" + 0.020*"đieu_tri" + 0.017*"nao" + 0.016*"chat_luong"
# INFO : topic #46 (0.010): 0.055*"cong_nghe" + 0.037*"nhan_tao" + 0.034*"thong_minh" + 0.032*"con_nguoi" + 0.031*"tri_tue" + 0.020*"he_thong" + 0.020*"kha_nang" + 0.014*"nghien_cuu" + 0.014*"nganh" + 0.014*"may"
# INFO : topic #36 (0.010): 0.042*"song" + 0.038*"cuoc_song" + 0.017*"cong_viec" + 0.016*"loi" + 0.014*"lanh_manh" + 0.013*"virtual" + 0.013*"suc_khoe" + 0.012*"thuong_xuyen" + 0.012*"y_nghia" + 0.011*"thoi_quen"
# INFO : topic diff=0.581978, rho=0.324826
# INFO : PROGRESS: pass 6, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #17 (0.010): 0.091*"da" + 0.085*"san_pham" + 0.045*"sach" + 0.038*"am" + 0.034*"bui" + 0.025*"duong" + 0.023*"lan" + 0.023*"dau" + 0.020*"lua_chon" + 0.019*"kho"
# INFO : topic #56 (0.010): 0.092*"moi_truong" + 0.042*"cong_nghiep" + 0.034*"o_nhiem" + 0.026*"bao_ve" + 0.022*"xanh" + 0.020*"san_xuat" + 0.018*"song" + 0.016*"tai_nguyen" + 0.014*"rac_thai" + 0.013*"con_nguoi"
# INFO : topic #22 (0.010): 0.000*"da" + 0.000*"lan" + 0.000*"skincare" + 0.000*"cham_soc" + 0.000*"duong" + 0.000*"mat" + 0.000*"nang" + 0.000*"am" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #11 (0.010): 0.000*"agile" + 0.000*"ta" + 0.000*"moi_truong" + 0.000*"du_an" + 0.000*"thong_minh" + 0.000*"khach_hang" + 0.000*"quan_ly" + 0.000*"da" + 0.000*"he_thong" + 0.000*"bao_ve"
# INFO : topic #45 (0.010): 0.000*"calo" + 0.000*"can" + 0.000*"kinh_te" + 0.000*"moi_truong" + 0.000*"co_the" + 0.000*"thuc_pham" + 0.000*"khung_hoang" + 0.000*"da" + 0.000*"sprint" + 0.000*"uong"
# INFO : topic diff=0.477905, rho=0.324826
# INFO : -36.721 per-word bound, 113248538917.4 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 6, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #22 (0.010): 0.000*"da" + 0.000*"lan" + 0.000*"skincare" + 0.000*"cham_soc" + 0.000*"duong" + 0.000*"mat" + 0.000*"nang" + 0.000*"am" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #32 (0.010): 0.038*"tu_đong" + 0.036*"ung_dung" + 0.033*"du_lieu" + 0.030*"ket_noi" + 0.022*"smartphone" + 0.021*"tuong_tac" + 0.020*"đoan" + 0.019*"hoa" + 0.019*"hoc" + 0.019*"đa"
# INFO : topic #1 (0.010): 0.319*"tiet_kiem" + 0.238*"tien" + 0.099*"khoan" + 0.060*"ngan_hang" + 0.030*"tai_khoan" + 0.027*"chi" + 0.025*"đau_tu" + 0.022*"gui" + 0.021*"giao_dich" + 0.017*"thanh_toan"
# INFO : topic #52 (0.010): 0.264*"calo" + 0.116*"can" + 0.073*"co_the" + 0.041*"nap" + 0.032*"protein" + 0.029*"kcal" + 0.023*"calories" + 0.022*"thuc_pham" + 0.022*"van_đong" + 0.022*"nang_luong"
# INFO : topic #35 (0.010): 0.122*"tien" + 0.079*"đien" + 0.072*"chi_tieu" + 0.041*"thu_nhap" + 0.031*"ve_sinh" + 0.026*"an_ninh" + 0.025*"hop_ly" + 0.024*"app" + 0.022*"tuan" + 0.022*"gia_ca"
# INFO : topic diff=0.420860, rho=0.324826
# INFO : PROGRESS: pass 7, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #44 (0.010): 0.000*"khoi_nghiep" + 0.000*"moi_truong" + 0.000*"nam" + 0.000*"thi_truong" + 0.000*"kinh_doanh" + 0.000*"kinh_te" + 0.000*"doanh_nghiep" + 0.000*"o_nhiem" + 0.000*"tien" + 0.000*"nguyen"
# INFO : topic #47 (0.010): 0.000*"moi_truong" + 0.000*"o_nhiem" + 0.000*"bao_ve" + 0.000*"kinh_te" + 0.000*"he_thong" + 0.000*"khu" + 0.000*"thong_minh" + 0.000*"khung_hoang" + 0.000*"con_nguoi" + 0.000*"y_thuc"
# INFO : topic #40 (0.010): 0.720*"tay" + 0.164*"mu" + 0.000*"da" + 0.000*"du_lich" + 0.000*"duong" + 0.000*"mat" + 0.000*"chet" + 0.000*"lan" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #29 (0.010): 0.120*"ta" + 0.110*"co" + 0.108*"phu_nu" + 0.078*"mac" + 0.067*"mau" + 0.056*"vat" + 0.047*"ngu" + 0.032*"hai" + 0.022*"vua" + 0.022*"ket_hop"
# INFO : topic #24 (0.010): 0.081*"đau_tu" + 0.056*"vay" + 0.043*"đong_tien" + 0.037*"tien" + 0.031*"usd" + 0.028*"lao" + 0.028*"gia" + 0.025*"pho_chu_tich" + 0.025*"cong_ty" + 0.023*"san"
# INFO : topic diff=0.400021, rho=0.308936
# INFO : PROGRESS: pass 7, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #31 (0.010): 0.000*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic #23 (0.010): 0.111*"ngu" + 0.075*"giac_ngu" + 0.036*"co_the" + 0.035*"thuoc" + 0.023*"ngon" + 0.022*"suc_khoe" + 0.022*"đieu_tri" + 0.020*"tra" + 0.019*"tri" + 0.019*"nao"
# INFO : topic #28 (0.010): 0.030*"nam" + 0.029*"xa_hoi" + 0.027*"khoa_hoc" + 0.022*"vien" + 0.016*"giao_thong" + 0.016*"chinh_phu" + 0.016*"dan" + 0.015*"viet_nam" + 0.015*"luat" + 0.015*"quan_ly"
# INFO : topic #8 (0.010): 0.194*"len_an" + 0.068*"đoan_ket" + 0.000*"do" + 0.000*"tet" + 0.000*"le" + 0.000*"đoc" + 0.000*"tieng" + 0.000*"sach" + 0.000*"khoi_nghiep" + 0.000*"ban_đoc"
# INFO : topic #40 (0.010): 0.674*"tay" + 0.170*"mu" + 0.000*"da" + 0.000*"du_lich" + 0.000*"duong" + 0.000*"mat" + 0.000*"chet" + 0.000*"lan" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic diff=0.343169, rho=0.308936
# INFO : -36.694 per-word bound, 111154985525.0 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 7, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #25 (0.010): 0.032*"khoa_hoc" + 0.031*"ung_dung" + 0.029*"hop_đong" + 0.020*"hanh_chinh" + 0.020*"so" + 0.019*"tphcm" + 0.015*"bat_đong_san" + 0.014*"doanh_nghiep" + 0.014*"chuyen_gia" + 0.013*"luc"
# INFO : topic #36 (0.010): 0.045*"cuoc_song" + 0.040*"song" + 0.017*"virtual" + 0.017*"cong_viec" + 0.016*"y_nghia" + 0.013*"loi" + 0.013*"huong" + 0.012*"thuong_xuyen" + 0.012*"uu_điem" + 0.011*"tich_cuc"
# INFO : topic #48 (0.010): 0.142*"javascript" + 0.121*"html" + 0.110*"web" + 0.071*"thu_vien" + 0.065*"trang_web" + 0.052*"giao_dien" + 0.044*"ma" + 0.040*"xay_dung" + 0.040*"js" + 0.039*"de_dang"
# INFO : topic #44 (0.010): 0.000*"khoi_nghiep" + 0.000*"moi_truong" + 0.000*"nam" + 0.000*"thi_truong" + 0.000*"kinh_doanh" + 0.000*"kinh_te" + 0.000*"doanh_nghiep" + 0.000*"o_nhiem" + 0.000*"tien" + 0.000*"nguyen"
# INFO : topic #52 (0.010): 0.264*"calo" + 0.116*"can" + 0.073*"co_the" + 0.041*"nap" + 0.031*"protein" + 0.029*"kcal" + 0.023*"nang_luong" + 0.023*"calories" + 0.022*"van_đong" + 0.021*"thuc_pham"
# INFO : topic diff=0.315674, rho=0.308936
# INFO : PROGRESS: pass 8, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #20 (0.010): 0.033*"thiet_ke" + 0.015*"kieu" + 0.015*"nghiem" + 0.015*"hinh_anh" + 0.014*"gioi_thieu" + 0.014*"khung" + 0.013*"huong_dan" + 0.012*"thiet_bi" + 0.012*"nut" + 0.012*"đieu_khien"
# INFO : topic #31 (0.010): 0.000*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic #22 (0.010): 0.000*"da" + 0.000*"lan" + 0.000*"skincare" + 0.000*"cham_soc" + 0.000*"duong" + 0.000*"mat" + 0.000*"nang" + 0.000*"am" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #19 (0.010): 0.060*"tang_truong" + 0.042*"the_gioi" + 0.039*"kinh" + 0.026*"oto" + 0.025*"cham" + 0.024*"trang_thai" + 0.021*"anh_huong" + 0.019*"sat" + 0.018*"đay" + 0.018*"đau"
# INFO : topic #2 (0.010): 0.056*"than" + 0.026*"nhan" + 0.025*"lam_viec" + 0.019*"de_dang" + 0.018*"thoi_quen" + 0.018*"ton" + 0.017*"cong_nhan" + 0.016*"cong_viec" + 0.016*"tieng" + 0.014*"ke_hoach"
# INFO : topic diff=0.313170, rho=0.295171
# INFO : PROGRESS: pass 8, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #56 (0.010): 0.094*"moi_truong" + 0.038*"cong_nghiep" + 0.034*"o_nhiem" + 0.027*"bao_ve" + 0.023*"xanh" + 0.019*"song" + 0.017*"san_xuat" + 0.016*"tai_nguyen" + 0.014*"rac_thai" + 0.012*"sinh_thai"
# INFO : topic #33 (0.010): 0.076*"mat_ngu" + 0.022*"am" + 0.020*"chua" + 0.015*"nguyen_nhan" + 0.013*"chong" + 0.011*"sau" + 0.011*"hai" + 0.010*"tam" + 0.010*"che_đo" + 0.009*"anh_sang"
# INFO : topic #41 (0.010): 0.317*"loc" + 0.297*"may" + 0.240*"khong_khi" + 0.026*"trong_lanh" + 0.024*"kha_nang" + 0.015*"o_nhiem" + 0.015*"khu" + 0.011*"xuat" + 0.008*"moi_truong" + 0.007*"long"
# INFO : topic #27 (0.010): 0.040*"san_xuat" + 0.026*"khach_hang" + 0.021*"doanh_nghiep" + 0.019*"quyet_đinh" + 0.019*"du_lieu" + 0.016*"he_thong" + 0.016*"dich_vu" + 0.016*"san_pham" + 0.015*"phan_tich" + 0.014*"quan_ly"
# INFO : topic #31 (0.010): 0.000*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic diff=0.275869, rho=0.295171
# INFO : -36.674 per-word bound, 109635902498.5 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 8, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #52 (0.010): 0.263*"calo" + 0.116*"can" + 0.073*"co_the" + 0.040*"nap" + 0.031*"protein" + 0.028*"kcal" + 0.025*"nang_luong" + 0.022*"calories" + 0.022*"van_đong" + 0.021*"thuc_pham"
# INFO : topic #40 (0.010): 0.717*"tay" + 0.185*"mu" + 0.000*"da" + 0.000*"du_lich" + 0.000*"duong" + 0.000*"mat" + 0.000*"chet" + 0.000*"lan" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #11 (0.010): 0.000*"agile" + 0.000*"ta" + 0.000*"moi_truong" + 0.000*"du_an" + 0.000*"thong_minh" + 0.000*"khach_hang" + 0.000*"quan_ly" + 0.000*"da" + 0.000*"he_thong" + 0.000*"bao_ve"
# INFO : topic #54 (0.010): 0.000*"da" + 0.000*"backend" + 0.000*"san_pham" + 0.000*"thong_minh" + 0.000*"ta" + 0.000*"kem" + 0.000*"frontend" + 0.000*"skincare" + 0.000*"du_lieu" + 0.000*"duong"
# INFO : topic #35 (0.010): 0.137*"tien" + 0.070*"đien" + 0.068*"chi_tieu" + 0.040*"thu_nhap" + 0.029*"chi_phi" + 0.028*"ve_sinh" + 0.024*"an_ninh" + 0.023*"hop_ly" + 0.022*"khu_vuc" + 0.022*"app"
# INFO : topic diff=0.260837, rho=0.295171
# INFO : PROGRESS: pass 9, at document #67/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #9 (0.010): 0.268*"da" + 0.062*"skincare" + 0.054*"lan" + 0.053*"cham_soc" + 0.049*"mat" + 0.044*"kem" + 0.037*"duong" + 0.025*"rua" + 0.024*"quy_trinh" + 0.024*"nang"
# INFO : topic #31 (0.010): 0.000*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic #32 (0.010): 0.034*"ung_dung" + 0.031*"du_lieu" + 0.030*"tu_đong" + 0.026*"ket_noi" + 0.019*"đoan" + 0.019*"đa" + 0.018*"hoc" + 0.017*"tuong_tac" + 0.017*"hoa" + 0.016*"dang"
# INFO : topic #33 (0.010): 0.044*"mat_ngu" + 0.019*"am" + 0.017*"chong" + 0.016*"chua" + 0.012*"sau" + 0.012*"hai" + 0.011*"che_đo" + 0.010*"nguyen_nhan" + 0.009*"an_kieng" + 0.009*"dang"
# INFO : topic #0 (0.010): 0.252*"user" + 0.222*"stories" + 0.054*"nhac_nho" + 0.053*"marketer" + 0.043*"liet_ke" + 0.032*"good" + 0.032*"role" + 0.021*"cot" + 0.021*"huong" + 0.018*"me"
# INFO : topic diff=0.265318, rho=0.283096
# INFO : PROGRESS: pass 9, at document #134/166
# INFO : merging changes from 67 documents into a model of 166 documents
# INFO : topic #25 (0.010): 0.026*"bat_đong_san" + 0.026*"khoa_hoc" + 0.023*"ung_dung" + 0.019*"hop_đong" + 0.018*"thi_truong" + 0.016*"doanh_nghiep" + 0.016*"chuyen_gia" + 0.015*"tin_dung" + 0.015*"so" + 0.014*"anh"
# INFO : topic #36 (0.010): 0.049*"cuoc_song" + 0.048*"song" + 0.018*"cong_viec" + 0.016*"y_nghia" + 0.015*"huong" + 0.015*"thuong_xuyen" + 0.014*"loi" + 0.012*"tich_cuc" + 0.011*"cang_thang" + 0.011*"lo_lang"
# INFO : topic #52 (0.010): 0.269*"calo" + 0.118*"can" + 0.074*"co_the" + 0.041*"nap" + 0.032*"protein" + 0.028*"kcal" + 0.026*"nang_luong" + 0.023*"calories" + 0.022*"van_đong" + 0.021*"đot"
# INFO : topic #33 (0.010): 0.076*"mat_ngu" + 0.022*"am" + 0.020*"chua" + 0.015*"nguyen_nhan" + 0.014*"chong" + 0.011*"sau" + 0.011*"hai" + 0.010*"tam" + 0.009*"anh_sang" + 0.009*"che_đo"
# INFO : topic #24 (0.010): 0.092*"đau_tu" + 0.058*"vay" + 0.039*"tien" + 0.038*"đong_tien" + 0.027*"usd" + 0.026*"cong_ty" + 0.026*"san" + 0.025*"gia" + 0.024*"lao" + 0.023*"đong"
# INFO : topic diff=0.236871, rho=0.283096
# INFO : -36.659 per-word bound, 108472630296.6 perplexity estimate based on a held-out corpus of 32 documents with 15007 words
# INFO : PROGRESS: pass 9, at document #166/166
# INFO : merging changes from 32 documents into a model of 166 documents
# INFO : topic #16 (0.010): 0.279*"ao" + 0.169*"vr" + 0.049*"thiet_bi" + 0.048*"trai" + 0.026*"the_gioi" + 0.022*"nen_tang" + 0.019*"mat" + 0.018*"tich_hop" + 0.016*"nam" + 0.013*"phan_mem"
# INFO : topic #13 (0.010): 0.000*"khoi_nghiep" + 0.000*"moi_truong" + 0.000*"kinh_doanh" + 0.000*"y_tuong" + 0.000*"tien" + 0.000*"suc_khoe" + 0.000*"muc_tieu" + 0.000*"lam_viec" + 0.000*"thanh_cong" + 0.000*"đung"
# INFO : topic #46 (0.010): 0.073*"cong_nghe" + 0.044*"nhan_tao" + 0.036*"tri_tue" + 0.035*"con_nguoi" + 0.028*"thong_minh" + 0.022*"he_thong" + 0.021*"kha_nang" + 0.017*"nganh" + 0.014*"nghien_cuu" + 0.013*"may_tinh"
# INFO : topic #9 (0.010): 0.266*"da" + 0.060*"skincare" + 0.054*"lan" + 0.052*"cham_soc" + 0.048*"mat" + 0.044*"kem" + 0.036*"duong" + 0.026*"rua" + 0.024*"quy_trinh" + 0.024*"nang"
# INFO : topic #31 (0.010): 0.000*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic diff=0.227710, rho=0.283096
# INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=4138, num_topics=57, decay=0.5, chunksize=67> in 15.18s', 'datetime': '2023-01-01T08:28:22.771695', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %%
from gensim.models.coherencemodel import CoherenceModel

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)
coherence_model_lda = CoherenceModel(model=lda_model, texts=sentences, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# INFO : using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# INFO : 1 batches submitted to accumulate stats from 64 documents (25378 virtual)
# INFO : 2 batches submitted to accumulate stats from 128 documents (49615 virtual)
# INFO : 3 batches submitted to accumulate stats from 192 documents (72920 virtual)
# INFO : 7 accumulators retrieved from output queue
# INFO : accumulated word occurrence stats for 72973 virtual documents
# Coherence Score:  0.49037017168042835

# %%
import gensim
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
print('\nPerplexity: ', lda_model.log_perplexity(corpus))
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 166 documents, 4138 features, 35081 non-zero entries
# INFO : -20.993 per-word bound, 2086841.5 perplexity estimate based on a held-out corpus of 166 documents with 78387 words
# Perplexity:  -20.992889596594793

# %%
lda_model.save('../models/LDA.model')
lda_model.print_topics()
# Out:
# INFO : LdaState lifecycle event {'fname_or_handle': '../models/LDA.model.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-01-01T08:29:11.396770', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/LDA.model.state
# INFO : LdaModel lifecycle event {'fname_or_handle': '../models/LDA.model', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['id2word', 'dispatcher', 'state'], 'datetime': '2023-01-01T08:29:11.430773', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : storing np array 'expElogbeta' to ../models/LDA.model.expElogbeta.npy
# INFO : not storing attribute id2word
# INFO : not storing attribute dispatcher
# INFO : not storing attribute state
# INFO : saved ../models/LDA.model
# INFO : topic #0 (0.010): 0.199*"user" + 0.175*"stories" + 0.088*"nhac_nho" + 0.042*"marketer" + 0.034*"liet_ke" + 0.025*"good" + 0.025*"role" + 0.022*"me" + 0.017*"cot" + 0.017*"huong"
# INFO : topic #10 (0.010): 0.000*"ung_dung" + 0.000*"swift" + 0.000*"thong_minh" + 0.000*"du_lich" + 0.000*"ngon_ngu" + 0.000*"thiet_ke" + 0.000*"chuyen" + 0.000*"trang_web" + 0.000*"mo_hinh" + 0.000*"xay_dung"
# INFO : topic #15 (0.010): 0.000*"khoi_nghiep" + 0.000*"kinh_doanh" + 0.000*"da" + 0.000*"kinh_te" + 0.000*"đau_tu" + 0.000*"the_gioi" + 0.000*"huong" + 0.000*"cong_ty" + 0.000*"lan" + 0.000*"thi_truong"
# INFO : topic #56 (0.010): 0.093*"moi_truong" + 0.032*"o_nhiem" + 0.032*"cong_nghiep" + 0.026*"bao_ve" + 0.022*"xanh" + 0.019*"song" + 0.017*"tai_nguyen" + 0.016*"san_xuat" + 0.014*"rac_thai" + 0.014*"sinh_thai"
# INFO : topic #13 (0.010): 0.000*"khoi_nghiep" + 0.000*"moi_truong" + 0.000*"kinh_doanh" + 0.000*"y_tuong" + 0.000*"tien" + 0.000*"suc_khoe" + 0.000*"muc_tieu" + 0.000*"lam_viec" + 0.000*"thanh_cong" + 0.000*"đung"
# INFO : topic #31 (0.010): 0.000*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"
# INFO : topic #2 (0.010): 0.065*"than" + 0.030*"nhan" + 0.025*"lam_viec" + 0.020*"de_dang" + 0.019*"ton" + 0.019*"thoi_quen" + 0.018*"cong_viec" + 0.016*"kenh" + 0.016*"cong_nhan" + 0.016*"tieng"
# INFO : topic #48 (0.010): 0.138*"javascript" + 0.115*"html" + 0.111*"web" + 0.069*"thu_vien" + 0.064*"trang_web" + 0.050*"giao_dien" + 0.048*"de_dang" + 0.043*"ma" + 0.041*"xay_dung" + 0.040*"đon_gian"
# INFO : topic #9 (0.010): 0.266*"da" + 0.060*"skincare" + 0.054*"lan" + 0.052*"cham_soc" + 0.048*"mat" + 0.044*"kem" + 0.036*"duong" + 0.026*"rua" + 0.024*"quy_trinh" + 0.024*"nang"
# INFO : topic #11 (0.010): 0.000*"agile" + 0.000*"ta" + 0.000*"moi_truong" + 0.000*"du_an" + 0.000*"thong_minh" + 0.000*"khach_hang" + 0.000*"quan_ly" + 0.000*"da" + 0.000*"he_thong" + 0.000*"bao_ve"
# INFO : topic #28 (0.010): 0.032*"nam" + 0.031*"khoa_hoc" + 0.029*"xa_hoi" + 0.029*"vien" + 0.021*"giao_thong" + 0.019*"chinh_phu" + 0.019*"luat" + 0.018*"đuong" + 0.017*"dan" + 0.016*"tham_gia"
# INFO : topic #30 (0.010): 0.062*"kinh_doanh" + 0.061*"khoi_nghiep" + 0.050*"tu_than" + 0.027*"huong" + 0.027*"đau_tu" + 0.022*"mao_hiem" + 0.021*"cong_ty" + 0.020*"so_huu" + 0.019*"quy" + 0.018*"mo_rong"
# INFO : topic #51 (0.010): 0.273*"nguyen" + 0.258*"ts" + 0.149*"chu_ky" + 0.054*"kien" + 0.049*"nam" + 0.043*"nhan_đinh" + 0.023*"nong" + 0.016*"vien_truong" + 0.009*"cuoc_chien" + 0.000*"tai_co_cau"
# INFO : topic #47 (0.010): 0.000*"moi_truong" + 0.000*"o_nhiem" + 0.000*"bao_ve" + 0.000*"kinh_te" + 0.000*"he_thong" + 0.000*"khu" + 0.000*"thong_minh" + 0.000*"khung_hoang" + 0.000*"con_nguoi" + 0.000*"y_thuc"
# INFO : topic #5 (0.010): 0.024*"than" + 0.023*"song" + 0.023*"the_hien" + 0.021*"le" + 0.021*"bui" + 0.016*"hien_đai" + 0.015*"hinh_thanh" + 0.014*"hoa" + 0.013*"hut" + 0.013*"xanh"
# INFO : topic #22 (0.010): 0.000*"da" + 0.000*"lan" + 0.000*"skincare" + 0.000*"cham_soc" + 0.000*"duong" + 0.000*"mat" + 0.000*"nang" + 0.000*"am" + 0.000*"kem" + 0.000*"san_pham"
# INFO : topic #8 (0.010): 0.276*"len_an" + 0.045*"đoan_ket" + 0.000*"do" + 0.000*"tet" + 0.000*"le" + 0.000*"đoc" + 0.000*"tieng" + 0.000*"sach" + 0.000*"khoi_nghiep" + 0.000*"ban_đoc"
# INFO : topic #24 (0.010): 0.092*"vay" + 0.084*"đau_tu" + 0.041*"pho_chu_tich" + 0.039*"lao" + 0.038*"usd" + 0.036*"tien" + 0.034*"đong_tien" + 0.023*"đong" + 0.023*"gia" + 0.022*"cong_ty"
# INFO : topic #55 (0.010): 0.089*"ung_dung" + 0.086*"ngon_ngu" + 0.057*"lap_trinh" + 0.029*"pho_bien" + 0.023*"facebook" + 0.022*"ra_đoi" + 0.020*"lap_trinh_vien" + 0.019*"chuong_trinh" + 0.018*"toc_đo" + 0.018*"windows"
# INFO : topic #6 (0.010): 0.219*"du_bao" + 0.131*"trat_tu" + 0.081*"lai_suat" + 0.060*"imf" + 0.043*"fed" + 0.042*"trung_uong" + 0.030*"đay" + 0.026*"tien_te" + 0.018*"bo" + 0.017*"euro"
# [(0,
#   '0.199*"user" + 0.175*"stories" + 0.088*"nhac_nho" + 0.042*"marketer" + 0.034*"liet_ke" + 0.025*"good" + 0.025*"role" + 0.022*"me" + 0.017*"cot" + 0.017*"huong"'),
#  (10,
#   '0.000*"ung_dung" + 0.000*"swift" + 0.000*"thong_minh" + 0.000*"du_lich" + 0.000*"ngon_ngu" + 0.000*"thiet_ke" + 0.000*"chuyen" + 0.000*"trang_web" + 0.000*"mo_hinh" + 0.000*"xay_dung"'),
#  (15,
#   '0.000*"khoi_nghiep" + 0.000*"kinh_doanh" + 0.000*"da" + 0.000*"kinh_te" + 0.000*"đau_tu" + 0.000*"the_gioi" + 0.000*"huong" + 0.000*"cong_ty" + 0.000*"lan" + 0.000*"thi_truong"'),
#  (56,
#   '0.093*"moi_truong" + 0.032*"o_nhiem" + 0.032*"cong_nghiep" + 0.026*"bao_ve" + 0.022*"xanh" + 0.019*"song" + 0.017*"tai_nguyen" + 0.016*"san_xuat" + 0.014*"rac_thai" + 0.014*"sinh_thai"'),
#  (13,
#   '0.000*"khoi_nghiep" + 0.000*"moi_truong" + 0.000*"kinh_doanh" + 0.000*"y_tuong" + 0.000*"tien" + 0.000*"suc_khoe" + 0.000*"muc_tieu" + 0.000*"lam_viec" + 0.000*"thanh_cong" + 0.000*"đung"'),
#  (31,
#   '0.000*"da" + 0.000*"skincare" + 0.000*"duong" + 0.000*"san_pham" + 0.000*"ngon_ngu" + 0.000*"cham_soc" + 0.000*"kem" + 0.000*"lan" + 0.000*"mat" + 0.000*"am"'),
#  (2,
#   '0.065*"than" + 0.030*"nhan" + 0.025*"lam_viec" + 0.020*"de_dang" + 0.019*"ton" + 0.019*"thoi_quen" + 0.018*"cong_viec" + 0.016*"kenh" + 0.016*"cong_nhan" + 0.016*"tieng"'),
#  (48,
#   '0.138*"javascript" + 0.115*"html" + 0.111*"web" + 0.069*"thu_vien" + 0.064*"trang_web" + 0.050*"giao_dien" + 0.048*"de_dang" + 0.043*"ma" + 0.041*"xay_dung" + 0.040*"đon_gian"'),
#  (9,
#   '0.266*"da" + 0.060*"skincare" + 0.054*"lan" + 0.052*"cham_soc" + 0.048*"mat" + 0.044*"kem" + 0.036*"duong" + 0.026*"rua" + 0.024*"quy_trinh" + 0.024*"nang"'),
#  (11,
#   '0.000*"agile" + 0.000*"ta" + 0.000*"moi_truong" + 0.000*"du_an" + 0.000*"thong_minh" + 0.000*"khach_hang" + 0.000*"quan_ly" + 0.000*"da" + 0.000*"he_thong" + 0.000*"bao_ve"'),
#  (28,
#   '0.032*"nam" + 0.031*"khoa_hoc" + 0.029*"xa_hoi" + 0.029*"vien" + 0.021*"giao_thong" + 0.019*"chinh_phu" + 0.019*"luat" + 0.018*"đuong" + 0.017*"dan" + 0.016*"tham_gia"'),
#  (30,
#   '0.062*"kinh_doanh" + 0.061*"khoi_nghiep" + 0.050*"tu_than" + 0.027*"huong" + 0.027*"đau_tu" + 0.022*"mao_hiem" + 0.021*"cong_ty" + 0.020*"so_huu" + 0.019*"quy" + 0.018*"mo_rong"'),
#  (51,
#   '0.273*"nguyen" + 0.258*"ts" + 0.149*"chu_ky" + 0.054*"kien" + 0.049*"nam" + 0.043*"nhan_đinh" + 0.023*"nong" + 0.016*"vien_truong" + 0.009*"cuoc_chien" + 0.000*"tai_co_cau"'),
#  (47,
#   '0.000*"moi_truong" + 0.000*"o_nhiem" + 0.000*"bao_ve" + 0.000*"kinh_te" + 0.000*"he_thong" + 0.000*"khu" + 0.000*"thong_minh" + 0.000*"khung_hoang" + 0.000*"con_nguoi" + 0.000*"y_thuc"'),
#  (5,
#   '0.024*"than" + 0.023*"song" + 0.023*"the_hien" + 0.021*"le" + 0.021*"bui" + 0.016*"hien_đai" + 0.015*"hinh_thanh" + 0.014*"hoa" + 0.013*"hut" + 0.013*"xanh"'),
#  (22,
#   '0.000*"da" + 0.000*"lan" + 0.000*"skincare" + 0.000*"cham_soc" + 0.000*"duong" + 0.000*"mat" + 0.000*"nang" + 0.000*"am" + 0.000*"kem" + 0.000*"san_pham"'),
#  (8,
#   '0.276*"len_an" + 0.045*"đoan_ket" + 0.000*"do" + 0.000*"tet" + 0.000*"le" + 0.000*"đoc" + 0.000*"tieng" + 0.000*"sach" + 0.000*"khoi_nghiep" + 0.000*"ban_đoc"'),
#  (24,
#   '0.092*"vay" + 0.084*"đau_tu" + 0.041*"pho_chu_tich" + 0.039*"lao" + 0.038*"usd" + 0.036*"tien" + 0.034*"đong_tien" + 0.023*"đong" + 0.023*"gia" + 0.022*"cong_ty"'),
#  (55,
#   '0.089*"ung_dung" + 0.086*"ngon_ngu" + 0.057*"lap_trinh" + 0.029*"pho_bien" + 0.023*"facebook" + 0.022*"ra_đoi" + 0.020*"lap_trinh_vien" + 0.019*"chuong_trinh" + 0.018*"toc_đo" + 0.018*"windows"'),
#  (6,
#   '0.219*"du_bao" + 0.131*"trat_tu" + 0.081*"lai_suat" + 0.060*"imf" + 0.043*"fed" + 0.042*"trung_uong" + 0.030*"đay" + 0.026*"tien_te" + 0.018*"bo" + 0.017*"euro"')]

# %%
import numpy as np
from gensim import similarities

doc_topic_dist = np.array(
    [[tup[1] for tup in lst] for lst in lda_model[corpus]]
)
index = similarities.MatrixSimilarity(lda_model[corpus])
# Out:
# WARNING : scanning corpus to determine the number of features (consider setting `num_features` explicitly)
# INFO : creating matrix with 166 documents and 57 features

# %%
doc_topic_dist
# Out:
# array([[9.6513622e-06, 1.9529607e-03, 9.6513622e-06, ..., 9.6513622e-06,
#         5.5283848e-02, 9.6513622e-06],
#        [4.0562365e-05, 4.0562365e-05, 4.0562365e-05, ..., 4.0562365e-05,
#         9.3020992e-03, 4.0562365e-05],
#        [3.3616550e-05, 3.3616550e-05, 3.3616550e-05, ..., 3.3616550e-05,
#         1.0988716e-01, 3.3616550e-05],
#        ...,
#        [2.8207336e-05, 2.8207336e-05, 2.8207336e-05, ..., 2.8207336e-05,
#         5.1376913e-02, 2.8207336e-05],
#        [6.6876208e-05, 6.6876208e-05, 6.6876208e-05, ..., 6.6876208e-05,
#         6.6876208e-05, 9.0271495e-02],
#        [2.7892875e-05, 2.7892875e-05, 2.7892875e-05, ..., 2.7892875e-05,
#         5.0065722e-02, 2.7892875e-05]], dtype=float32)

# %%
index.save('../models/matrixSimilarity.index')
# Out:
# INFO : MatrixSimilarity lifecycle event {'fname_or_handle': '../models/matrixSimilarity.index', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-01-01T08:29:15.590477', 'gensim': '4.2.0', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO : saved ../models/matrixSimilarity.index

# %%
doc_topic_dist.shape
# Out:
# (166, 57)

# %%
import joblib

# %%
joblib.dump(doc_topic_dist, '../models/doc_topic_dist.dat')
# Out:
# ['../models/doc_topic_dist.dat']

# %%
from gensim.models.coherencemodel import CoherenceModel

# %%
import gensim
corpus = gensim.corpora.MmCorpus('../models/corpus.mm')
print('\nPerplexity: ', lda_model.log_perplexity(corpus))
# Out:
# INFO : loaded corpus index from ../models/corpus.mm.index
# INFO : initializing cython corpus reader from ../models/corpus.mm
# INFO : accepted corpus with 166 documents, 4138 features, 35081 non-zero entries
# INFO : -20.993 per-word bound, 2086794.1 perplexity estimate based on a held-out corpus of 166 documents with 78387 words
# Perplexity:  -20.992856835397987

# %%
sentences = make_sentences()
sentences = make_texts_corpus(sentences)

# %%
coherence_model_lda = CoherenceModel(model=lda_model, texts=sentences, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# INFO : using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# INFO : 1 batches submitted to accumulate stats from 64 documents (25378 virtual)
# INFO : 2 batches submitted to accumulate stats from 128 documents (49615 virtual)
# INFO : 3 batches submitted to accumulate stats from 192 documents (72920 virtual)
# INFO : 7 accumulators retrieved from output queue
# INFO : accumulated word occurrence stats for 72973 virtual documents
# Coherence Score:  0.49037017168042835
